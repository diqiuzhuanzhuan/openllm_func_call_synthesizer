# %%
# 将 model_function_call 字段中的单引号转换为双引号
import ast
import json

def convert_single_quotes_to_double_quotes(data_string):
    """
    将字符串中的单引号转换为双引号，使其成为有效的JSON格式
    
    参数:
        data_string: 包含单引号的字符串
    
    返回:
        转换后的JSON字符串
    """
    try:
        # 使用 ast.literal_eval 安全地解析Python字面量字符串
        parsed_data = ast.literal_eval(data_string)
        # 使用 json.dumps 将其转换为标准JSON格式（双引号）
        return json.dumps(parsed_data, ensure_ascii=False)
    except (ValueError, SyntaxError) as e:
        print(f"解析失败: {e}")
        return data_string

# 示例使用
sample_string = "[{'model': 'claude-sonnet-4', 'function_call': '{\"name\": \"music_settings_control\", \"arguments\": {\"auto_stop_time\": 15}}'}, {'model': 'gemini-2.5', 'function_call': '{\"name\": \"music_settings_control\", \"arguments\": {\"auto_stop_time\": 15}}'}, {'model': 'gpt-4o', 'function_call': '{\"name\": \"music_settings_control\", \"arguments\": {\"auto_stop_time\": 15}}'}, {'model': 'qwen3-4b-2507', 'function_call': '{\"name\": \"music_play_control\", \"arguments\": {\"title\": \"any_music_content\", \"type\": \"song\", \"source\": \"recent\", \"play_mode\": \"normal\"}}'}]"

converted_string = convert_single_quotes_to_double_quotes(sample_string)
print("原始字符串:")
print(sample_string)
print("\n转换后的字符串:")
print(converted_string)
# Out:
# 原始字符串:
# [{'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}, {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}, {'model': 'gpt-4o', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}, {'model': 'qwen3-4b-2507', 'function_call': '{"name": "music_play_control", "arguments": {"title": "any_music_content", "type": "song", "source": "recent", "play_mode": "normal"}}'}]
#
# 转换后的字符串:
# [{"model": "claude-sonnet-4", "function_call": "{\"name\": \"music_settings_control\", \"arguments\": {\"auto_stop_time\": 15}}"}, {"model": "gemini-2.5", "function_call": "{\"name\": \"music_settings_control\", \"arguments\": {\"auto_stop_time\": 15}}"}, {"model": "gpt-4o", "function_call": "{\"name\": \"music_settings_control\", \"arguments\": {\"auto_stop_time\": 15}}"}, {"model": "qwen3-4b-2507", "function_call": "{\"name\": \"music_play_control\", \"arguments\": {\"title\": \"any_music_content\", \"type\": \"song\", \"source\": \"recent\", \"play_mode\": \"normal\"}}"}]

# %%
# Out:
# 8192

# %%
# 对DataFrame中的model_function_call列应用转换
# 假设你的DataFrame叫做df，并且有model_function_call列

# 方法1: 对单个值进行转换
if 'df' in globals():
    # 转换单个值
    original_value = df.iloc[1]['model_function_call']
    converted_value = convert_single_quotes_to_double_quotes(original_value)
    
    print("原始值:")
    print(original_value)
    print("\n转换后的值:")
    print(converted_value)
    
    # 方法2: 对整列进行批量转换
    print("\n" + "="*50)
    print("批量转换整列:")
    
    # 创建新列存储转换后的结果
    df['model_function_call_json'] = df['model_function_call'].apply(convert_single_quotes_to_double_quotes)
    
    # 或者直接替换原列
    # df['model_function_call'] = df['model_function_call'].apply(convert_single_quotes_to_double_quotes)
    
    print("转换完成！")
    print(f"转换了 {len(df)} 行数据")
else:
    print("未找到DataFrame 'df'，请先加载数据")

# %%
# 验证转换结果
if 'df' in globals() and 'model_function_call_json' in df.columns:
    print("验证转换结果:")
    print("="*50)
    
    # 查看转换前后的对比
    sample_row = 1
    original = df.iloc[sample_row]['model_function_call']
    converted = df.iloc[sample_row]['model_function_call_json']
    
    print("原始数据 (单引号):")
    print(original[:200] + "..." if len(original) > 200 else original)
    
    print("\n转换后数据 (双引号):")
    print(converted[:200] + "..." if len(converted) > 200 else converted)
    
    # 验证转换后的数据可以被正确解析为JSON
    try:
        parsed_json = json.loads(converted)
        print(f"\n✅ JSON解析成功！解析出 {len(parsed_json)} 个模型结果")
        
        # 显示第一个模型的结果
        if parsed_json:
            first_model = parsed_json[0]
            print(f"\n第一个模型: {first_model['model']}")
            print(f"函数调用: {first_model['function_call']}")
            
            # 进一步解析function_call
            function_call_json = json.loads(first_model['function_call'])
            print(f"函数名: {function_call_json['name']}")
            print(f"参数: {function_call_json['arguments']}")
            
    except json.JSONDecodeError as e:
        print(f"❌ JSON解析失败: {e}")
else:
    print("请先运行上面的转换代码")

# %%
#!/usr/bin/env python
# coding: utf-8

import pandas as pd
# from read_file_util import read_excel

import pandas as pd
import requests
import json
import time

# %%
# from typing import List, Dict, Any
# from collections import Counter

# def vote_for_field_values(values: List[Any], weights: List[int]) -> Any:
#     """
#     对字段值进行加权投票
    
#     参数:
#         values: 字段值列表
#         weights: 对应的权重列表
    
#     返回:
#         票数最高的值
#     """
#     counter = {}
#     for value, weight in zip(values, weights):
#         if value in counter:
#             counter[value] += weight
#         else:
#             counter[value] = weight
    
#     print(f"字段值投票: {dict(counter)}")
    
#     # 找出最高票数的值
#     max_score = max(counter.values())
#     # 如果有多个值票数相同，选择第一个出现的
#     for value in values:
#         if counter[value] == max_score:
#             return value

# def vote_for_nested_dict(dicts: List[Dict], weights: List[int]) -> Dict:
#     """
#     对嵌套字典的每个字段进行投票
    
#     参数:
#         dicts: 字典列表
#         weights: 对应的权重列表
    
#     返回:
#         投票后的字典
#     """
#     if not dicts:
#         return {}
    
#     result = {}
    
#     # 获取所有可能的键
#     all_keys = set()
#     for d in dicts:
#         all_keys.update(d.keys())
    
#     for key in all_keys:
#         values = []
#         current_weights = []
        
#         for d, weight in zip(dicts, weights):
#             if key in d:
#                 values.append(d[key])
#                 current_weights.append(weight)
        
#         if values:
#             print(f"\n处理字段 '{key}': {values}")
#             # 如果值是字典，递归处理
#             if isinstance(values[0], dict):
#                 result[key] = vote_for_nested_dict(values, current_weights)
#                 # print('-------------dict  result[key]--------------', result[key])
#             else:
#                 result[key] = vote_for_field_values(values, current_weights)
#                 # print('-------------list result[key]--------------', result[key])
    
#     return result

# def vote_for_ground_truth(model_a: List[Dict], model_b: List[Dict], model_c: List[Dict]) -> List[Dict]:
#     """
#     对三个模型的结果进行加权投票，对每个字典的每个字段分别投票。
    
#     参数:
#         model_a, model_b, model_c: 每个模型输出的字典列表
    
#     返回:
#         一个列表，包含每个位置上投票后的字典
#     """
#     results = []
#     weights = [1, 2, 1]  # model_a, model_b, model_c 的权重
    
#     # 确定最大长度
#     max_length = max(len(model_a), len(model_b), len(model_c))
    
#     for i in range(max_length):
#         print(f"\n=== 处理位置 {i} ===")
#         current_dicts = []
#         current_weights = []
        
#         # 收集当前位置的字典
#         if i < len(model_a):
#             current_dicts.append(model_a[i])
#             current_weights.append(weights[0])
#             print(f"Model A: {model_a[i]}")
#         if i < len(model_b):
#             current_dicts.append(model_b[i])
#             current_weights.append(weights[1])
#             print(f"Model B: {model_b[i]}")
#         if i < len(model_c):
#             current_dicts.append(model_c[i])
#             current_weights.append(weights[2])
#             print(f"Model C: {model_c[i]}")
#         # print('-------------current_dicts--------------', current_dicts)
#         if current_dicts:
#             voted_dict = vote_for_nested_dict(current_dicts, current_weights)
#             results.append(voted_dict)
#             print(f"\n位置 {i} 投票结果: {voted_dict}")
    
#     return results



# # 示例输入：三个模型生成的字点
# model_a_results = [
#     {"function-name": "music_call", "param": {"name": "lisa", "type": "normal"}},
#     {"function-name": "video_play", "param": {"id": "123", "quality": "high"}},
#     {"function-name": "text_display11", "param": {"content": "Hellodd", "font": "Arial"}}
# ]

# model_b_results = [
#     {"function-name": "music_callAA", "param": {"name": "Joe", "type": "normal"}},
#     {"function-name": "video_play", "param": {"id": "123", "quality": "low"}},
#     {"function-name": "text_display11", "param": {"content": "Hellodd", "font": "Times New Roman"}}
# ]

# model_c_results = [
#     {"function-name": "music_callBB", "param": {"name": "Joe", "type": "vip"}},
#     {"function-name": "video_play", "param": {"id": "123", "quality": "high"}},
#     {"function-name": "text_display", "param": {"content": "Hello", "font": "Arial"}}
# ]

# # 执行投票
# ground_truth = vote_for_ground_truth(model_a_results, model_b_results, model_c_results)

# # 输出结果
# print("最终的 Ground Truth 字点列表:")
# for i, point in enumerate(ground_truth):
#     print(f"位置 {i}: {point}")

# %%
import json
from typing import List, Dict, Any

def simple_vote_function(parsed_dicts, weights):
    """简化的投票函数，避免复杂的递归问题"""
    if not parsed_dicts:
        return {}
    
    result = {}
    
    # 获取所有键
    all_keys = set()
    for d in parsed_dicts:
        all_keys.update(d.keys())
    
    # 对每个键投票
    for key in all_keys:
        values = [d[key] for d in parsed_dicts if key in d]
        key_weights = [w for d, w in zip(parsed_dicts, weights) if key in d]
        
        if isinstance(values[0], dict):
            # 嵌套字典：递归处理
            result[key] = simple_vote_function(values, key_weights)
        else:
            # 简单值：投票选择
            counter = {}
            for val, weight in zip(values, key_weights):
                counter[val] = counter.get(val, 0) + weight
            result[key] = max(counter, key=counter.get)
    
    return result
    
def vote_for_model_results(model_results: List[Dict]) -> Dict:
    """
    对多个模型的结果进行加权投票
    
    参数:
        model_results: 包含model和function_call的字典列表
                      格式: [{'model': 'model_name', 'function_call': 'json_string'}, ...]
    
    返回:
        投票后的最终function_call字典
    """
    # 模型权重映射
    model_weights = {
        'claude-sonnet-4': 2,
        'gemini-2.5': 1,
        'gpt-4o': 2,
        'qwen3-4b-2507': 0.5
    }
    
    print(f"输入的模型结果数量: {len(model_results)}")
    
    # 解析function_call JSON字符串并收集权重
    parsed_results = []
    weights = []
    
    for item in model_results:
        model_name = item['model']
        function_call_str = item['function_call']
        
        print(f"处理模型: {model_name}")
        
        try:
            # 解析JSON字符串
            function_call_dict = json.loads(function_call_str)
            parsed_results.append(function_call_dict)
            
            # 获取对应权重
            weight = model_weights.get(model_name, 1.0)  # 默认权重1.0
            weights.append(weight)
            
            print(f"  权重: {weight}")
            print(f"  Function Call: {function_call_dict}")
            
        except json.JSONDecodeError as e:
            print(f"  跳过无效的JSON: {function_call_str}")
            print(f"  错误: {e}")
            continue
    
    if not parsed_results:
        print("没有有效的结果可以投票")
        return {}
    
    print(f"\n有效结果数量: {len(parsed_results)}")
    print(f"对应权重: {weights}")
    
    # 使用现有的投票函数
    print("-------------调试信息：检查vote_for_nested_dict函数的输入-------------")
    print(parsed_results, type(parsed_results))
    # voted_result = vote_for_nested_dict(parsed_results, weights)
    voted_result = simple_vote_function(parsed_results, weights)
    
    return voted_result

# 测试数据
test_data = [
    {'model': 'claude-sonnet-4',
     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
    {'model': 'gemini-2.5',
     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
    {'model': 'gpt-4o',
     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
    {'model': 'qwen3-4b-2507',
     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
]

print("=== 测试相同结果的投票 ===")
result1 = vote_for_model_results(test_data)
print(f"\n最终投票结果: {result1}")
# Out:
# === 测试相同结果的投票 ===
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
#
# 最终投票结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}

# %%
# 测试不同结果的投票
print("\n" + "="*60)
print("=== 测试不同结果的投票 ===")

test_data_different = [
    {'model': 'claude-sonnet-4',
     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15, "volume": "high"}}'},
    {'model': 'gemini-2.5',
     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 20, "volume": "low"}}'},
    {'model': 'gpt-4o',
     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15, "volume": "medium"}}'},
    {'model': 'qwen3-4b-2507',
     'function_call': '{"name": "music_control", "arguments": {"auto_stop_time": 10, "volume": "high"}}'}
]

result2 = vote_for_model_results(test_data_different)
print(f"\n最终投票结果: {result2}")

print("\n" + "="*60)
print("投票分析:")
print("权重分布: claude-sonnet-4(2) + gpt-4o(2) + gemini-2.5(1) + qwen3-4b-2507(0.5)")
print("name字段:")
print("  - music_settings_control: claude(2) + gemini(1) + gpt(2) = 5票")
print("  - music_control: qwen(0.5) = 0.5票")
print("  → music_settings_control 获胜")
print("arguments.auto_stop_time字段:")
print("  - 15: claude(2) + gpt(2) = 4票")
print("  - 20: gemini(1) = 1票") 
print("  - 10: qwen(0.5) = 0.5票")
print("  → 15 获胜")
print("arguments.volume字段:")
print("  - high: claude(2) + qwen(0.5) = 2.5票")
print("  - low: gemini(1) = 1票")
print("  - medium: gpt(2) = 2票")
print("  → high 获胜")
# Out:
# ============================================================
# === 测试不同结果的投票 ===
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15, 'volume': 'high'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 20, 'volume': 'low'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15, 'volume': 'medium'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_control', 'arguments': {'auto_stop_time': 10, 'volume': 'high'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15, 'volume': 'high'}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 20, 'volume': 'low'}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15, 'volume': 'medium'}}, {'name': 'music_control', 'arguments': {'auto_stop_time': 10, 'volume': 'high'}}] <class 'list'>
#
# 最终投票结果: {'arguments': {'volume': 'high', 'auto_stop_time': 15}, 'name': 'music_settings_control'}
#
# ============================================================
# 投票分析:
# 权重分布: claude-sonnet-4(2) + gpt-4o(2) + gemini-2.5(1) + qwen3-4b-2507(0.5)
# name字段:
#   - music_settings_control: claude(2) + gemini(1) + gpt(2) = 5票
#   - music_control: qwen(0.5) = 0.5票
#   → music_settings_control 获胜
# arguments.auto_stop_time字段:
#   - 15: claude(2) + gpt(2) = 4票
#   - 20: gemini(1) = 1票
#   - 10: qwen(0.5) = 0.5票
#   → 15 获胜
# arguments.volume字段:
#   - high: claude(2) + qwen(0.5) = 2.5票
#   - low: gemini(1) = 1票
#   - medium: gpt(2) = 2票
#   → high 获胜

# %%
# 测试只有3个模型的情况
print("\n" + "="*60)
print("=== 测试只有3个模型的情况 ===")

test_data_three = [
    {'model': 'claude-sonnet-4',
     'function_call': '{"name": "video_play", "arguments": {"video_id": "123", "quality": "4K"}}'},
    {'model': 'gemini-2.5',
     'function_call': '{"name": "video_play", "arguments": {"video_id": "123", "quality": "HD"}}'},
    {'model': 'gpt-4o',
     'function_call': '{"name": "video_play", "arguments": {"video_id": "456", "quality": "4K"}}'}
]

result3 = vote_for_model_results(test_data_three)
print(f"\n最终投票结果: {result3}")

print("\n" + "="*60)
print("投票分析 (3个模型):")
print("权重分布: claude-sonnet-4(2) + gpt-4o(2) + gemini-2.5(1)")
print("name字段: 所有都是video_play → video_play 获胜")
print("arguments.video_id字段:")
print("  - 123: claude(2) + gemini(1) = 3票")
print("  - 456: gpt(2) = 2票")
print("  → 123 获胜")
print("arguments.quality字段:")
print("  - 4K: claude(2) + gpt(2) = 4票")
print("  - HD: gemini(1) = 1票")
print("  → 4K 获胜")
# Out:
# ============================================================
# === 测试只有3个模型的情况 ===
# 输入的模型结果数量: 3
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_play', 'arguments': {'video_id': '123', 'quality': '4K'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_play', 'arguments': {'video_id': '123', 'quality': 'HD'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_play', 'arguments': {'video_id': '456', 'quality': '4K'}}
#
# 有效结果数量: 3
# 对应权重: [2, 1, 2]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_play', 'arguments': {'video_id': '123', 'quality': '4K'}}, {'name': 'video_play', 'arguments': {'video_id': '123', 'quality': 'HD'}}, {'name': 'video_play', 'arguments': {'video_id': '456', 'quality': '4K'}}] <class 'list'>
#
# 处理字段 'arguments': [{'video_id': '123', 'quality': '4K'}, {'video_id': '123', 'quality': 'HD'}, {'video_id': '456', 'quality': '4K'}]
#
# 处理字段 'video_id': ['123', '123', '456']
# 字段值投票: {'123': 3, '456': 2}
#
# 处理字段 'quality': ['4K', 'HD', '4K']
# 字段值投票: {'4K': 4, 'HD': 1}
#
# 处理字段 'name': ['video_play', 'video_play', 'video_play']
# 字段值投票: {'video_play': 5}
#
# 最终投票结果: {'arguments': {'video_id': '123', 'quality': '4K'}, 'name': 'video_play'}
#
# ============================================================
# 投票分析 (3个模型):
# 权重分布: claude-sonnet-4(2) + gpt-4o(2) + gemini-2.5(1)
# name字段: 所有都是video_play → video_play 获胜
# arguments.video_id字段:
#   - 123: claude(2) + gemini(1) = 3票
#   - 456: gpt(2) = 2票
#   → 123 获胜
# arguments.quality字段:
#   - 4K: claude(2) + gpt(2) = 4票
#   - HD: gemini(1) = 1票
#   → 4K 获胜

# %%
def batch_vote_for_queries(df_grouped_data):
    """
    批量处理多个query的投票
    
    参数:
        df_grouped_data: DataFrame，包含query和对应的model_function_call列表
    
    返回:
        DataFrame，包含每个query的投票结果
    """
    results = []
    
    for _, row in df_grouped_data.iterrows():
        query = row['query']
        model_function_calls = row['model_function_call']
        
        print(f"\n{'='*50}")
        print(f"处理Query: {query}")
        print(f"模型数量: {len(model_function_calls)}")
        
        # 对当前query进行投票
        voted_result = vote_for_model_results(model_function_calls)
        
        results.append({
            'query': query,
            'model_function_calls': model_function_calls,
            'voted_function_call': voted_result
        })
    
    return pd.DataFrame(results)

# 使用示例
print("\n" + "="*60)
print("=== 批量处理示例 ===")

# 模拟从前面group by得到的数据
sample_grouped_data = pd.DataFrame([
    {
        'query': '设置音乐自动停止',
        'model_function_call': [
            {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
            {'model': 'gpt-4o', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
            {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 20}}'}
        ]
    },
    {
        'query': '播放视频',
        'model_function_call': [
            {'model': 'claude-sonnet-4', 'function_call': '{"name": "video_play", "arguments": {"quality": "4K"}}'},
            {'model': 'gpt-4o', 'function_call': '{"name": "video_play", "arguments": {"quality": "HD"}}'},
            {'model': 'gemini-2.5', 'function_call': '{"name": "video_play", "arguments": {"quality": "4K"}}'}
        ]
    }
])

# 批量处理
batch_results = batch_vote_for_queries(sample_grouped_data)

print(f"\n最终批量处理结果:")
for _, row in batch_results.iterrows():
    print(f"\nQuery: {row['query']}")
    print(f"投票结果: {row['voted_function_call']}")
# Out:
# ============================================================
# === 批量处理示例 ===
#
# ==================================================
# 处理Query: 设置音乐自动停止
# 模型数量: 3
# 输入的模型结果数量: 3
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 20}}
#
# 有效结果数量: 3
# 对应权重: [2, 2, 1]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 20}}] <class 'list'>
#
# ==================================================
# 处理Query: 播放视频
# 模型数量: 3
# 输入的模型结果数量: 3
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_play', 'arguments': {'quality': '4K'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_play', 'arguments': {'quality': 'HD'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_play', 'arguments': {'quality': '4K'}}
#
# 有效结果数量: 3
# 对应权重: [2, 2, 1]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_play', 'arguments': {'quality': '4K'}}, {'name': 'video_play', 'arguments': {'quality': 'HD'}}, {'name': 'video_play', 'arguments': {'quality': '4K'}}] <class 'list'>
#
# 最终批量处理结果:
#
# Query: 设置音乐自动停止
# 投票结果: {'arguments': {'auto_stop_time': 15}, 'name': 'music_settings_control'}
#
# Query: 播放视频
# 投票结果: {'arguments': {'quality': '4K'}, 'name': 'video_play'}

# %%
import pandas as pd
df = pd.read_excel('/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/merge_data/query_and_function_call.xlsx')

# %%
df['model_function_call'] = df['model_function_call'].apply(lambda x: eval(x))

# %%
df = df[['query', 'model_function_call']]
df
# Out:
#                                 query  \
# 0                 10分間だけ音楽を流してから停止したい
# 1                15分でミュージックアプリの再生を止めて
# 2       15分後に音楽が停止するようにタイマーをセットしてください
# 3     15分後に音楽が止まるように設定するにはどうすれば良いですか？
# 4              15分後に音楽を止めるようにお願いしたいです
# ...                               ...
# 3326                   麻烦帮我设定音乐定时停止功能
# 3327          麻烦帮我设置一下，音乐听完15分钟就自动停掉。
# 3328                    麻烦帮我调出最近的观看记录
# 3329                  麻烦播放一下《速度与激情》电影
# 3330                         麻烦播放一下音乐
#
#                                     model_function_call
# 0     [{'model': 'claude-sonnet-4', 'function_call':...
# 1     [{'model': 'claude-sonnet-4', 'function_call':...
# 2     [{'model': 'claude-sonnet-4', 'function_call':...
# 3     [{'model': 'claude-sonnet-4', 'function_call':...
# 4     [{'model': 'claude-sonnet-4', 'function_call':...
# ...                                                 ...
# 3326  [{'model': 'claude-sonnet-4', 'function_call':...
# 3327  [{'model': 'claude-sonnet-4', 'function_call':...
# 3328  [{'model': 'claude-sonnet-4', 'function_call':...
# 3329  [{'model': 'claude-sonnet-4', 'function_call':...
# 3330  [{'model': 'claude-sonnet-4', 'function_call':...
#
# [3331 rows x 2 columns]

# %%
df_dict = df.to_dict(orient='records')

# %%
[
    {
        'query': '设置音乐自动停止',
        'model_function_call': [
            {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
            {'model': 'gpt-4o', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
            {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 20}}'}
        ]
    },
    {
        'query': '播放视频',
        'model_function_call': [
            {'model': 'claude-sonnet-4', 'function_call': '{"name": "video_play", "arguments": {"quality": "4K"}}'},
            {'model': 'gpt-4o', 'function_call': '{"name": "video_play", "arguments": {"quality": "HD"}}'},
            {'model': 'gemini-2.5', 'function_call': '{"name": "video_play", "arguments": {"quality": "4K"}}'}
        ]
    }
])

# %%
df_dict
# Out:
# [{'query': '10分間だけ音楽を流してから停止したい',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 10}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 10}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Music", "type": "album", "play_mode": "normal", "source": "recent"}}'}]},
#  {'query': '15分でミュージックアプリの再生を止めて',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "any_music_content", "type": "song", "source": "recent", "play_mode": "normal"}}'}]},
#  {'query': '15分後に音楽が停止するようにタイマーをセットしてください',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}]},
#  {'query': '15分後に音楽が止まるように設定するにはどうすれば良いですか？',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}]},
#  {'query': '15分後に音楽を止めるようにお願いしたいです',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}]},
#  {'query': '15分後に音楽を止めるようにアプリの設定を変更してもらえますか？',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}]},
#  {'query': '15分後に音楽を自動停止させるように設定して',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}]},
#  {'query': '15分後に音楽を自動停止するように設定して',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}]},
#  {'query': '15分経ったら音楽が止まるようにできますか',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}]},
#  {'query': '15分钟后自动停止音乐播放',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}]},
#  {'query': '1時間のスリープタイマーをセットして',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 60}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 60}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 60}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 60}}'}]},
#  {'query': '30分後に音楽再生を自動で終了させてください',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}'}]},
#  {'query': '8月に撮影された山の風景写真を探してください。',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "8\\u6708\\u306b\\u64ae\\u5f71\\u3055\\u308c\\u305f\\u5c71\\u306e\\u98a8\\u666f\\u5199\\u771f"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "\\u5c71\\u306e\\u98a8\\u666f\\u5199\\u771f 8\\u6708"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "8\\u6708\\u306b\\u64ae\\u5f71\\u3055\\u308c\\u305f\\u5c71\\u306e\\u98a8\\u666f\\u5199\\u771f"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "\\u5c71\\u306e\\u98a8\\u666f\\u5199\\u771f 8\\u6708"}}'}]},
#  {'query': 'Ab sofort Serie spielen.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Serie", "type": "tv"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "video_play_control", "arguments": {"type": "tv"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Serie", "type": "tv"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Serie", "type": "tv"}}'}]},
#  {'query': "Abspielen: 'Interstellar'.",
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Interstellar", "type": "movie"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Interstellar", "type": "album"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Interstellar", "type": "movie"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Interstellar", "type": "movie"}}'}]},
#  {'query': 'Access device information.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'}]},
#  {'query': 'Access the movie database for me.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "*", "type": "movie"}}'},
#    {'model': 'gemini-2.5', 'function_call': '{}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "movie", "type": "movie"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "Inception", "type": "movie"}}'}]},
#  {'query': "Add a new people album called 'Coworkers' to organize office photos",
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Coworkers", "album_type": "face"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Coworkers", "album_type": "face"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Coworkers", "album_type": "face"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Coworkers", "album_type": "face"}}'}]},
#  {'query': 'Adjust music app settings',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}]},
#  {'query': 'Adjust settings to stop music after a specified time',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}]},
#  {'query': "After receiving device details, what's the next step?",
#   'model_function_call': [{'model': 'gemini-2.5',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'},
#    {'model': 'gpt-4o', 'function_call': '{}'}]},
#  {'query': 'After the party, I need an album for all the pictures.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Party Photos", "album_type": "normal"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Party", "album_type": "normal"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "After Party Pictures", "album_type": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Party Photos", "album_type": "normal"}}'}]},
#  {'query': 'After the party, I need to organize photos into a new album.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Party Photos", "album_type": "normal"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "party", "album_type": "normal"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Party Photos", "album_type": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Party Photos", "album_type": "normal"}}'}]},
#  {'query': 'After the recent update, what’s changed in my operating system?',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'}]},
#  {'query': 'After the update, I want to see the system information.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'}]},
#  {'query': 'After the update, verify all system components are working',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'}]},
#  {'query': 'After uploading photos, can the list of albums be updated?',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "common"}}'}]},
#  {'query': 'After watching those films, what’s next in my history?',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "next", "source": "recent"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "video_play_control", "arguments": {"source": "recent"}}'},
#    {'model': 'gpt-4o', 'function_call': '{}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "films", "type": "movie"}}'}]},
#  {'query': 'Aktiviere den Schlaftimer',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}'}]},
#  {'query': 'Aktiviere die Musikwiedergabe für den Künstler Mozart',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Mozart", "type": "artist"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Mozart", "type": "artist"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Mozart", "type": "artist"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Mozart", "type": "artist"}}'}]},
#  {'query': "Album 'Hochzeit 2024' erstellen!",
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Hochzeit 2024", "album_type": "normal"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Hochzeit 2024", "album_type": "normal"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Hochzeit 2024", "album_type": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Hochzeit 2024", "album_type": "normal"}}'}]},
#  {'query': "Album für Babyfotos erstellen mit dem Namen 'Klein Emma'",
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Klein Emma", "album_type": "baby"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Klein Emma", "album_type": "baby"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Klein Emma", "album_type": "baby"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Klein Emma", "album_type": "baby"}}'}]},
#  {'query': 'Albumliste generieren',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "common"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "common"}}'}]},
#  {'query': 'Alle Songs von Rammstein in zufälliger Reihenfolge abspielen',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Rammstein", "type": "artist", "play_mode": "random"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Rammstein", "type": "artist", "play_mode": "random"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Rammstein", "type": "artist", "play_mode": "random"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Rammstein", "type": "artist", "play_mode": "random"}}'}]},
#  {'query': 'Als Nutzer möchte ich eine Übersicht meiner normalen Alben erhalten.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'}]},
#  {'query': 'As a business professional, I need a summary of the network capabilities.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "network"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "network"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "network"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "network"}}'}]},
#  {'query': 'As a casual user, how do I access various album types?',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "common"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "common"}}'}]},
#  {'query': 'As a film enthusiast, I want to play my favorite TV series.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "favorite TV series", "type": "tv", "source": "favorites"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "favorite TV series", "type": "tv"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "favorite TV series", "type": "tv"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "favorite TV series", "type": "tv"}}'}]},
#  {'query': "As a movie enthusiast, I'm looking for old western movies.",
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "old western movies", "type": "movie"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "old western movies", "type": "movie"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "old western movies", "type": "movie"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "old western movies", "type": "movie"}}'}]},
#  {'query': 'As a music enthusiast, I want to hear my top album on repeat.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_play_control", "arguments": {"type": "album", "source": "favorites", "play_mode": "loop"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "my top album", "type": "album", "play_mode": "loop"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "top album", "type": "album", "play_mode": "loop"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "top album", "type": "album", "play_mode": "loop"}}'}]},
#  {'query': 'As a newbie, how do I make an album?',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "My First Album", "album_type": "normal"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "My New Album", "album_type": "normal"}}'},
#    {'model': 'gpt-4o', 'function_call': '{}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "My First Album", "album_type": "normal"}}'}]},
#  {'query': 'As a photographer, I need stock images of urban scenes.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "urban scenes"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "urban scenes"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "urban scenes"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "urban scenes"}}'}]},
#  {'query': 'As a professional photographer, I need to organize my pictures into albums.',
#   'model_function_call': [{'model': 'gpt-4o',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Placeholder Album Name", "album_type": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'}]},
#  {'query': 'As a professional, I would like to set a specific playback duration for the music.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 0}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 0}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}]},
#  {'query': 'As a tech enthusiast, I want detailed device specifics.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'}]},
#  {'query': 'As a tech-savvy user, I need to configure auto-stop for music playback.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}]},
#  {'query': 'As a technical user, I need to gather detailed information about the network status.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "network"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "network"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "network"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "network"}}'}]},
#  {'query': 'As a user, I want to view my standard albums.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'}]},
#  {'query': "As someone who's not technically inclined, I'd like an easy way to manage playback settings.",
#   'model_function_call': [{'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Relaxing Music", "type": "album", "play_mode": "normal"}}'}]},
#  {'query': 'Automatische Abschaltung der Wiedergabe nach einer halben Stunde',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}'}]},
#  {'query': 'Automatische Musikabschaltung für den Einschlafmodus aktivieren',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}]},
#  {'query': 'Automatischen Musik-Stopp einrichten.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}]},
#  {'query': 'Baby-Fotoalben anzeigen bitte',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "baby"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "baby"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "baby"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "baby"}}'}]},
#  {'query': 'Baby相册里都有什么？',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "baby"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "baby"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "baby"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "baby"}}'}]},
#  {'query': "Beeil dich und starte den Film 'Avatar', ich habe nicht viel Zeit.",
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Avatar", "type": "movie"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Avatar", "type": "movie"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Avatar", "type": "movie"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Avatar", "type": "movie"}}'}]},
#  {'query': 'Beende die Musik, ich muss telefonieren.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_play_control", "arguments": {}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Musik", "type": "song", "play_mode": "stop"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_play_control", "arguments": {"play_mode": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "all", "type": "album", "source": "recent"}}'}]},
#  {'query': 'Before I go to bed, can you set a music timer?',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}'}]},
#  {'query': 'Before I troubleshoot, what is the current device information?',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'}]},
#  {'query': 'Before the meeting, I need to check system performance metrics',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'}]},
#  {'query': 'Begin playing the Harry Potter series',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Harry Potter", "type": "collection"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Harry Potter", "type": "collection"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Harry Potter", "type": "collection"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "Harry Potter", "type": "movie"}}'}]},
#  {'query': 'Bekomme die Liste der regulären Alben.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'}]},
#  {'query': 'Benötige Gerätespezifikationen für die Dokumentation',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'}]},
#  {'query': 'Benötige Übersicht aller Bilderalben für die Präsentation',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "common"}}'}]},
#  {'query': 'Bevor ich das Gerät verkaufe, möchte ich alle technischen Daten wissen.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "device"}}'}]},
#  {'query': 'Bevor ich eine Software installiere, welche Systeminfos brauche ich?',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_system_info", "arguments": {"system_type": "system"}}'}]},
#  {'query': 'Bilder finden',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Bilder"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Bilder"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Bilder finden"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "placeholders"}}'}]},
#  {'query': 'Bilder mit Sonnenuntergängen finden.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Sonnenunterg\\u00e4nge"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "sonnenunterg\\u00e4nge"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Sonnenunterg\\u00e4nge"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Sonnenunterg\\u00e4ngen"}}'}]},
#  {'query': 'Bilder mit einem Hund auf dem Gras finden.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Hund auf dem Gras"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "dog on the grass"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Hund auf dem Gras"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "dog on the grass"}}'}]},
#  {'query': 'Bilder suchen',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Bilder"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Bilder"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Bilder suchen"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "placeholder"}}'}]},
#  {'query': 'Bilder suchen für ein Schulprojekt',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Schulprojekt"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Bilder f\\u00fcr Schulprojekt"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Schulprojekt"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "school project"}}'}]},
#  {'query': 'Bilder suchen für ein Webdesign',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Webdesign"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Bilder f\\u00fcr Webdesign"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Webdesign"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "web design"}}'}]},
#  {'query': 'Bilder von Urlaubszielen in Portugal suchen.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Portugal Urlaubsziele"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Urlaubsziel Portugal"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Urlaubszielen in Portugal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Urlaubsziele in Portugal"}}'}]},
#  {'query': 'Bildergalerie durchsuchen nach Strand und Meer',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Strand und Meer"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Strand und Meer"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Strand und Meer"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Strand und Meer"}}'}]},
#  {'query': 'Bitte Album-Repository mit Typ-Parameter abrufen',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "common"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "common"}}'}]},
#  {'query': "Bitte aktivieren Sie die Filmwiedergabe für 'Der Pate'",
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Der Pate", "type": "movie"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Der Pate", "type": "movie"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Der Pate", "type": "movie"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Der Pate", "type": "movie"}}'}]},
#  {'query': 'Bitte den markierten Titel aus meiner Favoritenliste wiedergeben',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "markierten Titel", "source": "favorites"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_play_control", "arguments": {"source": "favorites", "type": "album"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_play_control", "arguments": {"source": "favorites"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "common"}}'}]},
#  {'query': 'Bitte die Fotoalbumsliste anzeigen.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "common"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "common"}}'}]},
#  {'query': 'Bitte die Musik in 15 Minuten stoppen.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "stop", "type": "song"}}'}]},
#  {'query': 'Bitte durchsuchen Sie unsere Videodatenbank nach dem Film Inception',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "Inception", "type": "movie"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "Inception", "type": "movie"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "Inception", "type": "movie"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "Inception", "type": "movie"}}'}]},
#  {'query': 'Bitte ein Album für Fotos anlegen.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Neues Album", "album_type": "normal"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Fotos", "album_type": "normal"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Neues Album", "album_type": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Photos from vacation", "album_type": "normal"}}'}]},
#  {'query': 'Bitte empfehlen Sie mir TV-Serien für Kinder.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "Kinder TV-Serien", "type": "tv"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "TV-Serien f\\u00fcr Kinder", "type": "tv"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "Kinder-TV-Serien", "type": "tv"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "Kinder-TV-Serie", "type": "tv"}}'}]},
#  {'query': 'Bitte erstellen Sie ein Babyalbum mit dem Namen "Meine ersten Schritte".',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Meine ersten Schritte", "album_type": "baby"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Meine ersten Schritte", "album_type": "baby"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Meine ersten Schritte", "album_type": "baby"}}'},
#    {'model': 'qwen3-4b-2507',
# ...
#  {'query': "Könntest du bitte ein Album für 'Meine Familie' anlegen?",
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Meine Familie", "album_type": "normal"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Meine Familie", "album_type": "normal"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Meine Familie", "album_type": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Meine Familie", "album_type": "normal"}}'}]},
#  {'query': 'Könntest du bitte ein Bildalbum für mich erstellen?',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Neues Album", "album_type": "normal"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Neues Bildalbum", "album_type": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "My Vacation Photos", "album_type": "normal"}}'}]},
#  {'query': 'Könntest du den Film abspielen, den ich als Favoriten markiert habe?',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "", "source": "favorites"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "video_play_control", "arguments": {"source": "favorites", "title": ""}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "", "source": "favorites"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "favoriten", "source": "favorites"}}'}]},
#  {'query': 'Könntest du den Song von Adele starten?',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Adele", "type": "artist"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Adele", "type": "artist"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Adele", "type": "artist"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Adele", "type": "artist"}}'}]},
#  {'query': 'Könntest du die Lautstärke erhöhen, während das Lied spielt?',
#   'model_function_call': [{'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {}}'}]},
#  {'query': 'Könntest du mir bitte die letzten gespielten Lieder zeigen?',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_play_control", "arguments": {"source": "recent"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_play_control", "arguments": {"source": "recent"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_play_control", "arguments": {"source": "recent"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_play_control", "arguments": {"source": "recent"}}'}]},
#  {'query': 'Könntest du mir ein paar gute Filme vorschlagen?',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "good movies", "type": "movie"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "Empfehlungen", "type": "movie"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "good movies", "type": "movie"}}'}]},
#  {'query': 'Könntest du mir helfen, einen automatischen Stopp einzustellen?',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}]},
#  {'query': 'Könntest du mir schnell die besten Bilder von Städtereisen zeigen?',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "St\\u00e4dtereisen"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "Bilder von St\\u00e4dtereisen"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "beste Bilder von St\\u00e4dtereisen"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "search_photos", "arguments": {"keyword": "St\\u00e4dtereisen"}}'}]},
#  {'query': "Könntest du nach dem Film 'Inception' suchen?",
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "Inception", "type": "movie"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "Inception", "type": "movie"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "Inception", "type": "movie"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "Inception", "type": "movie"}}'}]},
#  {'query': 'Könntest du nach der Fernsehserie Game of Thrones suchen?',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "Game of Thrones", "type": "tv"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "Game of Thrones", "type": "tv"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "Game of Thrones", "type": "tv"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "Game of Thrones", "type": "tv"}}'}]},
#  {'query': 'Lade die Albumliste',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "common"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "common"}}'}]},
#  {'query': 'Lass mal meine Rock-Playlist laufen',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Rock", "type": "playlist"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_play_control", "arguments": {"type": "playlist", "title": "Rock"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Rock-Playlist", "type": "playlist"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Rock-Playlist", "type": "playlist"}}'}]},
#  {'query': 'Lass mich die Playlist für die morgige Yoga-Session abspielen.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Yoga-Session", "type": "playlist"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "morgige Yoga-Session Playlist", "type": "playlist"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Playlist f\\u00fcr die Yoga-Session", "type": "playlist"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Yoga Meditation", "type": "playlist", "source": "favorites", "play_mode": "loop"}}'}]},
#  {'query': "Launch 'The Crown'.",
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}'}]},
#  {'query': 'Launch Inception from my saved favorites',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Inception", "type": "movie", "source": "favorites"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "Inception", "source": "favorites"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "Inception", "source": "favorites"}}'}]},
#  {'query': 'Launch The Crown please',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}'}]},
#  {'query': 'Launch the most recent drama I viewed.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "most recent drama", "type": "tv", "source": "recent"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "video_play_control", "arguments": {"source": "recent", "type": "tv"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "placeholder", "source": "recent"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "most recent drama", "type": "tv", "source": "recent"}}'}]},
#  {'query': 'Lege die Dauer des automatischen Stopps auf 50 Minuten fest.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 50}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 50}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 50}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 50}}'}]},
#  {'query': "Lege ein Album vom Typ 'Gesichter' an.",
#   'model_function_call': [{'model': 'gemini-2.5',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Gesichter", "album_type": "face"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Gesichter", "album_type": "face"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Gesichter", "album_type": "face"}}'}]},
#  {'query': "Lege ein neues Album mit dem Namen 'Familie' an",
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Familie", "album_type": "normal"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Familie", "album_type": "normal"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Familie", "album_type": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Familie", "album_type": "normal"}}'}]},
#  {'query': "Legen Sie ein Album für Gesichtserkennung an: 'Freundeskreis'",
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Freundeskreis", "album_type": "face"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Freundeskreis", "album_type": "face"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Freundeskreis", "album_type": "face"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Freundeskreis", "album_type": "face"}}'}]},
#  {'query': 'Let me see the normal albums, please.',
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'}]},
#  {'query': "Let's get some music going.",
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_play_control", "arguments": {}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": null, "type": "playlist"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_play_control", "arguments": {}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "lofi hip hop", "type": "playlist", "source": "recent", "play_mode": "random"}}'}]},
#  {'query': "Let's listen to some tunes.",
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "music_play_control", "arguments": {}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "tunes"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "music_play_control", "arguments": {}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "music_play_control", "arguments": {"title": "some tunes", "type": "album", "source": "recent"}}'}]},
#  {'query': "Let's start a new album for the family reunion.",
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Family Reunion", "album_type": "normal"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "family reunion", "album_type": "normal"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "Family Reunion", "album_type": "normal"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "create_album", "arguments": {"album_name": "family_reunion", "album_type": "normal"}}'}]},
#  {'query': "Let's watch 'The Crown'.",
#   'model_function_call': [{'model': 'claude-sonnet-4',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}'},
#    {'model': 'gemini-2.5',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}'},
#    {'model': 'gpt-4o',
#     'function_call': '{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}'},
#    {'model': 'qwen3-4b-2507',
#     'function_call': '{"name": "video_search_control", "arguments": {"title": "The Crown", "type": "tv"}}'}]},
#  ...]

# %%
aa = df.iloc[1]['model_function_call']
print(aa), type(aa)
# Out:
# [{'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}, {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}, {'model': 'gpt-4o', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}, {'model': 'qwen3-4b-2507', 'function_call': '{"name": "music_play_control", "arguments": {"title": "any_music_content", "type": "song", "source": "recent", "play_mode": "normal"}}'}]
# (None, list)

# %%
aa
# Out:
# [{'model': 'claude-sonnet-4',
#   'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#  {'model': 'gemini-2.5',
#   'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#  {'model': 'gpt-4o',
#   'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#  {'model': 'qwen3-4b-2507',
#   'function_call': '{"name": "music_play_control", "arguments": {"title": "any_music_content", "type": "song", "source": "recent", "play_mode": "normal"}}'}]

# %%
import ast
import  json
def convert_single_quotes_to_double_quotes(data_string):
    """
    将字符串中的单引号转换为双引号，使其成为有效的JSON格式
    
    参数:
        data_string: 包含单引号的字符串
    
    返回:
        转换后的JSON字符串
    """
    try:
        # 使用 ast.literal_eval 安全地解析Python字面量字符串
        parsed_data = ast.literal_eval(data_string)
        # 使用 json.dumps 将其转换为标准JSON格式（双引号）
        return json.dumps(parsed_data, ensure_ascii=False)
    except (ValueError, SyntaxError) as e:
        print(f"解析失败: {e}")
        return data_string

# %%
ss = df.iloc[1]['model_function_call']

# %%
print(convert_single_quotes_to_double_quotes(ss))
# Out:
# [{"model": "claude-sonnet-4", "function_call": "{\"name\": \"music_settings_control\", \"arguments\": {\"auto_stop_time\": 15}}"}, {"model": "gemini-2.5", "function_call": "{\"name\": \"music_settings_control\", \"arguments\": {\"auto_stop_time\": 15}}"}, {"model": "gpt-4o", "function_call": "{\"name\": \"music_settings_control\", \"arguments\": {\"auto_stop_time\": 15}}"}, {"model": "qwen3-4b-2507", "function_call": "{\"name\": \"music_play_control\", \"arguments\": {\"title\": \"any_music_content\", \"type\": \"song\", \"source\": \"recent\", \"play_mode\": \"normal\"}}"}]

# %%
df.iloc[1]['model_function_call']
# Out:
# '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "any_music_content", "type": "song", "source": "recent", "play_mode": "normal"}}\'}]'

# %%
json.dumps(df.iloc[1]['model_function_call'])
# Out:
# '"[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{\\"name\\": \\"music_settings_control\\", \\"arguments\\": {\\"auto_stop_time\\": 15}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{\\"name\\": \\"music_settings_control\\", \\"arguments\\": {\\"auto_stop_time\\": 15}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{\\"name\\": \\"music_settings_control\\", \\"arguments\\": {\\"auto_stop_time\\": 15}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{\\"name\\": \\"music_play_control\\", \\"arguments\\": {\\"title\\": \\"any_music_content\\", \\"type\\": \\"song\\", \\"source\\": \\"recent\\", \\"play_mode\\": \\"normal\\"}}\'}]"'

# %%
result_dict = df[['query', 'model_function_call']].to_dict('records')

# %%
result_dict
# Out:
# [{'query': '10分間だけ音楽を流してから停止したい',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 10}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 10}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Music", "type": "album", "play_mode": "normal", "source": "recent"}}\'}]'},
#  {'query': '15分でミュージックアプリの再生を止めて',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "any_music_content", "type": "song", "source": "recent", "play_mode": "normal"}}\'}]'},
#  {'query': '15分後に音楽が停止するようにタイマーをセットしてください',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}]'},
#  {'query': '15分後に音楽が止まるように設定するにはどうすれば良いですか？',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}]'},
#  {'query': '15分後に音楽を止めるようにお願いしたいです',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}]'},
#  {'query': '15分後に音楽を止めるようにアプリの設定を変更してもらえますか？',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}]'},
#  {'query': '15分後に音楽を自動停止させるように設定して',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}]'},
#  {'query': '15分後に音楽を自動停止するように設定して',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}]'},
#  {'query': '15分経ったら音楽が止まるようにできますか',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}]'},
#  {'query': '15分钟后自动停止音乐播放',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}]'},
#  {'query': '1時間のスリープタイマーをセットして',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 60}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 60}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 60}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 60}}\'}]'},
#  {'query': '30分後に音楽再生を自動で終了させてください',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}\'}]'},
#  {'query': '8月に撮影された山の風景写真を探してください。',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "8\\\\u6708\\\\u306b\\\\u64ae\\\\u5f71\\\\u3055\\\\u308c\\\\u305f\\\\u5c71\\\\u306e\\\\u98a8\\\\u666f\\\\u5199\\\\u771f"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "\\\\u5c71\\\\u306e\\\\u98a8\\\\u666f\\\\u5199\\\\u771f 8\\\\u6708"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "8\\\\u6708\\\\u306b\\\\u64ae\\\\u5f71\\\\u3055\\\\u308c\\\\u305f\\\\u5c71\\\\u306e\\\\u98a8\\\\u666f\\\\u5199\\\\u771f"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "\\\\u5c71\\\\u306e\\\\u98a8\\\\u666f\\\\u5199\\\\u771f 8\\\\u6708"}}\'}]'},
#  {'query': 'Ab sofort Serie spielen.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Serie", "type": "tv"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "video_play_control", "arguments": {"type": "tv"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Serie", "type": "tv"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Serie", "type": "tv"}}\'}]'},
#  {'query': "Abspielen: 'Interstellar'.",
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Interstellar", "type": "movie"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Interstellar", "type": "album"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Interstellar", "type": "movie"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Interstellar", "type": "movie"}}\'}]'},
#  {'query': 'Access device information.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}]'},
#  {'query': 'Access the movie database for me.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "*", "type": "movie"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "movie", "type": "movie"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "Inception", "type": "movie"}}\'}]'},
#  {'query': "Add a new people album called 'Coworkers' to organize office photos",
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Coworkers", "album_type": "face"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Coworkers", "album_type": "face"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Coworkers", "album_type": "face"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Coworkers", "album_type": "face"}}\'}]'},
#  {'query': 'Adjust music app settings',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}]'},
#  {'query': 'Adjust settings to stop music after a specified time',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}]'},
#  {'query': "After receiving device details, what's the next step?",
#   'model_function_call': '[{\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{}\'}]'},
#  {'query': 'After the party, I need an album for all the pictures.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Party Photos", "album_type": "normal"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Party", "album_type": "normal"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "After Party Pictures", "album_type": "normal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Party Photos", "album_type": "normal"}}\'}]'},
#  {'query': 'After the party, I need to organize photos into a new album.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Party Photos", "album_type": "normal"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "party", "album_type": "normal"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Party Photos", "album_type": "normal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Party Photos", "album_type": "normal"}}\'}]'},
#  {'query': 'After the recent update, what’s changed in my operating system?',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}]'},
#  {'query': 'After the update, I want to see the system information.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}]'},
#  {'query': 'After the update, verify all system components are working',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}]'},
#  {'query': 'After uploading photos, can the list of albums be updated?',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "common"}}\'}]'},
#  {'query': 'After watching those films, what’s next in my history?',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "next", "source": "recent"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "video_play_control", "arguments": {"source": "recent"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "films", "type": "movie"}}\'}]'},
#  {'query': 'Aktiviere den Schlaftimer',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}\'}]'},
#  {'query': 'Aktiviere die Musikwiedergabe für den Künstler Mozart',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Mozart", "type": "artist"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Mozart", "type": "artist"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Mozart", "type": "artist"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Mozart", "type": "artist"}}\'}]'},
#  {'query': "Album 'Hochzeit 2024' erstellen!",
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Hochzeit 2024", "album_type": "normal"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Hochzeit 2024", "album_type": "normal"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Hochzeit 2024", "album_type": "normal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Hochzeit 2024", "album_type": "normal"}}\'}]'},
#  {'query': "Album für Babyfotos erstellen mit dem Namen 'Klein Emma'",
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Klein Emma", "album_type": "baby"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Klein Emma", "album_type": "baby"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Klein Emma", "album_type": "baby"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Klein Emma", "album_type": "baby"}}\'}]'},
#  {'query': 'Albumliste generieren',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "common"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "common"}}\'}]'},
#  {'query': 'Alle Songs von Rammstein in zufälliger Reihenfolge abspielen',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Rammstein", "type": "artist", "play_mode": "random"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Rammstein", "type": "artist", "play_mode": "random"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Rammstein", "type": "artist", "play_mode": "random"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Rammstein", "type": "artist", "play_mode": "random"}}\'}]'},
#  {'query': 'Als Nutzer möchte ich eine Übersicht meiner normalen Alben erhalten.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}]'},
#  {'query': 'As a business professional, I need a summary of the network capabilities.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "network"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "network"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "network"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "network"}}\'}]'},
#  {'query': 'As a casual user, how do I access various album types?',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "common"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "common"}}\'}]'},
#  {'query': 'As a film enthusiast, I want to play my favorite TV series.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "favorite TV series", "type": "tv", "source": "favorites"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "favorite TV series", "type": "tv"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "favorite TV series", "type": "tv"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "favorite TV series", "type": "tv"}}\'}]'},
#  {'query': "As a movie enthusiast, I'm looking for old western movies.",
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "old western movies", "type": "movie"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "old western movies", "type": "movie"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "old western movies", "type": "movie"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "old western movies", "type": "movie"}}\'}]'},
#  {'query': 'As a music enthusiast, I want to hear my top album on repeat.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_play_control", "arguments": {"type": "album", "source": "favorites", "play_mode": "loop"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "my top album", "type": "album", "play_mode": "loop"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "top album", "type": "album", "play_mode": "loop"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "top album", "type": "album", "play_mode": "loop"}}\'}]'},
#  {'query': 'As a newbie, how do I make an album?',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "My First Album", "album_type": "normal"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "My New Album", "album_type": "normal"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "My First Album", "album_type": "normal"}}\'}]'},
#  {'query': 'As a photographer, I need stock images of urban scenes.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "urban scenes"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "urban scenes"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "urban scenes"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "urban scenes"}}\'}]'},
#  {'query': 'As a professional photographer, I need to organize my pictures into albums.',
#   'model_function_call': '[{\'model\': \'gpt-4o\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Placeholder Album Name", "album_type": "normal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}]'},
#  {'query': 'As a professional, I would like to set a specific playback duration for the music.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 0}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 0}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}]'},
#  {'query': 'As a tech enthusiast, I want detailed device specifics.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}]'},
#  {'query': 'As a tech-savvy user, I need to configure auto-stop for music playback.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}]'},
#  {'query': 'As a technical user, I need to gather detailed information about the network status.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "network"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "network"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "network"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "network"}}\'}]'},
#  {'query': 'As a user, I want to view my standard albums.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}]'},
#  {'query': "As someone who's not technically inclined, I'd like an easy way to manage playback settings.",
#   'model_function_call': '[{\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Relaxing Music", "type": "album", "play_mode": "normal"}}\'}]'},
#  {'query': 'Automatische Abschaltung der Wiedergabe nach einer halben Stunde',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}\'}]'},
#  {'query': 'Automatische Musikabschaltung für den Einschlafmodus aktivieren',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}]'},
#  {'query': 'Automatischen Musik-Stopp einrichten.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}]'},
#  {'query': 'Baby-Fotoalben anzeigen bitte',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "baby"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "baby"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "baby"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "baby"}}\'}]'},
#  {'query': 'Baby相册里都有什么？',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "baby"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "baby"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "baby"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "baby"}}\'}]'},
#  {'query': "Beeil dich und starte den Film 'Avatar', ich habe nicht viel Zeit.",
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Avatar", "type": "movie"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Avatar", "type": "movie"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Avatar", "type": "movie"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Avatar", "type": "movie"}}\'}]'},
#  {'query': 'Beende die Musik, ich muss telefonieren.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_play_control", "arguments": {}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Musik", "type": "song", "play_mode": "stop"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_play_control", "arguments": {"play_mode": "normal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "all", "type": "album", "source": "recent"}}\'}]'},
#  {'query': 'Before I go to bed, can you set a music timer?',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}\'}]'},
#  {'query': 'Before I troubleshoot, what is the current device information?',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}]'},
#  {'query': 'Before the meeting, I need to check system performance metrics',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}]'},
#  {'query': 'Begin playing the Harry Potter series',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Harry Potter", "type": "collection"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Harry Potter", "type": "collection"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Harry Potter", "type": "collection"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "Harry Potter", "type": "movie"}}\'}]'},
#  {'query': 'Bekomme die Liste der regulären Alben.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}]'},
#  {'query': 'Benötige Gerätespezifikationen für die Dokumentation',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}]'},
#  {'query': 'Benötige Übersicht aller Bilderalben für die Präsentation',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "common"}}\'}]'},
#  {'query': 'Bevor ich das Gerät verkaufe, möchte ich alle technischen Daten wissen.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "device"}}\'}]'},
#  {'query': 'Bevor ich eine Software installiere, welche Systeminfos brauche ich?',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_system_info", "arguments": {"system_type": "system"}}\'}]'},
#  {'query': 'Bilder finden',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Bilder"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Bilder"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Bilder finden"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "placeholders"}}\'}]'},
#  {'query': 'Bilder mit Sonnenuntergängen finden.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Sonnenunterg\\\\u00e4nge"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "sonnenunterg\\\\u00e4nge"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Sonnenunterg\\\\u00e4nge"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Sonnenunterg\\\\u00e4ngen"}}\'}]'},
#  {'query': 'Bilder mit einem Hund auf dem Gras finden.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Hund auf dem Gras"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "dog on the grass"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Hund auf dem Gras"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "dog on the grass"}}\'}]'},
#  {'query': 'Bilder suchen',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Bilder"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Bilder"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Bilder suchen"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "placeholder"}}\'}]'},
#  {'query': 'Bilder suchen für ein Schulprojekt',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Schulprojekt"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Bilder f\\\\u00fcr Schulprojekt"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Schulprojekt"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "school project"}}\'}]'},
#  {'query': 'Bilder suchen für ein Webdesign',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Webdesign"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Bilder f\\\\u00fcr Webdesign"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Webdesign"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "web design"}}\'}]'},
#  {'query': 'Bilder von Urlaubszielen in Portugal suchen.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Portugal Urlaubsziele"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Urlaubsziel Portugal"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Urlaubszielen in Portugal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Urlaubsziele in Portugal"}}\'}]'},
#  {'query': 'Bildergalerie durchsuchen nach Strand und Meer',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Strand und Meer"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Strand und Meer"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Strand und Meer"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Strand und Meer"}}\'}]'},
#  {'query': 'Bitte Album-Repository mit Typ-Parameter abrufen',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "common"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "common"}}\'}]'},
#  {'query': "Bitte aktivieren Sie die Filmwiedergabe für 'Der Pate'",
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Der Pate", "type": "movie"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Der Pate", "type": "movie"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Der Pate", "type": "movie"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Der Pate", "type": "movie"}}\'}]'},
#  {'query': 'Bitte den markierten Titel aus meiner Favoritenliste wiedergeben',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "markierten Titel", "source": "favorites"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_play_control", "arguments": {"source": "favorites", "type": "album"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_play_control", "arguments": {"source": "favorites"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "common"}}\'}]'},
#  {'query': 'Bitte die Fotoalbumsliste anzeigen.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "common"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "common"}}\'}]'},
#  {'query': 'Bitte die Musik in 15 Minuten stoppen.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "stop", "type": "song"}}\'}]'},
#  {'query': 'Bitte durchsuchen Sie unsere Videodatenbank nach dem Film Inception',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "Inception", "type": "movie"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "Inception", "type": "movie"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "Inception", "type": "movie"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "Inception", "type": "movie"}}\'}]'},
#  {'query': 'Bitte ein Album für Fotos anlegen.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Neues Album", "album_type": "normal"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Fotos", "album_type": "normal"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Neues Album", "album_type": "normal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Photos from vacation", "album_type": "normal"}}\'}]'},
#  {'query': 'Bitte empfehlen Sie mir TV-Serien für Kinder.',
# ...
#  {'query': 'Könntest du bitte ein Bildalbum für mich erstellen?',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Neues Album", "album_type": "normal"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Neues Bildalbum", "album_type": "normal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "My Vacation Photos", "album_type": "normal"}}\'}]'},
#  {'query': 'Könntest du den Film abspielen, den ich als Favoriten markiert habe?',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "", "source": "favorites"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "video_play_control", "arguments": {"source": "favorites", "title": ""}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "", "source": "favorites"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "favoriten", "source": "favorites"}}\'}]'},
#  {'query': 'Könntest du den Song von Adele starten?',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Adele", "type": "artist"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Adele", "type": "artist"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Adele", "type": "artist"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Adele", "type": "artist"}}\'}]'},
#  {'query': 'Könntest du die Lautstärke erhöhen, während das Lied spielt?',
#   'model_function_call': '[{\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {}}\'}]'},
#  {'query': 'Könntest du mir bitte die letzten gespielten Lieder zeigen?',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_play_control", "arguments": {"source": "recent"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_play_control", "arguments": {"source": "recent"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_play_control", "arguments": {"source": "recent"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_play_control", "arguments": {"source": "recent"}}\'}]'},
#  {'query': 'Könntest du mir ein paar gute Filme vorschlagen?',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "good movies", "type": "movie"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "Empfehlungen", "type": "movie"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "good movies", "type": "movie"}}\'}]'},
#  {'query': 'Könntest du mir helfen, einen automatischen Stopp einzustellen?',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 30}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}\'}]'},
#  {'query': 'Könntest du mir schnell die besten Bilder von Städtereisen zeigen?',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "St\\\\u00e4dtereisen"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "Bilder von St\\\\u00e4dtereisen"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "beste Bilder von St\\\\u00e4dtereisen"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "search_photos", "arguments": {"keyword": "St\\\\u00e4dtereisen"}}\'}]'},
#  {'query': "Könntest du nach dem Film 'Inception' suchen?",
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "Inception", "type": "movie"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "Inception", "type": "movie"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "Inception", "type": "movie"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "Inception", "type": "movie"}}\'}]'},
#  {'query': 'Könntest du nach der Fernsehserie Game of Thrones suchen?',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "Game of Thrones", "type": "tv"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "Game of Thrones", "type": "tv"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "Game of Thrones", "type": "tv"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "Game of Thrones", "type": "tv"}}\'}]'},
#  {'query': 'Lade die Albumliste',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "common"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "common"}}\'}]'},
#  {'query': 'Lass mal meine Rock-Playlist laufen',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Rock", "type": "playlist"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_play_control", "arguments": {"type": "playlist", "title": "Rock"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Rock-Playlist", "type": "playlist"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Rock-Playlist", "type": "playlist"}}\'}]'},
#  {'query': 'Lass mich die Playlist für die morgige Yoga-Session abspielen.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Yoga-Session", "type": "playlist"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "morgige Yoga-Session Playlist", "type": "playlist"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Playlist f\\\\u00fcr die Yoga-Session", "type": "playlist"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Yoga Meditation", "type": "playlist", "source": "favorites", "play_mode": "loop"}}\'}]'},
#  {'query': "Launch 'The Crown'.",
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}\'}]'},
#  {'query': 'Launch Inception from my saved favorites',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Inception", "type": "movie", "source": "favorites"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "Inception", "source": "favorites"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "Inception", "source": "favorites"}}\'}]'},
#  {'query': 'Launch The Crown please',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}\'}]'},
#  {'query': 'Launch the most recent drama I viewed.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "most recent drama", "type": "tv", "source": "recent"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "video_play_control", "arguments": {"source": "recent", "type": "tv"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "placeholder", "source": "recent"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "most recent drama", "type": "tv", "source": "recent"}}\'}]'},
#  {'query': 'Lege die Dauer des automatischen Stopps auf 50 Minuten fest.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 50}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 50}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 50}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_settings_control", "arguments": {"auto_stop_time": 50}}\'}]'},
#  {'query': "Lege ein Album vom Typ 'Gesichter' an.",
#   'model_function_call': '[{\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Gesichter", "album_type": "face"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Gesichter", "album_type": "face"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Gesichter", "album_type": "face"}}\'}]'},
#  {'query': "Lege ein neues Album mit dem Namen 'Familie' an",
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Familie", "album_type": "normal"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Familie", "album_type": "normal"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Familie", "album_type": "normal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Familie", "album_type": "normal"}}\'}]'},
#  {'query': "Legen Sie ein Album für Gesichtserkennung an: 'Freundeskreis'",
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Freundeskreis", "album_type": "face"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Freundeskreis", "album_type": "face"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Freundeskreis", "album_type": "face"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Freundeskreis", "album_type": "face"}}\'}]'},
#  {'query': 'Let me see the normal albums, please.',
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "get_album_list", "arguments": {"album_type": "normal"}}\'}]'},
#  {'query': "Let's get some music going.",
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_play_control", "arguments": {}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": null, "type": "playlist"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_play_control", "arguments": {}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "lofi hip hop", "type": "playlist", "source": "recent", "play_mode": "random"}}\'}]'},
#  {'query': "Let's listen to some tunes.",
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "music_play_control", "arguments": {}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "tunes"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "music_play_control", "arguments": {}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "music_play_control", "arguments": {"title": "some tunes", "type": "album", "source": "recent"}}\'}]'},
#  {'query': "Let's start a new album for the family reunion.",
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Family Reunion", "album_type": "normal"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "family reunion", "album_type": "normal"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "Family Reunion", "album_type": "normal"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "create_album", "arguments": {"album_name": "family_reunion", "album_type": "normal"}}\'}]'},
#  {'query': "Let's watch 'The Crown'.",
#   'model_function_call': '[{\'model\': \'claude-sonnet-4\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}\'}, {\'model\': \'gemini-2.5\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}\'}, {\'model\': \'gpt-4o\', \'function_call\': \'{"name": "video_play_control", "arguments": {"title": "The Crown", "type": "tv"}}\'}, {\'model\': \'qwen3-4b-2507\', \'function_call\': \'{"name": "video_search_control", "arguments": {"title": "The Crown", "type": "tv"}}\'}]'},
#  ...]

# %%
result_df.columns
# Out:
# Index(['Unnamed: 0', 'query', 'model_function_call'], dtype='object')

# %%
result_df = result_df[['query', 'model_function_call']]

# %%
result_df['model_function_call'] = result_df['model_function_call'].apply(eval)

# %%
result_df.iloc[1]['model_function_call'][0]['function_call']
# Out:
# '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'

# %%
# 调试版本的主函数
def debug_vote_for_model_results(model_results):
    """调试版本的投票主函数"""
    model_weights = {
        'claude-sonnet-4': 2,
        'gemini-2.5': 1,
        'gpt-4o': 2,
        'qwen3-4b-2507': 0.5
    }
    
    print(f"\n=== debug_vote_for_model_results 开始 ===")
    print(f"输入 model_results 类型: {type(model_results)}")
    print(f"输入 model_results 长度: {len(model_results)}")
    
    # 检查输入数据
    print(f"\n检查输入数据:")
    for i, item in enumerate(model_results):
        print(f"  项目 {i}:")
        print(f"    类型: {type(item)}")
        print(f"    内容: {item}")
        
        if isinstance(item, dict):
            print(f"    keys: {list(item.keys())}")
        else:
            print(f"    ✗ 不是字典！")
    
    # 解析过程
    parsed_results = []
    weights = []
    
    print(f"\n开始解析过程:")
    for i, item in enumerate(model_results):
        print(f"\n处理项目 {i}:")
        
        if not isinstance(item, dict):
            print(f"  跳过：不是字典")
            continue
            
        if 'model' not in item or 'function_call' not in item:
            print(f"  跳过：缺少必要字段")
            continue
        
        model_name = item['model']
        function_call_str = item['function_call']
        
        print(f"  模型: {model_name}")
        print(f"  function_call字符串: {function_call_str}")
        print(f"  function_call字符串类型: {type(function_call_str)}")
        
        try:
            # 解析JSON
            function_call_dict = json.loads(function_call_str)
            print(f"  解析后的结果: {function_call_dict}")
            print(f"  解析后的类型: {type(function_call_dict)}")
            
            # 验证解析结果
            if isinstance(function_call_dict, dict):
                parsed_results.append(function_call_dict)
                weight = model_weights.get(model_name, 1.0)
                weights.append(weight)
                print(f"  ✓ 添加成功，权重: {weight}")
            elif isinstance(function_call_dict, list):
                print(f"  ✗ 解析结果是列表，不是字典！")
                print(f"  列表内容: {function_call_dict}")
            else:
                print(f"  ✗ 解析结果类型不对: {type(function_call_dict)}")
                
        except json.JSONDecodeError as e:
            print(f"  ✗ JSON解析失败: {e}")
        except Exception as e:
            print(f"  ✗ 其他错误: {e}")
    
    print(f"\n解析完成:")
    print(f"parsed_results 长度: {len(parsed_results)}")
    print(f"weights: {weights}")
    
    # 再次检查 parsed_results
    print(f"\n最终检查 parsed_results:")
    for i, item in enumerate(parsed_results):
        print(f"  结果 {i}: {type(item)} - {item}")
    
    if not parsed_results:
        print("没有有效结果，返回空字典")
        return {}
    
    # 调用调试版本的投票函数
    return debug_simple_vote_function(parsed_results, weights)

# 现在你可以用这个函数来调试
print("调试函数已创建。")
print("使用方法: debug_vote_for_model_results(你的数据)")
print("这会显示详细的调试信息，帮助找出问题所在。")
# Out:
# 调试函数已创建。
# 使用方法: debug_vote_for_model_results(你的数据)
# 这会显示详细的调试信息，帮助找出问题所在。

# %%
# 修复版本的批量处理函数
def debug_batch_vote_for_queries(df_grouped_data):
    """调试版本的批量处理函数"""
    results = []
    
    print(f"\n=== debug_batch_vote_for_queries 开始 ===")
    print(f"输入数据类型: {type(df_grouped_data)}")
    print(f"输入数据行数: {len(df_grouped_data)}")
    
    for idx, row in df_grouped_data.iterrows():
        print(f"\n{'='*60}")
        print(f"处理第 {idx} 行")
        
        query = row['query']
        model_function_calls = row['model_function_call']
        
        print(f"Query: {query}")
        print(f"model_function_calls 类型: {type(model_function_calls)}")
        print(f"model_function_calls 长度: {len(model_function_calls)}")
        
        # 检查 model_function_calls 的内容
        print(f"model_function_calls 内容预览:")
        for i, item in enumerate(model_function_calls[:2]):  # 只显示前2个
            print(f"  项目 {i}: {type(item)} - {item}")
        
        try:
            # 使用调试版本的投票函数
            voted_result = debug_vote_for_model_results(model_function_calls)
            print(f"投票成功！结果: {voted_result}")
            
            results.append({
                'query': query,
                'model_function_calls': model_function_calls,
                'voted_function_call': voted_result
            })
            
        except Exception as e:
            print(f"投票失败: {e}")
            import traceback
            traceback.print_exc()
            
            # 添加失败的记录
            results.append({
                'query': query,
                'model_function_calls': model_function_calls,
                'voted_function_call': {'error': str(e)}
            })
    
    return pd.DataFrame(results)

print("调试版本的批量处理函数已创建。")
print("使用方法: debug_batch_vote_for_queries(你的DataFrame)")
print("这会显示每一步的详细信息。")
# Out:
# 调试版本的批量处理函数已创建。
# 使用方法: debug_batch_vote_for_queries(你的DataFrame)
# 这会显示每一步的详细信息。

# %%
result_df.shape
# Out:
# (3331, 2)

# %%
# 替换原来的调用
batch_results = debug_batch_vote_for_queries(result_df)
# Out:
# === debug_batch_vote_for_queries 开始 ===
# 输入数据类型: <class 'pandas.core.frame.DataFrame'>
# 输入数据行数: 3331
#
# ============================================================
# 处理第 0 行
# Query: 10分間だけ音楽を流してから停止したい
# model_function_calls 类型: <class 'list'>
# model_function_calls 长度: 3
# model_function_calls 内容预览:
#   项目 0: <class 'dict'> - {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 10}}'}
#   项目 1: <class 'dict'> - {'model': 'gpt-4o', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 10}}'}
#
# === debug_vote_for_model_results 开始 ===
# 输入 model_results 类型: <class 'list'>
# 输入 model_results 长度: 3
#
# 检查输入数据:
#   项目 0:
#     类型: <class 'dict'>
#     内容: {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 10}}'}
#     keys: ['model', 'function_call']
#   项目 1:
#     类型: <class 'dict'>
#     内容: {'model': 'gpt-4o', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 10}}'}
#     keys: ['model', 'function_call']
#   项目 2:
#     类型: <class 'dict'>
#     内容: {'model': 'qwen3-4b-2507', 'function_call': '{"name": "music_play_control", "arguments": {"title": "Music", "type": "album", "play_mode": "normal", "source": "recent"}}'}
#     keys: ['model', 'function_call']
#
# 开始解析过程:
#
# 处理项目 0:
#   模型: claude-sonnet-4
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 10}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 10}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 1:
#   模型: gpt-4o
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 10}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 10}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 2:
#   模型: qwen3-4b-2507
#   function_call字符串: {"name": "music_play_control", "arguments": {"title": "Music", "type": "album", "play_mode": "normal", "source": "recent"}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_play_control', 'arguments': {'title': 'Music', 'type': 'album', 'play_mode': 'normal', 'source': 'recent'}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 0.5
#
# 解析完成:
# parsed_results 长度: 3
# weights: [2, 2, 0.5]
#
# 最终检查 parsed_results:
#   结果 0: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 10}}
#   结果 1: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 10}}
#   结果 2: <class 'dict'> - {'name': 'music_play_control', 'arguments': {'title': 'Music', 'type': 'album', 'play_mode': 'normal', 'source': 'recent'}}
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 3
# weights: [2, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 10}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 10}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'name': 'music_play_control', 'arguments': {'title': 'Music', 'type': 'album', 'play_mode': 'normal', 'source': 'recent'}}
#     ✓ 是字典，keys: ['name', 'arguments']
#
# 过滤后的字典数量: 3
# 过滤后的权重: [2, 2, 0.5]
# 所有键: {'arguments', 'name'}
#
# 处理键 'arguments':
#   值: [{'auto_stop_time': 10}, {'auto_stop_time': 10}, {'title': 'Music', 'type': 'album', 'play_mode': 'normal', 'source': 'recent'}]
#   权重: [2, 2, 0.5]
#   递归处理嵌套字典
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 3
# weights: [2, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 10}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 10}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'title': 'Music', 'type': 'album', 'play_mode': 'normal', 'source': 'recent'}
#     ✓ 是字典，keys: ['title', 'type', 'play_mode', 'source']
#
# 过滤后的字典数量: 3
# 过滤后的权重: [2, 2, 0.5]
# 所有键: {'source', 'type', 'auto_stop_time', 'title', 'play_mode'}
#
# 处理键 'source':
#   值: ['recent']
#   权重: [0.5]
#   简单值投票
#   投票结果: recent
#
# 处理键 'type':
#   值: ['album']
#   权重: [0.5]
#   简单值投票
#   投票结果: album
#
# 处理键 'auto_stop_time':
#   值: [10, 10]
#   权重: [2, 2]
#   简单值投票
#   投票结果: 10
#
# 处理键 'title':
#   值: ['Music']
#   权重: [0.5]
#   简单值投票
#   投票结果: Music
#
# 处理键 'play_mode':
#   值: ['normal']
#   权重: [0.5]
#   简单值投票
#   投票结果: normal
#
# 最终结果: {'source': 'recent', 'type': 'album', 'auto_stop_time': 10, 'title': 'Music', 'play_mode': 'normal'}
#
# 处理键 'name':
#   值: ['music_settings_control', 'music_settings_control', 'music_play_control']
#   权重: [2, 2, 0.5]
#   简单值投票
#   投票结果: music_settings_control
#
# 最终结果: {'arguments': {'source': 'recent', 'type': 'album', 'auto_stop_time': 10, 'title': 'Music', 'play_mode': 'normal'}, 'name': 'music_settings_control'}
# 投票成功！结果: {'arguments': {'source': 'recent', 'type': 'album', 'auto_stop_time': 10, 'title': 'Music', 'play_mode': 'normal'}, 'name': 'music_settings_control'}
#
# ============================================================
# 处理第 1 行
# Query: 15分でミュージックアプリの再生を止めて
# model_function_calls 类型: <class 'list'>
# model_function_calls 长度: 4
# model_function_calls 内容预览:
#   项目 0: <class 'dict'> - {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#   项目 1: <class 'dict'> - {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#
# === debug_vote_for_model_results 开始 ===
# 输入 model_results 类型: <class 'list'>
# 输入 model_results 长度: 4
#
# 检查输入数据:
#   项目 0:
#     类型: <class 'dict'>
#     内容: {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 1:
#     类型: <class 'dict'>
#     内容: {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 2:
#     类型: <class 'dict'>
#     内容: {'model': 'gpt-4o', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 3:
#     类型: <class 'dict'>
#     内容: {'model': 'qwen3-4b-2507', 'function_call': '{"name": "music_play_control", "arguments": {"title": "any_music_content", "type": "song", "source": "recent", "play_mode": "normal"}}'}
#     keys: ['model', 'function_call']
#
# 开始解析过程:
#
# 处理项目 0:
#   模型: claude-sonnet-4
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 1:
#   模型: gemini-2.5
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 1
#
# 处理项目 2:
#   模型: gpt-4o
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 3:
#   模型: qwen3-4b-2507
#   function_call字符串: {"name": "music_play_control", "arguments": {"title": "any_music_content", "type": "song", "source": "recent", "play_mode": "normal"}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_play_control', 'arguments': {'title': 'any_music_content', 'type': 'song', 'source': 'recent', 'play_mode': 'normal'}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 0.5
#
# 解析完成:
# parsed_results 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 最终检查 parsed_results:
#   结果 0: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 1: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 2: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 3: <class 'dict'> - {'name': 'music_play_control', 'arguments': {'title': 'any_music_content', 'type': 'song', 'source': 'recent', 'play_mode': 'normal'}}
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'name': 'music_play_control', 'arguments': {'title': 'any_music_content', 'type': 'song', 'source': 'recent', 'play_mode': 'normal'}}
#     ✓ 是字典，keys: ['name', 'arguments']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'arguments', 'name'}
#
# 处理键 'arguments':
#   值: [{'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'title': 'any_music_content', 'type': 'song', 'source': 'recent', 'play_mode': 'normal'}]
#   权重: [2, 1, 2, 0.5]
#   递归处理嵌套字典
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'title': 'any_music_content', 'type': 'song', 'source': 'recent', 'play_mode': 'normal'}
#     ✓ 是字典，keys: ['title', 'type', 'source', 'play_mode']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'source', 'type', 'auto_stop_time', 'title', 'play_mode'}
#
# 处理键 'source':
#   值: ['recent']
#   权重: [0.5]
#   简单值投票
#   投票结果: recent
#
# 处理键 'type':
#   值: ['song']
#   权重: [0.5]
#   简单值投票
#   投票结果: song
#
# 处理键 'auto_stop_time':
#   值: [15, 15, 15]
#   权重: [2, 1, 2]
#   简单值投票
#   投票结果: 15
#
# 处理键 'title':
#   值: ['any_music_content']
#   权重: [0.5]
#   简单值投票
#   投票结果: any_music_content
#
# 处理键 'play_mode':
#   值: ['normal']
#   权重: [0.5]
#   简单值投票
#   投票结果: normal
#
# 最终结果: {'source': 'recent', 'type': 'song', 'auto_stop_time': 15, 'title': 'any_music_content', 'play_mode': 'normal'}
#
# 处理键 'name':
#   值: ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_play_control']
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: music_settings_control
#
# 最终结果: {'arguments': {'source': 'recent', 'type': 'song', 'auto_stop_time': 15, 'title': 'any_music_content', 'play_mode': 'normal'}, 'name': 'music_settings_control'}
# 投票成功！结果: {'arguments': {'source': 'recent', 'type': 'song', 'auto_stop_time': 15, 'title': 'any_music_content', 'play_mode': 'normal'}, 'name': 'music_settings_control'}
#
# ============================================================
# 处理第 2 行
# Query: 15分後に音楽が停止するようにタイマーをセットしてください
# model_function_calls 类型: <class 'list'>
# model_function_calls 长度: 4
# model_function_calls 内容预览:
#   项目 0: <class 'dict'> - {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#   项目 1: <class 'dict'> - {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#
# === debug_vote_for_model_results 开始 ===
# 输入 model_results 类型: <class 'list'>
# 输入 model_results 长度: 4
#
# 检查输入数据:
#   项目 0:
#     类型: <class 'dict'>
#     内容: {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 1:
#     类型: <class 'dict'>
#     内容: {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 2:
#     类型: <class 'dict'>
#     内容: {'model': 'gpt-4o', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 3:
#     类型: <class 'dict'>
#     内容: {'model': 'qwen3-4b-2507', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#
# 开始解析过程:
#
# 处理项目 0:
#   模型: claude-sonnet-4
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 1:
#   模型: gemini-2.5
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 1
#
# 处理项目 2:
#   模型: gpt-4o
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 3:
#   模型: qwen3-4b-2507
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 0.5
#
# 解析完成:
# parsed_results 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 最终检查 parsed_results:
#   结果 0: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 1: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 2: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 3: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'arguments', 'name'}
#
# 处理键 'arguments':
#   值: [{'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}]
#   权重: [2, 1, 2, 0.5]
#   递归处理嵌套字典
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'auto_stop_time'}
#
# 处理键 'auto_stop_time':
#   值: [15, 15, 15, 15]
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: 15
#
# 最终结果: {'auto_stop_time': 15}
#
# 处理键 'name':
#   值: ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: music_settings_control
#
# 最终结果: {'arguments': {'auto_stop_time': 15}, 'name': 'music_settings_control'}
# 投票成功！结果: {'arguments': {'auto_stop_time': 15}, 'name': 'music_settings_control'}
#
# ============================================================
# 处理第 3 行
# Query: 15分後に音楽が止まるように設定するにはどうすれば良いですか？
# model_function_calls 类型: <class 'list'>
# model_function_calls 长度: 4
# model_function_calls 内容预览:
#   项目 0: <class 'dict'> - {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#   项目 1: <class 'dict'> - {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#
# === debug_vote_for_model_results 开始 ===
# 输入 model_results 类型: <class 'list'>
# 输入 model_results 长度: 4
#
# 检查输入数据:
#   项目 0:
#     类型: <class 'dict'>
#     内容: {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 1:
#     类型: <class 'dict'>
#     内容: {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 2:
#     类型: <class 'dict'>
#     内容: {'model': 'gpt-4o', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 3:
#     类型: <class 'dict'>
#     内容: {'model': 'qwen3-4b-2507', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#
# 开始解析过程:
#
# 处理项目 0:
#   模型: claude-sonnet-4
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 1:
#   模型: gemini-2.5
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 1
#
# 处理项目 2:
#   模型: gpt-4o
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 3:
#   模型: qwen3-4b-2507
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 0.5
#
# 解析完成:
# parsed_results 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 最终检查 parsed_results:
#   结果 0: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 1: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 2: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 3: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'arguments', 'name'}
#
# 处理键 'arguments':
#   值: [{'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}]
#   权重: [2, 1, 2, 0.5]
#   递归处理嵌套字典
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'auto_stop_time'}
#
# 处理键 'auto_stop_time':
#   值: [15, 15, 15, 15]
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: 15
#
# 最终结果: {'auto_stop_time': 15}
#
# 处理键 'name':
#   值: ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: music_settings_control
#
# 最终结果: {'arguments': {'auto_stop_time': 15}, 'name': 'music_settings_control'}
# 投票成功！结果: {'arguments': {'auto_stop_time': 15}, 'name': 'music_settings_control'}
#
# ============================================================
# 处理第 4 行
# Query: 15分後に音楽を止めるようにお願いしたいです
# model_function_calls 类型: <class 'list'>
# model_function_calls 长度: 4
# model_function_calls 内容预览:
#   项目 0: <class 'dict'> - {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#   项目 1: <class 'dict'> - {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#
# === debug_vote_for_model_results 开始 ===
# 输入 model_results 类型: <class 'list'>
# 输入 model_results 长度: 4
#
# 检查输入数据:
#   项目 0:
#     类型: <class 'dict'>
#     内容: {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 1:
#     类型: <class 'dict'>
#     内容: {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 2:
#     类型: <class 'dict'>
#     内容: {'model': 'gpt-4o', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 3:
#     类型: <class 'dict'>
#     内容: {'model': 'qwen3-4b-2507', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#
# 开始解析过程:
#
# 处理项目 0:
#   模型: claude-sonnet-4
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 1:
#   模型: gemini-2.5
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 1
#
# 处理项目 2:
#   模型: gpt-4o
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 3:
#   模型: qwen3-4b-2507
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 0.5
#
# 解析完成:
# parsed_results 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 最终检查 parsed_results:
#   结果 0: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 1: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 2: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 3: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'arguments', 'name'}
#
# 处理键 'arguments':
#   值: [{'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}]
#   权重: [2, 1, 2, 0.5]
#   递归处理嵌套字典
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'auto_stop_time'}
#
# 处理键 'auto_stop_time':
#   值: [15, 15, 15, 15]
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: 15
#
# 最终结果: {'auto_stop_time': 15}
#
# 处理键 'name':
#   值: ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: music_settings_control
#
# 最终结果: {'arguments': {'auto_stop_time': 15}, 'name': 'music_settings_control'}
# 投票成功！结果: {'arguments': {'auto_stop_time': 15}, 'name': 'music_settings_control'}
#
# ============================================================
# 处理第 5 行
# Query: 15分後に音楽を止めるようにアプリの設定を変更してもらえますか？
# model_function_calls 类型: <class 'list'>
# model_function_calls 长度: 4
# model_function_calls 内容预览:
#   项目 0: <class 'dict'> - {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#   项目 1: <class 'dict'> - {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#
# === debug_vote_for_model_results 开始 ===
# 输入 model_results 类型: <class 'list'>
# 输入 model_results 长度: 4
#
# 检查输入数据:
#   项目 0:
#     类型: <class 'dict'>
#     内容: {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 1:
#     类型: <class 'dict'>
#     内容: {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 2:
#     类型: <class 'dict'>
#     内容: {'model': 'gpt-4o', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 3:
#     类型: <class 'dict'>
#     内容: {'model': 'qwen3-4b-2507', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#
# 开始解析过程:
#
# 处理项目 0:
#   模型: claude-sonnet-4
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 1:
#   模型: gemini-2.5
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 1
#
# 处理项目 2:
#   模型: gpt-4o
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 3:
#   模型: qwen3-4b-2507
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 0.5
#
# 解析完成:
# parsed_results 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 最终检查 parsed_results:
#   结果 0: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 1: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 2: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 3: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'arguments', 'name'}
#
# 处理键 'arguments':
#   值: [{'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}]
#   权重: [2, 1, 2, 0.5]
#   递归处理嵌套字典
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'auto_stop_time'}
#
# 处理键 'auto_stop_time':
#   值: [15, 15, 15, 15]
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: 15
#
# 最终结果: {'auto_stop_time': 15}
#
# 处理键 'name':
#   值: ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: music_settings_control
#
# 最终结果: {'arguments': {'auto_stop_time': 15}, 'name': 'music_settings_control'}
# 投票成功！结果: {'arguments': {'auto_stop_time': 15}, 'name': 'music_settings_control'}
#
# ============================================================
# 处理第 6 行
# Query: 15分後に音楽を自動停止させるように設定して
# model_function_calls 类型: <class 'list'>
# model_function_calls 长度: 4
# model_function_calls 内容预览:
#   项目 0: <class 'dict'> - {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#   项目 1: <class 'dict'> - {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#
# === debug_vote_for_model_results 开始 ===
# 输入 model_results 类型: <class 'list'>
# 输入 model_results 长度: 4
#
# 检查输入数据:
#   项目 0:
#     类型: <class 'dict'>
#     内容: {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 1:
#     类型: <class 'dict'>
#     内容: {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 2:
#     类型: <class 'dict'>
#     内容: {'model': 'gpt-4o', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 3:
#     类型: <class 'dict'>
#     内容: {'model': 'qwen3-4b-2507', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#
# 开始解析过程:
#
# 处理项目 0:
#   模型: claude-sonnet-4
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 1:
#   模型: gemini-2.5
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 1
#
# 处理项目 2:
#   模型: gpt-4o
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 3:
#   模型: qwen3-4b-2507
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 0.5
#
# 解析完成:
# parsed_results 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 最终检查 parsed_results:
#   结果 0: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 1: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 2: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 3: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'arguments', 'name'}
#
# 处理键 'arguments':
#   值: [{'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}]
#   权重: [2, 1, 2, 0.5]
#   递归处理嵌套字典
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'auto_stop_time'}
#
# 处理键 'auto_stop_time':
#   值: [15, 15, 15, 15]
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: 15
#
# 最终结果: {'auto_stop_time': 15}
#
# 处理键 'name':
#   值: ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: music_settings_control
#
# 最终结果: {'arguments': {'auto_stop_time': 15}, 'name': 'music_settings_control'}
# 投票成功！结果: {'arguments': {'auto_stop_time': 15}, 'name': 'music_settings_control'}
#
# ============================================================
# 处理第 7 行
# Query: 15分後に音楽を自動停止するように設定して
# model_function_calls 类型: <class 'list'>
# model_function_calls 长度: 4
# model_function_calls 内容预览:
#   项目 0: <class 'dict'> - {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#   项目 1: <class 'dict'> - {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#
# === debug_vote_for_model_results 开始 ===
# 输入 model_results 类型: <class 'list'>
# 输入 model_results 长度: 4
#
# 检查输入数据:
#   项目 0:
#     类型: <class 'dict'>
#     内容: {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 1:
#     类型: <class 'dict'>
#     内容: {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 2:
#     类型: <class 'dict'>
#     内容: {'model': 'gpt-4o', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 3:
#     类型: <class 'dict'>
#     内容: {'model': 'qwen3-4b-2507', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#
# 开始解析过程:
#
# 处理项目 0:
#   模型: claude-sonnet-4
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 1:
#   模型: gemini-2.5
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 1
#
# 处理项目 2:
#   模型: gpt-4o
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 3:
#   模型: qwen3-4b-2507
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 0.5
#
# 解析完成:
# parsed_results 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 最终检查 parsed_results:
#   结果 0: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 1: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 2: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 3: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'arguments', 'name'}
#
# 处理键 'arguments':
#   值: [{'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}]
#   权重: [2, 1, 2, 0.5]
#   递归处理嵌套字典
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'auto_stop_time'}
#
# 处理键 'auto_stop_time':
#   值: [15, 15, 15, 15]
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: 15
#
# 最终结果: {'auto_stop_time': 15}
#
# 处理键 'name':
#   值: ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: music_settings_control
#
# 最终结果: {'arguments': {'auto_stop_time': 15}, 'name': 'music_settings_control'}
# 投票成功！结果: {'arguments': {'auto_stop_time': 15}, 'name': 'music_settings_control'}
#
# ============================================================
# 处理第 8 行
# Query: 15分経ったら音楽が止まるようにできますか
# model_function_calls 类型: <class 'list'>
# model_function_calls 长度: 4
# model_function_calls 内容预览:
#   项目 0: <class 'dict'> - {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#   项目 1: <class 'dict'> - {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#
# === debug_vote_for_model_results 开始 ===
# 输入 model_results 类型: <class 'list'>
# 输入 model_results 长度: 4
#
# 检查输入数据:
#   项目 0:
#     类型: <class 'dict'>
#     内容: {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 1:
#     类型: <class 'dict'>
#     内容: {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 2:
#     类型: <class 'dict'>
#     内容: {'model': 'gpt-4o', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 3:
#     类型: <class 'dict'>
#     内容: {'model': 'qwen3-4b-2507', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#
# 开始解析过程:
#
# 处理项目 0:
#   模型: claude-sonnet-4
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 1:
#   模型: gemini-2.5
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 1
#
# 处理项目 2:
#   模型: gpt-4o
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 3:
#   模型: qwen3-4b-2507
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 0.5
#
# 解析完成:
# parsed_results 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 最终检查 parsed_results:
#   结果 0: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 1: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 2: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   结果 3: <class 'dict'> - {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#     ✓ 是字典，keys: ['name', 'arguments']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'arguments', 'name'}
#
# 处理键 'arguments':
#   值: [{'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}]
#   权重: [2, 1, 2, 0.5]
#   递归处理嵌套字典
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'auto_stop_time': 15}
#     ✓ 是字典，keys: ['auto_stop_time']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'auto_stop_time'}
#
# 处理键 'auto_stop_time':
#   值: [15, 15, 15, 15]
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: 15
#
# 最终结果: {'auto_stop_time': 15}
#
# 处理键 'name':
#   值: ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: music_settings_control
#
# 最终结果: {'arguments': {'auto_stop_time': 15}, 'name': 'music_settings_control'}
# 投票成功！结果: {'arguments': {'auto_stop_time': 15}, 'name': 'music_settings_control'}
#
# ============================================================
# 处理第 9 行
# Query: 15分钟后自动停止音乐播放
# model_function_calls 类型: <class 'list'>
# model_function_calls 长度: 4
# model_function_calls 内容预览:
#   项目 0: <class 'dict'> - {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#   项目 1: <class 'dict'> - {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#
# === debug_vote_for_model_results 开始 ===
# 输入 model_results 类型: <class 'list'>
# 输入 model_results 长度: 4
#
# 检查输入数据:
#   项目 0:
#     类型: <class 'dict'>
#     内容: {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 1:
#     类型: <class 'dict'>
#     内容: {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 2:
#     类型: <class 'dict'>
#     内容: {'model': 'gpt-4o', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#   项目 3:
#     类型: <class 'dict'>
#     内容: {'model': 'qwen3-4b-2507', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
#     keys: ['model', 'function_call']
#
# 开始解析过程:
#
# 处理项目 0:
#   模型: claude-sonnet-4
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 1:
#   模型: gemini-2.5
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 1
#
# 处理项目 2:
#   模型: gpt-4o
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 3:
#   模型: qwen3-4b-2507
#   function_call字符串: {"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}
#   function_call字符串类型: <class 'str'>
# ...
#     ✓ 是字典，keys: ['system_type']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'system_type': 'storage'}
#     ✓ 是字典，keys: ['system_type']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'system_type'}
#
# 处理键 'system_type':
#   值: ['storage', 'storage', 'storage', 'storage']
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: storage
#
# 最终结果: {'system_type': 'storage'}
#
# 处理键 'name':
#   值: ['get_system_info', 'get_system_info', 'get_system_info', 'get_system_info']
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: get_system_info
#
# 最终结果: {'arguments': {'system_type': 'storage'}, 'name': 'get_system_info'}
# 投票成功！结果: {'arguments': {'system_type': 'storage'}, 'name': 'get_system_info'}
#
# ============================================================
# 处理第 135 行
# Query: Can you find and run the collection of superhero films?
# model_function_calls 类型: <class 'list'>
# model_function_calls 长度: 3
# model_function_calls 内容预览:
#   项目 0: <class 'dict'> - {'model': 'gemini-2.5', 'function_call': '{"name": "video_search_control", "arguments": {"title": "superhero", "type": "collection"}}'}
#   项目 1: <class 'dict'> - {'model': 'gpt-4o', 'function_call': '{"name": "video_play_control", "arguments": {"title": "superhero films", "type": "collection"}}'}
#
# === debug_vote_for_model_results 开始 ===
# 输入 model_results 类型: <class 'list'>
# 输入 model_results 长度: 3
#
# 检查输入数据:
#   项目 0:
#     类型: <class 'dict'>
#     内容: {'model': 'gemini-2.5', 'function_call': '{"name": "video_search_control", "arguments": {"title": "superhero", "type": "collection"}}'}
#     keys: ['model', 'function_call']
#   项目 1:
#     类型: <class 'dict'>
#     内容: {'model': 'gpt-4o', 'function_call': '{"name": "video_play_control", "arguments": {"title": "superhero films", "type": "collection"}}'}
#     keys: ['model', 'function_call']
#   项目 2:
#     类型: <class 'dict'>
#     内容: {'model': 'qwen3-4b-2507', 'function_call': '{"name": "video_search_control", "arguments": {"title": "superhero films", "type": "movie"}}'}
#     keys: ['model', 'function_call']
#
# 开始解析过程:
#
# 处理项目 0:
#   模型: gemini-2.5
#   function_call字符串: {"name": "video_search_control", "arguments": {"title": "superhero", "type": "collection"}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'video_search_control', 'arguments': {'title': 'superhero', 'type': 'collection'}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 1
#
# 处理项目 1:
#   模型: gpt-4o
#   function_call字符串: {"name": "video_play_control", "arguments": {"title": "superhero films", "type": "collection"}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'video_play_control', 'arguments': {'title': 'superhero films', 'type': 'collection'}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 2:
#   模型: qwen3-4b-2507
#   function_call字符串: {"name": "video_search_control", "arguments": {"title": "superhero films", "type": "movie"}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'video_search_control', 'arguments': {'title': 'superhero films', 'type': 'movie'}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 0.5
#
# 解析完成:
# parsed_results 长度: 3
# weights: [1, 2, 0.5]
#
# 最终检查 parsed_results:
#   结果 0: <class 'dict'> - {'name': 'video_search_control', 'arguments': {'title': 'superhero', 'type': 'collection'}}
#   结果 1: <class 'dict'> - {'name': 'video_play_control', 'arguments': {'title': 'superhero films', 'type': 'collection'}}
#   结果 2: <class 'dict'> - {'name': 'video_search_control', 'arguments': {'title': 'superhero films', 'type': 'movie'}}
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 3
# weights: [1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'name': 'video_search_control', 'arguments': {'title': 'superhero', 'type': 'collection'}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'name': 'video_play_control', 'arguments': {'title': 'superhero films', 'type': 'collection'}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'name': 'video_search_control', 'arguments': {'title': 'superhero films', 'type': 'movie'}}
#     ✓ 是字典，keys: ['name', 'arguments']
#
# 过滤后的字典数量: 3
# 过滤后的权重: [1, 2, 0.5]
# 所有键: {'arguments', 'name'}
#
# 处理键 'arguments':
#   值: [{'title': 'superhero', 'type': 'collection'}, {'title': 'superhero films', 'type': 'collection'}, {'title': 'superhero films', 'type': 'movie'}]
#   权重: [1, 2, 0.5]
#   递归处理嵌套字典
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 3
# weights: [1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'title': 'superhero', 'type': 'collection'}
#     ✓ 是字典，keys: ['title', 'type']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'title': 'superhero films', 'type': 'collection'}
#     ✓ 是字典，keys: ['title', 'type']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'title': 'superhero films', 'type': 'movie'}
#     ✓ 是字典，keys: ['title', 'type']
#
# 过滤后的字典数量: 3
# 过滤后的权重: [1, 2, 0.5]
# 所有键: {'type', 'title'}
#
# 处理键 'type':
#   值: ['collection', 'collection', 'movie']
#   权重: [1, 2, 0.5]
#   简单值投票
#   投票结果: collection
#
# 处理键 'title':
#   值: ['superhero', 'superhero films', 'superhero films']
#   权重: [1, 2, 0.5]
#   简单值投票
#   投票结果: superhero films
#
# 最终结果: {'type': 'collection', 'title': 'superhero films'}
#
# 处理键 'name':
#   值: ['video_search_control', 'video_play_control', 'video_search_control']
#   权重: [1, 2, 0.5]
#   简单值投票
#   投票结果: video_play_control
#
# 最终结果: {'arguments': {'type': 'collection', 'title': 'superhero films'}, 'name': 'video_play_control'}
# 投票成功！结果: {'arguments': {'type': 'collection', 'title': 'superhero films'}, 'name': 'video_play_control'}
#
# ============================================================
# 处理第 136 行
# Query: Can you find any TV shows with the word 'dragon' in the title?
# model_function_calls 类型: <class 'list'>
# model_function_calls 长度: 4
# model_function_calls 内容预览:
#   项目 0: <class 'dict'> - {'model': 'claude-sonnet-4', 'function_call': '{"name": "video_search_control", "arguments": {"title": "dragon", "type": "tv"}}'}
#   项目 1: <class 'dict'> - {'model': 'gemini-2.5', 'function_call': '{"name": "video_search_control", "arguments": {"title": "dragon", "type": "tv"}}'}
#
# === debug_vote_for_model_results 开始 ===
# 输入 model_results 类型: <class 'list'>
# 输入 model_results 长度: 4
#
# 检查输入数据:
#   项目 0:
#     类型: <class 'dict'>
#     内容: {'model': 'claude-sonnet-4', 'function_call': '{"name": "video_search_control", "arguments": {"title": "dragon", "type": "tv"}}'}
#     keys: ['model', 'function_call']
#   项目 1:
#     类型: <class 'dict'>
#     内容: {'model': 'gemini-2.5', 'function_call': '{"name": "video_search_control", "arguments": {"title": "dragon", "type": "tv"}}'}
#     keys: ['model', 'function_call']
#   项目 2:
#     类型: <class 'dict'>
#     内容: {'model': 'gpt-4o', 'function_call': '{"name": "video_search_control", "arguments": {"title": "dragon", "type": "tv"}}'}
#     keys: ['model', 'function_call']
#   项目 3:
#     类型: <class 'dict'>
#     内容: {'model': 'qwen3-4b-2507', 'function_call': '{"name": "video_search_control", "arguments": {"title": "dragon", "type": "tv"}}'}
#     keys: ['model', 'function_call']
#
# 开始解析过程:
#
# 处理项目 0:
#   模型: claude-sonnet-4
#   function_call字符串: {"name": "video_search_control", "arguments": {"title": "dragon", "type": "tv"}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'video_search_control', 'arguments': {'title': 'dragon', 'type': 'tv'}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 1:
#   模型: gemini-2.5
#   function_call字符串: {"name": "video_search_control", "arguments": {"title": "dragon", "type": "tv"}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'video_search_control', 'arguments': {'title': 'dragon', 'type': 'tv'}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 1
#
# 处理项目 2:
#   模型: gpt-4o
#   function_call字符串: {"name": "video_search_control", "arguments": {"title": "dragon", "type": "tv"}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'video_search_control', 'arguments': {'title': 'dragon', 'type': 'tv'}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 3:
#   模型: qwen3-4b-2507
#   function_call字符串: {"name": "video_search_control", "arguments": {"title": "dragon", "type": "tv"}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'video_search_control', 'arguments': {'title': 'dragon', 'type': 'tv'}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 0.5
#
# 解析完成:
# parsed_results 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 最终检查 parsed_results:
#   结果 0: <class 'dict'> - {'name': 'video_search_control', 'arguments': {'title': 'dragon', 'type': 'tv'}}
#   结果 1: <class 'dict'> - {'name': 'video_search_control', 'arguments': {'title': 'dragon', 'type': 'tv'}}
#   结果 2: <class 'dict'> - {'name': 'video_search_control', 'arguments': {'title': 'dragon', 'type': 'tv'}}
#   结果 3: <class 'dict'> - {'name': 'video_search_control', 'arguments': {'title': 'dragon', 'type': 'tv'}}
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'name': 'video_search_control', 'arguments': {'title': 'dragon', 'type': 'tv'}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'name': 'video_search_control', 'arguments': {'title': 'dragon', 'type': 'tv'}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'name': 'video_search_control', 'arguments': {'title': 'dragon', 'type': 'tv'}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'name': 'video_search_control', 'arguments': {'title': 'dragon', 'type': 'tv'}}
#     ✓ 是字典，keys: ['name', 'arguments']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'arguments', 'name'}
#
# 处理键 'arguments':
#   值: [{'title': 'dragon', 'type': 'tv'}, {'title': 'dragon', 'type': 'tv'}, {'title': 'dragon', 'type': 'tv'}, {'title': 'dragon', 'type': 'tv'}]
#   权重: [2, 1, 2, 0.5]
#   递归处理嵌套字典
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'title': 'dragon', 'type': 'tv'}
#     ✓ 是字典，keys: ['title', 'type']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'title': 'dragon', 'type': 'tv'}
#     ✓ 是字典，keys: ['title', 'type']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'title': 'dragon', 'type': 'tv'}
#     ✓ 是字典，keys: ['title', 'type']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'title': 'dragon', 'type': 'tv'}
#     ✓ 是字典，keys: ['title', 'type']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'type', 'title'}
#
# 处理键 'type':
#   值: ['tv', 'tv', 'tv', 'tv']
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: tv
#
# 处理键 'title':
#   值: ['dragon', 'dragon', 'dragon', 'dragon']
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: dragon
#
# 最终结果: {'type': 'tv', 'title': 'dragon'}
#
# 处理键 'name':
#   值: ['video_search_control', 'video_search_control', 'video_search_control', 'video_search_control']
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: video_search_control
#
# 最终结果: {'arguments': {'type': 'tv', 'title': 'dragon'}, 'name': 'video_search_control'}
# 投票成功！结果: {'arguments': {'type': 'tv', 'title': 'dragon'}, 'name': 'video_search_control'}
#
# ============================================================
# 处理第 137 行
# Query: Can you find images related to summer vacations?
# model_function_calls 类型: <class 'list'>
# model_function_calls 长度: 4
# model_function_calls 内容预览:
#   项目 0: <class 'dict'> - {'model': 'claude-sonnet-4', 'function_call': '{"name": "search_photos", "arguments": {"keyword": "summer vacations"}}'}
#   项目 1: <class 'dict'> - {'model': 'gemini-2.5', 'function_call': '{"name": "search_photos", "arguments": {"keyword": "summer vacations"}}'}
#
# === debug_vote_for_model_results 开始 ===
# 输入 model_results 类型: <class 'list'>
# 输入 model_results 长度: 4
#
# 检查输入数据:
#   项目 0:
#     类型: <class 'dict'>
#     内容: {'model': 'claude-sonnet-4', 'function_call': '{"name": "search_photos", "arguments": {"keyword": "summer vacations"}}'}
#     keys: ['model', 'function_call']
#   项目 1:
#     类型: <class 'dict'>
#     内容: {'model': 'gemini-2.5', 'function_call': '{"name": "search_photos", "arguments": {"keyword": "summer vacations"}}'}
#     keys: ['model', 'function_call']
#   项目 2:
#     类型: <class 'dict'>
#     内容: {'model': 'gpt-4o', 'function_call': '{"name": "search_photos", "arguments": {"keyword": "summer vacations"}}'}
#     keys: ['model', 'function_call']
#   项目 3:
#     类型: <class 'dict'>
#     内容: {'model': 'qwen3-4b-2507', 'function_call': '{"name": "search_photos", "arguments": {"keyword": "summer vacation"}}'}
#     keys: ['model', 'function_call']
#
# 开始解析过程:
#
# 处理项目 0:
#   模型: claude-sonnet-4
#   function_call字符串: {"name": "search_photos", "arguments": {"keyword": "summer vacations"}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'search_photos', 'arguments': {'keyword': 'summer vacations'}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 1:
#   模型: gemini-2.5
#   function_call字符串: {"name": "search_photos", "arguments": {"keyword": "summer vacations"}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'search_photos', 'arguments': {'keyword': 'summer vacations'}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 1
#
# 处理项目 2:
#   模型: gpt-4o
#   function_call字符串: {"name": "search_photos", "arguments": {"keyword": "summer vacations"}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'search_photos', 'arguments': {'keyword': 'summer vacations'}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 2
#
# 处理项目 3:
#   模型: qwen3-4b-2507
#   function_call字符串: {"name": "search_photos", "arguments": {"keyword": "summer vacation"}}
#   function_call字符串类型: <class 'str'>
#   解析后的结果: {'name': 'search_photos', 'arguments': {'keyword': 'summer vacation'}}
#   解析后的类型: <class 'dict'>
#   ✓ 添加成功，权重: 0.5
#
# 解析完成:
# parsed_results 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 最终检查 parsed_results:
#   结果 0: <class 'dict'> - {'name': 'search_photos', 'arguments': {'keyword': 'summer vacations'}}
#   结果 1: <class 'dict'> - {'name': 'search_photos', 'arguments': {'keyword': 'summer vacations'}}
#   结果 2: <class 'dict'> - {'name': 'search_photos', 'arguments': {'keyword': 'summer vacations'}}
#   结果 3: <class 'dict'> - {'name': 'search_photos', 'arguments': {'keyword': 'summer vacation'}}
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'name': 'search_photos', 'arguments': {'keyword': 'summer vacations'}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'name': 'search_photos', 'arguments': {'keyword': 'summer vacations'}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'name': 'search_photos', 'arguments': {'keyword': 'summer vacations'}}
#     ✓ 是字典，keys: ['name', 'arguments']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'name': 'search_photos', 'arguments': {'keyword': 'summer vacation'}}
#     ✓ 是字典，keys: ['name', 'arguments']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'arguments', 'name'}
#
# 处理键 'arguments':
#   值: [{'keyword': 'summer vacations'}, {'keyword': 'summer vacations'}, {'keyword': 'summer vacations'}, {'keyword': 'summer vacation'}]
#   权重: [2, 1, 2, 0.5]
#   递归处理嵌套字典
#
# === debug_simple_vote_function 开始 ===
# parsed_dicts 类型: <class 'list'>
# parsed_dicts 长度: 4
# weights: [2, 1, 2, 0.5]
#
# 检查 parsed_dicts 中的每个元素:
#   元素 0:
#     类型: <class 'dict'>
#     内容: {'keyword': 'summer vacations'}
#     ✓ 是字典，keys: ['keyword']
#   元素 1:
#     类型: <class 'dict'>
#     内容: {'keyword': 'summer vacations'}
#     ✓ 是字典，keys: ['keyword']
#   元素 2:
#     类型: <class 'dict'>
#     内容: {'keyword': 'summer vacations'}
#     ✓ 是字典，keys: ['keyword']
#   元素 3:
#     类型: <class 'dict'>
#     内容: {'keyword': 'summer vacation'}
#     ✓ 是字典，keys: ['keyword']
#
# 过滤后的字典数量: 4
# 过滤后的权重: [2, 1, 2, 0.5]
# 所有键: {'keyword'}
#
# 处理键 'keyword':
#   值: ['summer vacations', 'summer vacations', 'summer vacations', 'summer vacation']
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: summer vacations
#
# 最终结果: {'keyword': 'summer vacations'}
#
# 处理键 'name':
#   值: ['search_photos', 'search_photos', 'search_photos', 'search_photos']
#   权重: [2, 1, 2, 0.5]
#   简单值投票
#   投票结果: search_photos
#
# 最终结果: {'arguments': {'keyword': 'summer vacations'}, 'name': 'search_photos'}
# 投票成功！结果: {'arguments': {'keyword': 'summer vacations'}, 'name': 'search_photos'}
#
# ============================================================
# 处理第 138 行
# Query: Can you find me series that are good for unwinding after work?

# %%
# 批量处理
batch_results = batch_vote_for_queries(result_df)
# Out:
# ==================================================
# 处理Query: 10分間だけ音楽を流してから停止したい
# 模型数量: 3
# 输入的模型结果数量: 3
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 10}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 10}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Music', 'type': 'album', 'play_mode': 'normal', 'source': 'recent'}}
#
# 有效结果数量: 3
# 对应权重: [2, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 10}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 10}}, {'name': 'music_play_control', 'arguments': {'title': 'Music', 'type': 'album', 'play_mode': 'normal', 'source': 'recent'}}] <class 'list'>
#
# ==================================================
# 处理Query: 15分でミュージックアプリの再生を止めて
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'any_music_content', 'type': 'song', 'source': 'recent', 'play_mode': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_play_control', 'arguments': {'title': 'any_music_content', 'type': 'song', 'source': 'recent', 'play_mode': 'normal'}}] <class 'list'>
#
# ==================================================
# 处理Query: 15分後に音楽が停止するようにタイマーをセットしてください
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
#
# ==================================================
# 处理Query: 15分後に音楽が止まるように設定するにはどうすれば良いですか？
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
#
# ==================================================
# 处理Query: 15分後に音楽を止めるようにお願いしたいです
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
#
# ==================================================
# 处理Query: 15分後に音楽を止めるようにアプリの設定を変更してもらえますか？
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
#
# ==================================================
# 处理Query: 15分後に音楽を自動停止させるように設定して
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
#
# ==================================================
# 处理Query: 15分後に音楽を自動停止するように設定して
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
#
# ==================================================
# 处理Query: 15分経ったら音楽が止まるようにできますか
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
#
# ==================================================
# 处理Query: 15分钟后自动停止音乐播放
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
#
# ==================================================
# 处理Query: 1時間のスリープタイマーをセットして
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}] <class 'list'>
#
# ==================================================
# 处理Query: 30分後に音楽再生を自動で終了させてください
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}] <class 'list'>
#
# ==================================================
# 处理Query: 8月に撮影された山の風景写真を探してください。
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '8月に撮影された山の風景写真'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '山の風景写真 8月'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '8月に撮影された山の風景写真'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '山の風景写真 8月'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'search_photos', 'arguments': {'keyword': '8月に撮影された山の風景写真'}}, {'name': 'search_photos', 'arguments': {'keyword': '山の風景写真 8月'}}, {'name': 'search_photos', 'arguments': {'keyword': '8月に撮影された山の風景写真'}}, {'name': 'search_photos', 'arguments': {'keyword': '山の風景写真 8月'}}] <class 'list'>
#
# ==================================================
# 处理Query: Ab sofort Serie spielen.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Serie', 'type': 'tv'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_play_control', 'arguments': {'type': 'tv'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Serie', 'type': 'tv'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Serie', 'type': 'tv'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_play_control', 'arguments': {'title': 'Serie', 'type': 'tv'}}, {'name': 'video_play_control', 'arguments': {'type': 'tv'}}, {'name': 'video_play_control', 'arguments': {'title': 'Serie', 'type': 'tv'}}, {'name': 'video_play_control', 'arguments': {'title': 'Serie', 'type': 'tv'}}] <class 'list'>
#
# ==================================================
# 处理Query: Abspielen: 'Interstellar'.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Interstellar', 'type': 'movie'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Interstellar', 'type': 'album'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Interstellar', 'type': 'movie'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Interstellar', 'type': 'movie'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_play_control', 'arguments': {'title': 'Interstellar', 'type': 'movie'}}, {'name': 'music_play_control', 'arguments': {'title': 'Interstellar', 'type': 'album'}}, {'name': 'video_play_control', 'arguments': {'title': 'Interstellar', 'type': 'movie'}}, {'name': 'video_play_control', 'arguments': {'title': 'Interstellar', 'type': 'movie'}}] <class 'list'>
#
# ==================================================
# 处理Query: Access device information.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}] <class 'list'>
#
# ==================================================
# 处理Query: Access the movie database for me.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': '*', 'type': 'movie'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'movie', 'type': 'movie'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'Inception', 'type': 'movie'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_search_control', 'arguments': {'title': '*', 'type': 'movie'}}, {}, {'name': 'video_search_control', 'arguments': {'title': 'movie', 'type': 'movie'}}, {'name': 'video_search_control', 'arguments': {'title': 'Inception', 'type': 'movie'}}] <class 'list'>
#
# ==================================================
# 处理Query: Add a new people album called 'Coworkers' to organize office photos
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}, {'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}, {'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}, {'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}] <class 'list'>
#
# ==================================================
# 处理Query: Adjust music app settings
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {}}, {'name': 'music_settings_control', 'arguments': {}}, {'name': 'music_settings_control', 'arguments': {}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
#
# ==================================================
# 处理Query: Adjust settings to stop music after a specified time
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
#
# ==================================================
# 处理Query: After receiving device details, what's the next step?
# 模型数量: 2
# 输入的模型结果数量: 2
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {}
#
# 有效结果数量: 2
# 对应权重: [1, 2]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, {}] <class 'list'>
#
# ==================================================
# 处理Query: After the party, I need an album for all the pictures.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Party', 'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'After Party Pictures', 'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'Party', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'After Party Pictures', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}] <class 'list'>
#
# ==================================================
# 处理Query: After the party, I need to organize photos into a new album.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'party', 'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'party', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}] <class 'list'>
#
# ==================================================
# 处理Query: After the recent update, what’s changed in my operating system?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}] <class 'list'>
#
# ==================================================
# 处理Query: After the update, I want to see the system information.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}] <class 'list'>
#
# ==================================================
# 处理Query: After the update, verify all system components are working
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}] <class 'list'>
#
# ==================================================
# 处理Query: After uploading photos, can the list of albums be updated?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}] <class 'list'>
#
# ==================================================
# 处理Query: After watching those films, what’s next in my history?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'next', 'source': 'recent'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_play_control', 'arguments': {'source': 'recent'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'films', 'type': 'movie'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_play_control', 'arguments': {'title': 'next', 'source': 'recent'}}, {'name': 'video_play_control', 'arguments': {'source': 'recent'}}, {}, {'name': 'video_search_control', 'arguments': {'title': 'films', 'type': 'movie'}}] <class 'list'>
#
# ==================================================
# 处理Query: Aktiviere den Schlaftimer
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}] <class 'list'>
#
# ==================================================
# 处理Query: Aktiviere die Musikwiedergabe für den Künstler Mozart
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}, {'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}, {'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}, {'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}] <class 'list'>
#
# ==================================================
# 处理Query: Album 'Hochzeit 2024' erstellen!
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}] <class 'list'>
#
# ==================================================
# 处理Query: Album für Babyfotos erstellen mit dem Namen 'Klein Emma'
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}, {'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}, {'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}, {'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}] <class 'list'>
#
# ==================================================
# 处理Query: Albumliste generieren
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}] <class 'list'>
#
# ==================================================
# 处理Query: Alle Songs von Rammstein in zufälliger Reihenfolge abspielen
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}, {'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}, {'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}, {'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}] <class 'list'>
#
# ==================================================
# 处理Query: Als Nutzer möchte ich eine Übersicht meiner normalen Alben erhalten.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}] <class 'list'>
#
# ==================================================
# 处理Query: As a business professional, I need a summary of the network capabilities.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_system_info', 'arguments': {'system_type': 'network'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}] <class 'list'>
#
# ==================================================
# 处理Query: As a casual user, how do I access various album types?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}] <class 'list'>
#
# ==================================================
# 处理Query: As a film enthusiast, I want to play my favorite TV series.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv', 'source': 'favorites'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_play_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv', 'source': 'favorites'}}, {'name': 'video_search_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv'}}, {'name': 'video_play_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv'}}, {'name': 'video_play_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv'}}] <class 'list'>
#
# ==================================================
# 处理Query: As a movie enthusiast, I'm looking for old western movies.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}, {'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}, {'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}, {'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}] <class 'list'>
#
# ==================================================
# 处理Query: As a music enthusiast, I want to hear my top album on repeat.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'type': 'album', 'source': 'favorites', 'play_mode': 'loop'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'my top album', 'type': 'album', 'play_mode': 'loop'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'top album', 'type': 'album', 'play_mode': 'loop'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'top album', 'type': 'album', 'play_mode': 'loop'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_play_control', 'arguments': {'type': 'album', 'source': 'favorites', 'play_mode': 'loop'}}, {'name': 'music_play_control', 'arguments': {'title': 'my top album', 'type': 'album', 'play_mode': 'loop'}}, {'name': 'music_play_control', 'arguments': {'title': 'top album', 'type': 'album', 'play_mode': 'loop'}}, {'name': 'music_play_control', 'arguments': {'title': 'top album', 'type': 'album', 'play_mode': 'loop'}}] <class 'list'>
#
# ==================================================
# 处理Query: As a newbie, how do I make an album?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'My First Album', 'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'My New Album', 'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'My First Album', 'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'create_album', 'arguments': {'album_name': 'My First Album', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'My New Album', 'album_type': 'normal'}}, {}, {'name': 'create_album', 'arguments': {'album_name': 'My First Album', 'album_type': 'normal'}}] <class 'list'>
#
# ==================================================
# 处理Query: As a photographer, I need stock images of urban scenes.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}, {'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}, {'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}, {'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}] <class 'list'>
#
# ==================================================
# 处理Query: As a professional photographer, I need to organize my pictures into albums.
# 模型数量: 2
# 输入的模型结果数量: 2
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Placeholder Album Name', 'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
#
# 有效结果数量: 2
# 对应权重: [2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'create_album', 'arguments': {'album_name': 'Placeholder Album Name', 'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}] <class 'list'>
#
# ==================================================
# 处理Query: As a professional, I would like to set a specific playback duration for the music.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 0}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 0}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 0}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 0}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
#
# ==================================================
# 处理Query: As a tech enthusiast, I want detailed device specifics.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}] <class 'list'>
#
# ==================================================
# 处理Query: As a tech-savvy user, I need to configure auto-stop for music playback.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
#
# ==================================================
# 处理Query: As a technical user, I need to gather detailed information about the network status.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_system_info', 'arguments': {'system_type': 'network'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}] <class 'list'>
#
# ==================================================
# 处理Query: As a user, I want to view my standard albums.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}] <class 'list'>
#
# ==================================================
# 处理Query: As someone who's not technically inclined, I'd like an easy way to manage playback settings.
# 模型数量: 3
# 输入的模型结果数量: 3
# 处理模型: gemini-2.5
#   权重: 1
# ...
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'My Photo Album', 'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'My Vacation Photos', 'album_type': 'normal'}}
#
# 有效结果数量: 3
# 对应权重: [2, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'create_album', 'arguments': {'album_name': 'New Album', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'My Photo Album', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'My Vacation Photos', 'album_type': 'normal'}}] <class 'list'>
#
# ==================================================
# 处理Query: Could you please help me find mountain hiking images?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'mountain hiking'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'mountain hiking images'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'mountain hiking'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'mountain hiking'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'search_photos', 'arguments': {'keyword': 'mountain hiking'}}, {'name': 'search_photos', 'arguments': {'keyword': 'mountain hiking images'}}, {'name': 'search_photos', 'arguments': {'keyword': 'mountain hiking'}}, {'name': 'search_photos', 'arguments': {'keyword': 'mountain hiking'}}] <class 'list'>
#
# ==================================================
# 处理Query: Could you please help me find the movie Pulp Fiction?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'Pulp Fiction', 'type': 'movie'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'Pulp Fiction', 'type': 'movie'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'Pulp Fiction', 'type': 'movie'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'Pulp Fiction', 'type': 'movie'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_search_control', 'arguments': {'title': 'Pulp Fiction', 'type': 'movie'}}, {'name': 'video_search_control', 'arguments': {'title': 'Pulp Fiction', 'type': 'movie'}}, {'name': 'video_search_control', 'arguments': {'title': 'Pulp Fiction', 'type': 'movie'}}, {'name': 'video_search_control', 'arguments': {'title': 'Pulp Fiction', 'type': 'movie'}}] <class 'list'>
#
# ==================================================
# 处理Query: Could you please play some music for me?
# 模型数量: 3
# 输入的模型结果数量: 3
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Peaceful Piano', 'type': 'song', 'source': 'recent'}}
#
# 有效结果数量: 3
# 对应权重: [2, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_play_control', 'arguments': {}}, {'name': 'music_play_control', 'arguments': {}}, {'name': 'music_play_control', 'arguments': {'title': 'Peaceful Piano', 'type': 'song', 'source': 'recent'}}] <class 'list'>
#
# ==================================================
# 处理Query: Could you please provide a comprehensive overview of available photo albums?
# 模型数量: 3
# 输入的模型结果数量: 3
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
#
# 有效结果数量: 3
# 对应权重: [2, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}] <class 'list'>
#
# ==================================================
# 处理Query: Could you please search for TV shows about cooking?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'cooking', 'type': 'tv'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'cooking', 'type': 'tv'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'cooking', 'type': 'tv'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'cooking', 'type': 'tv'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_search_control', 'arguments': {'title': 'cooking', 'type': 'tv'}}, {'name': 'video_search_control', 'arguments': {'title': 'cooking', 'type': 'tv'}}, {'name': 'video_search_control', 'arguments': {'title': 'cooking', 'type': 'tv'}}, {'name': 'video_search_control', 'arguments': {'title': 'cooking', 'type': 'tv'}}] <class 'list'>
#
# ==================================================
# 处理Query: Could you please set a music sleep timer?
# 模型数量: 3
# 输入的模型结果数量: 3
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
#
# 有效结果数量: 3
# 对应权重: [2, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}] <class 'list'>
#
# ==================================================
# 处理Query: Could you please set up a photo album for my child's birthday?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': "Child's Birthday", 'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': "Child's Birthday", 'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': "Child's Birthday", 'album_type': 'baby'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': "Child's Birthday", 'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'create_album', 'arguments': {'album_name': "Child's Birthday", 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': "Child's Birthday", 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': "Child's Birthday", 'album_type': 'baby'}}, {'name': 'create_album', 'arguments': {'album_name': "Child's Birthday", 'album_type': 'normal'}}] <class 'list'>
#
# ==================================================
# 处理Query: Could you please start playback of my recent tracks in normal mode?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'source': 'recent', 'play_mode': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'source': 'recent', 'play_mode': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'source': 'recent', 'play_mode': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'recent tracks', 'source': 'recent', 'play_mode': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_play_control', 'arguments': {'source': 'recent', 'play_mode': 'normal'}}, {'name': 'music_play_control', 'arguments': {'source': 'recent', 'play_mode': 'normal'}}, {'name': 'music_play_control', 'arguments': {'source': 'recent', 'play_mode': 'normal'}}, {'name': 'music_play_control', 'arguments': {'title': 'recent tracks', 'source': 'recent', 'play_mode': 'normal'}}] <class 'list'>
#
# ==================================================
# 处理Query: Could you please start playing my music selection?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'my music selection'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'my music selection', 'type': 'playlist'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_play_control', 'arguments': {}}, {'name': 'music_play_control', 'arguments': {'title': 'my music selection'}}, {'name': 'music_play_control', 'arguments': {}}, {'name': 'music_play_control', 'arguments': {'title': 'my music selection', 'type': 'playlist'}}] <class 'list'>
#
# ==================================================
# 处理Query: Could you please start playing the album by this artist?
# 模型数量: 3
# 输入的模型结果数量: 3
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'type': 'artist', 'title': '{artist_name}'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'type': 'album'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'album by this artist', 'type': 'album'}}
#
# 有效结果数量: 3
# 对应权重: [1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_play_control', 'arguments': {'type': 'artist', 'title': '{artist_name}'}}, {'name': 'music_play_control', 'arguments': {'type': 'album'}}, {'name': 'music_play_control', 'arguments': {'title': 'album by this artist', 'type': 'album'}}] <class 'list'>
#
# ==================================================
# 处理Query: Could you please start streaming the TV series 'Stranger Things'?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Stranger Things', 'type': 'tv'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Stranger Things', 'type': 'tv'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Stranger Things', 'type': 'tv'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Stranger Things', 'type': 'tv'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_play_control', 'arguments': {'title': 'Stranger Things', 'type': 'tv'}}, {'name': 'video_play_control', 'arguments': {'title': 'Stranger Things', 'type': 'tv'}}, {'name': 'video_play_control', 'arguments': {'title': 'Stranger Things', 'type': 'tv'}}, {'name': 'video_play_control', 'arguments': {'title': 'Stranger Things', 'type': 'tv'}}] <class 'list'>
#
# ==================================================
# 处理Query: Could you provide a list of all photo albums available?
# 模型数量: 3
# 输入的模型结果数量: 3
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
#
# 有效结果数量: 3
# 对应权重: [1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}] <class 'list'>
#
# ==================================================
# 处理Query: Could you provide a selection of animated series for kids?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'animated series for kids', 'type': 'tv'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'animated series for kids', 'type': 'tv'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'animated series for kids', 'type': 'tv'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'animated series for kids', 'type': 'tv'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_search_control', 'arguments': {'title': 'animated series for kids', 'type': 'tv'}}, {'name': 'video_search_control', 'arguments': {'title': 'animated series for kids', 'type': 'tv'}}, {'name': 'video_search_control', 'arguments': {'title': 'animated series for kids', 'type': 'tv'}}, {'name': 'video_search_control', 'arguments': {'title': 'animated series for kids', 'type': 'tv'}}] <class 'list'>
#
# ==================================================
# 处理Query: Could you provide detailed information about the device and storage on this system?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: [{'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'storage'}}]
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'storage'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, [{'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'storage'}}], {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'storage'}}] <class 'list'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[109], line 2
#       1 # 批量处理
# ----> 2 batch_results = batch_vote_for_queries(result_df)
#
# Cell In[96], line 22, in batch_vote_for_queries(df_grouped_data)
#      19     print(f"模型数量: {len(model_function_calls)}")
#      21     # 对当前query进行投票
# ---> 22     voted_result = vote_for_model_results(model_function_calls)
#      24     results.append({
#      25         'query': query,
#      26         'model_function_calls': model_function_calls,
#      27         'voted_function_call': voted_result
#      28     })
#      30 return pd.DataFrame(results)
#
# Cell In[93], line 92, in vote_for_model_results(model_results)
#      90 print(parsed_results, type(parsed_results))
#      91 # voted_result = vote_for_nested_dict(parsed_results, weights)
# ---> 92 voted_result = simple_vote_function(parsed_results, weights)
#      94 return voted_result
#
# Cell In[93], line 14, in simple_vote_function(parsed_dicts, weights)
#      12 all_keys = set()
#      13 for d in parsed_dicts:
# ---> 14     all_keys.update(d.keys())
#      16 # 对每个键投票
#      17 for key in all_keys:
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
sample_grouped_data
# Out:
#       query                                model_function_call
# 0  设置音乐自动停止  [{'model': 'claude-sonnet-4', 'function_call':...
# 1      播放视频  [{'model': 'claude-sonnet-4', 'function_call':...

# %% [markdown]
# # 合并数据

# %%
f1 = "/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/function_call_0919/claude-sonnet-4-20250514_function_call_0919/output.csv"
f2 = "/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/function_call_0919/gemini-2.5-flash-lite_function_call_0919/output.csv"
f3 = "/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/function_call_0919/gpt4o_function_call_0919/output.csv"
f4 = "/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/function_call_0919/qwen3_4b_2507_function_call_0919/output.csv"

# f1 = "/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/function_call_0919/react_claude-sonnet-4-20250514_function_call_0919/output.csv"
# f2 = "/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/function_call_0919/react_gemini-2.5-flash-lite_function_call_0919/output.csv"
# f3 = "/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/function_call_0919/react_gpt4o_function_call_0919/output.csv"
# f4 = "/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/function_call_0919/react_qwen3_4b_2507_function_call_0919/output.csv"

# %%
def change_decode(function_call):
    # 解码并重新编码为正确格式
    function_call_data = json.loads(function_call)
    function_call_new= json.dumps(function_call_data, ensure_ascii=False)
    return function_call_new

# %%
df1 = pd.read_csv(f1)
df1['function_call_model'] = 'claude-sonnet-4'
print(df1.shape, df1.columns)
df2 = pd.read_csv(f2)
df2['function_call_model'] = 'gemini-2.5'
print(df2.shape, df2.columns)
df3 = pd.read_csv(f3)
df3['function_call_model'] = 'gpt-4o'
print(df3.shape, df3.columns)   
df4 = pd.read_csv(f4)
df4['function_call_model'] = 'qwen3-4b-2507'
print(df4.shape, df4.columns)

# 找出在df3里但不在df2里的query
queries_in_df3 = set(df3['query'])
queries_in_df2 = set(df2['query'])
queries_only_in_df3 = queries_in_df3 - queries_in_df2

# print(f"\ndf3中的query数量: {len(queries_in_df3)}")
# print(f"df2中的query数量: {len(queries_in_df2)}")
# print(f"只在df3中存在的query数量: {len(queries_only_in_df3)}")

# if len(queries_only_in_df3) > 0:
#     print(f"\n只在df3中存在的query前10个:")
#     for i, query in enumerate(list(queries_only_in_df3)[:10]):
#         print(f"{i+1}. {query}")
# Out:
# (3046, 11) Index(['query', 'dimension', 'language', 'function', 'function_hash',
#        'provider', 'model', 'functions', 'prompt', 'function_call',
#        'function_call_model'],
#       dtype='object')
# (3057, 11) Index(['query', 'dimension', 'language', 'function', 'function_hash',
#        'provider', 'model', 'functions', 'prompt', 'function_call',
#        'function_call_model'],
#       dtype='object')
# (3432, 11) Index(['query', 'dimension', 'language', 'function', 'function_hash',
#        'provider', 'model', 'functions', 'prompt', 'function_call',
#        'function_call_model'],
#       dtype='object')
# (3387, 11) Index(['query', 'dimension', 'language', 'function', 'function_hash',
#        'provider', 'model', 'functions', 'prompt', 'function_call',
#        'function_call_model'],
#       dtype='object')

# %%
df1['function_call'] = df1['function_call'].apply(lambda x: change_decode(x))
df2['function_call'] = df2['function_call'].apply(lambda x: change_decode(x))
df3['function_call'] = df3['function_call'].apply(lambda x: change_decode(x))
df4['function_call'] = df4['function_call'].apply(lambda x: change_decode(x))

# %%
queries_only_in_df3
# Out:
# {' vender 给了我一个保修号，我需要核对一下设备信息。',
#  'Add a new album to my photo library',
#  'Adjust music app settings for automatic stop after a specified time',
#  'After our last discussion, could you clarify which albums are available?',
#  "After uploading several photos, now it's time to make an album",
#  'Als Anfänger, wie erstelle ich ein neues Fotoalbum?',
#  'Als Profi im Bereich Fotoverwaltung möchte ich die vollständige Liste aller Albumtypen erhalten.',
#  'As a photography enthusiast, how can I create a new album?',
#  'As a professional photographer, I need to create an album quickly.',
#  'As follow-up, can you list albums focusing on specific categories?',
#  'Automatische Abschaltung der Musik konfigurieren',
#  'Begin streaming the sci-fi films from my recent history, urgently!',
#  'Benötige dringend ein neues Album für meine Fotos',
#  'Bilder finden und anzeigen',
#  'Bitte die Alben auflisten.',
#  'Bitte ein Album erstellen.',
#  'Bitte empfehle mir gute Filme zum Anschauen.',
#  'Bitte erstelle ein neues Fotoalbum',
#  'Bitte erstellen Sie ein Fotoalbum für mich.',
#  'Bitte exportieren Sie die Liste aller verfügbaren Albumkategorien',
#  'Bitte führen Sie eine Videosuche nach dem Titel durch',
#  'Bitte hilf mir, eine gute Dramaserie zu finden.',
#  'Bitte starte das video-on-demand Angebot.',
#  'Can a new album be created?',
#  'Can you create a new photo album for me?',
#  'Can you fetch some photos for me?',
#  'Can you find a TV show for me?',
#  'Can you help me find a good show to binge-watch this weekend?',
#  'Can you help me search for photos?',
#  'Can you help me start a photo album?',
#  'Can you make a new photo album for me?',
#  'Can you play something relaxing for me?',
#  'Can you play the latest episode of my favorite TV show?',
#  'Can you please fetch the albums for viewing?',
#  'Can you please play the prioritized video content from my watchlist?',
#  'Can you repeat the last album I played?',
#  'Can you search for TV shows?',
#  'Can you search for television dramas?',
#  'Can you show me different types of photo albums?',
#  'Can you show me that documentary I saved to my favorites?',
#  'Configure music settings to automatically stop playing music',
#  'Could you clarify the steps to make a photo album after uploading pictures?',
#  'Could you filter my albums to just show regular and baby albums?',
#  'Could you find the movie matching the specified title?',
#  'Could you help me set up a photo album?',
#  'Could you kindly help me by making a new album?',
#  'Could you look up TV series and movies?',
#  'Could you look up some photos for me?',
#  'Could you play music?',
#  'Could you play the latest episodes of my favorite TV series?',
#  'Could you please create a photo album for me?',
#  'Could you please create an album for my photos?',
#  'Could you please play that romantic comedy for me?',
#  'Could you provide the assortment of albums?',
#  'Could you retrieve the set of photo albums?',
#  'Create a brand-new photo album',
#  'Create a new photo album',
#  'Create an album',
#  'Create an album now',
#  'Create an album now.',
#  'Create another photo album like the previous one',
#  'Display comprehensive system specifications and hardware information',
#  'During my lunch break, can you find that series I loved?',
#  'During my project, I need to reference my normal and face albums.',
#  'Ein neues Bildalbum soll angelegt werden',
#  'Empfehle mir Actionfilme aus den 90ern.',
#  'Entwickele ein neues Album für meine Fotos ',
#  'Erschaffe ein frisches Album für Fotos',
#  'Erstelle bitte ein Album für meine Bilder.',
#  'Erstelle bitte ein Standardalbum',
#  'Erstelle ein Album.',
#  'Erstelle ein neues Fotoalbum',
#  'Erstelle ein normales Fotoalbum',
#  'Erstellen Sie ein Album und bestätigen Sie die Erstellung.',
#  'Erzeuge ein neues Fotoalbum.',
#  'Es wäre gut, wenn die Musik nach einiger Zeit von selbst stoppt.',
#  'Establish a new album with my pictures',
#  'Fetch detailed data regarding the device, OS, storage, network status, warranty, or UGREEN Link account.',
#  'Find images using a keyword.',
#  'Find me some movies.',
#  'Find the TV show with a similar title.',
#  'Finde mir ein paar coole Filme.',
#  'For the upcoming event, I want to create a photo album beforehand.',
#  'Generate a new photo album.',
#  'Generate a normal type photo album with a specific name',
#  'Gerne die Timer-Einstellung für Musik ändern.',
#  'Get me a listing of all photo album types.',
#  'Gib mir die Fotoalben ohne Babyalben.',
#  'Gib mir eine Liste aller verfügbaren Fernsehprogramme.',
#  "Give me a breakdown of my device's specs, including the storage.",
#  'Got any recommendations for TV series?',
#  'Hallo, ich hätte gerne ein paar Lieder.',
#  'Help me find a movie please!',
#  'Help me make a simple photo album please',
#  'Help me stop music automatically by adjusting the playback settings',
#  'How can I search for specific photos?',
#  'How do I watch my favorite movies from last month?',
#  'I am seeking photos to enhance my presentation',
#  'I need a normal album made real quick.',
#  'I need a standard photo album to organize my pictures',
#  'I need something to relax. Can you play a TV series?',
#  'I need those albums right now!',
#  "I need to create a photo album, but I'm not sure how.",
#  'I need to find a good series before the holidays.',
#  'I need to listen to a specific track again.',
#  'I need to play a specific song title.',
#  'I need to set up a photo album. Could you assist with that?',
#  'I urgently need to create a photo album right now',
#  'I want to browse through my photo collections',
#  'I want to create a new photo album.',
#  'I want to listen to some tunes.',
#  'I want to organize my pictures into a new album',
#  'I want to review all my picture albums.',
#  'I want to see the full album list.',
#  'I want to set a sleep timer for the music app to stop after a chosen time',
#  'I would like to retrieve my album collection.',
#  'I would like to see some images, please.',
#  "I'd like to hear some music please",
#  "I'd like to hear some music, please.",
#  "I'm facing trouble creating an album. What should I do?",
#  "I'm hosting a movie night, what should I watch?",
#  "I'm looking for a collection of movies, can you help?",
#  "I'm looking for a movie to watch with my family.",
#  "I'm looking to explore my photo collections. Could I get a list?",
#  "I'm new to using this tool, can you show me some films?",
#  "I'm ready to unwind with a comedy series. Could you play one for me?",
#  "I'm trying to find a photo; can you help?",
#  "I'm trying to find a specific TV series",
#  "I'm trying to organize my photos into a new album",
#  "I've watched many films. Any recommendations based on my past searches?",
#  'Ich benötige Zugriff auf meine Fotoalben.',
#  'Ich bin neu hier. Welche Arten von Fotoalben kann ich finden?',
#  'Ich bin nicht sicher, wie man ein neues Album erstellt. Kannst du mir dabei helfen?',
#  'Ich brauche Fotos, um meine Idee zu veranschaulichen.',
#  'Ich brauche Musik für meine Workout-Session, was kannst du mir empfehlen?',
#  'Ich brauche die Fotoalben.',
#  'Ich brauche dringend dieses Bild',
#  'Ich brauche dringend etwas Hintergrundmusik.',
#  'Ich brauche ein neues Fotoalbum, kannst du das erstellen?',
#  'Ich brauche eine Liste meiner normalen und Bedingungsalben.',
#  'Ich brauche eine passende Serie für den Abend.',
#  'Ich brauche jetzt sofort einen guten Film.',
#  'Ich fahre bald los, sorge dafür, dass die Musik dann stoppt.',
#  'Ich habe Lust auf etwas Entspannendes, spiel bitte eine ruhige Playlist.',
#  'Ich habe es eilig, spiel den letzten Film, den ich gespeichert habe.',
#  'Ich habe viele Bilder von meinem letzten Urlaub, ich möchte ein Album anlegen.',
#  'Ich habe viele Fotos und brauche ein neues Album dafür',
#  'Ich halte eine Präsentation, gib mir etwas Beruhigendes zum Hören.',
#  'Ich muss alle meine Fotoalben sehen',
#  'Ich muss dringend eine bestimmte Serie finden',
#  'Ich möchte Filme finden.',
#  'Ich möchte Musik hören',
#  'Ich möchte Musik hören.',
#  'Ich möchte ein Album erstellen.',
#  'Ich möchte ein Album zusammenstellen, wo die besten Bilder gesammelt werden.',
#  'Ich möchte ein neues Fotoalbum erstellen.',
#  'Ich möchte eine Filmreihe durchschauen, kannst du mir helfen?',
#  'Ich möchte, dass ein neues Fotoalbum für meine Kinder erstellt wird.',
#  'Ich plane eine Fotowand für mein neues Büro und benötige ein Album für die Bilder.',
#  'Ich plane einen Filmeabend, welche Filme sollte ich auswählen?',
#  'Ich sammle Fotos für ein Projekt und benötige ein entsprechendes Album',
#  'Ich will Bilder finden, die meine Botschaft unterstützen.',
#  'Ich will einen Actionfilm sehen.',
#  'If I want to review some classic shows, what do you recommend?',
#  'Implement a timer to end music playback after a short period.',
#  'In which TV series can I find the title that was mentioned?',
#  'Initialisiere eine neue Album-Instanz vom Typ normal',
#  'Initialize a new photo album instance with default type parameters',
#  'Initiate playback of a song.',
#  'Is this TV series available in your database?',
#  "It's time for some background music.",
#  "Just checking, can you play any TV series that I haven't finished?",
#  'Kann nicht das richtige Foto für meine Präsentation finden',
#  'Kannst du das Album nochmal neu anlegen mit einem anderen Namen?',
#  'Kannst du die Musikeinstellungen so ändern, dass die Wiedergabe automatisch endet?',
#  'Kannst du die neueste Episode der Serie abspielen, die ich momentan schaue?',
#  'Kannst du ein neues Album erstellen?',
#  'Kannst du einen Film finden?',
#  'Kannst du einen Sleep-Timer für die Musik einstellen?',
#  'Kannst du mir bitte dabei helfen, ein Album für meine Bilder zu erstellen?',
#  'Kannst du mir die Alben auflisten?',
#  'Kannst du mir die Liste der Bilderalben anzeigen?',
#  'Kannst du mir zeigen, welche Filme gerade im Kino laufen?',
#  'Kindly share comprehensive system details suitable for technical analysis.',
#  'Konfiguriere die Musik-App so, dass sie automatisch stoppt.',
#  'Können Sie mir bei der Suche nach Filmen helfen?',
#  'Können Sie mir bei der Suche nach einer Fernsehserie assistieren?',
#  'Könnten Sie bitte ein Fotoalbum erstellen?',
#  'Könnten Sie bitte nach diesem Film suchen?',
#  'Könnten Sie das gewählte Programm wiedergeben?',
#  'Könntest du bitte ein neues Album für Fotos erstellen?',
#  'Könntest du bitte nach Filmen suchen und mir diese auflisten?',
#  'Könntest du ein Album für meine Fotos erstellen?',
#  'Könntest du mir die beliebtesten Lieder der letzten Woche abspielen?',
#  'Lass die Musik nach einer bestimmten Zeit aufhören.',
#  'Lass uns eine Serie schauen.',
#  'Leg mal ein bisschen Musik auf.',
#  'Lege die Musik-Schlaffunktion fest.',
#  'Lege ein neues Album für meine Bilder an',
#  'Legen Sie ein Album für meine Fotos an',
#  'Legen Sie ein neues Fotoalbum an, das öffentlich sichtbar ist',
#  'List photo albums now!',
#  'Liste alle Alben, die entweder normale, Gesichts-, Baby-, bedingte oder Objekterkennungsalben sind.',
#  'Load my photo albums',
#  'Locate episodes of the series based on the name.',
#  'Locate media files quickly.',
#  'Locate the movie collection based on the given title.',
#  'Looking for a movie collection.',
#  'Looking for a movie to watch tonight',
#  'Loop this entire album',
#  'Mach mir mal schnell ein neues Fotoalbum',
#  'Make a general photo album without any specific theme',
#  'Make a photo album for me',
#  'Mein Ziel ist es, alle verfügbaren Alben zu sehen',
#  'Mein Ziel ist es, ein neues Fotoalbum zu haben',
#  'Musik abspielen',
#  'My goal is to establish a new photo album. Can this be done?',
#  'My goal is to have a new photo album created',
#  'My goal is to have background music playing',
#  'Nach dem Urlaub möchte ich ein Album für die neuen Bilder erstellen',
#  'Nach dem Urlaub möchte ich ein neues Fotoalbum anlegen',
#  'Need to check if you have this show for my watchlist',
#  'Need to locate this TV show ASAP',
#  'Need to make an album to share with family',
#  'Neues Fotoalbum anlegen',
#  'Obtain detailed insights on the system, device, storage, network status, warranty, or UGREEN Link account.',
#  'Play some upbeat music for my workout session.',
#  'Play something from my favorite TV shows',
#  'Play something from what I listened to yesterday',
#  'Play the album I saved last week in loop mode.',
#  'Play the video content now.',
#  'Please assist in adjusting the music settings for a scheduled auto-stop feature',
#  'Please conduct a search for movies and TV shows urgently.',
#  'Please create a photo album for me.',
#  'Please establish a new photo album for organizational purposes',
#  'Please find all relevant images.',
#  'Please find available video titles for me.',
#  'Please find me some good movies.',
#  'Please give me an overview of what photo albums I can access.',
#  'Please initiate audio entertainment for our meeting background',
#  'Please provide access to the company photo album repository',
#  'Please search for the TV show using the title input.',
#  'Please share the status of the network for urgent troubleshooting.',
#  'Query video database for television series containing keyword',
#  'Request creation of a standard photo repository',
#  "Retrieve detailed information about the device's hardware specifications and warranty.",
#  'Retrieve my entire album collection.',
#  'Retrieve the list of photo albums, including regular, people, baby, conditional, and object recognition albums.',
#  'Richte mir bitte eine neue Fotogalerie ein',
#  'SNSに投稿するための面白い画像を探してます。',
#  'Schnell - ich brauche alle meine Fotoalben!',
#  'Search for some video content.',
#  'Search the video library',
#  'Set me up with a fresh album for storing images',
#  'Set timer to stop music',
#  'Set up a new album for my pictures',
#  'Set up a new album with normal settings for my photos',
#  'Setting up the music app to automatically stop playing after a certain duration',
#  'Setze die Musikwiedergabe fort.',
#  'Setze die automatische Stoppzeit für Musik.',
#  'Show me all my photo albums',
#  'Show me some pictures.',
#  'Spiel den Film ab, den ich grade in meine Favoriten gespeichert habe',
#  'Spiel eine Serie ab.',
#  'Spiel einen Film ab',
#  'Spiel jetzt sofort die aktuellsten Songs ab.',
#  'Spiele bitte das neueste Album von Ed Sheeran.',
#  'Spiele mir einen Film ab.',
#  'Start playing music now.',
#  'Start playing music, please.',
#  'Start streaming The Office',
#  'Starte den Actionfilm, den ich gestern gespeichert habe.',
#  'Starte die Musikwiedergabe.',
#  'Starten Sie den Blockbuster aus meiner Favoritenliste.',
#  'Stoppe die Musik nach Ablauf des Timers.',
#  'Suche nach Filmen, die ich mag.',
#  'Suche nach TV-Serien und Filmen.',
#  'Suche nach einem Film oder einer Serie.',
#  'Suchst du nach Bildern für meinen Reiseführer?',
#  'Urgently, I need to set up a photo album for a client.',
#  'User needs a comprehensive list of all photo albums.',
#  'Videosuche starten',
#  'Want to find all movies in this franchise',
#  'Was hättest du für Musik, um eine Party zu feiern?',
#  'Was kann ich für einen entspannten Abend anschauen?',
#  'Was kann ich mir heute Abend ansehen? Zeig mir das!',
#  'Was sind die Optionen für verschiedene Fotoalben?',
#  'Watch something',
#  'We urgently need to create a new album for the event',
#  "We've finished the series. Are there more like it in your search tool?",
#  'Welche Arten von Alben gibt es in meiner Foto-Bibliothek?',
#  'Welche Filme habe ich zuletzt gesehen, die du abspielen kannst?',
#  'Welche Filme solltest du dir an einem Freitagabend ansehen?',
#  'Welche verschiedenen Albumtypen sind in meiner Bibliothek?',
#  'Welcher Titel interessiert dich?',
#  'What TV series match this title?',
#  'What are all the categories of photo albums I have?',
#  'What are the latest movie releases?',
#  'What are the top animated movies for kids?',
#  'What movie series are trending?',
#  'What movie title would you suggest for searching?',
#  'What steps do I take to create a photo album?',
#  "What's the process to set up a new album?",
#  'When can I create a new album for the photos I just took?',
#  'Which photo albums are currently available to view?',
#  'Wie kann ich auf meine Albensammlung zugreifen?',
#  'Would you be able to set up a photo album for me?',
#  'Would you mind starting some music?',
#  'Would you please help me find this movie collection?',
#  'Wären Sie so freundlich, ein Album für meine Fotos anzulegen?',
#  'Würden Sie so freundlich sein und ein neues Fotoalbum anlegen?',
#  'Zeig mir die letzten Videos, die ich geschaut habe.',
#  'Zeig mir einen Film oder eine Serie aus meinen Favoriten.',
#  'Zeige mir etwas aus meiner Watchlist',
#  'Zeigen Sie den Trailer des neuesten Films in meiner Watchlist.',
#  'create_albumファンクションを実行してください',
#  'Übersicht aller intelligenten Albumkategorien',
#  'あのテレビドラマの再生をお願いできますか？',
#  'おすすめのテレビドラマシリーズを教えて',
#  'お写真のアルバムを作成したいのですが、アルバム名とタイプを教えていただけますか？',
#  'お気に入りに入れてあるジブリ映画を見る',
#  'お気に入りのテレビ番組を再生したい',
#  'お気に入りのドラマを再生してもらえますか？',
#  'お気に入りの映画を再生',
#  'お気に入りの映画を再生して',
#  'お気に入りの映画を再生していただけますか？',
#  'お気に入りの映画を再生できない問題があります。',
#  'お願いして、写真アルバムを作成できますか？',
#  'こちらを検索してください！',
#  'このアルバムをリピートモードで再生',
#  'このジャンルの映画を詳しく教えてくれませんか？',
#  'このテーマに関連する写真を探してください。',
#  'このドラマの続きが気になる',
#  'この映画の続編があれば知りたいです。',
#  'この映画見せて！',
#  'この曲が好きなので再生して欲しいです。',
#  'この曲をかけてください',
#  'この特定のキーワードに基づいて写真を探しています。',
#  'こんにちは、映画のタイトルで検索したいのですが。',
#  'すぐに映画が見たいんだ',
#  'すぐに音楽を再生してほしい',
#  'すみませんが、ビデオを検索してください。',
#  'どのような作品があるでしょうか？',
#  'どのビデオを再生しますか？',
#  'どの種類の映画を探していますか？',
#  'どんなアルバムがあるか教えて',
#  'どんな映画が見たいですか？',
#  'もし可能なら、映画の再生をお願いします。',
#  'アルバムづくり初心者です。新しいものを作成するには？',
#  'アルバムのリストを教えてください。',
#  'アルバムの一覧を表示してください',
#  'アルバムの作成をお願いします',
#  'アルバムの種類について詳細を教えていただけますか？',
#  'アルバムの種類を教えてほしいです。',
#  'アルバムの種類別リストを提示せよ',
#  'アルバムを作成',
#  'アルバムを作成したいのですが、可能ですか？',
#  'アルバムを作成してください。',
#  'アルバムを作成せよ。',
#  'アルバムを再生してください。',
#  'アルバムを取得してください。',
#  'アルバムを技術的に作成する方法を教えてください。',
#  'アルバムを新しく作ってみたいです',
#  'アルバムを新しく作ってもらえますか？',
#  'アルバムを新しく作る方法を知りたい。',
#  'アルバム一覧を出力',
#  'アルバム一覧を取得したいです',
#  'アルバム名を指定してフォトアルバムを作成してください。',
#  'イメージ検索をお願いします',
#  'コンテンツの再生を開始してください',
#  'コンテンツ検索システムにアクセスしたく',
#  'システム情報、デバイス情報、ストレージ情報、ネットワーク情報、UGREEN Link関連情報を取得する方法を知りたいです。',
#  'シーン別にフォトアルバムリストを取得する手順を教えてください',
#  'ジャンルを指定せずに映画を再生したいです。',
#  'タイトルを入力して映画を検索します。',
#  'テレビシリーズの検索をお願いできますか？',
#  'テレビシリーズ検索ツール使用方法',
#  'テレビ番組を再生してほしい',
#  'テレビ番組を再生する',
#  'テレビ番組を探して',
#  'テレビ番組を検索',
#  'テレビ番組検索の続きとして、このタイトルを使用してください。',
#  'デバイスやオペレーティングシステム、ストレージ、ネットワークの状況、保証、UGREEN Linkアカウントに関する詳細情報を取得したいんですが。',
#  'デバイスやネットワークの詳細情報を専門的な言葉で教えていただけますか？',
#  'ドラマを最後まで観るために再生してくれ。',
#  'ノーマルタイプの写真アルバムを新規作成',
#  'ビジネスで使うため、音楽アプリの自動停止時間を設定したいです。',
#  'ビジネスプロフェッショナル向けのアルバムリスト取得手順を示してください',
#  'ビデオの種類と再生方法を教えてください。',
#  'ビデオを探しています。',
#  'ビデオを検索したいんですけど',
#  'ビデオ探しを手伝ってください。',
#  'フォトを見つけて',
#  'フォトアルバムのリストを取得するにはどうすればよいですか？',
#  'フォトアルバムを新規作成したいのですが',
#  'プレイリストの再生モードをシングルリピートに設定',
#  'プレイリストの楽曲再生機能を実行してください',
#  'プレゼンテーション用の画像素材を検索する必要があります',
#  'プロフェッショナルな言葉で保証やストレージ情報についてお知らせください。',
#  'ランダム再生で音楽をかけて',
#  'リラックスタイムに音楽を流してほしい',
#  '专业一点，我需要播放某个专辑，请告诉我怎么做。',
#  '为了保存这些图片，创建一个相册吧',
#  '今おすすめのテレビシリーズは何ですか？',
#  '今すぐドラマを再生してください。',
#  '今すぐ新しいアルバムを作りたい！',
#  '今日の気分に合うプレイリストを再生してくれる？',
#  '从记录中重新观看我上次没看完的视频。',
#  '仕事中に聴くためのプレイリストを探して再生してください。',
#  '以专业术语展示所有相册清单。',
#  '何か音楽流してよ',
#  '作为管理员，我需要创建一个新相册。',
#  '作業用にループ再生で音楽をお願いします',
#  '你能帮我找找我收藏的电影吗？',
#  '假期结束了，现在我要为这些照片建立一个新相册。',
#  '再生モードをループに設定してください。',
#  '写メ探せる？',
#  '写真が見つからないので探してほしい',
#  '写真のアルバム、たとえば人物、赤ちゃん、条件、物体の種類別に見たい。',
#  '写真のアルバムを作りたいです',
#  '写真を保存するアルバムがない',
#  '写真を探して',
#  '写真を探していただけませんでしょうか',
#  '写真を整理するためのアルバムが必要です',
#  '写真を検索したい',
#  '写真を検索して',
#  '写真アルバムの作成をお願いできますでしょうか',
#  '写真アルバムを作成してください',
#  '写真アルバムを探していますが、どこでリストを見ることができますか？',
#  '写真管理アプリで、アルバムの種類ごとの一覧を見たいです。',
#  '写真見つけたいんだけど～',
#  '列出我所有的相册，包括人脸识别、宝宝照和条件筛选的。',
#  '创建一个普通相册',
#  '创建相册',
#  '创建相册！',
#  '初心者向けにシステム情報やアカウント情報を教えてもらえますか？',
#  '制作一个标准相册来存放照片',
#  '加班累了，继续看未看完的综艺节目',
#  '加载电视剧内容，并立即开始播放。',
#  '動画コンテンツを探しています',
#  '動画作品の検索をお願いいたします',
#  '動画検索',
#  '单曲循环播放这首歌',
#  '单曲循环这首歌',
#  '友達との旅行用のアルバムを作りたいです。',
#  '可以帮我找到一些图片吗？',
#  '可以帮我播放电影吗？',
#  '可以给我播放这个专辑吗？',
#  '听说这部剧不错，能帮我找到吗',
#  '在家休息，想网上搜索一些电影。',
#  '夕食の後に家族と一緒に見たいので、この映画を再生して。',
#  '好きなアーティストの曲を今すぐ流したいです。',
#  '寝る前に見たい映画を再生して',
#  '寝る前に軽く映画でも見ようかな',
#  '寻找那个电视剧的名字。',
#  '専門家として、音楽アプリの再生停止設定を指示したい。',
#  '専門的な表現でフォトアルバムリストを取得する手順を教えてください',
#  '専門的な表現で写真を探してください。',
#  '展示人物相册里的所有照片。',
#  '希望能找到一部我收藏的经典影片。',
#  '帮我列出所有类型的相册',
#  '帮我创建相册',
#  '帮我在图库中检索图片',
#  '帮我建一个照片集',
#  '帮我找一些照片',
#  '帮我找找照片。',
#  '帮我放首歌',
#  '帮我生成一个相册。',
#  '帮我看看有哪些相册，常规的、人脸的、宝宝的、带条件的，还有识别物体的，都给我看看。',
#  '帮我设置音乐自动停止时间',
#  '建立一个照片专辑',
#  '开启音乐播放模式',
#  '循环播放歌单',
#  '快速展示所有照片册。',
#  '急いでアルバムを作成してください。',
#  '急いでアルバム作ってもらえる？',
#  '急いでプレゼン用の画像を探してます',
#  '急需找到某张照片',
#  '您能帮我找到一部经典电影吗？',
#  '您能帮我搜索一部电视剧吗？',
#  '想找部老电影回忆一下，麻烦帮我搜索',
#  '想把照片分类，需要新建相册',
#  '想看与最近的名人相关的电视剧。',
#  '想确认一下保修期和设备序列号信息',
#  '想给孩子的照片建个新专辑',
#  '我下周想免费看个电影，有什么好选择吗？',
#  '我不知道怎么创建相册，你能帮我吗？',
#  '我之前创建的相册有点不满意，想再做一个更好的，可以帮我吗？',
#  '我准备好了，让我们看一集电视剧吧。',
#  '我刚参加了一个旅行团，可以为此次旅行创建一个相册吗？',
#  '我发现了一部新电影，播放一下看看效果。',
#  '我只是一位普通用户，能不能帮我做个简单的相册？',
#  '我希望立即播放最新上映的电影',
#  '我希望能够找到所有的相册，不同类型的都可以。',
#  '我急需一些音乐来放松心情，能不能帮我找找？',
#  '我想了解这台设备的操作系统版本和硬件配置',
#  '我想创建一个新的相册。',
#  '我想创建一个普通类型的相册。',
#  '我想听歌',
#  '我想听点歌',
#  '我想在工作中使用不同的相册种类，有哪些选择？',
#  '我想搜索一部电视剧',
#  '我想整理相册，能不能显示我所有的相册类型？',
#  '我想新建一个相册',
#  '我想查找一部电影的名字',
#  '我想看一些图片。',
#  '我想要详细了解不同类型的相册',
#  '我想重温一下之前看过的电视剧，查找一下吧。',
#  '我的目标是找到特定的图片',
#  '我的目标是组织我的图片，需要新建一个相册。',
#  '我要创建一个常规相册。',
#  '我要创建一个新的相册。',
#  '我要创建一个相册',
#  '我要整理照片，先创建个相册',
#  '我要看电视剧，立即播放。',
#  '我需要一个新的相册',
#  '我需要浏览所有相册',
#  '我需要知道电影的名称',
#  '打开我收藏的那部古装剧呗',
#  '打开相册列表',
#  '执行图像检索功能',
#  '执行相册创建操作',
#  '执行音乐播放指令',
#  '找到电影并播放给我。',
#  '把所有相册的目录列出来。',
#  '搜索最新上映的电影',
#  '搜索照片',
#  '搜索这部电影的名称是什么？',
#  '播放一下我收藏的所有电视剧。',
#  '播放一首歌',
#  '播放我刚刚搜索过的电视连续剧。',
#  '播放我最近看的电视剧',
#  '播放收藏夹中的电影',
#  '播放最近观看的电视剧',
#  '播放歌曲',
#  '播放电影',
#  '播放视频',
#  '播放视频内容',
#  '播放这首歌',
#  '播放音乐',
#  '新しいアルバムが必要ですので、作成手続きを教えてください。',
#  '新しいアルバムを作っていただけませんか？',
#  '新しいアルバムを作ることはできますか',
#  '新しいアルバムを作成したいけど、どうしたらいいの？',
#  '新しいアルバムを作成したいですが、詳細な手順を教えてください。',
#  '新しいアルバムを作成したいと思っています。',
#  '新しいアルバムを作成してください',
#  '新しいアルバムを作成することが目標です。',
#  '新しいアルバムを作成せよ',
#  '新しいフォトアルバムを作ってください。',
#  '新しいフォトアルバムを作成したいです。',
#  '新しい写真アルバムを作成してください',
#  '新建一个相册，类型选normal',
#  '新建一个相片集',
#  '旅行中に映画を再生してほしい。',
#  '映像作品を探す方法を教えていただけますか',
#  '映像検索',
#  '映画のタイトルを検索してください',
#  '映画の再生ができていない問題があります。',
#  '映画の再生を開始して',
#  '映画をいくつか見たいんだ',
#  '映画を再生してくれますか',
#  '映画を急いで見たいので、再生してもらえますか？',
#  '映画を探しています。',
#  '映画を確認したいから再生して。',
#  '显示所有相册分类列表',
#  '显示所有相册清单给业务专业人士。',
#  '晚上睡前想让音乐自动停止',
#  '晚上适合播放哪种音乐？',
#  '曲が流れない問題を解決して。',
#  '曲をかけてくれる？',
#  '最新の映画検索',
#  '最近添加了什么新相册吗？我想看所有类型的。',
#  '最近見た履歴からビデオを再生する方法',
#  '最近見た映画を再生してください。',
#  '最近見た映画を再生してもらえますか？',
#  '最近観た映画の再生を開始してください。',
#  '有什么方法可以获得所有相册的列表？',
#  '有没有我的最爱列表里的电影？',
#  '有没有最近看过的剧？',
#  '查找图片',
#  '查看照片册清单，包括常规相册、人物相册、婴儿相册、条件相册和物体识别相册。',
#  '检索照片相册列表',
#  '業務用にアルバムを作成する手順を教えてください。',
#  '楽曲の再生をお願いします',
#  '楽曲をスタートしてください',
#  '気分転換に音楽を流したいな',
#  '照片太多了，需要一个相册来存放，麻烦新建一个。',
#  '照片数量增加了，是该新建相册的时候了。',
#  '特定のテーマで画像を探してもらえますか？',
#  '画像を探したいんですが',
#  '画像を探してください',
#  '画像を検索したいです。',
#  '画像を見つけたいです',
#  '看电视剧',
#  '给我列一个电影清单。',
#  '给我找到这个电影的名字。',
#  '给我推荐一些电影系列手册',
#  '给我播放歌单',
#  '给我播放音乐',
#  '给我设置一个音乐的睡眠定时。',
#  '老铁，给我放个电影呗',
#  '能不能帮我找一下这部电视剧',
#  '能不能给我播放音乐',
#  '能否为我提供常规相册的列表，例如普通、人物等？',
#  '能否告诉我那个电视剧的名字？',
#  '能否帮我找一下照片？',
#  '能否恢复刚才观看的电影进度',
#  '能否配置音乐休眠定时器',
#  '能帮我列出相册吗',
#  '能帮我开一个照片集吗？',
#  '能帮我找一下相片吗',
#  '能帮我找到一些图片吗？',
#  '能帮我把最近追的剧放出来吗？',
#  '能帮我播放一部电影吗？',
#  '能帮我放首歌吗',
#  '能推荐一些电视剧吗？',
#  '能给我推荐一下最近的热门影视吗？',
#  '能给我提供照片相册的列表吗？',
#  '観たい作品があるので探したいです',
#  '请为我建立一个新相册',
#  '请为我新建一个相册。',
#  '请你为我制作一个新的照片合集。',
#  '请列出所有的相册。',
#  '请创建一个新的照片相簿。',
#  '请协助检索相关图像资料',
#  '请协助检索该影片的具体信息',
#  '请将相册类型设置为“normal”。',
#  '请尽快给我推荐一些最近上映的大片。',
#  '请帮我创建一个相册。',
#  '请帮我搜索一下电影。',
#  '请帮我放首音乐',
#  '请帮我查找相册',
#  '请帮我调整音乐定时关闭功能',
#  '请您告诉我那个电视剧的名字。',
#  '请播放我喜欢的电影系列',
#  '请检索图像文件',
#  '请检索并播放影视资源《流浪地球》',
#  '请求创建新相册',
#  '请求设置音乐播放的自动结束时间。',
#  '请确保音乐在指定时间后会自动停止',
#  '请获取相册信息给我',
#  '请设定音乐应用的自动关闭时间选项',
#  '请问如何创建新的照片收藏夹？',
#  '请问如何设置音乐定时停止功能？',
#  '请问有没有好的电影推荐。',
#  '请问能否帮我新建一个照片专辑？',
#  '请问这部合集叫什么名字？',
#  '这个集合的名字是什么？',
#  '这是后续操作，帮我找电视剧名称',
#  '通常のアルバム、顔、赤ちゃん、条件、物体の各アルバムタイプを教えて',
#  '通常タイプのフォトアルバムを新しく作成したい',
#  '週末に観る映画を検索して',
#  '過去の名作映画をもう一度見たいです。',
#  '需要一个功能，让音乐在一段时间后自动停止。',
#  '需要建立一个照片管理相册',
#  '音楽が聴きたいんだけど、何かおすすめある？',
#  '音楽の再生を急いでお願いします。',
#  '音楽の再生時間を管理したいです',
#  '音楽の自動停止を設定したい',
#  '音楽をプレイしてもらえますか',
#  '音楽を停止したいのですが',
#  '音楽を流してください',
#  '音楽アプリの自動停止タイマーを使いたいのですが、どうすればいいですか？',
#  '音楽再生時間を設定してください',
#  '音楽設定を初心者向けに説明してください',
#  '音楽設定を調整する',
#  '麻烦帮我开一个新相册呗',
#  '麻烦帮我打开之前那部电影',
#  '麻烦帮我查一下这个电视剧',
#  '麻烦您帮忙查找照片',
#  '麻烦显示一下相册分类'}

# %%
# df = df1.copy()
df = pd.concat([df1, df2, df3, df4])
df.shape, df.columns
# Out:
# ((12922, 11),
#  Index(['query', 'dimension', 'language', 'function', 'function_hash',
#         'provider', 'model', 'functions', 'prompt', 'function_call',
#         'function_call_model'],
#        dtype='object'))

# %%
df.shape, df.columns
# Out:
# ((12922, 11),
#  Index(['query', 'dimension', 'language', 'function', 'function_hash',
#         'provider', 'model', 'functions', 'prompt', 'function_call',
#         'function_call_model'],
#        dtype='object'))

# %%
df.to_excel('/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/function_call_0919/merge_data.xlsx')

# %%
df
# Out:
#                                                   query            dimension  \
# 0     I need to set up a photo album. Could you assi...           Linguistic
# 1               How do I go about making a photo album?           Linguistic
# 2              Please create an album named 'Vacation'.           Linguistic
# 3     Create a photo album with the title 'Holiday M...          Specificity
# 4                I need a normal album made real quick.          Specificity
# ...                                                 ...                  ...
# 3372  Mein Gerät reagiert langsam, ich muss die Syst...  Contextual Scenario
# 3373                      Zeige mir alle Systemdetails.          Specificity
# 3374               Hol mir die Informationen zum Gerät.           Linguistic
# 3375  Ich möchte alle Systeminformationen sehen, ein...               Intent
# 3376          Technische Details des Systems auflisten.         User Persona
#
#      language                                           function  \
# 0     English  {\n  "name": "create_album",\n  "description":...
# 1     English  {\n  "name": "create_album",\n  "description":...
# 2     English  {\n  "name": "create_album",\n  "description":...
# 3     English  {\n  "name": "create_album",\n  "description":...
# 4     English  {\n  "name": "create_album",\n  "description":...
# ...       ...                                                ...
# 3372   German  {\n  "name": "get_system_info",\n  "descriptio...
# 3373   German  {\n  "name": "get_system_info",\n  "descriptio...
# 3374   German  {\n  "name": "get_system_info",\n  "descriptio...
# 3375   German  {\n  "name": "get_system_info",\n  "descriptio...
# 3376   German  {\n  "name": "get_system_info",\n  "descriptio...
#
#          function_hash provider                  model  \
# 0     dd2d2ca3743fef02   openai                 gpt-4o
# 1     dd2d2ca3743fef02   openai                 gpt-4o
# 2     dd2d2ca3743fef02   openai                 gpt-4o
# 3     dd2d2ca3743fef02   openai                 gpt-4o
# 4     dd2d2ca3743fef02   openai                 gpt-4o
# ...                ...      ...                    ...
# 3372  24719fdaa4ff4d76   google  gemini-2.5-flash-lite
# 3373  24719fdaa4ff4d76   google  gemini-2.5-flash-lite
# 3374  24719fdaa4ff4d76   google  gemini-2.5-flash-lite
# 3375  24719fdaa4ff4d76   google  gemini-2.5-flash-lite
# 3376  24719fdaa4ff4d76   google  gemini-2.5-flash-lite
#
#                                               functions  \
# 0     ['{\n  "name": "create_album",\n  "description...
# 1     ['{\n  "name": "create_album",\n  "description...
# 2     ['{\n  "name": "create_album",\n  "description...
# 3     ['{\n  "name": "create_album",\n  "description...
# 4     ['{\n  "name": "create_album",\n  "description...
# ...                                                 ...
# 3372  ['{\n  "name": "create_album",\n  "description...
# 3373  ['{\n  "name": "create_album",\n  "description...
# 3374  ['{\n  "name": "create_album",\n  "description...
# 3375  ['{\n  "name": "create_album",\n  "description...
# 3376  ['{\n  "name": "create_album",\n  "description...
#
#                                                  prompt  \
# 0     \n        You are designed to help with a vari...
# 1     \n        You are designed to help with a vari...
# 2     \n        You are designed to help with a vari...
# 3     \n        You are designed to help with a vari...
# 4     \n        You are designed to help with a vari...
# ...                                                 ...
# 3372  \n        You are designed to help with a vari...
# 3373  \n        You are designed to help with a vari...
# 3374  \n        You are designed to help with a vari...
# 3375  \n        You are designed to help with a vari...
# 3376  \n        You are designed to help with a vari...
#
#                                           function_call function_call_model
# 0     {"name": "get_album_list", "arguments": {"albu...     claude-sonnet-4
# 1     {"name": "create_album", "arguments": {"album_...     claude-sonnet-4
# 2     {"name": "create_album", "arguments": {"album_...     claude-sonnet-4
# 3     {"name": "create_album", "arguments": {"album_...     claude-sonnet-4
# 4     {"name": "create_album", "arguments": {"album_...     claude-sonnet-4
# ...                                                 ...                 ...
# 3372  {"name": "get_system_info", "arguments": {"sys...       qwen3-4b-2507
# 3373  {"name": "get_system_info", "arguments": {"sys...       qwen3-4b-2507
# 3374  {"name": "get_system_info", "arguments": {"sys...       qwen3-4b-2507
# 3375  {"name": "get_system_info", "arguments": {"sys...       qwen3-4b-2507
# 3376  {"name": "get_system_info", "arguments": {"sys...       qwen3-4b-2507
#
# [12344 rows x 11 columns]

# %%
df['model_function_call'] = df.apply(lambda row: {
    'model': row['function_call_model'], 
    'function_call': row['function_call']
}, axis=1)
result = df.groupby('query')['model_function_call'].apply(list).reset_index()

# %%
result.iloc[3416]['model_function_call']
# Out:
# [{'model': 'gemini-2.5',
#   'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#  {'model': 'gpt-4o',
#   'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'},
#  {'model': 'qwen3-4b-2507',
#   'function_call': '{"name": "get_album_list", "arguments": {"album_type": "normal"}}'}]

# %%
result.to_excel('/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/function_call_0919/query_and_function_call.xlsx')

# %%
df3[df3['query'] == '麻烦帮我开一个新相册呗']['function_call'].values[0]
# Out:
# '{"name": "create_album", "arguments": {"album_name": "新相册", "album_type": "normal"}}'

# %%
tmp = result[result['query'] == '麻烦帮我开一个新相册呗']
print(tmp['model_function_call'].values[0][0]['function_call'])
# Out:
# {"name": "create_album", "arguments": {"album_name": "新相册", "album_type": "normal"}}

# %%
print(tmp['model_function_call'].values[0])
# Out:
# [{'model': 'gpt-4o', 'function_call': '{"name": "create_album", "arguments": {"album_name": "\\u65b0\\u76f8\\u518c", "album_type": "normal"}}'}, {'model': 'qwen3-4b-2507', 'function_call': '{"name": "create_album", "arguments": {"album_name": "\\u65b0\\u76f8\\u518c", "album_type": "normal"}}'}]

# %%
result
# Out:
#                               query  \
# 0      vender 给了我一个保修号，我需要核对一下设备信息。
# 1        'Vikings' bitte abspielen.
# 2             15分で自動停止するように音楽設定してる？
# 3          15分後に自動で再生が停止する機能はありますか？
# 4           15分後に音楽が止まるように設定してください。
# ...                             ...
# 3412                麻烦您播放一下《长安十二时辰》
# 3413                麻烦播放我过去听过的音乐片段。
# 3414                     麻烦显示一下相册分类
# 3415                 麻烦设置一下音乐自动停止时间
# 3416             麻烦设置下音乐，让它50分钟后自己停
#
#                                     model_function_call
# 0     [{'model': 'claude-sonnet-4', 'function_call':...
# 1     [{'model': 'claude-sonnet-4', 'function_call':...
# 2     [{'model': 'claude-sonnet-4', 'function_call':...
# 3     [{'model': 'claude-sonnet-4', 'function_call':...
# 4     [{'model': 'claude-sonnet-4', 'function_call':...
# ...                                                 ...
# 3412  [{'model': 'claude-sonnet-4', 'function_call':...
# 3413  [{'model': 'claude-sonnet-4', 'function_call':...
# 3414  [{'model': 'claude-sonnet-4', 'function_call':...
# 3415  [{'model': 'gemini-2.5', 'function_call': '{"n...
# 3416  [{'model': 'claude-sonnet-4', 'function_call':...
#
# [3417 rows x 2 columns]

# %%
result.iloc[1]
# Out:
# query                                               15分でミュージックアプリの再生を止めて
# model_function_call    [{'model': 'claude-sonnet-4', 'function_call':...
# Name: 1, dtype: object

# %%
result.iloc[1]['model_function_call']
# Out:
# [{'model': 'claude-sonnet-4',
#   'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#  {'model': 'gemini-2.5',
#   'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#  {'model': 'gpt-4o',
#   'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#  {'model': 'qwen3-4b-2507',
#   'function_call': '{"name": "music_play_control", "arguments": {"title": "any_music_content", "type": "song", "source": "recent", "play_mode": "normal"}}'}]

# %%
batch_results_test = batch_vote_for_queries(result.ilo[0:2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_994087/4233326392.py in ?()
# ----> 1 batch_results_test = batch_vote_for_queries(result.ilo[0:2])
#
# ~/anaconda3/envs/py311_env_sdk/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ilo'

# %%
# 批量处理
batch_results = batch_vote_for_queries(result)
# Out:
# ==================================================
# 处理Query: 10分間だけ音楽を流してから停止したい
# 模型数量: 3
# 输入的模型结果数量: 3
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 10}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 10}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Music', 'type': 'album', 'play_mode': 'normal', 'source': 'recent'}}
#
# 有效结果数量: 3
# 对应权重: [2, 2, 0.5]
#
# 处理字段 'arguments': [{'auto_stop_time': 10}, {'auto_stop_time': 10}, {'title': 'Music', 'type': 'album', 'play_mode': 'normal', 'source': 'recent'}]
#
# 处理字段 'source': ['recent']
# 字段值投票: {'recent': 0.5}
#
# 处理字段 'type': ['album']
# 字段值投票: {'album': 0.5}
#
# 处理字段 'auto_stop_time': [10, 10]
# 字段值投票: {10: 4}
#
# 处理字段 'title': ['Music']
# 字段值投票: {'Music': 0.5}
#
# 处理字段 'play_mode': ['normal']
# 字段值投票: {'normal': 0.5}
#
# 处理字段 'name': ['music_settings_control', 'music_settings_control', 'music_play_control']
# 字段值投票: {'music_settings_control': 4, 'music_play_control': 0.5}
#
# ==================================================
# 处理Query: 15分でミュージックアプリの再生を止めて
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'any_music_content', 'type': 'song', 'source': 'recent', 'play_mode': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'title': 'any_music_content', 'type': 'song', 'source': 'recent', 'play_mode': 'normal'}]
#
# 处理字段 'source': ['recent']
# 字段值投票: {'recent': 0.5}
#
# 处理字段 'type': ['song']
# 字段值投票: {'song': 0.5}
#
# 处理字段 'auto_stop_time': [15, 15, 15]
# 字段值投票: {15: 5}
#
# 处理字段 'title': ['any_music_content']
# 字段值投票: {'any_music_content': 0.5}
#
# 处理字段 'play_mode': ['normal']
# 字段值投票: {'normal': 0.5}
#
# 处理字段 'name': ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_play_control']
# 字段值投票: {'music_settings_control': 5, 'music_play_control': 0.5}
#
# ==================================================
# 处理Query: 15分後に音楽が停止するようにタイマーをセットしてください
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}]
#
# 处理字段 'auto_stop_time': [15, 15, 15, 15]
# 字段值投票: {15: 5.5}
#
# 处理字段 'name': ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
# 字段值投票: {'music_settings_control': 5.5}
#
# ==================================================
# 处理Query: 15分後に音楽が止まるように設定するにはどうすれば良いですか？
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}]
#
# 处理字段 'auto_stop_time': [15, 15, 15, 15]
# 字段值投票: {15: 5.5}
#
# 处理字段 'name': ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
# 字段值投票: {'music_settings_control': 5.5}
#
# ==================================================
# 处理Query: 15分後に音楽を止めるようにお願いしたいです
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}]
#
# 处理字段 'auto_stop_time': [15, 15, 15, 15]
# 字段值投票: {15: 5.5}
#
# 处理字段 'name': ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
# 字段值投票: {'music_settings_control': 5.5}
#
# ==================================================
# 处理Query: 15分後に音楽を止めるようにアプリの設定を変更してもらえますか？
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}]
#
# 处理字段 'auto_stop_time': [15, 15, 15, 15]
# 字段值投票: {15: 5.5}
#
# 处理字段 'name': ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
# 字段值投票: {'music_settings_control': 5.5}
#
# ==================================================
# 处理Query: 15分後に音楽を自動停止させるように設定して
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}]
#
# 处理字段 'auto_stop_time': [15, 15, 15, 15]
# 字段值投票: {15: 5.5}
#
# 处理字段 'name': ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
# 字段值投票: {'music_settings_control': 5.5}
#
# ==================================================
# 处理Query: 15分後に音楽を自動停止するように設定して
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}]
#
# 处理字段 'auto_stop_time': [15, 15, 15, 15]
# 字段值投票: {15: 5.5}
#
# 处理字段 'name': ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
# 字段值投票: {'music_settings_control': 5.5}
#
# ==================================================
# 处理Query: 15分経ったら音楽が止まるようにできますか
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}]
#
# 处理字段 'auto_stop_time': [15, 15, 15, 15]
# 字段值投票: {15: 5.5}
#
# 处理字段 'name': ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
# 字段值投票: {'music_settings_control': 5.5}
#
# ==================================================
# 处理Query: 15分钟后自动停止音乐播放
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}]
#
# 处理字段 'auto_stop_time': [15, 15, 15, 15]
# 字段值投票: {15: 5.5}
#
# 处理字段 'name': ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
# 字段值投票: {'music_settings_control': 5.5}
#
# ==================================================
# 处理Query: 1時間のスリープタイマーをセットして
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'auto_stop_time': 60}, {'auto_stop_time': 60}, {'auto_stop_time': 60}, {'auto_stop_time': 60}]
#
# 处理字段 'auto_stop_time': [60, 60, 60, 60]
# 字段值投票: {60: 5.5}
#
# 处理字段 'name': ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
# 字段值投票: {'music_settings_control': 5.5}
#
# ==================================================
# 处理Query: 30分後に音楽再生を自動で終了させてください
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'auto_stop_time': 30}, {'auto_stop_time': 30}, {'auto_stop_time': 30}, {'auto_stop_time': 30}]
#
# 处理字段 'auto_stop_time': [30, 30, 30, 30]
# 字段值投票: {30: 5.5}
#
# 处理字段 'name': ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
# 字段值投票: {'music_settings_control': 5.5}
#
# ==================================================
# 处理Query: 8月に撮影された山の風景写真を探してください。
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '8月に撮影された山の風景写真'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '山の風景写真 8月'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '8月に撮影された山の風景写真'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '山の風景写真 8月'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'keyword': '8月に撮影された山の風景写真'}, {'keyword': '山の風景写真 8月'}, {'keyword': '8月に撮影された山の風景写真'}, {'keyword': '山の風景写真 8月'}]
#
# 处理字段 'keyword': ['8月に撮影された山の風景写真', '山の風景写真 8月', '8月に撮影された山の風景写真', '山の風景写真 8月']
# 字段值投票: {'8月に撮影された山の風景写真': 4, '山の風景写真 8月': 1.5}
#
# 处理字段 'name': ['search_photos', 'search_photos', 'search_photos', 'search_photos']
# 字段值投票: {'search_photos': 5.5}
#
# ==================================================
# 处理Query: Ab sofort Serie spielen.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Serie', 'type': 'tv'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_play_control', 'arguments': {'type': 'tv'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Serie', 'type': 'tv'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Serie', 'type': 'tv'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'title': 'Serie', 'type': 'tv'}, {'type': 'tv'}, {'title': 'Serie', 'type': 'tv'}, {'title': 'Serie', 'type': 'tv'}]
#
# 处理字段 'type': ['tv', 'tv', 'tv', 'tv']
# 字段值投票: {'tv': 5.5}
#
# 处理字段 'title': ['Serie', 'Serie', 'Serie']
# 字段值投票: {'Serie': 4.5}
#
# 处理字段 'name': ['video_play_control', 'video_play_control', 'video_play_control', 'video_play_control']
# 字段值投票: {'video_play_control': 5.5}
#
# ==================================================
# 处理Query: Abspielen: 'Interstellar'.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Interstellar', 'type': 'movie'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Interstellar', 'type': 'album'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Interstellar', 'type': 'movie'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Interstellar', 'type': 'movie'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'title': 'Interstellar', 'type': 'movie'}, {'title': 'Interstellar', 'type': 'album'}, {'title': 'Interstellar', 'type': 'movie'}, {'title': 'Interstellar', 'type': 'movie'}]
#
# 处理字段 'type': ['movie', 'album', 'movie', 'movie']
# 字段值投票: {'movie': 4.5, 'album': 1}
#
# 处理字段 'title': ['Interstellar', 'Interstellar', 'Interstellar', 'Interstellar']
# 字段值投票: {'Interstellar': 5.5}
#
# 处理字段 'name': ['video_play_control', 'music_play_control', 'video_play_control', 'video_play_control']
# 字段值投票: {'video_play_control': 4.5, 'music_play_control': 1}
#
# ==================================================
# 处理Query: Access device information.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'system_type': 'device'}, {'system_type': 'device'}, {'system_type': 'device'}, {'system_type': 'device'}]
#
# 处理字段 'system_type': ['device', 'device', 'device', 'device']
# 字段值投票: {'device': 5.5}
#
# 处理字段 'name': ['get_system_info', 'get_system_info', 'get_system_info', 'get_system_info']
# 字段值投票: {'get_system_info': 5.5}
#
# ==================================================
# 处理Query: Access the movie database for me.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': '*', 'type': 'movie'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'movie', 'type': 'movie'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'Inception', 'type': 'movie'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'title': '*', 'type': 'movie'}, {'title': 'movie', 'type': 'movie'}, {'title': 'Inception', 'type': 'movie'}]
#
# 处理字段 'type': ['movie', 'movie', 'movie']
# 字段值投票: {'movie': 4.5}
#
# 处理字段 'title': ['*', 'movie', 'Inception']
# 字段值投票: {'*': 2, 'movie': 2, 'Inception': 0.5}
#
# 处理字段 'name': ['video_search_control', 'video_search_control', 'video_search_control']
# 字段值投票: {'video_search_control': 4.5}
#
# ==================================================
# 处理Query: Add a new people album called 'Coworkers' to organize office photos
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'album_name': 'Coworkers', 'album_type': 'face'}, {'album_name': 'Coworkers', 'album_type': 'face'}, {'album_name': 'Coworkers', 'album_type': 'face'}, {'album_name': 'Coworkers', 'album_type': 'face'}]
#
# 处理字段 'album_type': ['face', 'face', 'face', 'face']
# 字段值投票: {'face': 5.5}
#
# 处理字段 'album_name': ['Coworkers', 'Coworkers', 'Coworkers', 'Coworkers']
# 字段值投票: {'Coworkers': 5.5}
#
# 处理字段 'name': ['create_album', 'create_album', 'create_album', 'create_album']
# 字段值投票: {'create_album': 5.5}
#
# ==================================================
# 处理Query: Adjust music app settings
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{}, {}, {}, {'auto_stop_time': 15}]
#
# 处理字段 'auto_stop_time': [15]
# 字段值投票: {15: 0.5}
#
# 处理字段 'name': ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
# 字段值投票: {'music_settings_control': 5.5}
#
# ==================================================
# 处理Query: Adjust settings to stop music after a specified time
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'auto_stop_time': 30}, {'auto_stop_time': 15}, {'auto_stop_time': 30}, {'auto_stop_time': 15}]
#
# 处理字段 'auto_stop_time': [30, 15, 30, 15]
# 字段值投票: {30: 4, 15: 1.5}
#
# 处理字段 'name': ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
# 字段值投票: {'music_settings_control': 5.5}
#
# ==================================================
# 处理Query: After receiving device details, what's the next step?
# 模型数量: 2
# 输入的模型结果数量: 2
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {}
#
# 有效结果数量: 2
# 对应权重: [1, 2]
#
# 处理字段 'arguments': [{'system_type': 'device'}]
#
# 处理字段 'system_type': ['device']
# 字段值投票: {'device': 1}
#
# 处理字段 'name': ['get_system_info']
# 字段值投票: {'get_system_info': 1}
#
# ==================================================
# 处理Query: After the party, I need an album for all the pictures.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Party', 'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'After Party Pictures', 'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'album_name': 'Party Photos', 'album_type': 'normal'}, {'album_name': 'Party', 'album_type': 'normal'}, {'album_name': 'After Party Pictures', 'album_type': 'normal'}, {'album_name': 'Party Photos', 'album_type': 'normal'}]
#
# 处理字段 'album_type': ['normal', 'normal', 'normal', 'normal']
# 字段值投票: {'normal': 5.5}
#
# 处理字段 'album_name': ['Party Photos', 'Party', 'After Party Pictures', 'Party Photos']
# 字段值投票: {'Party Photos': 2.5, 'Party': 1, 'After Party Pictures': 2}
#
# 处理字段 'name': ['create_album', 'create_album', 'create_album', 'create_album']
# 字段值投票: {'create_album': 5.5}
#
# ==================================================
# 处理Query: After the party, I need to organize photos into a new album.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'party', 'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'album_name': 'Party Photos', 'album_type': 'normal'}, {'album_name': 'party', 'album_type': 'normal'}, {'album_name': 'Party Photos', 'album_type': 'normal'}, {'album_name': 'Party Photos', 'album_type': 'normal'}]
#
# 处理字段 'album_type': ['normal', 'normal', 'normal', 'normal']
# 字段值投票: {'normal': 5.5}
#
# 处理字段 'album_name': ['Party Photos', 'party', 'Party Photos', 'Party Photos']
# 字段值投票: {'Party Photos': 4.5, 'party': 1}
#
# 处理字段 'name': ['create_album', 'create_album', 'create_album', 'create_album']
# 字段值投票: {'create_album': 5.5}
#
# ==================================================
# 处理Query: After the recent update, what’s changed in my operating system?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'system_type': 'system'}, {'system_type': 'system'}, {'system_type': 'system'}, {'system_type': 'system'}]
#
# 处理字段 'system_type': ['system', 'system', 'system', 'system']
# 字段值投票: {'system': 5.5}
#
# 处理字段 'name': ['get_system_info', 'get_system_info', 'get_system_info', 'get_system_info']
# 字段值投票: {'get_system_info': 5.5}
#
# ==================================================
# 处理Query: After the update, I want to see the system information.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'system_type': 'system'}, {'system_type': 'system'}, {'system_type': 'system'}, {'system_type': 'system'}]
#
# 处理字段 'system_type': ['system', 'system', 'system', 'system']
# 字段值投票: {'system': 5.5}
#
# 处理字段 'name': ['get_system_info', 'get_system_info', 'get_system_info', 'get_system_info']
# 字段值投票: {'get_system_info': 5.5}
#
# ==================================================
# 处理Query: After the update, verify all system components are working
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'system_type': 'system'}, {'system_type': 'system'}, {'system_type': 'system'}, {'system_type': 'system'}]
#
# 处理字段 'system_type': ['system', 'system', 'system', 'system']
# 字段值投票: {'system': 5.5}
#
# 处理字段 'name': ['get_system_info', 'get_system_info', 'get_system_info', 'get_system_info']
# 字段值投票: {'get_system_info': 5.5}
#
# ==================================================
# 处理Query: After uploading photos, can the list of albums be updated?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'album_type': 'normal'}, {'album_type': 'normal'}, {'album_type': 'normal'}, {'album_type': 'common'}]
#
# 处理字段 'album_type': ['normal', 'normal', 'normal', 'common']
# 字段值投票: {'normal': 5, 'common': 0.5}
#
# 处理字段 'name': ['get_album_list', 'get_album_list', 'get_album_list', 'get_album_list']
# 字段值投票: {'get_album_list': 5.5}
#
# ==================================================
# 处理Query: After watching those films, what’s next in my history?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'next', 'source': 'recent'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_play_control', 'arguments': {'source': 'recent'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'films', 'type': 'movie'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'title': 'next', 'source': 'recent'}, {'source': 'recent'}, {'title': 'films', 'type': 'movie'}]
#
# 处理字段 'source': ['recent', 'recent']
# 字段值投票: {'recent': 3}
#
# 处理字段 'type': ['movie']
# 字段值投票: {'movie': 0.5}
#
# 处理字段 'title': ['next', 'films']
# 字段值投票: {'next': 2, 'films': 0.5}
#
# 处理字段 'name': ['video_play_control', 'video_play_control', 'video_search_control']
# 字段值投票: {'video_play_control': 3, 'video_search_control': 0.5}
#
# ==================================================
# 处理Query: Aktiviere den Schlaftimer
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'auto_stop_time': 30}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 30}]
#
# 处理字段 'auto_stop_time': [30, 15, 15, 30]
# 字段值投票: {30: 2.5, 15: 3}
#
# 处理字段 'name': ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
# 字段值投票: {'music_settings_control': 5.5}
#
# ==================================================
# 处理Query: Aktiviere die Musikwiedergabe für den Künstler Mozart
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'title': 'Mozart', 'type': 'artist'}, {'title': 'Mozart', 'type': 'artist'}, {'title': 'Mozart', 'type': 'artist'}, {'title': 'Mozart', 'type': 'artist'}]
#
# 处理字段 'type': ['artist', 'artist', 'artist', 'artist']
# 字段值投票: {'artist': 5.5}
#
# 处理字段 'title': ['Mozart', 'Mozart', 'Mozart', 'Mozart']
# 字段值投票: {'Mozart': 5.5}
#
# 处理字段 'name': ['music_play_control', 'music_play_control', 'music_play_control', 'music_play_control']
# 字段值投票: {'music_play_control': 5.5}
#
# ==================================================
# 处理Query: Album 'Hochzeit 2024' erstellen!
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'album_name': 'Hochzeit 2024', 'album_type': 'normal'}, {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}, {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}, {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}]
#
# 处理字段 'album_type': ['normal', 'normal', 'normal', 'normal']
# 字段值投票: {'normal': 5.5}
#
# 处理字段 'album_name': ['Hochzeit 2024', 'Hochzeit 2024', 'Hochzeit 2024', 'Hochzeit 2024']
# 字段值投票: {'Hochzeit 2024': 5.5}
#
# 处理字段 'name': ['create_album', 'create_album', 'create_album', 'create_album']
# 字段值投票: {'create_album': 5.5}
#
# ==================================================
# 处理Query: Album für Babyfotos erstellen mit dem Namen 'Klein Emma'
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'album_name': 'Klein Emma', 'album_type': 'baby'}, {'album_name': 'Klein Emma', 'album_type': 'baby'}, {'album_name': 'Klein Emma', 'album_type': 'baby'}, {'album_name': 'Klein Emma', 'album_type': 'baby'}]
#
# 处理字段 'album_type': ['baby', 'baby', 'baby', 'baby']
# 字段值投票: {'baby': 5.5}
#
# 处理字段 'album_name': ['Klein Emma', 'Klein Emma', 'Klein Emma', 'Klein Emma']
# 字段值投票: {'Klein Emma': 5.5}
#
# 处理字段 'name': ['create_album', 'create_album', 'create_album', 'create_album']
# 字段值投票: {'create_album': 5.5}
#
# ==================================================
# 处理Query: Albumliste generieren
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'album_type': 'normal'}, {'album_type': 'common'}, {'album_type': 'normal'}, {'album_type': 'common'}]
#
# 处理字段 'album_type': ['normal', 'common', 'normal', 'common']
# 字段值投票: {'normal': 4, 'common': 1.5}
#
# 处理字段 'name': ['get_album_list', 'get_album_list', 'get_album_list', 'get_album_list']
# 字段值投票: {'get_album_list': 5.5}
#
# ==================================================
# 处理Query: Alle Songs von Rammstein in zufälliger Reihenfolge abspielen
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}, {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}, {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}, {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}]
#
# 处理字段 'play_mode': ['random', 'random', 'random', 'random']
# 字段值投票: {'random': 5.5}
#
# 处理字段 'type': ['artist', 'artist', 'artist', 'artist']
# 字段值投票: {'artist': 5.5}
#
# 处理字段 'title': ['Rammstein', 'Rammstein', 'Rammstein', 'Rammstein']
# 字段值投票: {'Rammstein': 5.5}
#
# 处理字段 'name': ['music_play_control', 'music_play_control', 'music_play_control', 'music_play_control']
# 字段值投票: {'music_play_control': 5.5}
#
# ==================================================
# 处理Query: Als Nutzer möchte ich eine Übersicht meiner normalen Alben erhalten.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'album_type': 'normal'}, {'album_type': 'normal'}, {'album_type': 'normal'}, {'album_type': 'normal'}]
#
# 处理字段 'album_type': ['normal', 'normal', 'normal', 'normal']
# 字段值投票: {'normal': 5.5}
#
# 处理字段 'name': ['get_album_list', 'get_album_list', 'get_album_list', 'get_album_list']
# 字段值投票: {'get_album_list': 5.5}
#
# ==================================================
# 处理Query: As a business professional, I need a summary of the network capabilities.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'system_type': 'network'}, {'system_type': 'network'}, {'system_type': 'network'}, {'system_type': 'network'}]
#
# 处理字段 'system_type': ['network', 'network', 'network', 'network']
# 字段值投票: {'network': 5.5}
#
# 处理字段 'name': ['get_system_info', 'get_system_info', 'get_system_info', 'get_system_info']
# 字段值投票: {'get_system_info': 5.5}
#
# ==================================================
# 处理Query: As a casual user, how do I access various album types?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'album_type': 'normal'}, {'album_type': 'common'}, {'album_type': 'normal'}, {'album_type': 'common'}]
#
# 处理字段 'album_type': ['normal', 'common', 'normal', 'common']
# 字段值投票: {'normal': 4, 'common': 1.5}
#
# 处理字段 'name': ['get_album_list', 'get_album_list', 'get_album_list', 'get_album_list']
# 字段值投票: {'get_album_list': 5.5}
#
# ==================================================
# 处理Query: As a film enthusiast, I want to play my favorite TV series.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv', 'source': 'favorites'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'title': 'favorite TV series', 'type': 'tv', 'source': 'favorites'}, {'title': 'favorite TV series', 'type': 'tv'}, {'title': 'favorite TV series', 'type': 'tv'}, {'title': 'favorite TV series', 'type': 'tv'}]
#
# 处理字段 'source': ['favorites']
# 字段值投票: {'favorites': 2}
#
# 处理字段 'type': ['tv', 'tv', 'tv', 'tv']
# 字段值投票: {'tv': 5.5}
#
# 处理字段 'title': ['favorite TV series', 'favorite TV series', 'favorite TV series', 'favorite TV series']
# 字段值投票: {'favorite TV series': 5.5}
#
# 处理字段 'name': ['video_play_control', 'video_search_control', 'video_play_control', 'video_play_control']
# 字段值投票: {'video_play_control': 4.5, 'video_search_control': 1}
#
# ==================================================
# 处理Query: As a movie enthusiast, I'm looking for old western movies.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'title': 'old western movies', 'type': 'movie'}, {'title': 'old western movies', 'type': 'movie'}, {'title': 'old western movies', 'type': 'movie'}, {'title': 'old western movies', 'type': 'movie'}]
#
# 处理字段 'type': ['movie', 'movie', 'movie', 'movie']
# 字段值投票: {'movie': 5.5}
#
# 处理字段 'title': ['old western movies', 'old western movies', 'old western movies', 'old western movies']
# 字段值投票: {'old western movies': 5.5}
#
# 处理字段 'name': ['video_search_control', 'video_search_control', 'video_search_control', 'video_search_control']
# 字段值投票: {'video_search_control': 5.5}
#
# ==================================================
# 处理Query: As a music enthusiast, I want to hear my top album on repeat.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'type': 'album', 'source': 'favorites', 'play_mode': 'loop'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'my top album', 'type': 'album', 'play_mode': 'loop'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'top album', 'type': 'album', 'play_mode': 'loop'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'top album', 'type': 'album', 'play_mode': 'loop'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'type': 'album', 'source': 'favorites', 'play_mode': 'loop'}, {'title': 'my top album', 'type': 'album', 'play_mode': 'loop'}, {'title': 'top album', 'type': 'album', 'play_mode': 'loop'}, {'title': 'top album', 'type': 'album', 'play_mode': 'loop'}]
#
# 处理字段 'title': ['my top album', 'top album', 'top album']
# 字段值投票: {'my top album': 1, 'top album': 2.5}
#
# 处理字段 'source': ['favorites']
# 字段值投票: {'favorites': 2}
#
# 处理字段 'type': ['album', 'album', 'album', 'album']
# 字段值投票: {'album': 5.5}
#
# 处理字段 'play_mode': ['loop', 'loop', 'loop', 'loop']
# 字段值投票: {'loop': 5.5}
#
# 处理字段 'name': ['music_play_control', 'music_play_control', 'music_play_control', 'music_play_control']
# 字段值投票: {'music_play_control': 5.5}
#
# ==================================================
# 处理Query: As a newbie, how do I make an album?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'My First Album', 'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'My New Album', 'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'My First Album', 'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'album_name': 'My First Album', 'album_type': 'normal'}, {'album_name': 'My New Album', 'album_type': 'normal'}, {'album_name': 'My First Album', 'album_type': 'normal'}]
#
# 处理字段 'album_type': ['normal', 'normal', 'normal']
# 字段值投票: {'normal': 3.5}
#
# 处理字段 'album_name': ['My First Album', 'My New Album', 'My First Album']
# 字段值投票: {'My First Album': 2.5, 'My New Album': 1}
#
# 处理字段 'name': ['create_album', 'create_album', 'create_album']
# 字段值投票: {'create_album': 3.5}
#
# ==================================================
# 处理Query: As a photographer, I need stock images of urban scenes.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'keyword': 'urban scenes'}, {'keyword': 'urban scenes'}, {'keyword': 'urban scenes'}, {'keyword': 'urban scenes'}]
#
# 处理字段 'keyword': ['urban scenes', 'urban scenes', 'urban scenes', 'urban scenes']
# 字段值投票: {'urban scenes': 5.5}
#
# 处理字段 'name': ['search_photos', 'search_photos', 'search_photos', 'search_photos']
# 字段值投票: {'search_photos': 5.5}
#
# ==================================================
# 处理Query: As a professional photographer, I need to organize my pictures into albums.
# 模型数量: 2
# 输入的模型结果数量: 2
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Placeholder Album Name', 'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
#
# 有效结果数量: 2
# 对应权重: [2, 0.5]
#
# 处理字段 'arguments': [{'album_name': 'Placeholder Album Name', 'album_type': 'normal'}, {'album_type': 'normal'}]
#
# 处理字段 'album_type': ['normal', 'normal']
# 字段值投票: {'normal': 2.5}
#
# 处理字段 'album_name': ['Placeholder Album Name']
# 字段值投票: {'Placeholder Album Name': 2}
#
# 处理字段 'name': ['create_album', 'get_album_list']
# 字段值投票: {'create_album': 2, 'get_album_list': 0.5}
#
# ==================================================
# 处理Query: As a professional, I would like to set a specific playback duration for the music.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 0}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 0}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'auto_stop_time': 30}, {'auto_stop_time': 0}, {'auto_stop_time': 0}, {'auto_stop_time': 15}]
#
# 处理字段 'auto_stop_time': [30, 0, 0, 15]
# 字段值投票: {30: 2, 0: 3, 15: 0.5}
#
# 处理字段 'name': ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
# 字段值投票: {'music_settings_control': 5.5}
#
# ==================================================
# 处理Query: As a tech enthusiast, I want detailed device specifics.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'system_type': 'device'}, {'system_type': 'device'}, {'system_type': 'device'}, {'system_type': 'device'}]
#
# 处理字段 'system_type': ['device', 'device', 'device', 'device']
# 字段值投票: {'device': 5.5}
#
# 处理字段 'name': ['get_system_info', 'get_system_info', 'get_system_info', 'get_system_info']
# 字段值投票: {'get_system_info': 5.5}
#
# ==================================================
# 处理Query: As a tech-savvy user, I need to configure auto-stop for music playback.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{}, {'auto_stop_time': 15}, {'auto_stop_time': 15}, {'auto_stop_time': 15}]
#
# 处理字段 'auto_stop_time': [15, 15, 15]
# 字段值投票: {15: 3.5}
#
# 处理字段 'name': ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
# 字段值投票: {'music_settings_control': 5.5}
#
# ==================================================
# 处理Query: As a technical user, I need to gather detailed information about the network status.
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
# ...
#
# 处理字段 'album_name': ['New Album', 'My Photo Album', 'My Vacation Photos']
# 字段值投票: {'New Album': 2, 'My Photo Album': 2, 'My Vacation Photos': 0.5}
#
# 处理字段 'name': ['create_album', 'create_album', 'create_album']
# 字段值投票: {'create_album': 4.5}
#
# ==================================================
# 处理Query: Could you please help me find mountain hiking images?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'mountain hiking'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'mountain hiking images'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'mountain hiking'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'mountain hiking'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'keyword': 'mountain hiking'}, {'keyword': 'mountain hiking images'}, {'keyword': 'mountain hiking'}, {'keyword': 'mountain hiking'}]
#
# 处理字段 'keyword': ['mountain hiking', 'mountain hiking images', 'mountain hiking', 'mountain hiking']
# 字段值投票: {'mountain hiking': 4.5, 'mountain hiking images': 1}
#
# 处理字段 'name': ['search_photos', 'search_photos', 'search_photos', 'search_photos']
# 字段值投票: {'search_photos': 5.5}
#
# ==================================================
# 处理Query: Could you please help me find the movie Pulp Fiction?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'Pulp Fiction', 'type': 'movie'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'Pulp Fiction', 'type': 'movie'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'Pulp Fiction', 'type': 'movie'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'Pulp Fiction', 'type': 'movie'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'title': 'Pulp Fiction', 'type': 'movie'}, {'title': 'Pulp Fiction', 'type': 'movie'}, {'title': 'Pulp Fiction', 'type': 'movie'}, {'title': 'Pulp Fiction', 'type': 'movie'}]
#
# 处理字段 'type': ['movie', 'movie', 'movie', 'movie']
# 字段值投票: {'movie': 5.5}
#
# 处理字段 'title': ['Pulp Fiction', 'Pulp Fiction', 'Pulp Fiction', 'Pulp Fiction']
# 字段值投票: {'Pulp Fiction': 5.5}
#
# 处理字段 'name': ['video_search_control', 'video_search_control', 'video_search_control', 'video_search_control']
# 字段值投票: {'video_search_control': 5.5}
#
# ==================================================
# 处理Query: Could you please play some music for me?
# 模型数量: 3
# 输入的模型结果数量: 3
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Peaceful Piano', 'type': 'song', 'source': 'recent'}}
#
# 有效结果数量: 3
# 对应权重: [2, 2, 0.5]
#
# 处理字段 'arguments': [{}, {}, {'title': 'Peaceful Piano', 'type': 'song', 'source': 'recent'}]
#
# 处理字段 'source': ['recent']
# 字段值投票: {'recent': 0.5}
#
# 处理字段 'type': ['song']
# 字段值投票: {'song': 0.5}
#
# 处理字段 'title': ['Peaceful Piano']
# 字段值投票: {'Peaceful Piano': 0.5}
#
# 处理字段 'name': ['music_play_control', 'music_play_control', 'music_play_control']
# 字段值投票: {'music_play_control': 4.5}
#
# ==================================================
# 处理Query: Could you please provide a comprehensive overview of available photo albums?
# 模型数量: 3
# 输入的模型结果数量: 3
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
#
# 有效结果数量: 3
# 对应权重: [2, 2, 0.5]
#
# 处理字段 'arguments': [{'album_type': 'normal'}, {'album_type': 'normal'}, {'album_type': 'common'}]
#
# 处理字段 'album_type': ['normal', 'normal', 'common']
# 字段值投票: {'normal': 4, 'common': 0.5}
#
# 处理字段 'name': ['get_album_list', 'get_album_list', 'get_album_list']
# 字段值投票: {'get_album_list': 4.5}
#
# ==================================================
# 处理Query: Could you please search for TV shows about cooking?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'cooking', 'type': 'tv'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'cooking', 'type': 'tv'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'cooking', 'type': 'tv'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'cooking', 'type': 'tv'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'title': 'cooking', 'type': 'tv'}, {'title': 'cooking', 'type': 'tv'}, {'title': 'cooking', 'type': 'tv'}, {'title': 'cooking', 'type': 'tv'}]
#
# 处理字段 'type': ['tv', 'tv', 'tv', 'tv']
# 字段值投票: {'tv': 5.5}
#
# 处理字段 'title': ['cooking', 'cooking', 'cooking', 'cooking']
# 字段值投票: {'cooking': 5.5}
#
# 处理字段 'name': ['video_search_control', 'video_search_control', 'video_search_control', 'video_search_control']
# 字段值投票: {'video_search_control': 5.5}
#
# ==================================================
# 处理Query: Could you please set a music sleep timer?
# 模型数量: 3
# 输入的模型结果数量: 3
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
#
# 有效结果数量: 3
# 对应权重: [2, 2, 0.5]
#
# 处理字段 'arguments': [{'auto_stop_time': 30}, {'auto_stop_time': 30}, {'auto_stop_time': 30}]
#
# 处理字段 'auto_stop_time': [30, 30, 30]
# 字段值投票: {30: 4.5}
#
# 处理字段 'name': ['music_settings_control', 'music_settings_control', 'music_settings_control']
# 字段值投票: {'music_settings_control': 4.5}
#
# ==================================================
# 处理Query: Could you please set up a photo album for my child's birthday?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': "Child's Birthday", 'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': "Child's Birthday", 'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': "Child's Birthday", 'album_type': 'baby'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': "Child's Birthday", 'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'album_name': "Child's Birthday", 'album_type': 'normal'}, {'album_name': "Child's Birthday", 'album_type': 'normal'}, {'album_name': "Child's Birthday", 'album_type': 'baby'}, {'album_name': "Child's Birthday", 'album_type': 'normal'}]
#
# 处理字段 'album_type': ['normal', 'normal', 'baby', 'normal']
# 字段值投票: {'normal': 3.5, 'baby': 2}
#
# 处理字段 'album_name': ["Child's Birthday", "Child's Birthday", "Child's Birthday", "Child's Birthday"]
# 字段值投票: {"Child's Birthday": 5.5}
#
# 处理字段 'name': ['create_album', 'create_album', 'create_album', 'create_album']
# 字段值投票: {'create_album': 5.5}
#
# ==================================================
# 处理Query: Could you please start playback of my recent tracks in normal mode?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'source': 'recent', 'play_mode': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'source': 'recent', 'play_mode': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'source': 'recent', 'play_mode': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'recent tracks', 'source': 'recent', 'play_mode': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'source': 'recent', 'play_mode': 'normal'}, {'source': 'recent', 'play_mode': 'normal'}, {'source': 'recent', 'play_mode': 'normal'}, {'title': 'recent tracks', 'source': 'recent', 'play_mode': 'normal'}]
#
# 处理字段 'title': ['recent tracks']
# 字段值投票: {'recent tracks': 0.5}
#
# 处理字段 'source': ['recent', 'recent', 'recent', 'recent']
# 字段值投票: {'recent': 5.5}
#
# 处理字段 'play_mode': ['normal', 'normal', 'normal', 'normal']
# 字段值投票: {'normal': 5.5}
#
# 处理字段 'name': ['music_play_control', 'music_play_control', 'music_play_control', 'music_play_control']
# 字段值投票: {'music_play_control': 5.5}
#
# ==================================================
# 处理Query: Could you please start playing my music selection?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'my music selection'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'my music selection', 'type': 'playlist'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{}, {'title': 'my music selection'}, {}, {'title': 'my music selection', 'type': 'playlist'}]
#
# 处理字段 'type': ['playlist']
# 字段值投票: {'playlist': 0.5}
#
# 处理字段 'title': ['my music selection', 'my music selection']
# 字段值投票: {'my music selection': 1.5}
#
# 处理字段 'name': ['music_play_control', 'music_play_control', 'music_play_control', 'music_play_control']
# 字段值投票: {'music_play_control': 5.5}
#
# ==================================================
# 处理Query: Could you please start playing the album by this artist?
# 模型数量: 3
# 输入的模型结果数量: 3
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'type': 'artist', 'title': '{artist_name}'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'type': 'album'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'album by this artist', 'type': 'album'}}
#
# 有效结果数量: 3
# 对应权重: [1, 2, 0.5]
#
# 处理字段 'arguments': [{'type': 'artist', 'title': '{artist_name}'}, {'type': 'album'}, {'title': 'album by this artist', 'type': 'album'}]
#
# 处理字段 'type': ['artist', 'album', 'album']
# 字段值投票: {'artist': 1, 'album': 2.5}
#
# 处理字段 'title': ['{artist_name}', 'album by this artist']
# 字段值投票: {'{artist_name}': 1, 'album by this artist': 0.5}
#
# 处理字段 'name': ['music_play_control', 'music_play_control', 'music_play_control']
# 字段值投票: {'music_play_control': 3.5}
#
# ==================================================
# 处理Query: Could you please start streaming the TV series 'Stranger Things'?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Stranger Things', 'type': 'tv'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Stranger Things', 'type': 'tv'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Stranger Things', 'type': 'tv'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Stranger Things', 'type': 'tv'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'title': 'Stranger Things', 'type': 'tv'}, {'title': 'Stranger Things', 'type': 'tv'}, {'title': 'Stranger Things', 'type': 'tv'}, {'title': 'Stranger Things', 'type': 'tv'}]
#
# 处理字段 'type': ['tv', 'tv', 'tv', 'tv']
# 字段值投票: {'tv': 5.5}
#
# 处理字段 'title': ['Stranger Things', 'Stranger Things', 'Stranger Things', 'Stranger Things']
# 字段值投票: {'Stranger Things': 5.5}
#
# 处理字段 'name': ['video_play_control', 'video_play_control', 'video_play_control', 'video_play_control']
# 字段值投票: {'video_play_control': 5.5}
#
# ==================================================
# 处理Query: Could you provide a list of all photo albums available?
# 模型数量: 3
# 输入的模型结果数量: 3
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
#
# 有效结果数量: 3
# 对应权重: [1, 2, 0.5]
#
# 处理字段 'arguments': [{'album_type': 'normal'}, {'album_type': 'normal'}, {'album_type': 'common'}]
#
# 处理字段 'album_type': ['normal', 'normal', 'common']
# 字段值投票: {'normal': 3, 'common': 0.5}
#
# 处理字段 'name': ['get_album_list', 'get_album_list', 'get_album_list']
# 字段值投票: {'get_album_list': 3.5}
#
# ==================================================
# 处理Query: Could you provide a selection of animated series for kids?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'animated series for kids', 'type': 'tv'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'animated series for kids', 'type': 'tv'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'animated series for kids', 'type': 'tv'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'animated series for kids', 'type': 'tv'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
#
# 处理字段 'arguments': [{'title': 'animated series for kids', 'type': 'tv'}, {'title': 'animated series for kids', 'type': 'tv'}, {'title': 'animated series for kids', 'type': 'tv'}, {'title': 'animated series for kids', 'type': 'tv'}]
#
# 处理字段 'type': ['tv', 'tv', 'tv', 'tv']
# 字段值投票: {'tv': 5.5}
#
# 处理字段 'title': ['animated series for kids', 'animated series for kids', 'animated series for kids', 'animated series for kids']
# 字段值投票: {'animated series for kids': 5.5}
#
# 处理字段 'name': ['video_search_control', 'video_search_control', 'video_search_control', 'video_search_control']
# 字段值投票: {'video_search_control': 5.5}
#
# ==================================================
# 处理Query: Could you provide detailed information about the device and storage on this system?
# 模型数量: 4
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: [{'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'storage'}}]
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'storage'}}
#
# 有效结果数量: 4
# 对应权重: [2, 1, 2, 0.5]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 2
#       1 # 批量处理
# ----> 2 batch_results = batch_vote_for_queries(result)
#
# Cell In[65], line 22, in batch_vote_for_queries(df_grouped_data)
#      19     print(f"模型数量: {len(model_function_calls)}")
#      21     # 对当前query进行投票
# ---> 22     voted_result = vote_for_model_results(model_function_calls)
#      24     results.append({
#      25         'query': query,
#      26         'model_function_calls': model_function_calls,
#      27         'voted_function_call': voted_result
#      28     })
#      30 return pd.DataFrame(results)
#
# Cell In[62], line 60, in vote_for_model_results(model_results)
#      57 print(f"对应权重: {weights}")
#      59 # 使用现有的投票函数
# ---> 60 voted_result = vote_for_nested_dict(parsed_results, weights)
#      62 return voted_result
#
# Cell In[38], line 50, in vote_for_nested_dict(dicts, weights)
#      48 all_keys = set()
#      49 for d in dicts:
# ---> 50     all_keys.update(d.keys())
#      52 for key in all_keys:
#      53     values = []
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
result
# Out:
#                                 query  \
# 0                 10分間だけ音楽を流してから停止したい
# 1                15分でミュージックアプリの再生を止めて
# 2       15分後に音楽が停止するようにタイマーをセットしてください
# 3     15分後に音楽が止まるように設定するにはどうすれば良いですか？
# 4              15分後に音楽を止めるようにお願いしたいです
# ...                               ...
# 3326                   麻烦帮我设定音乐定时停止功能
# 3327          麻烦帮我设置一下，音乐听完15分钟就自动停掉。
# 3328                    麻烦帮我调出最近的观看记录
# 3329                  麻烦播放一下《速度与激情》电影
# 3330                         麻烦播放一下音乐
#
#                                     model_function_call
# 0     [{'model': 'claude-sonnet-4', 'function_call':...
# 1     [{'model': 'claude-sonnet-4', 'function_call':...
# 2     [{'model': 'claude-sonnet-4', 'function_call':...
# 3     [{'model': 'claude-sonnet-4', 'function_call':...
# 4     [{'model': 'claude-sonnet-4', 'function_call':...
# ...                                                 ...
# 3326  [{'model': 'claude-sonnet-4', 'function_call':...
# 3327  [{'model': 'claude-sonnet-4', 'function_call':...
# 3328  [{'model': 'claude-sonnet-4', 'function_call':...
# 3329  [{'model': 'claude-sonnet-4', 'function_call':...
# 3330  [{'model': 'claude-sonnet-4', 'function_call':...
#
# [3331 rows x 2 columns]

# %%
result.iloc[4]['model_function_call']
# Out:
# [{'model': 'claude-sonnet-4',
#   'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#  {'model': 'gemini-2.5',
#   'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#  {'model': 'gpt-4o',
#   'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
#  {'model': 'qwen3-4b-2507',
#   'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}]

# %%
df['model'].value_counts()
# Out:
# model
# claude-sonnet-4-20250514      2416
# gemini-2.5-flash-lite         2355
# gpt-4o-mini                   2322
# gpt-4o                        2249
# claude-3-5-sonnet-20241022    2035
# gpt-3.5-turbo                 1505
# Name: count, dtype: int64

# %%
df.iloc[1]['function_call']
# Out:
# '{"name": "create_album", "arguments": {"album_name": "New Album", "album_type": "normal"}}'

# %%
df.groupby('query').count()
# Out:
#                                                   query            dimension  \
# 0              Can you create a new photo album for me?           Linguistic
# 1                  How do I set up a fresh photo album?           Linguistic
# 2                    Please generate a new photo album.           Linguistic
# 3     Create a normal photo album called 'Vacation M...          Specificity
# 4           I need an album; can it be for baby photos?          Specificity
# ...                                                 ...                  ...
# 3296  Bevor ich eine Software installiere, welche Sy...  Contextual Scenario
# 3297                         Geräteinformationen bitte.           Linguistic
# 3298         Wie viel Speicherplatz ist noch verfügbar?          Specificity
# 3299     Ich bin kein Experte, was sagt mir das System?         User Persona
# 3300  Ich will die Details über mein UGREEN Link Kon...               Intent
#
#      language                                           function  \
# 0     English  {\n  "name": "create_album",\n  "description":...
# 1     English  {\n  "name": "create_album",\n  "description":...
# 2     English  {\n  "name": "create_album",\n  "description":...
# 3     English  {\n  "name": "create_album",\n  "description":...
# 4     English  {\n  "name": "create_album",\n  "description":...
# ...       ...                                                ...
# 3296   German  {\n  "name": "get_system_info",\n  "descriptio...
# 3297   German  {\n  "name": "get_system_info",\n  "descriptio...
# 3298   German  {\n  "name": "get_system_info",\n  "descriptio...
# 3299   German  {\n  "name": "get_system_info",\n  "descriptio...
# 3300   German  {\n  "name": "get_system_info",\n  "descriptio...
#
#          function_hash provider                  model  \
# 0     741b1509eb4dde82   openai                 gpt-4o
# 1     741b1509eb4dde82   openai                 gpt-4o
# 2     741b1509eb4dde82   openai                 gpt-4o
# 3     741b1509eb4dde82   openai                 gpt-4o
# 4     741b1509eb4dde82   openai                 gpt-4o
# ...                ...      ...                    ...
# 3296  24719fdaa4ff4d76   google  gemini-2.5-flash-lite
# 3297  24719fdaa4ff4d76   google  gemini-2.5-flash-lite
# 3298  24719fdaa4ff4d76   google  gemini-2.5-flash-lite
# 3299  24719fdaa4ff4d76   google  gemini-2.5-flash-lite
# 3300  24719fdaa4ff4d76   google  gemini-2.5-flash-lite
#
#                                               functions  \
# 0     ['{\n  "name": "create_album",\n  "description...
# 1     ['{\n  "name": "create_album",\n  "description...
# 2     ['{\n  "name": "create_album",\n  "description...
# 3     ['{\n  "name": "create_album",\n  "description...
# 4     ['{\n  "name": "create_album",\n  "description...
# ...                                                 ...
# 3296  ['{\n  "name": "create_album",\n  "description...
# 3297  ['{\n  "name": "create_album",\n  "description...
# 3298  ['{\n  "name": "create_album",\n  "description...
# 3299  ['{\n  "name": "create_album",\n  "description...
# 3300  ['{\n  "name": "create_album",\n  "description...
#
#                                                  prompt  \
# 0     \n            You are an expert in structured ...
# 1     \n            You are an expert in structured ...
# 2     \n            You are an expert in structured ...
# 3     \n            You are an expert in structured ...
# 4     \n            You are an expert in structured ...
# ...                                                 ...
# 3296  \n            You are an expert in structured ...
# 3297  \n            You are an expert in structured ...
# 3298  \n            You are an expert in structured ...
# 3299  \n            You are an expert in structured ...
# 3300  \n            You are an expert in structured ...
#
#                                           function_call
# 0     {"name": "create_album", "arguments": {"album_...
# 1     {"name": "create_album", "arguments": {"album_...
# 2     {"name": "create_album", "arguments": {"album_...
# 3     {"name": "create_album", "arguments": {"album_...
# 4     {"name": "create_album", "arguments": {"album_...
# ...                                                 ...
# 3296  {"name": "get_system_info", "arguments": {"sys...
# 3297  {"name": "get_system_info", "arguments": {"sys...
# 3298  {"name": "get_system_info", "arguments": {"sys...
# 3299  {"name": "get_system_info", "arguments": {"sys...
# 3300  {"name": "get_system_info", "arguments": {"sys...
#
# [12882 rows x 10 columns]

# %%
# 简单测试来重现错误
simple_test = [
    {'model': 'claude-sonnet-4', 'function_call': '{"name": "test_func", "arguments": {"param": "value"}}'},
    {'model': 'gpt-4o', 'function_call': '{"name": "test_func", "arguments": {"param": "value2"}}'}
]

print("测试数据类型:")
print(f"simple_test类型: {type(simple_test)}")
for i, item in enumerate(simple_test):
    print(f"元素{i}类型: {type(item)}")
    print(f"元素{i}内容: {item}")

# 尝试调用投票函数看看错误
try:
    result = vote_for_model_results(simple_test)
    print(f"成功：{result}")
except Exception as e:
    print(f"错误: {e}")
    import traceback
    traceback.print_exc()

# %%
# 修复版本的投票函数
def vote_for_model_results_v2(model_results: List[Dict]) -> Dict:
    """
    修复版本：对多个模型的结果进行加权投票
    """
    model_weights = {
        'claude-sonnet-4': 2,
        'gemini-2.5': 1,
        'gpt-4o': 2,
        'qwen3-4b-2507': 0.5
    }
    
    print(f"输入的模型结果数量: {len(model_results)}")
    
    parsed_results = []
    weights = []
    
    for item in model_results:
        model_name = item['model']
        function_call_str = item['function_call']
        
        print(f"处理模型: {model_name}")
        
        try:
            function_call_dict = json.loads(function_call_str)
            
            # 确保解析结果是字典
            if isinstance(function_call_dict, dict):
                parsed_results.append(function_call_dict)
                weight = model_weights.get(model_name, 1.0)
                weights.append(weight)
                print(f"  权重: {weight}")
                print(f"  Function Call: {function_call_dict}")
            else:
                print(f"  跳过：解析结果不是字典，类型: {type(function_call_dict)}")
                
        except json.JSONDecodeError as e:
            print(f"  跳过无效的JSON: {function_call_str}")
            continue
    
    if not parsed_results:
        return {}
    
    print(f"\n开始投票，有效结果数量: {len(parsed_results)}")
    print(f"权重: {weights}")
    
    # 调试parsed_results
    print(f"调试parsed_results:")
    for i, result in enumerate(parsed_results):
        print(f"  结果{i}类型: {type(result)}, 是字典: {isinstance(result, dict)}")
        if isinstance(result, dict):
            print(f"  结果{i}keys: {list(result.keys())}")
    
    # 确保所有元素都是字典
    valid_dicts = [r for r in parsed_results if isinstance(r, dict)]
    valid_weights = [w for r, w in zip(parsed_results, weights) if isinstance(r, dict)]
    
    if not valid_dicts:
        print("没有有效的字典")
        return {}
    
    # 手动实现简化的投票逻辑
    result = {}
    
    # 获取所有键
    all_keys = set()
    for d in valid_dicts:
        all_keys.update(d.keys())
    
    print(f"所有键: {all_keys}")
    
    for key in all_keys:
        print(f"\n处理字段 '{key}':")
        values = []
        key_weights = []
        
        for d, weight in zip(valid_dicts, valid_weights):
            if key in d:
                values.append(d[key])
                key_weights.append(weight)
        
        print(f"  值: {values}")
        print(f"  权重: {key_weights}")
        
        if values:
            if isinstance(values[0], dict):
                # 递归处理嵌套字典
                result[key] = vote_for_model_results_v2_nested(values, key_weights)
            else:
                # 简单值投票
                result[key] = vote_for_simple_values(values, key_weights)
    
    return result

def vote_for_simple_values(values, weights):
    """对简单值进行投票"""
    counter = {}
    for value, weight in zip(values, weights):
        if value in counter:
            counter[value] += weight
        else:
            counter[value] = weight
    
    print(f"    简单值投票结果: {counter}")
    
    max_score = max(counter.values())
    for value in values:
        if counter[value] == max_score:
            return value

def vote_for_model_results_v2_nested(dicts, weights):
    """处理嵌套字典"""
    result = {}
    all_keys = set()
    
    for d in dicts:
        if isinstance(d, dict):
            all_keys.update(d.keys())
    
    for key in all_keys:
        values = []
        key_weights = []
        
        for d, weight in zip(dicts, weights):
            if isinstance(d, dict) and key in d:
                values.append(d[key])
                key_weights.append(weight)
        
        if values:
            if isinstance(values[0], dict):
                result[key] = vote_for_model_results_v2_nested(values, key_weights)
            else:
                result[key] = vote_for_simple_values(values, key_weights)
    
    return result

# %%
# 测试修复版本
print("=== 测试修复版本的投票函数 ===")

test_data_v2 = [
    {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15, "volume": "high"}}'},
    {'model': 'gpt-4o', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15, "volume": "medium"}}'},
    {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 20, "volume": "high"}}'}
]

try:
    result_v2 = vote_for_model_results_v2(test_data_v2)
    print(f"\n修复版本成功！结果: {result_v2}")
except Exception as e:
    print(f"修复版本仍有错误: {e}")
    import traceback
    traceback.print_exc()

# %%
# 增强版调试函数 - 找出列表在哪里
def debug_simple_vote_function(parsed_dicts, weights):
    """调试版本的投票函数"""
    print(f"\n=== debug_simple_vote_function 开始 ===")
    print(f"parsed_dicts 类型: {type(parsed_dicts)}")
    print(f"parsed_dicts 长度: {len(parsed_dicts)}")
    print(f"weights: {weights}")
    
    # 详细检查每个元素
    print(f"\n检查 parsed_dicts 中的每个元素:")
    for i, item in enumerate(parsed_dicts):
        print(f"  元素 {i}:")
        print(f"    类型: {type(item)}")
        print(f"    内容: {item}")
        
        if isinstance(item, dict):
            print(f"    ✓ 是字典，keys: {list(item.keys())}")
        elif isinstance(item, list):
            print(f"    ✗ 是列表！长度: {len(item)}")
            if item:
                print(f"    列表第一个元素: {item[0]} (类型: {type(item[0])})")
        else:
            print(f"    ✗ 其他类型: {type(item)}")
    
    # 过滤出真正的字典
    actual_dicts = []
    actual_weights = []
    
    for item, weight in zip(parsed_dicts, weights):
        if isinstance(item, dict):
            actual_dicts.append(item)
            actual_weights.append(weight)
        else:
            print(f"  跳过非字典元素: {item}")
    
    print(f"\n过滤后的字典数量: {len(actual_dicts)}")
    print(f"过滤后的权重: {actual_weights}")
    
    if not actual_dicts:
        print("没有有效的字典，返回空结果")
        return {}
    
    # 继续处理
    result = {}
    all_keys = set()
    
    for d in actual_dicts:
        all_keys.update(d.keys())
    
    print(f"所有键: {all_keys}")
    
    for key in all_keys:
        values = [d[key] for d in actual_dicts if key in d]
        key_weights = [w for d, w in zip(actual_dicts, actual_weights) if key in d]
        
        print(f"\n处理键 '{key}':")
        print(f"  值: {values}")
        print(f"  权重: {key_weights}")
        
        if values and isinstance(values[0], dict):
            print(f"  递归处理嵌套字典")
            result[key] = debug_simple_vote_function(values, key_weights)
        else:
            print(f"  简单值投票")
            counter = {}
            for val, weight in zip(values, key_weights):
                counter[val] = counter.get(val, 0) + weight
            result[key] = max(counter, key=counter.get)
            print(f"  投票结果: {result[key]}")
    
    print(f"\n最终结果: {result}")
    return result

# %%
# 调试版本的主函数
def debug_vote_for_model_results(model_results):
    """调试版本的投票主函数"""
    model_weights = {
        'claude-sonnet-4': 2,
        'gemini-2.5': 1,
        'gpt-4o': 2,
        'qwen3-4b-2507': 0.5
    }
    
    print(f"\n=== debug_vote_for_model_results 开始 ===")
    print(f"输入 model_results 类型: {type(model_results)}")
    print(f"输入 model_results 长度: {len(model_results)}")
    
    # 检查输入数据
    print(f"\n检查输入数据:")
    for i, item in enumerate(model_results):
        print(f"  项目 {i}:")
        print(f"    类型: {type(item)}")
        print(f"    内容: {item}")
        
        if isinstance(item, dict):
            print(f"    keys: {list(item.keys())}")
        else:
            print(f"    ✗ 不是字典！")
    
    # 解析过程
    parsed_results = []
    weights = []
    
    print(f"\n开始解析过程:")
    for i, item in enumerate(model_results):
        print(f"\n处理项目 {i}:")
        
        if not isinstance(item, dict):
            print(f"  跳过：不是字典")
            continue
            
        if 'model' not in item or 'function_call' not in item:
            print(f"  跳过：缺少必要字段")
            continue
        
        model_name = item['model']
        function_call_str = item['function_call']
        
        print(f"  模型: {model_name}")
        print(f"  function_call字符串: {function_call_str}")
        print(f"  function_call字符串类型: {type(function_call_str)}")
        
        try:
            # 解析JSON
            function_call_dict = json.loads(function_call_str)
            print(f"  解析后的结果: {function_call_dict}")
            print(f"  解析后的类型: {type(function_call_dict)}")
            
            # 验证解析结果
            if isinstance(function_call_dict, dict):
                parsed_results.append(function_call_dict)
                weight = model_weights.get(model_name, 1.0)
                weights.append(weight)
                print(f"  ✓ 添加成功，权重: {weight}")
            elif isinstance(function_call_dict, list):
                print(f"  ✗ 解析结果是列表，不是字典！")
                print(f"  列表内容: {function_call_dict}")
            else:
                print(f"  ✗ 解析结果类型不对: {type(function_call_dict)}")
                
        except json.JSONDecodeError as e:
            print(f"  ✗ JSON解析失败: {e}")
        except Exception as e:
            print(f"  ✗ 其他错误: {e}")
    
    print(f"\n解析完成:")
    print(f"parsed_results 长度: {len(parsed_results)}")
    print(f"weights: {weights}")
    
    # 再次检查 parsed_results
    print(f"\n最终检查 parsed_results:")
    for i, item in enumerate(parsed_results):
        print(f"  结果 {i}: {type(item)} - {item}")
    
    if not parsed_results:
        print("没有有效结果，返回空字典")
        return {}
    
    # 调用调试版本的投票函数
    return debug_simple_vote_function(parsed_results, weights)

# 现在你可以用这个函数来调试
print("调试函数已创建。")
print("使用方法: debug_vote_for_model_results(你的数据)")
print("这会显示详细的调试信息，帮助找出问题所在。")

# %%
# 修复版本的批量处理函数
def debug_batch_vote_for_queries(df_grouped_data):
    """调试版本的批量处理函数"""
    results = []
    
    print(f"\n=== debug_batch_vote_for_queries 开始 ===")
    print(f"输入数据类型: {type(df_grouped_data)}")
    print(f"输入数据行数: {len(df_grouped_data)}")
    
    for idx, row in df_grouped_data.iterrows():
        print(f"\n{'='*60}")
        print(f"处理第 {idx} 行")
        
        query = row['query']
        model_function_calls = row['model_function_call']
        
        print(f"Query: {query}")
        print(f"model_function_calls 类型: {type(model_function_calls)}")
        print(f"model_function_calls 长度: {len(model_function_calls)}")
        
        # 检查 model_function_calls 的内容
        print(f"model_function_calls 内容预览:")
        for i, item in enumerate(model_function_calls[:2]):  # 只显示前2个
            print(f"  项目 {i}: {type(item)} - {item}")
        
        try:
            # 使用调试版本的投票函数
            voted_result = debug_vote_for_model_results(model_function_calls)
            print(f"投票成功！结果: {voted_result}")
            
            results.append({
                'query': query,
                'model_function_calls': model_function_calls,
                'voted_function_call': voted_result
            })
            
        except Exception as e:
            print(f"投票失败: {e}")
            import traceback
            traceback.print_exc()
            
            # 添加失败的记录
            results.append({
                'query': query,
                'model_function_calls': model_function_calls,
                'voted_function_call': {'error': str(e)}
            })
    
    return pd.DataFrame(results)

print("调试版本的批量处理函数已创建。")
print("使用方法: debug_batch_vote_for_queries(你的DataFrame)")
print("这会显示每一步的详细信息。")

# %%
# 修复版本的批量处理函数
def batch_vote_for_queries_v2(df_grouped_data):
    """
    修复版本：批量处理多个query的投票
    """
    results = []
    
    for _, row in df_grouped_data.iterrows():
        query = row['query']
        model_function_calls = row['model_function_call']
        
        print(f"\n{'='*50}")
        print(f"处理Query: {query}")
        print(f"模型数量: {len(model_function_calls)}")
        
        # 使用修复版本的投票函数
        voted_result = vote_for_model_results_v2(model_function_calls)
        
        results.append({
            'query': query,
            'model_function_calls': model_function_calls,
            'voted_function_call': voted_result
        })
    
    return pd.DataFrame(results)

print("修复版本的批量处理函数已创建")
print("现在你可以使用 batch_vote_for_queries_v2(your_dataframe) 来处理数据")

# %%
# 详细调试函数
def debug_vote_for_nested_dict(dicts, weights):
    """
    详细调试vote_for_nested_dict函数的每一步
    """
    print(f"\n=== debug_vote_for_nested_dict 开始 ===")
    print(f"输入dicts类型: {type(dicts)}")
    print(f"输入dicts长度: {len(dicts)}")
    print(f"输入weights: {weights}")
    print(f"weights类型: {type(weights)}")
    
    # 检查每个元素
    print(f"\n检查dicts中的每个元素:")
    for i, d in enumerate(dicts):
        print(f"  元素{i}:")
        print(f"    类型: {type(d)}")
        print(f"    内容: {d}")
        if isinstance(d, dict):
            print(f"    keys: {list(d.keys())}")
        elif isinstance(d, list):
            print(f"    列表长度: {len(d)}")
            print(f"    列表内容前3项: {d[:3]}")
        else:
            print(f"    其他类型，值: {d}")
    
    if not dicts:
        print("输入为空，返回空字典")
        return {}
    
    print(f"\n开始获取所有键...")
    result = {}
    all_keys = set()
    
    try:
        for i, d in enumerate(dicts):
            print(f"  处理元素{i}: {type(d)}")
            if isinstance(d, dict):
                keys = d.keys()
                print(f"    元素{i}的keys: {list(keys)}")
                all_keys.update(keys)
            else:
                print(f"    错误！元素{i}不是字典: {d}")
                raise TypeError(f"元素{i}不是字典，类型: {type(d)}")
        
        print(f"所有键集合: {all_keys}")
        
        # 处理每个键
        for key in all_keys:
            print(f"\n处理键 '{key}':")
            values = []
            current_weights = []
            
            for d, weight in zip(dicts, weights):
                if key in d:
                    value = d[key]
                    values.append(value)
                    current_weights.append(weight)
                    print(f"  从字典中获取 {key}: {value} (权重: {weight})")
            
            print(f"  键 '{key}' 的所有值: {values}")
            print(f"  对应权重: {current_weights}")
            
            if values:
                # 检查值的类型
                first_value = values[0]
                print(f"  第一个值的类型: {type(first_value)}")
                
                if isinstance(first_value, dict):
                    print(f"  值是字典，递归处理...")
                    result[key] = debug_vote_for_nested_dict(values, current_weights)
                else:
                    print(f"  值是简单类型，进行投票...")
                    result[key] = debug_vote_for_field_values(values, current_weights)
        
        print(f"\n最终结果: {result}")
        return result
        
    except Exception as e:
        print(f"\n错误发生: {e}")
        print(f"错误类型: {type(e)}")
        import traceback
        traceback.print_exc()
        return {}

def debug_vote_for_field_values(values, weights):
    """调试字段值投票"""
    print(f"    进入debug_vote_for_field_values")
    print(f"    values: {values}")
    print(f"    weights: {weights}")
    
    counter = {}
    for value, weight in zip(values, weights):
        if value in counter:
            counter[value] += weight
        else:
            counter[value] = weight
    
    print(f"    投票结果: {counter}")
    
    max_score = max(counter.values())
    for value in values:
        if counter[value] == max_score:
            print(f"    获胜值: {value}")
            return value

# %%
print("=== 问题诊断和解决方案 ===")

# %%
# 使用你提供的数据进行调试测试
test_dicts = [
    {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, 
    {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, 
    {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, 
    {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
]

test_weights = [2, 1, 2, 0.5]  # 对应的权重

print("=== 开始调试测试 ===")
print(f"测试数据: {test_dicts}")
print(f"测试权重: {test_weights}")

# 使用调试函数
try:
    debug_result = debug_vote_for_nested_dict(test_dicts, test_weights)
    print(f"\n调试成功！结果: {debug_result}")
except Exception as e:
    print(f"\n调试失败: {e}")
    import traceback
    traceback.print_exc()

# %%
# 测试原始的vote_for_nested_dict函数，找出问题所在
print("=== 测试原始的vote_for_nested_dict函数 ===")

# 先检查原始函数是否存在
try:
    # 使用相同的测试数据调用原始函数
    print("调用原始的vote_for_nested_dict函数...")
    original_result = vote_for_nested_dict(test_dicts, test_weights)
    print(f"原始函数成功！结果: {original_result}")
except Exception as e:
    print(f"原始函数失败: {e}")
    print(f"错误类型: {type(e)}")
    
    # 打印详细的错误信息
    import traceback
    print("\n完整错误堆栈:")
    traceback.print_exc()
    
    print(f"\n分析错误:")
    print(f"错误消息: {str(e)}")
    if "'list' object has no attribute 'keys'" in str(e):
        print("确认：错误是因为尝试对列表调用.keys()方法")
        print("这意味着在某个地方，一个列表被当作字典处理了")
        
        # 检查是否是递归调用时的问题
        print("\n检查arguments字段的值:")
        for i, d in enumerate(test_dicts):
            if 'arguments' in d:
                arg_value = d['arguments']
                print(f"  字典{i}的arguments值: {arg_value}")
                print(f"  类型: {type(arg_value)}")
                if isinstance(arg_value, dict):
                    print(f"  keys: {list(arg_value.keys())}")

# 让我们也检查一下vote_for_field_values函数
print(f"\n=== 检查vote_for_field_values函数 ===")
try:
    test_values = ['music_settings_control', 'music_settings_control', 'music_settings_control', 'music_settings_control']
    test_result = vote_for_field_values(test_values, test_weights)
    print(f"vote_for_field_values测试成功: {test_result}")
except Exception as e:
    print(f"vote_for_field_values测试失败: {e}")
    traceback.print_exc()

# %%
print("调试信息：检查vote_for_nested_dict函数的输入")

# %%
df = pd.read_csv('/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/claude_ugreen_function_call/output.csv')
df.shape, df.columns
# Out:
# ((3185, 10),
#  Index(['query', 'dimension', 'language', 'function', 'function_hash',
#         'provider', 'model', 'functions', 'prompt', 'function_call'],
#        dtype='object'))

# %%
df2 = pd.read_csv('/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/ugreen_function_call/output.csv')
df2.shape, df2.columns

# %%
df3 = pd.read_csv('/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/ugreen_function_call/output.csv')
df3.shape, df3.columns
# Out:
# ((3347, 10),
#  Index(['query', 'dimension', 'language', 'function', 'function_hash',
#         'provider', 'model', 'functions', 'prompt', 'function_call'],
#        dtype='object'))

# %%
# # 测试修改后的投票函数
# print("=== 测试新的投票算法 ===")

# # 执行投票
# ground_truth = vote_for_ground_truth(model_a_results, model_b_results, model_c_results)

# # 输出最终结果
# print("\n" + "="*50)
# print("最终的 Ground Truth 结果:")
# print("="*50)
# for i, point in enumerate(ground_truth):
#     print(f"位置 {i}: {point}")
    
# print("\n分析:")
# print("第一个位置:")
# print("- function-name: 所有模型都是 'music_call'，所以选择 'music_call'")
# print("- name: Model A='lisa'(权重5), Model B='Joe'(权重3), Model C='Joe'(权重2)")
# print("  Joe总权重=3+2=5, lisa权重=5, 平局时选择第一个出现的，所以选择 'lisa'")
# print("- type: Model A='normal'(权重5), Model B='normal'(权重3), Model C='vip'(权重2)")
# print("  normal总权重=5+3=8, vip权重=2, 所以选择 'normal'")

# %%
ss = "你是一名专业的翻译员，任务是将来自语音识别（ASR）系统输出的文本进行翻译。\n\n要求：\n1. 准确翻译：输入文本是英语, 将文本翻译成简体中文，保留所有原文含义和细节。\n2. 一致性：译文的句子数量、顺序和编号必须与原文完全一致，一句对应一句。\n3. 格式标准化：严格按照以下格式输出，每句以 Sentence [编号]: 开头，后接翻译内容。例如：\nSentence 1: [翻译后的内容]\nSentence 2: [翻译后的内容]\n...\n \n4. 不添加或遗漏信息：不要篡改原文内容。如遇不清晰或不完整的部分，保持原样，不要猜测或虚构。\n5. 保持语气和风格：译文应尽量保持原文的语气和风格（正式、非正式、技术性等）。\n6. 只输出翻译结果：不要添加额外的解释、注释或其他内容。\n\n# 输入格式：\n原文以编号列表形式提供，如：\nSentence 1: 原文内容。\nSentence 2: 原文内容。\n\n# 输出格式：\n严格按照以下标准输出：\nSentence 1: [翻译后的内容]\nSentence 2: [翻译后的内容]\n\n# 用户输入：\n\nSentence 1: Then comes his opponent, Canada.\nSentence 2: A polite father in double denim and a Canada jersey to electronic strains of O Canada.\nSentence 3: Really hard.\nSentence 4: You know, in the time Canada has come out for your super wrestler, super shows. It's true, I've rattled a few cages, eh?\nSentence 5: As the two warm up, USA Hole shouts out an insult, Bartender, I need some ice. And a crowd of about 500 people, many of whom addressed in support of their characters, erupts and booze.\nSentence 6: Yeah. Mm.\nSentence 7: Super Wrestlers is an indie wrestling league in Chicago. It's been going for a few years and this was its 10th edition.\nSentence 8: Super\nSentence 9: They describe themselves as Earth's strangest pro wrestling show, and I'm pretty sure there's no doubt about that. Besides USA Holt and Canada, the recent show featured Barrospith, Stephen Flo and the Pubic Moose, wearing an antler hat and a large wig over his groin.\nSentence 10: Pro Wrestling has long been dominated by the WWE.\nSentence 11: which had revenues last year of one point four billion dollars. Recently the franchise has been stuttering. SmackDown, the weekly show, has seen lower viewership this year, and WW Raw, which is a second show, has struggled with a move to Netflix.\nSentence 12: That revenue growth has tailed off and All Elite Wrestling, the biggest competitor, has been eating into its market share.\nSentence 13: Indie wrestling shows are booming, though few are as silly as the super wrestlers.\nSentence 14: Game Changer Wrestling, a hardcore wrestling league which started in New Jersey, now puts shows on all over the world.\nSentence 15: Its appeal seems to be a not more violence.\nSentence 16: The IWC World Heavyweight Championship.\nSentence 17: Or there's the International Wrestling Cartel, which is an indie league that came out of Pittsburgh and is often seen as a training ground for new wrestlers elsewhere.\nSentence 18: Imports are thriving too, such as New Japan Pro Wrestling, which is shown on AXS cable TV channel.\nSentence 19: So what's driving the shift? Social media is a big part of it. A generation ago, wrestling fans could really only watch what was on television, and that meant WWE.\nSentence 20: But nowadays, wrestling leagues can promote themselves on YouTube.\nSentence 21: Weird can work.\nSentence 22: The Super Wrestlers take a lot of their inspiration from Chicago's comedy and fits in, which inspires a lot of the experimentation.\nSentence 23: Is politics playing a role too? With the exception of golf, few sports are so closely linked to Donald Trump as pro wrestling.\n"
print(ss)
# Out:
# 你是一名专业的翻译员，任务是将来自语音识别（ASR）系统输出的文本进行翻译。
#
# 要求：
# 1. 准确翻译：输入文本是英语, 将文本翻译成简体中文，保留所有原文含义和细节。
# 2. 一致性：译文的句子数量、顺序和编号必须与原文完全一致，一句对应一句。
# 3. 格式标准化：严格按照以下格式输出，每句以 Sentence [编号]: 开头，后接翻译内容。例如：
# Sentence 1: [翻译后的内容]
# Sentence 2: [翻译后的内容]
# ...
#
# 4. 不添加或遗漏信息：不要篡改原文内容。如遇不清晰或不完整的部分，保持原样，不要猜测或虚构。
# 5. 保持语气和风格：译文应尽量保持原文的语气和风格（正式、非正式、技术性等）。
# 6. 只输出翻译结果：不要添加额外的解释、注释或其他内容。
#
# # 输入格式：
# 原文以编号列表形式提供，如：
# Sentence 1: 原文内容。
# Sentence 2: 原文内容。
#
# # 输出格式：
# 严格按照以下标准输出：
# Sentence 1: [翻译后的内容]
# Sentence 2: [翻译后的内容]
#
# # 用户输入：
#
# Sentence 1: Then comes his opponent, Canada.
# Sentence 2: A polite father in double denim and a Canada jersey to electronic strains of O Canada.
# Sentence 3: Really hard.
# Sentence 4: You know, in the time Canada has come out for your super wrestler, super shows. It's true, I've rattled a few cages, eh?
# Sentence 5: As the two warm up, USA Hole shouts out an insult, Bartender, I need some ice. And a crowd of about 500 people, many of whom addressed in support of their characters, erupts and booze.
# Sentence 6: Yeah. Mm.
# Sentence 7: Super Wrestlers is an indie wrestling league in Chicago. It's been going for a few years and this was its 10th edition.
# Sentence 8: Super
# Sentence 9: They describe themselves as Earth's strangest pro wrestling show, and I'm pretty sure there's no doubt about that. Besides USA Holt and Canada, the recent show featured Barrospith, Stephen Flo and the Pubic Moose, wearing an antler hat and a large wig over his groin.
# Sentence 10: Pro Wrestling has long been dominated by the WWE.
# Sentence 11: which had revenues last year of one point four billion dollars. Recently the franchise has been stuttering. SmackDown, the weekly show, has seen lower viewership this year, and WW Raw, which is a second show, has struggled with a move to Netflix.
# Sentence 12: That revenue growth has tailed off and All Elite Wrestling, the biggest competitor, has been eating into its market share.
# Sentence 13: Indie wrestling shows are booming, though few are as silly as the super wrestlers.
# Sentence 14: Game Changer Wrestling, a hardcore wrestling league which started in New Jersey, now puts shows on all over the world.
# Sentence 15: Its appeal seems to be a not more violence.
# Sentence 16: The IWC World Heavyweight Championship.
# Sentence 17: Or there's the International Wrestling Cartel, which is an indie league that came out of Pittsburgh and is often seen as a training ground for new wrestlers elsewhere.
# Sentence 18: Imports are thriving too, such as New Japan Pro Wrestling, which is shown on AXS cable TV channel.
# Sentence 19: So what's driving the shift? Social media is a big part of it. A generation ago, wrestling fans could really only watch what was on television, and that meant WWE.
# Sentence 20: But nowadays, wrestling leagues can promote themselves on YouTube.
# Sentence 21: Weird can work.
# Sentence 22: The Super Wrestlers take a lot of their inspiration from Chicago's comedy and fits in, which inspires a lot of the experimentation.
# Sentence 23: Is politics playing a role too? With the exception of golf, few sports are so closely linked to Donald Trump as pro wrestling.

# %%
print("=== 代码工作原理详细解释 ===")
print("输入的字典没有被'转换'，而是被'拆解'和'重组'")
print()
print("以第一个位置为例:")
print("输入:")
print("Model A: {'function-name': 'music_call', 'param': {'name': 'lisa', 'type': 'normal'}}")
print("Model B: {'function-name': 'music_callAA', 'param': {'name': 'Joe', 'type': 'normal'}}")
print("Model C: {'function-name': 'music_callBB', 'param': {'name': 'Joe', 'type': 'vip'}}")
print()
print("处理过程:")
print("1. 拆解每个字段:")
print("   function-name: ['music_call', 'music_callAA', 'music_callBB']")
print("   param.name: ['lisa', 'Joe', 'Joe']")
print("   param.type: ['normal', 'normal', 'vip']")
print()
print("2. 对每个字段投票(权重都是1):")
print("   function-name投票: music_call=1票, music_callAA=1票, music_callBB=1票")
print("   → 平票时选第一个: music_call")
print("   param.name投票: lisa=1票, Joe=2票")
print("   → Joe获胜")
print("   param.type投票: normal=2票, vip=1票")
print("   → normal获胜")
print()
print("3. 重组结果:")
print("   {'function-name': 'music_call', 'param': {'name': 'Joe', 'type': 'normal'}}")

# %%
print("=== 核心逻辑总结 ===")
print()
print("这个投票算法的核心思想是:")
print("1. 不是对整个字典进行投票")
print("2. 而是对字典中的每个字段分别投票")
print("3. 然后把获胜的字段值组装成新的字典")
print()
print("举个更简单的例子:")
print("如果有3个人投票选择一个人的信息:")
print("人A说: 这个人叫张三，25岁，住北京")
print("人B说: 这个人叫李四，25岁，住上海") 
print("人C说: 这个人叫李四，30岁，住北京")
print()
print("传统投票: 每个人的完整描述作为一票，无法确定获胜者")
print("字段投票: ")
print("  姓名: 张三(1票) vs 李四(2票) → 李四获胜")
print("  年龄: 25岁(2票) vs 30岁(1票) → 25岁获胜") 
print("  住址: 北京(2票) vs 上海(1票) → 北京获胜")
print("最终结果: 这个人叫李四，25岁，住北京")
print()
print("这就是为什么你的结果是:")
print("{'function-name': 'music_call', 'param': {'name': 'Joe', 'type': 'normal'}}")
print("每个字段都是通过投票选出的最优值组合而成")

# %%
import json
from typing import List, Dict, Any

def vote_for_model_results(model_results: List[Dict]) -> Dict:
    """
    对多个模型的结果进行加权投票
    
    参数:
        model_results: 包含model和function_call的字典列表
                      格式: [{'model': 'model_name', 'function_call': 'json_string'}, ...]
    
    返回:
        投票后的最终function_call字典
    """
    # 模型权重映射
    model_weights = {
        'claude-sonnet-4': 2,
        'gemini-2.5': 1,
        'gpt-4o': 2,
        'qwen3-4b-2507': 0.5
    }
    
    print(f"输入的模型结果数量: {len(model_results)}")
    
    # 解析function_call JSON字符串并收集权重
    parsed_results = []
    weights = []
    
    for item in model_results:
        model_name = item['model']
        function_call_str = item['function_call']
        
        print(f"处理模型: {model_name}")
        
        try:
            # 解析JSON字符串
            function_call_dict = json.loads(function_call_str)
            parsed_results.append(function_call_dict)
            
            # 获取对应权重
            weight = model_weights.get(model_name, 1.0)  # 默认权重1.0
            weights.append(weight)
            
            print(f"  权重: {weight}")
            print(f"  Function Call: {function_call_dict}")
            
        except json.JSONDecodeError as e:
            print(f"  跳过无效的JSON: {function_call_str}")
            print(f"  错误: {e}")
            continue
    
    if not parsed_results:
        print("没有有效的结果可以投票")
        return {}
    
    print(f"\n有效结果数量: {len(parsed_results)}")
    print(f"对应权重: {weights}")
    
    # 使用现有的投票函数
    voted_result = vote_for_nested_dict(parsed_results, weights)
    
    return voted_result

# 测试数据
test_data = [
    {'model': 'claude-sonnet-4',
     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
    {'model': 'gemini-2.5',
     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
    {'model': 'gpt-4o',
     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
    {'model': 'qwen3-4b-2507',
     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'}
]

print("=== 测试相同结果的投票 ===")
result1 = vote_for_model_results(test_data)
print(f"\n最终投票结果: {result1}")

# %%
# 测试不同结果的投票
print("\n" + "="*60)
print("=== 测试不同结果的投票 ===")

test_data_different = [
    {'model': 'claude-sonnet-4',
     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15, "volume": "high"}}'},
    {'model': 'gemini-2.5',
     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 20, "volume": "low"}}'},
    {'model': 'gpt-4o',
     'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15, "volume": "medium"}}'},
    {'model': 'qwen3-4b-2507',
     'function_call': '{"name": "music_control", "arguments": {"auto_stop_time": 10, "volume": "high"}}'}
]

result2 = vote_for_model_results(test_data_different)
print(f"\n最终投票结果: {result2}")

print("\n" + "="*60)
print("投票分析:")
print("权重分布: claude-sonnet-4(2) + gpt-4o(2) + gemini-2.5(1) + qwen3-4b-2507(0.5)")
print("name字段:")
print("  - music_settings_control: claude(2) + gemini(1) + gpt(2) = 5票")
print("  - music_control: qwen(0.5) = 0.5票")
print("  → music_settings_control 获胜")
print("arguments.auto_stop_time字段:")
print("  - 15: claude(2) + gpt(2) = 4票")
print("  - 20: gemini(1) = 1票") 
print("  - 10: qwen(0.5) = 0.5票")
print("  → 15 获胜")
print("arguments.volume字段:")
print("  - high: claude(2) + qwen(0.5) = 2.5票")
print("  - low: gemini(1) = 1票")
print("  - medium: gpt(2) = 2票")
print("  → high 获胜")

# %%
# 测试只有3个模型的情况
print("\n" + "="*60)
print("=== 测试只有3个模型的情况 ===")

test_data_three = [
    {'model': 'claude-sonnet-4',
     'function_call': '{"name": "video_play", "arguments": {"video_id": "123", "quality": "4K"}}'},
    {'model': 'gemini-2.5',
     'function_call': '{"name": "video_play", "arguments": {"video_id": "123", "quality": "HD"}}'},
    {'model': 'gpt-4o',
     'function_call': '{"name": "video_play", "arguments": {"video_id": "456", "quality": "4K"}}'}
]

result3 = vote_for_model_results(test_data_three)
print(f"\n最终投票结果: {result3}")

print("\n" + "="*60)
print("投票分析 (3个模型):")
print("权重分布: claude-sonnet-4(2) + gpt-4o(2) + gemini-2.5(1)")
print("name字段: 所有都是video_play → video_play 获胜")
print("arguments.video_id字段:")
print("  - 123: claude(2) + gemini(1) = 3票")
print("  - 456: gpt(2) = 2票")
print("  → 123 获胜")
print("arguments.quality字段:")
print("  - 4K: claude(2) + gpt(2) = 4票")
print("  - HD: gemini(1) = 1票")
print("  → 4K 获胜")

# %%
def batch_vote_for_queries(df_grouped_data):
    """
    批量处理多个query的投票
    
    参数:
        df_grouped_data: DataFrame，包含query和对应的model_function_call列表
    
    返回:
        DataFrame，包含每个query的投票结果
    """
    results = []
    
    for _, row in df_grouped_data.iterrows():
        query = row['query']
        model_function_calls = row['model_function_call']
        
        print(f"\n{'='*50}")
        print(f"处理Query: {query}")
        print(f"模型数量: {len(model_function_calls)}")
        
        # 对当前query进行投票
        voted_result = vote_for_model_results(model_function_calls)
        
        results.append({
            'query': query,
            'model_function_calls': model_function_calls,
            'voted_function_call': voted_result
        })
    
    return pd.DataFrame(results)

# 使用示例
print("\n" + "="*60)
print("=== 批量处理示例 ===")

# 模拟从前面group by得到的数据
sample_grouped_data = pd.DataFrame([
    {
        'query': '设置音乐自动停止',
        'model_function_call': [
            {'model': 'claude-sonnet-4', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
            {'model': 'gpt-4o', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 15}}'},
            {'model': 'gemini-2.5', 'function_call': '{"name": "music_settings_control", "arguments": {"auto_stop_time": 20}}'}
        ]
    },
    {
        'query': '播放视频',
        'model_function_call': [
            {'model': 'claude-sonnet-4', 'function_call': '{"name": "video_play", "arguments": {"quality": "4K"}}'},
            {'model': 'gpt-4o', 'function_call': '{"name": "video_play", "arguments": {"quality": "HD"}}'},
            {'model': 'gemini-2.5', 'function_call': '{"name": "video_play", "arguments": {"quality": "4K"}}'}
        ]
    }
])

# 批量处理
batch_results = batch_vote_for_queries(sample_grouped_data)

print(f"\n最终批量处理结果:")
for _, row in batch_results.iterrows():
    print(f"\nQuery: {row['query']}")
    print(f"投票结果: {row['voted_function_call']}")

# %%
import pandas as pd
import json

# 创建示例数据，模拟你的DataFrame结构
data = [
    {'query': '播放音乐', 'model': 'model_a', 'function_call': '{"function-name": "music_call", "param": {"name": "lisa", "type": "normal"}}'},
    {'query': '播放音乐', 'model': 'model_b', 'function_call': '{"function-name": "music_call", "param": {"name": "Joe", "type": "normal"}}'},
    {'query': '播放音乐', 'model': 'model_c', 'function_call': '{"function-name": "music_call", "param": {"name": "Joe", "type": "vip"}}'},
    {'query': '播放视频', 'model': 'model_a', 'function_call': '{"function-name": "video_play", "param": {"id": "123", "quality": "high"}}'},
    {'query': '播放视频', 'model': 'model_b', 'function_call': '{"function-name": "video_play", "param": {"id": "123", "quality": "low"}}'},
    {'query': '播放视频', 'model': 'model_c', 'function_call': '{"function-name": "video_play", "param": {"id": "123", "quality": "high"}}'},
    {'query': '显示文本', 'model': 'model_a', 'function_call': '{"function-name": "text_display", "param": {"content": "Hello", "font": "Arial"}}'},
    {'query': '显示文本', 'model': 'model_b', 'function_call': '{"function-name": "text_display", "param": {"content": "Hello", "font": "Times"}}'},
]

df = pd.DataFrame(data)
print("原始DataFrame:")
print(df)
print(f"形状: {df.shape}")
print(f"列名: {list(df.columns)}")

# %%
# 方法2: 使用agg聚合多列
print("=== 方法2: 使用agg聚合多列 ===")

result2 = df.groupby('query').agg({
    'model': list,
    'function_call': list
}).reset_index()

# 创建model_function_call列表
result2['model_function_call'] = result2.apply(lambda row: [
    {'model': model, 'function_call': fc} 
    for model, fc in zip(row['model'], row['function_call'])
], axis=1)

# 只保留需要的列
result2_final = result2[['query', 'model_function_call']]

print("Group by 结果 (方法2):")
print(result2_final)

print("\n详细查看:")
for _, row in result2_final.iterrows():
    print(f"\nQuery: {row['query']}")
    for i, item in enumerate(row['model_function_call']):
        print(f"  {i+1}. {item}")

# %%
# 方法3: 结合投票算法的完整解决方案
print("=== 方法3: 结合投票算法的完整解决方案 ===")

# 按query分组并创建model_function_call列表
grouped_df = df.groupby('query').agg({
    'model': list,
    'function_call': list
}).reset_index()

# 为每个query创建model_function_call列表并进行投票
def process_query_group(row):
    """处理每个query组，返回投票结果"""
    models = row['model']
    function_calls = row['function_call']
    
    # 创建model_function_call列表
    model_function_calls = [
        {'model': model, 'function_call': fc}
        for model, fc in zip(models, function_calls)
    ]
    
    # 解析function_call JSON字符串为字典
    parsed_function_calls = []
    for item in model_function_calls:
        try:
            fc_dict = json.loads(item['function_call'])
            parsed_function_calls.append(fc_dict)
        except:
            # 如果解析失败，跳过该项
            continue
    
    # 如果有足够的数据，进行投票
    if len(parsed_function_calls) >= 2:
        # 为投票算法准备数据（这里简化为取前3个，不足的用空字典填充）
        while len(parsed_function_calls) < 3:
            parsed_function_calls.append({})
        
        # 使用投票算法（这里简化处理）
        voted_result = parsed_function_calls[0]  # 简化：直接取第一个
    else:
        voted_result = parsed_function_calls[0] if parsed_function_calls else {}
    
    return {
        'model_function_call_list': model_function_calls,
        'voted_function_call': voted_result
    }

# 应用处理函数
grouped_df['processed'] = grouped_df.apply(process_query_group, axis=1)

# 展开结果
final_result = pd.DataFrame({
    'query': grouped_df['query'],
    'model_function_call': grouped_df['processed'].apply(lambda x: x['model_function_call_list']),
    'voted_function_call': grouped_df['processed'].apply(lambda x: x['voted_function_call'])
})

print("最终结果:")
print(final_result)

print("\n详细查看每个query的处理结果:")
for _, row in final_result.iterrows():
    print(f"\n{'='*50}")
    print(f"Query: {row['query']}")
    print(f"Model Function Call List:")
    for i, item in enumerate(row['model_function_call']):
        print(f"  {i+1}. Model: {item['model']}")
        print(f"     Function Call: {item['function_call']}")
    print(f"Voted Result: {row['voted_function_call']}")
    print('='*50)

# %%
# 方法1: 先创建model_function_call列，然后group by
print("=== 方法1: 先创建组合列，再分组 ===")

# 创建model_function_call列，包含model和function_call的字典
df['model_function_call'] = df.apply(lambda row: {
    'model': row['model'], 
    'function_call': row['function_call']
}, axis=1)

print("添加model_function_call列后的DataFrame:")
print(df[['query', 'model_function_call']].head())

# 按query分组，将相同query的model_function_call放入列表
result1 = df.groupby('query')['model_function_call'].apply(list).reset_index()
print("\nGroup by 结果 (方法1):")
print(result1)

print("\n详细查看每个query的model_function_call列表:")
for _, row in result1.iterrows():
    print(f"\nQuery: {row['query']}")
    for i, item in enumerate(row['model_function_call']):
        print(f"  {i+1}. {item}")

# %%
def tokenize_lens(text):
    # 英文分词：按空格分词
    english_tokens = text.split()

    # 中文分词：按单个字符分词
    chinese_tokens = []
    for char in text:
        if '\u4e00' <= char <= '\u9fff':  # 判断字符是否为中文
            chinese_tokens.append(char)

    # 合并英文字符和中文单字
    tokens = english_tokens + chinese_tokens
    return len(tokens)

# %%
all_text = """
        You are designed to help with a variety of tasks, from answering questions to providing summaries to other types of analyses.

        ## Tools

        You have access to a wide variety of tools. You are responsible for using the tools in any sequence you deem appropriate to complete the task at hand.
        This may require breaking the task into subtasks and using different tools to complete each subtask.

        You have access to the following tools:
        > Tool Name: create_album
Tool Description: Create a new photo album
Tool Args: {"type": "object", "properties": {"album_name": {"type": "string", "description": "The name of the album to be created"}, "album_type": {"type": "string", "enum": ["normal"], "description": "The type of the album, default by normal"}}, "required": ["album_name", "album_type"], "additionalProperties": false}

> Tool Name: search_photos
Tool Description: Search for photos or images
Tool Args: {"type": "object", "properties": {"keyword": {"type": "string", "description": "The search keyword for photos or images. It can be descriptive text or a file name, e.g., 'photos taken last August' or 'dog on the grass'."}}, "required": ["keyword"], "additionalProperties": false}

> Tool Name: get_album_list
Tool Description: Retrieve the list of photo albums, including regular albums, people albums, baby albums, conditional albums, and object recognition albums.
Tool Args: {"type": "object", "properties": {"album_type": {"type": "string", "enum": ["normal", "face", "baby", "condition", "object"], "description": "The type of album to retrieve. Options: normal (regular album), face (people album), baby (baby album), condition (conditional album), object (object recognition album, 识物相册)."}}, "required": ["album_type"], "additionalProperties": false}

> Tool Name: music_play_control
Tool Description: Music control tool: play songs, albums, artists, playlists, and other music content. Supports playback modes, and retrieving content from recent history or favorites.
Tool Args: {"type": "object", "properties": {"title": {"type": "string", "description": "Name or title of the music content"}, "source": {"type": "string", "enum": ["recent", "favorites"], "description": "Content source: recent=recently played, favorites=liked songs. Only specify when user explicitly mentions recent or favorite content."}, "play_mode": {"type": "string", "enum": ["normal", "random", "single", "loop"], "description": "Playback mode: normal=sequential, random=shuffle, single=repeat single track, loop=repeat all."}}, "anyOf": [{"required": ["title"]}, {"required": ["source"]}], "additionalProperties": false}

> Tool Name: music_settings_control
Tool Description: Control music app settings
Tool Args: {"type": "object", "properties": {"auto_stop_time": {"type": "number", "description": "Set sleep timer duration, for example, stop playback after 15 minutes"}}, "required": ["auto_stop_time"], "additionalProperties": false}

> Tool Name: video_search_control
Tool Description: Video search tool: search TV series, movies, and other video content. 
Tool Args: {"type": "object", "properties": {"title": {"type": "string", "description": "Name or title of the video content, supports fuzzy matching."}, "type": {"type": "string", "enum": ["tv", "movie", "collection"], "description": "Content type: tv=TV series/drama, movie=films/blockbusters, collection=movie series/collections."}}, "required": ["title"], "additionalProperties": false}

> Tool Name: video_play_control
Tool Description: Video play tool: play TV series, movies, and other video content. Supports retrieving content from recently watched history and favorites.
Tool Args: {"type": "object", "properties": {"title": {"type": "string", "description": "Name or title of the video content, supports fuzzy matching."}, "type": {"type": "string", "enum": ["tv", "movie", "collection"], "description": "Content type: tv=TV series/drama, movie=films/blockbusters, collection=movie series/collections."}}, "required": ["title"], "additionalProperties": false}

> Tool Name: get_system_info
Tool Description: Retrieve detailed information about the device, operating system, storage, network status, warranty, or UGREEN Link account.
Tool Args: {"type": "object", "properties": {"system_type": {"type": "string", "description": "The category of information to query. Options: system=system info, device=device info, storage=storage info, network=network info, uglink=UGREEN Link related info.", "enum": ["system", "device", "storage", "network", "uglink"]}}, "required": ["system_type"], "additionalProperties": false}

        Below is the user's request:
        Can you create a new photo album for me?

        ## Output Format

        Please answer in the same language as the question and use the following format:

        ```
        Thought: The current language of the user is: (user's language). I need to use a tool to help me answer the question.
        Action: tool name (one of create_album, search_photos, get_album_list, music_play_control, music_settings_control, video_search_control, video_play_control, get_system_info) if using a tool.
        Action Input: the input to the tool, in a JSON format representing the kwargs (e.g. {"input": "hello world", "num_beams": 5})
        ```

        Please ALWAYS start with a Thought.

        NEVER surround your response with markdown code markers. You may use code markers within your response if you need to.
        """

# %%
tokenize_lens(all_text)
# Out:
# 667

# %% [markdown]
# # 用deepseek qwen3 新生成数据 预处理

# %%
import pandas as pd

# 合并所有数据
all_data = []

# 创建相册数据
create_album_data = [
  {
    "input": "创建一个新相册",
    "output": {
      "intent": "create_album",
      "slots": {}
    }
  },
  {
    "input": "新建一个名为旅行的相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "旅行"
      }
    }
  },
  {
    "input": "创建一个宝宝成长相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "宝宝成长",
        "album_type": "baby"
      }
    }
  },
  {
    "input": "建立人物相册，名字叫家人",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "家人",
        "album_type": "face"
      }
    }
  },
  {
    "input": "创建一个普通相册，命名为风景",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "风景",
        "album_type": "normal"
      }
    }
  },
  {
    "input": "新建猫咪相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "猫咪",
        "album_type": "object"
      }
    }
  },
  {
    "input": "创建一个条件相册，包含去年十月的照片",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_type": "condition"
      }
    }
  },
  {
    "input": "建立狗狗照片相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "狗狗照片",
        "album_type": "object"
      }
    }
  },
  {
    "input": "创建一个婚礼纪念相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "婚礼纪念"
      }
    }
  },
  {
    "input": "新建家庭相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "家庭"
      }
    }
  },
  {
    "input": "创建朋友聚会相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "朋友聚会"
      }
    }
  },
  {
    "input": "建立生日派对相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "生日派对"
      }
    }
  },
  {
    "input": "创建一个宝宝专属相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "宝宝专属",
        "album_type": "baby"
      }
    }
  },
  {
    "input": "新建人物识别相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_type": "face"
      }
    }
  },
  {
    "input": "创建假期照片相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "假期照片"
      }
    }
  },
  {
    "input": "建立美食摄影相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "美食摄影"
      }
    }
  },
  {
    "input": "创建一个汽车相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "汽车",
        "album_type": "object"
      }
    }
  },
  {
    "input": "新建自然风光相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "自然风光"
      }
    }
  },
  {
    "input": "创建条件筛选相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_type": "condition"
      }
    }
  },
  {
    "input": "建立我的珍藏相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "我的珍藏"
      }
    }
  }
]

# 搜索照片数据
search_photos_data = [
  {
    "input": "搜索照片",
    "output": {
      "intent": "search_photos",
      "slots": {}
    }
  },
  {
    "input": "查找去年十二月拍的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "去年十二月拍的照片"
      }
    }
  },
  {
    "input": "搜索关于足球的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "关于足球的照片"
      }
    }
  },
  {
    "input": "找一下在海边的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "在海边的照片"
      }
    }
  },
  {
    "input": "搜索游乐园的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "游乐园的照片"
      }
    }
  },
  {
    "input": "查找生日派对的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "生日派对的照片"
      }
    }
  },
  {
    "input": "搜索婚礼当天的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "婚礼当天的照片"
      }
    }
  },
  {
    "input": "找一下去年夏天的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "去年夏天的照片"
      }
    }
  },
  {
    "input": "搜索美食照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "美食照片"
      }
    }
  },
  {
    "input": "查找宠物的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "宠物的照片"
      }
    }
  },
  {
    "input": "搜索旅行时拍的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "旅行时拍的照片"
      }
    }
  },
  {
    "input": "找一下家庭聚会的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "家庭聚会的照片"
      }
    }
  },
  {
    "input": "搜索夜景照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "夜景照片"
      }
    }
  },
  {
    "input": "查找雪景照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "雪景照片"
      }
    }
  },
  {
    "input": "搜索日出时分的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "日出时分的照片"
      }
    }
  },
  {
    "input": "找一下毕业典礼的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "毕业典礼的照片"
      }
    }
  },
  {
    "input": "搜索运动时的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "运动时的照片"
      }
    }
  },
  {
    "input": "查找节日庆祝的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "节日庆祝的照片"
      }
    }
  },
  {
    "input": "搜索城市风光的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "城市风光的照片"
      }
    }
  },
  {
    "input": "找一下自然风景的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "自然风景的照片"
      }
    }
  }
]

# 获取相册列表数据
get_album_list_data = [
  {
    "input": "显示相册列表",
    "output": {
      "intent": "get_album_list",
      "slots": {}
    }
  },
  {
    "input": "查看所有相册",
    "output": {
      "intent": "get_album_list",
      "slots": {}
    }
  },
  {
    "input": "获取普通相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "normal"
      }
    }
  },
  {
    "input": "显示人物相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "face"
      }
    }
  },
  {
    "input": "查看宝宝相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "baby"
      }
    }
  },
  {
    "input": "获取条件相册列表",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "condition"
      }
    }
  },
  {
    "input": "显示物体相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "object"
      }
    }
  },
  {
    "input": "查看所有人物相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "face"
      }
    }
  },
  {
    "input": "获取宝宝成长相册列表",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "baby"
      }
    }
  },
  {
    "input": "显示条件筛选的相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "condition"
      }
    }
  },
  {
    "input": "查看宠物相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "object"
      }
    }
  },
  {
    "input": "获取常规相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "normal"
      }
    }
  },
  {
    "input": "显示人脸识别相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "face"
      }
    }
  },
  {
    "input": "查看婴儿相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "baby"
      }
    }
  },
  {
    "input": "获取按条件分类的相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "condition"
      }
    }
  },
  {
    "input": "显示物品识别相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "object"
      }
    }
  },
  {
    "input": "查看所有类型的相册",
    "output": {
      "intent": "get_album_list",
      "slots": {}
    }
  },
  {
    "input": "获取标准相册列表",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "normal"
      }
    }
  },
  {
    "input": "显示按人物分类的相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "face"
      }
    }
  },
  {
    "input": "查看儿童相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "baby"
      }
    }
  }
]

# 音乐播放控制数据
music_play_control_data = [
  {
    "input": "播放音乐",
    "output": {
      "intent": "music_play_control",
      "slots": {}
    }
  },
  {
    "input": "播放周杰伦的歌",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "周杰伦"
      }
    }
  },
  {
    "input": "播放青花瓷",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "青花瓷"
      }
    }
  },
  {
    "input": "随机播放我收藏的音乐",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "source": "favorites",
        "play_mode": "random"
      }
    }
  },
  {
    "input": "顺序播放最近听的歌",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "source": "recent",
        "play_mode": "normal"
      }
    }
  },
  {
    "input": "单曲循环播放七里香",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "七里香",
        "play_mode": "single"
      }
    }
  },
  {
    "input": "循环播放我的收藏",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "source": "favorites",
        "play_mode": "loop"
      }
    }
  },
  {
    "input": "播放邓紫棋的泡沫",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "邓紫棋的泡沫"
      }
    }
  },
  {
    "input": "随机播放",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "play_mode": "random"
      }
    }
  },
  {
    "input": "播放古典音乐",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "古典音乐"
      }
    }
  },
  {
    "input": "播放我最近听的歌单",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "source": "recent"
      }
    }
  },
  {
    "input": "循环播放当前歌曲",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "play_mode": "single"
      }
    }
  },
  {
    "input": "播放流行歌曲",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "流行歌曲"
      }
    }
  },
  {
    "input": "随机播放我最喜欢的歌",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "source": "favorites",
        "play_mode": "random"
      }
    }
  },
  {
    "input": "顺序播放钢琴曲",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "钢琴曲",
        "play_mode": "normal"
      }
    }
  },
  {
    "input": "播放林俊杰的专辑",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "林俊杰的专辑"
      }
    }
  },
  {
    "input": "单曲循环夜曲",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "夜曲",
        "play_mode": "single"
      }
    }
  },
  {
    "input": "循环播放播放列表",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "play_mode": "loop"
      }
    }
  },
  {
    "input": "播放摇滚乐",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "摇滚乐"
      }
    }
  },
  {
    "input": "播放我喜欢的音乐",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "source": "favorites"
      }
    }
  }
]

# 音乐设置控制数据
music_settings_control_data = [
  {
    "input": "设置音乐播放器",
    "output": {
      "intent": "music_settings_control",
      "slots": {}
    }
  },
  {
    "input": "设置30分钟后自动停止",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "30分钟"
      }
    }
  },
  {
    "input": "一小时后自动关闭音乐",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "1小时"
      }
    }
  },
  {
    "input": "设置45分钟自动停止播放",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "45分钟"
      }
    }
  },
  {
    "input": "两小时后停止音乐",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "2小时"
      }
    }
  },
  {
    "input": "设置15分钟自动关机",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "15分钟"
      }
    }
  },
  {
    "input": "一小时后自动停止",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "1小时"
      }
    }
  },
  {
    "input": "设置90分钟自动关闭",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "90分钟"
      }
    }
  },
  {
    "input": "三十分钟后停止播放",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "30分钟"
      }
    }
  },
  {
    "input": "设置一小时自动停止",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "1小时"
      }
    }
  },
  {
    "input": "45分钟后关闭音乐",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "45分钟"
      }
    }
  },
  {
    "input": "设置两小时自动停止",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "2小时"
      }
    }
  },
  {
    "input": "一小时后自动关机",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "1小时"
      }
    }
  },
  {
    "input": "设置20分钟自动停止播放",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "20分钟"
      }
    }
  },
  {
    "input": "三小时后停止音乐",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "3小时"
      }
    }
  },
  {
    "input": "设置50分钟自动关闭",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "50分钟"
      }
    }
  },
  {
    "input": "一小时后自动停止播放",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "1小时"
      }
    }
  },
  {
    "input": "设置25分钟自动关机",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "25分钟"
      }
    }
  },
  {
    "input": "两小时三十分后停止",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "2小时30分"
      }
    }
  },
  {
    "input": "设置40分钟自动停止",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "40分钟"
      }
    }
  }
]

# 视频搜索和播放控制数据
video_data = [
  {
    "input": "搜索视频",
    "output": {
      "intent": "video_search_control",
      "slots": {}
    }
  },
  {
    "input": "找一下喜剧电影",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "喜剧",
        "type": "movie"
      }
    }
  },
  {
    "input": "搜索权力的游戏",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "权力的游戏",
        "type": "tv"
      }
    }
  },
  {
    "input": "查找漫威系列电影",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "漫威系列",
        "type": "collection"
      }
    }
  },
  {
    "input": "搜索动作片",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "动作片",
        "type": "movie"
      }
    }
  },
  {
    "input": "找恐怖电影",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "恐怖",
        "type": "movie"
      }
    }
  },
  {
    "input": "搜索科幻电视剧",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "科幻",
        "type": "tv"
      }
    }
  },
  {
    "input": "查找成龙的电影",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "成龙",
        "type": "movie"
      }
    }
  },
  {
    "input": "搜索爱情片",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "爱情片",
        "type": "movie"
      }
    }
  },
  {
    "input": "找迪士尼系列电影",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "迪士尼系列",
        "type": "collection"
      }
    }
  },
  {
    "input": "搜索悬疑剧",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "悬疑",
        "type": "tv"
      }
    }
  },
  {
    "input": "查找周星驰的喜剧",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "周星驰的喜剧",
        "type": "movie"
      }
    }
  },
  {
    "input": "搜索动画电影",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "动画",
        "type": "movie"
      }
    }
  },
  {
    "input": "找历史纪录片",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "历史纪录片",
        "type": "tv"
      }
    }
  },
  {
    "input": "搜索DC宇宙系列",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "DC宇宙系列",
        "type": "collection"
      }
    }
  },
  {
    "input": "查找战争片",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "战争片",
        "type": "movie"
      }
    }
  },
  {
    "input": "搜索家庭剧",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "家庭剧",
        "type": "tv"
      }
    }
  },
  {
    "input": "找哈利波特系列",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "哈利波特系列",
        "type": "collection"
      }
    }
  },
  {
    "input": "搜索音乐电影",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "音乐电影",
        "type": "movie"
      }
    }
  },
  {
    "input": "查找犯罪题材电视剧",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "犯罪题材",
        "type": "tv"
      }
    }
  },
  {
    "input": "播放视频",
    "output": {
      "intent": "video_play_control",
      "slots": {}
    }
  },
  {
    "input": "播放阿凡达",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "阿凡达",
        "type": "movie"
      }
    }
  },
  {
    "input": "播放最受欢迎的电影",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "最受欢迎的电影",
        "type": "movie"
      }
    }
  },
  {
    "input": "播放科幻片",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "科幻片",
        "type": "movie"
      }
    }
  },
  {
    "input": "播放老友记",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "老友记",
        "type": "tv"
      }
    }
  },
  {
    "input": "播放漫威系列",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "漫威系列",
        "type": "collection"
      }
    }
  },
  {
    "input": "播放喜剧电视剧",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "喜剧",
        "type": "tv"
      }
    }
  },
  {
    "input": "播放泰坦尼克号",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "泰坦尼克号",
        "type": "movie"
      }
    }
  },
  {
    "input": "播放动作电影",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "动作电影",
        "type": "movie"
      }
    }
  },
  {
    "input": "播放权力的游戏",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "权力的游戏",
        "type": "tv"
      }
    }
  },
  {
    "input": "播放星球大战系列",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "星球大战系列",
        "type": "collection"
      }
    }
  },
  {
    "input": "播放恐怖片",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "恐怖片",
        "type": "movie"
      }
    }
  },
  {
    "input": "播放悬疑剧",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "悬疑剧",
        "type": "tv"
      }
    }
  },
  {
    "input": "播放指环王系列",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "指环王系列",
        "type": "collection"
      }
    }
  },
  {
    "input": "播放爱情电影",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "爱情电影",
        "type": "movie"
      }
    }
  },
  {
    "input": "播放历史纪录片",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "历史纪录片",
        "type": "tv"
      }
    }
  },
  {
    "input": "播放迪士尼经典系列",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "迪士尼经典系列",
        "type": "collection"
      }
    }
  },
  {
    "input": "播放动画片",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "动画片",
        "type": "movie"
      }
    }
  },
  {
    "input": "播放犯罪题材剧集",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "犯罪题材",
        "type": "tv"
      }
    }
  },
  {
    "input": "播放最新上映的电影",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "最新上映的电影",
        "type": "movie"
      }
    }
  }
]

# 系统信息数据
system_info_data = [
  {
    "input": "查看系统信息",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "system"
      }
    }
  },
  {
    "input": "显示设备信息",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "device"
      }
    }
  },
  {
    "input": "查看存储空间",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "storage"
      }
    }
  },
  {
    "input": "显示网络状态",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "network"
      }
    }
  },
  {
    "input": "查看UGREEN Link信息",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "uglink"
      }
    }
  },
  {
    "input": "系统状态",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "system"
      }
    }
  },
  {
    "input": "设备详情",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "device"
      }
    }
  },
  {
    "input": "存储使用情况",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "storage"
      }
    }
  },
  {
    "input": "网络连接信息",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "network"
      }
    }
  },
  {
    "input": "UGREEN Link状态",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "uglink"
      }
    }
  },
  {
    "input": "系统配置",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "system"
      }
    }
  },
  {
    "input": "硬件信息",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "device"
      }
    }
  },
  {
    "input": "剩余存储空间",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "storage"
      }
    }
  },
  {
    "input": "网络速度",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "network"
      }
    }
  },
  {
    "input": "UGREEN Link连接状态",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "uglink"
      }
    }
  },
  {
    "input": "系统版本",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "system"
      }
    }
  },
  {
    "input": "设备型号",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "device"
      }
    }
  },
  {
    "input": "磁盘空间",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "storage"
      }
    }
  },
  {
    "input": "WiFi信号强度",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "network"
      }
    }
  },
  {
    "input": "UGREEN Link设备列表",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "uglink"
      }
    }
  }
]

# 合并所有数据
all_data = (create_album_data + search_photos_data + get_album_list_data + 
           music_play_control_data + music_settings_control_data + 
           video_data + system_info_data)

# 转换为DataFrame格式
df_data = []
for item in all_data:
    df_data.append({
        'input': item['input'],
        'output': str(item['output']),
        'output_intent': item['output']['intent'],
        'output_slots': str(item['output']['slots'])
    })

# 创建DataFrame
dp_data1_df = pd.DataFrame(df_data)
print(f"数据形状: {dp_data1_df.shape}")
print(f"列名: {dp_data1_df.columns.tolist()}")
dp_data1_df.head()
# Out:
# 数据形状: (160, 4)
# 列名: ['input', 'output', 'output_intent', 'output_slots']
#             input                                             output  \
# 0         创建一个新相册            {'intent': 'create_album', 'slots': {}}
# 1     新建一个名为旅行的相册  {'intent': 'create_album', 'slots': {'album_na...
# 2      创建一个宝宝成长相册  {'intent': 'create_album', 'slots': {'album_na...
# 3    建立人物相册，名字叫家人  {'intent': 'create_album', 'slots': {'album_na...
# 4  创建一个普通相册，命名为风景  {'intent': 'create_album', 'slots': {'album_na...
#
#   output_intent                                  output_slots
# 0  create_album                                            {}
# 1  create_album                          {'album_name': '旅行'}
# 2  create_album  {'album_name': '宝宝成长', 'album_type': 'baby'}
# 3  create_album    {'album_name': '家人', 'album_type': 'face'}
# 4  create_album  {'album_name': '风景', 'album_type': 'normal'}

# %%
dp_data1_df
# Out:
#                input                                             output  \
# 0            创建一个新相册            {'intent': 'create_album', 'slots': {}}
# 1        新建一个名为旅行的相册  {'intent': 'create_album', 'slots': {'album_na...
# 2         创建一个宝宝成长相册  {'intent': 'create_album', 'slots': {'album_na...
# 3       建立人物相册，名字叫家人  {'intent': 'create_album', 'slots': {'album_na...
# 4     创建一个普通相册，命名为风景  {'intent': 'create_album', 'slots': {'album_na...
# ..               ...                                                ...
# 155             系统版本  {'intent': 'get_system_info', 'slots': {'syste...
# 156             设备型号  {'intent': 'get_system_info', 'slots': {'syste...
# 157             磁盘空间  {'intent': 'get_system_info', 'slots': {'syste...
# 158         WiFi信号强度  {'intent': 'get_system_info', 'slots': {'syste...
# 159  UGREEN Link设备列表  {'intent': 'get_system_info', 'slots': {'syste...
#
#        output_intent                                  output_slots
# 0       create_album                                            {}
# 1       create_album                          {'album_name': '旅行'}
# 2       create_album  {'album_name': '宝宝成长', 'album_type': 'baby'}
# 3       create_album    {'album_name': '家人', 'album_type': 'face'}
# 4       create_album  {'album_name': '风景', 'album_type': 'normal'}
# ..               ...                                           ...
# 155  get_system_info                     {'system_type': 'system'}
# 156  get_system_info                     {'system_type': 'device'}
# 157  get_system_info                    {'system_type': 'storage'}
# 158  get_system_info                    {'system_type': 'network'}
# 159  get_system_info                     {'system_type': 'uglink'}
#
# [160 rows x 4 columns]

# %%
qwen_data = [
    {"query": "显示条件相册目录", "response": {"intent": "get_album_list", "slots": {"album_type": "condition"}}},
    {"query": "请告诉我存储空间的详细情况", "response": {"intent": "get_system_info", "slots": {"system_type": "storage"}}},
    {"query": "请搜索一下上个月拍的照片，谢谢", "response": {"intent": "search_photos", "slots": {"description": "上个月拍的"}}},
    {"query": "我要找去年旅游景点的照片", "response": {"intent": "search_photos", "slots": {"description": "去年旅游景点"}}},
    {"query": "创建一个新的相册", "response": {"intent": "create_album", "slots": {}}},
    {"query": "播放一些轻松的音乐", "response": {"intent": "music_play_control", "slots": {"title": "轻松的音乐"}}},
    {"query": "设置30分钟后自动停止播放", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "30分钟"}}},
    {"query": "搜索科幻电影", "response": {"intent": "video_search_control", "slots": {"title": "科幻电影", "type": "movie"}}},
    {"query": "播放最新的电视剧", "response": {"intent": "video_play_control", "slots": {"title": "最新的电视剧", "type": "tv"}}},
    {"query": "查看系统运行状态", "response": {"intent": "get_system_info", "slots": {"system_type": "system"}}}
]

# 转换qwen_data为DataFrame格式
qwen_df_data = []
for item in qwen_data:
    qwen_df_data.append({
        'input': item['query'],
        'output': str(item['response']),
        'output_intent': item['response']['intent'],
        'output_slots': str(item['response']['slots'])
    })

# 创建qwen DataFrame
qwen_df = pd.DataFrame(qwen_df_data)

# 合并所有DataFrame
final_combined_df = pd.concat([combined_df, qwen_df], ignore_index=True)

print(f"原合并数据集形状: {combined_df.shape}")
print(f"Qwen数据集形状: {qwen_df.shape}")
print(f"最终合并数据集形状: {final_combined_df.shape}")
print(f"最终合并后列名: {final_combined_df.columns.tolist()}")

final_combined_df.tail()
# Out:
# [{'input': '明天会下雨吗', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '关灯', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '点一份披萨', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '查询火车票', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '帮我写一封信', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '解数学方程', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '设置提醒', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '视频通话', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '发电子邮件', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '创建待办事项', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '导航到最近的地铁站', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '查看汇率', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '讲个故事', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '播放播客', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '打开空调', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '调节温度', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '启动扫地机器人', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '查询快递状态', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '预订餐厅', 'output': {'intent': 'unknown', 'slots': {}}},
#  {'input': '查看体育新闻', 'output': {'intent': 'unknown', 'slots': {}}}]

# %%
# 合并所有数据
all_data_2 = dp_data_2

# 转换为DataFrame格式
df_data_2 = []
for item in all_data_2:
    df_data_2.append({
        'input': item['input'],
        'output': str(item['output']),
        'output_intent': item['output']['intent'],
        'output_slots': str(item['output']['slots'])
    })

# 创建第二个DataFrame
dp_data2_df = pd.DataFrame(df_data_2)

# 合并两个DataFrame
combined_df = pd.concat([dp_data1_df, dp_data2_df], ignore_index=True)

print(f"第一个数据集形状: {dp_data1_df.shape}")
print(f"第二个数据集形状: {dp_data2_df.shape}")
print(f"合并后数据集形状: {combined_df.shape}")
print(f"合并后列名: {combined_df.columns.tolist()}")

combined_df.head()
# Out:
# 第一个数据集形状: (160, 4)
# 第二个数据集形状: (140, 4)
# 合并后数据集形状: (300, 4)
# 合并后列名: ['input', 'output', 'output_intent', 'output_slots']
#             input                                             output  \
# 0         创建一个新相册            {'intent': 'create_album', 'slots': {}}
# 1     新建一个名为旅行的相册  {'intent': 'create_album', 'slots': {'album_na...
# 2      创建一个宝宝成长相册  {'intent': 'create_album', 'slots': {'album_na...
# 3    建立人物相册，名字叫家人  {'intent': 'create_album', 'slots': {'album_na...
# 4  创建一个普通相册，命名为风景  {'intent': 'create_album', 'slots': {'album_na...
#
#   output_intent                                  output_slots
# 0  create_album                                            {}
# 1  create_album                          {'album_name': '旅行'}
# 2  create_album  {'album_name': '宝宝成长', 'album_type': 'baby'}
# 3  create_album    {'album_name': '家人', 'album_type': 'face'}
# 4  create_album  {'album_name': '风景', 'album_type': 'normal'}

# %%
combined_df['output_intent'].value_counts()
# Out:
# output_intent
# create_album              40
# search_photos             40
# get_album_list            40
# music_play_control        40
# music_settings_control    40
# video_search_control      40
# video_play_control        40
# get_system_info           20
# Name: count, dtype: int64

# %%
combined_df.shape
# Out:
# (300, 4)

# %%
qwen_data = [
    {"query": "显示条件相册目录", "response": {"intent": "get_album_list", "slots": {"album_type": "condition"}}},
    {"query": "请告诉我存储空间的详细情况", "response": {"intent": "get_system_info", "slots": {"system_type": "storage"}}},
    {"query": "请搜索一下上个月拍的照片，谢谢", "response": {"intent": "search_photos", "slots": {"description": "上个月拍的"}}},
    {"query": "我要找去年旅游景点的照片", "response": {"intent": "search_photos", "slots": {"description": "去年旅游景点"}}},
    {"query": "我想看电影《阿凡达》", "response": {"intent": "video_play_control", "slots": {"title": "阿凡达", "type": "movie"}}},
    {"query": "让音乐在半小时后自动关闭", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "30分钟"}}},
    {"query": "我希望创建一个包含我的宠物照片的专辑，叫做可爱宠物。", "response": {"intent": "create_album", "slots": {"album_name": "可爱宠物"}}},
    {"query": "设置音乐播放器睡眠模式，20分钟后停止", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "20分钟"}}},
    {"query": "毕业照片太多了，得新建个相册整理一下", "response": {"intent": "create_album", "slots": {}}},
    {"query": "准备升级前想先了解当前系统配置", "response": {"intent": "get_system_info", "slots": {"system_type": "system"}}},
    {"query": "立即播放《青花瓷》", "response": {"intent": "music_play_control", "slots": {"title": "青花瓷"}}},
    {"query": "在公司的年度晚会上拍了很多照片，我想做一个相册整理一下。", "response": {"intent": "create_album", "slots": {}}},
    {"query": "请提供网络信息细节。", "response": {"intent": "get_system_info", "slots": {"system_type": "network"}}},
    {"query": "查看UGREEN Link账户绑定信息", "response": {"intent": "get_system_info", "slots": {"system_type": "uglink"}}},
    {"query": "UGREEN Link账户详情是什么？", "response": {"intent": "get_system_info", "slots": {"system_type": "uglink"}}},
    {"query": "搜索《指环王》的电影全集。", "response": {"intent": "video_search_control", "slots": {"title": "指环王", "type": "collection"}}},
    {"query": "我想看看普通相册里有什么内容", "response": {"intent": "get_album_list", "slots": {"album_type": "normal"}}},
    {"query": "我不想让音乐一直播，设置一个25分钟的定时器吧。", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "25分钟"}}},
    {"query": "从最近播放中选一首专辑，并使用循环模式播放。", "response": {"intent": "music_play_control", "slots": {"source": "recent", "play_mode": "loop"}}},
    {"query": "工作时需要背景音乐播放90分钟后自动关闭", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "90分钟"}}},
    {"query": "帮我找一下《权力的游戏》这部剧。", "response": {"intent": "video_search_control", "slots": {"title": "权力的游戏", "type": "tv"}}},
    {"query": "帮我打开《延禧攻略》这部剧", "response": {"intent": "video_play_control", "slots": {"title": "延禧攻略", "type": "tv"}}},
    {"query": "你能帮我放一下我喜欢的歌曲吗？", "response": {"intent": "music_play_control", "slots": {"source": "favorites"}}},
    {"query": "搜索《指环王》的电影全集。", "response": {"intent": "video_search_control", "slots": {"title": "指环王", "type": "collection"}}},
    {"query": "搜索上周拍的海滩照片，谢谢", "response": {"intent": "search_photos", "slots": {"description": "上周拍的海滩照片"}}},
    {"query": "请帮我找所有家庭聚会的照片，特别是有孩子的", "response": {"intent": "search_photos", "slots": {"description": "所有家庭聚会的照片，特别是有孩子的"}}},
    {"query": "搜索《复仇者联盟》的电影全集", "response": {"intent": "video_search_control", "slots": {"title": "复仇者联盟", "type": "collection"}}},
    {"query": "找一下《西游记》的电视剧集", "response": {"intent": "video_search_control", "slots": {"title": "西游记", "type": "tv"}}},
    {"query": "创建一个相册叫'生日派对'，包含所有2023年的生日照片", "response": {"intent": "create_album", "slots": {"album_name": "生日派对"}}},
    {"query": "新建一个相册，记录我的婚礼，命名为'幸福时刻'", "response": {"intent": "create_album", "slots": {"album_name": "幸福时刻"}}},
    {"query": "请告诉我电池剩余电量的详细信息", "response": {"intent": "get_system_info", "slots": {"system_type": "battery"}}},
    {"query": "查看当前设备的内存使用情况", "response": {"intent": "get_system_info", "slots": {"system_type": "memory"}}},
    {"query": "设置音乐播放15分钟后自动停止", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "15分钟"}}},
    {"query": "让音乐在10分钟后自动关闭", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "10分钟"}}},
    {"query": "播放我收藏的歌单《周末心情》", "response": {"intent": "music_play_control", "slots": {"source": "favorites", "title": "周末心情"}}},
    {"query": "用随机模式播放最近的播放列表", "response": {"intent": "music_play_control", "slots": {"source": "recent", "play_mode": "random"}}},
    {"query": "显示所有家庭相册的列表", "response": {"intent": "get_album_list", "slots": {"album_type": "family"}}},
    {"query": "请列出工作相关的相册", "response": {"intent": "get_album_list", "slots": {"album_type": "work"}}},
    {"query": "播放《泰坦尼克号》这部电影", "response": {"intent": "video_play_control", "slots": {"title": "泰坦尼克号", "type": "movie"}}},
    {"query": "打开《三体》电视剧第一集", "response": {"intent": "video_play_control", "slots": {"title": "三体", "type": "tv"}}},
    {"query": "搜索上个月的旅行照片", "response": {"intent": "search_photos", "slots": {"description": "上个月的旅行照片"}}},
    {"query": "我想找今年春节拍的照片", "response": {"intent": "search_photos", "slots": {"description": "今年春节拍的照片"}}},
    {"query": "请提供相机设置的详细信息", "response": {"intent": "get_system_info", "slots": {"system_type": "camera"}}},
    {"query": "查看设备的蓝牙连接状态", "response": {"intent": "get_system_info", "slots": {"system_type": "bluetooth"}}},
    {"query": "想创建一个相册，叫'宠物日常'，包含所有猫的照片", "response": {"intent": "create_album", "slots": {"album_name": "宠物日常"}}},
    {"query": "设置音乐播放30分钟后自动关闭", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "30分钟"}}},
    {"query": "从我的播放列表中随机选一首歌播放", "response": {"intent": "music_play_control", "slots": {"source": "playlist", "play_mode": "random"}}},
    {"query": "搜索《哈利波特》系列电影", "response": {"intent": "video_search_control", "slots": {"title": "哈利波特", "type": "collection"}}},
    {"query": "找一下《甄嬛传》的电视剧全集", "response": {"intent": "video_search_control", "slots": {"title": "甄嬛传", "type": "tv"}}},
    {"query": "我需要一个相册来整理会议照片，命名为'项目记录'", "response": {"intent": "create_album", "slots": {"album_name": "项目记录"}}},
    {"query": "创建一个相册叫'宝宝成长'", "response": {"intent": "create_album", "slots": {"album_name": "宝宝成长"}}},
    {"query": "搜索上个月拍的宝宝照片", "response": {"intent": "search_photos", "slots": {"description": "上个月拍的宝宝照片"}}},
    {"query": "显示人脸相册的目录", "response": {"intent": "get_album_list", "slots": {"album_type": "face"}}},
    {"query": "查看存储空间的使用情况", "response": {"intent": "get_system_info", "slots": {"system_type": "storage"}}},
    {"query": "让音乐在20分钟后自动关闭", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "20分钟"}}},
    {"query": "播放《七里香》", "response": {"intent": "music_play_control", "slots": {"title": "七里香"}}},
    {"query": "创建相册'旅行纪念'，包含所有景点照片", "response": {"intent": "create_album", "slots": {"album_name": "旅行纪念"}}},
    {"query": "显示条件相册列表", "response": {"intent": "get_album_list", "slots": {"album_type": "condition"}}},
    {"query": "搜索《甄嬛传》电视剧", "response": {"intent": "video_search_control", "slots": {"title": "甄嬛传", "type": "tv"}}},
    {"query": "我想看《阿凡达》电影", "response": {"intent": "video_play_control", "slots": {"title": "阿凡达", "type": "movie"}}},
    {"query": "查看UGREEN Link账户信息", "response": {"intent": "get_system_info", "slots": {"system_type": "uglink"}}},
    {"query": "搜索宝宝满月的照片", "response": {"intent": "search_photos", "slots": {"description": "宝宝满月的照片"}}},
    {"query": "显示对象相册（猫的照片）", "response": {"intent": "get_album_list", "slots": {"album_type": "object"}}},
    {"query": "请提供网络连接状态", "response": {"intent": "get_system_info", "slots": {"system_type": "network"}}},
    {"query": "设置音乐播放30分钟后停止", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "30分钟"}}},
    {"query": "用随机模式播放最近播放列表", "response": {"intent": "music_play_control", "slots": {"source": "recent", "play_mode": "random"}}},
    {"query": "创建相册'节日合集'", "response": {"intent": "create_album", "slots": {"album_name": "节日合集"}}},
    {"query": "显示普通相册列表", "response": {"intent": "get_album_list", "slots": {"album_type": "normal"}}},
    {"query": "搜索《流浪地球》系列电影", "response": {"intent": "video_search_control", "slots": {"title": "流浪地球", "type": "collection"}}},
    {"query": "播放《权力的游戏》第一季", "response": {"intent": "video_play_control", "slots": {"title": "权力的游戏", "type": "tv", "season": "1"}}},
    {"query": "查看系统版本信息", "response": {"intent": "get_system_info", "slots": {"system_type": "system"}}},
    {"query": "搜索去年拍的旅行照片", "response": {"intent": "search_photos", "slots": {"description": "去年拍的旅行照片"}}},
    {"query": "显示婴儿相册", "response": {"intent": "get_album_list", "slots": {"album_type": "baby"}}},
    {"query": "请提供设备型号", "response": {"intent": "get_system_info", "slots": {"system_type": "device"}}},
    {"query": "让音乐在1小时后自动关闭", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "1小时"}}},
    {"query": "播放周杰伦的《晴天》", "response": {"intent": "music_play_control", "slots": {"title": "晴天", "artist": "周杰伦"}}},
    {"query": "创建相册'毕业纪念'", "response": {"intent": "create_album", "slots": {"album_name": "毕业纪念"}}},
    {"query": "搜索条件相册里的照片", "response": {"intent": "search_photos", "slots": {"description": "条件相册里的照片"}}},
    {"query": "播放《三体》电视剧", "response": {"intent": "video_play_control", "slots": {"title": "三体", "type": "tv"}}},
    {"query": "查看存储剩余容量", "response": {"intent": "get_system_info", "slots": {"system_type": "storage"}}},
    {"query": "搜索宝宝周岁照片", "response": {"intent": "search_photos", "slots": {"description": "宝宝周岁照片"}}},
    {"query": "显示人脸相册内容", "response": {"intent": "get_album_list", "slots": {"album_type": "face"}}},
    {"query": "请提供网络带宽信息", "response": {"intent": "get_system_info", "slots": {"system_type": "network"}}},
    {"query": "设置音乐播放45分钟后停止", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "45分钟"}}},
    {"query": "用顺序模式播放收藏夹", "response": {"intent": "music_play_control", "slots": {"source": "favorites", "play_mode": "normal"}}},
    {"query": "创建相册'宠物日常'", "response": {"intent": "create_album", "slots": {"album_name": "宠物日常"}}},
    {"query": "显示条件相册的详细内容", "response": {"intent": "get_album_list", "slots": {"album_type": "condition"}}},
    {"query": "搜索《指环王》电影", "response": {"intent": "video_search_control", "slots": {"title": "指环王", "type": "movie"}}},
    {"query": "播放《阿甘正传》", "response": {"intent": "video_play_control", "slots": {"title": "阿甘正传", "type": "movie"}}},
    {"query": "查看UGREEN Link绑定状态", "response": {"intent": "get_system_info", "slots": {"system_type": "uglink"}}},
    {"query": "搜索上个月的宝宝照片", "response": {"intent": "search_photos", "slots": {"description": "上个月的宝宝照片"}}},
    {"query": "显示对象相册（猫的照片）", "response": {"intent": "get_album_list", "slots": {"album_type": "object"}}},
    {"query": "请提供系统存储详情", "response": {"intent": "get_system_info", "slots": {"system_type": "storage"}}},
    {"query": "让音乐在30分钟后自动停止", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "30分钟"}}},
    {"query": "播放《平凡之路》", "response": {"intent": "music_play_control", "slots": {"title": "平凡之路"}}},
    {"query": "创建相册'家庭聚会'", "response": {"intent": "create_album", "slots": {"album_name": "家庭聚会"}}},
    {"query": "显示普通相册列表", "response": {"intent": "get_album_list", "slots": {"album_type": "normal"}}},
    {"query": "搜索《西游记》电视剧", "response": {"intent": "video_search_control", "slots": {"title": "西游记", "type": "tv"}}},
    {"query": "播放《流浪地球2》", "response": {"intent": "video_play_control", "slots": {"title": "流浪地球2", "type": "movie"}}},
    {"query": "查看网络连接速度", "response": {"intent": "get_system_info", "slots": {"system_type": "network"}}},
    {"query": "设置音乐播放60分钟后关闭", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "60分钟"}}},
    {"query": "用循环模式播放最近播放", "response": {"intent": "music_play_control", "slots": {"source": "recent", "play_mode": "loop"}}},
    {"query": "创建相册'宝宝满月'", "response": {"intent": "create_album", "slots": {"album_name": "宝宝满月"}}},
    {"query": "搜索去年拍的宠物照片", "response": {"intent": "search_photos", "slots": {"description": "去年拍的宠物照片"}}},
    {"query": "显示人脸相册的详细内容", "response": {"intent": "get_album_list", "slots": {"album_type": "face"}}},
    {"query": "查看设备型号信息", "response": {"intent": "get_system_info", "slots": {"system_type": "device"}}},
    {"query": "设置音乐播放25分钟后自动停止", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "25分钟"}}},
    {"query": "播放《晴天》的纯音乐版", "response": {"intent": "music_play_control", "slots": {"title": "晴天", "version": "纯音乐版"}}},
    {"query": "创建相册'毕业旅行'", "response": {"intent": "create_album", "slots": {"album_name": "毕业旅行"}}},
    {"query": "显示条件相册的列表", "response": {"intent": "get_album_list", "slots": {"album_type": "condition"}}},
    {"query": "搜索《西游记》电视剧全集", "response": {"intent": "video_search_control", "slots": {"title": "西游记", "type": "tv"}}},
    {"query": "播放《泰坦尼克号》电影", "response": {"intent": "video_play_control", "slots": {"title": "泰坦尼克号", "type": "movie"}}},
    {"query": "查看UGREEN Link绑定信息", "response": {"intent": "get_system_info", "slots": {"system_type": "uglink"}}},
    {"query": "搜索宝宝周岁照片", "response": {"intent": "search_photos", "slots": {"description": "宝宝周岁照片"}}},
    {"query": "显示对象相册（猫的日常）", "response": {"intent": "get_album_list", "slots": {"album_type": "object"}}},
    {"query": "请提供网络带宽数据", "response": {"intent": "get_system_info", "slots": {"system_type": "network"}}},
    {"query": "让音乐在40分钟后自动关闭", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "40分钟"}}},
    {"query": "用随机模式播放我的歌单", "response": {"intent": "music_play_control", "slots": {"source": "favorites", "play_mode": "random"}}},
    {"query": "创建相册'节日庆典'", "response": {"intent": "create_album", "slots": {"album_name": "节日庆典"}}},
    {"query": "显示普通相册的名称", "response": {"intent": "get_album_list", "slots": {"album_type": "normal"}}},
    {"query": "搜索《指环王》电影系列", "response": {"intent": "video_search_control", "slots": {"title": "指环王", "type": "collection"}}},
    {"query": "播放《三体》第一季", "response": {"intent": "video_play_control", "slots": {"title": "三体", "type": "tv", "season": "1"}}},
    {"query": "查看系统版本号", "response": {"intent": "get_system_info", "slots": {"system_type": "system"}}},
    {"query": "搜索上月拍的旅行照片", "response": {"intent": "search_photos", "slots": {"description": "上月拍的旅行照片"}}},
    {"query": "显示婴儿相册的内容", "response": {"intent": "get_album_list", "slots": {"album_type": "baby"}}},
    {"query": "请提供设备电池信息", "response": {"intent": "get_system_info", "slots": {"system_type": "device"}}},
    {"query": "设置音乐播放1小时后停止", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "1小时"}}},
    {"query": "播放周杰伦的《七里香》", "response": {"intent": "music_play_control", "slots": {"title": "七里香", "artist": "周杰伦"}}},
    {"query": "创建相册'婚礼纪念'", "response": {"intent": "create_album", "slots": {"album_name": "婚礼纪念"}}},
    {"query": "搜索条件相册中的照片", "response": {"intent": "search_photos", "slots": {"description": "条件相册中的照片"}}},
    {"query": "播放《流浪地球》电影", "response": {"intent": "video_play_control", "slots": {"title": "流浪地球", "type": "movie"}}},
    {"query": "查看存储空间剩余", "response": {"intent": "get_system_info", "slots": {"system_type": "storage"}}},
    {"query": "搜索宝宝百天照片", "response": {"intent": "search_photos", "slots": {"description": "宝宝百天照片"}}},
    {"query": "显示人脸相册的列表", "response": {"intent": "get_album_list", "slots": {"album_type": "face"}}},
    {"query": "请提供网络连接详情", "response": {"intent": "get_system_info", "slots": {"system_type": "network"}}},
    {"query": "设置音乐播放50分钟后停止", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "50分钟"}}},
    {"query": "用顺序模式播放最近播放", "response": {"intent": "music_play_control", "slots": {"source": "recent", "play_mode": "normal"}}},
    {"query": "创建相册'宠物日记'", "response": {"intent": "create_album", "slots": {"album_name": "宠物日记"}}},
    {"query": "显示条件相册的目录", "response": {"intent": "get_album_list", "slots": {"album_type": "condition"}}},
    {"query": "搜索《权力的游戏》电视剧", "response": {"intent": "video_search_control", "slots": {"title": "权力的游戏", "type": "tv"}}},
    {"query": "播放《阿甘正传》电影", "response": {"intent": "video_play_control", "slots": {"title": "阿甘正传", "type": "movie"}}},
    {"query": "查看UGREEN Link账户状态", "response": {"intent": "get_system_info", "slots": {"system_type": "uglink"}}},
    {"query": "搜索去年的宝宝照片", "response": {"intent": "search_photos", "slots": {"description": "去年的宝宝照片"}}},
    {"query": "显示对象相册（狗的照片）", "response": {"intent": "get_album_list", "slots": {"album_type": "object"}}},
    {"query": "请提供系统存储容量", "response": {"intent": "get_system_info", "slots": {"system_type": "storage"}}},
    {"query": "让音乐在35分钟后自动停止", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "35分钟"}}},
    {"query": "播放《平凡之路》", "response": {"intent": "music_play_control", "slots": {"title": "平凡之路"}}},
    {"query": "创建相册'家庭合影'", "response": {"intent": "create_album", "slots": {"album_name": "家庭合影"}}},
    {"query": "显示普通相册的详细信息", "response": {"intent": "get_album_list", "slots": {"album_type": "normal"}}},
    {"query": "搜索《甄嬛传》电视剧", "response": {"intent": "video_search_control", "slots": {"title": "甄嬛传", "type": "tv"}}},
    {"query": "播放《流浪地球2》", "response": {"intent": "video_play_control", "slots": {"title": "流浪地球2", "type": "movie"}}},
    {"query": "查看网络延迟数据", "response": {"intent": "get_system_info", "slots": {"system_type": "network"}}},
    {"query": "设置音乐播放60分钟后关闭", "response": {"intent": "music_settings_control", "slots": {"auto_stop_time": "60分钟"}}},
    {"query": "用循环模式播放收藏夹", "response": {"intent": "music_play_control", "slots": {"source": "favorites", "play_mode": "loop"}}},
    {"input": "创建一个叫'旅行日记'的相册", "output": {"intent": "create_album", "slots": {"album_name": "旅行日记"}}},
    {"input": "新建相册'毕业照'", "output": {"intent": "create_album", "slots": {"album_name": "毕业照"}}},
    {"input": "建个'海滩日落'相册", "output": {"intent": "create_album", "slots": {"album_name": "海滩日落"}}},
    {"input": "创建'宝宝成长'相册", "output": {"intent": "create_album", "slots": {"album_name": "宝宝成长"}}},
    {"input": "新建相册名字叫'2023旅行'", "output": {"intent": "create_album", "slots": {"album_name": "2023旅行"}}},
    {"input": "找找去年拍的海滩照片", "output": {"intent": "search_photos", "slots": {"description": "去年拍的海滩"}}},
    {"input": "搜索关于足球比赛的照片", "output": {"intent": "search_photos", "slots": {"description": "关于足球比赛"}}},
    {"input": "看看上个月在巴黎拍的照片", "output": {"intent": "search_photos", "slots": {"description": "上个月在巴黎"}}},
    {"input": "找找猫的图片", "output": {"intent": "search_photos", "slots": {"description": "猫"}}},
    {"input": "搜索'樱花季'的风景照", "output": {"intent": "search_photos", "slots": {"description": "樱花季"}}},
    {"input": "显示所有普通相册", "output": {"intent": "get_album_list", "slots": {"album_type": "normal"}}},
    {"input": "打开人物相册", "output": {"intent": "get_album_list", "slots": {"album_type": "face"}}},
    {"input": "查看宝宝相册", "output": {"intent": "get_album_list", "slots": {"album_type": "baby"}}},
    {"input": "找找'去年旅行'条件相册", "output": {"intent": "get_album_list", "slots": {"album_type": "condition"}}},
    {"input": "显示猫主题相册", "output": {"intent": "get_album_list", "slots": {"album_type": "object"}}},
    {"input": "播放最近播放的歌", "output": {"intent": "music_play_control", "slots": {"source": "recent"}}},
    {"input": "播放我喜欢的歌单", "output": {"intent": "music_play_control", "slots": {"source": "favorites"}}},
    {"input": "随机播放周杰伦的专辑", "output": {"intent": "music_play_control", "slots": {"title": "周杰伦的专辑", "play_mode": "random"}}},
    {"input": "顺序播放《七里香》", "output": {"intent": "music_play_control", "slots": {"title": "七里香", "play_mode": "normal"}}},
    {"input": "单曲循环《告白气球》", "output": {"intent": "music_play_control", "slots": {"title": "告白气球", "play_mode": "single"}}},
    {"input": "设置自动停止30分钟", "output": {"intent": "music_settings_control", "slots": {"auto_stop_time": "30 minutes"}}},
    {"input": "1小时后自动停止", "output": {"intent": "music_settings_control", "slots": {"auto_stop_time": "1 hour"}}},
    {"input": "自动停止时间设为45分钟", "output": {"intent": "music_settings_control", "slots": {"auto_stop_time": "45 minutes"}}},
    {"input": "开启自动停止20分钟", "output": {"intent": "music_settings_control", "slots": {"auto_stop_time": "20 minutes"}}},
    {"input": "取消自动停止", "output": {"intent": "music_settings_control", "slots": {}}},
    {"input": "搜索《甄嬛传》电视剧", "output": {"intent": "video_search_control", "slots": {"title": "甄嬛传", "type": "tv"}}},
    {"input": "找找最近上映的电影", "output": {"intent": "video_search_control", "slots": {"title": "最近上映", "type": "movie"}}},
    {"input": "看看《复仇者联盟》系列", "output": {"intent": "video_search_control", "slots": {"title": "复仇者联盟", "type": "collection"}}},
    {"input": "搜索《流浪地球》电影", "output": {"intent": "video_search_control", "slots": {"title": "流浪地球", "type": "movie"}}},
    {"input": "找找《动物世界》纪录片", "output": {"intent": "video_search_control", "slots": {"title": "动物世界", "type": "tv"}}},
    {"input": "播放《甄嬛传》电视剧", "output": {"intent": "video_play_control", "slots": {"title": "甄嬛传", "type": "tv"}}},
    {"input": "播放《阿凡达》电影", "output": {"intent": "video_play_control", "slots": {"title": "阿凡达", "type": "movie"}}},
    {"input": "循环播放《指环王》系列", "output": {"intent": "video_play_control", "slots": {"title": "指环王", "type": "collection"}}},
    {"input": "顺序播放《泰坦尼克号》", "output": {"intent": "video_play_control", "slots": {"title": "泰坦尼克号", "type": "movie"}}},
    {"input": "播放《猫和老鼠》动画片", "output": {"intent": "video_play_control", "slots": {"title": "猫和老鼠", "type": "tv"}}},
    {"input": "查系统信息", "output": {"intent": "get_system_info", "slots": {"system_type": "system"}}},
    {"input": "看看设备信息", "output": {"intent": "get_system_info", "slots": {"system_type": "device"}}},
    {"input": "查存储空间", "output": {"intent": "get_system_info", "slots": {"system_type": "storage"}}},
    {"input": "网络设置", "output": {"intent": "get_system_info", "slots": {"system_type": "network"}}},
    {"input": "Ugreen链接信息", "output": {"intent": "get_system_info", "slots": {"system_type": "uglink"}}},
    {"input": "创建'旅行日记'相册", "output": {"intent": "create_album", "slots": {"album_name": "旅行日记"}}},
    {"input": "新建'美食集'相册", "output": {"intent": "create_album", "slots": {"album_name": "美食集"}}},
    {"input": "建个'宠物日常'相册", "output": {"intent": "create_album", "slots": {"album_name": "宠物日常"}}},
    {"input": "创建'毕业照'相册", "output": {"intent": "create_album", "slots": {"album_name": "毕业照"}}},
    {"input": "新建'2024旅行'相册", "output": {"intent": "create_album", "slots": {"album_name": "2024旅行"}}},
    {"input": "建个'家庭聚会'相册", "output": {"intent": "create_album", "slots": {"album_name": "家庭聚会"}}},
    {"input": "创建'音乐节'相册", "output": {"intent": "create_album", "slots": {"album_name": "音乐节"}}},
    {"input": "新建'节日'相册", "output": {"intent": "create_album", "slots": {"album_name": "节日"}}},
    {"input": "建个'雪山风景'相册", "output": {"intent": "create_album", "slots": {"album_name": "雪山风景"}}},
    {"input": "创建'宠物合照'相册", "output": {"intent": "create_album", "slots": {"album_name": "宠物合照"}}},
    {"input": "新建'日常记录'相册", "output": {"intent": "create_album", "slots": {"album_name": "日常记录"}}},
    {"input": "建个'樱花季'相册", "output": {"intent": "create_album", "slots": {"album_name": "樱花季"}}},
    {"input": "找找去年拍的雪山照片", "output": {"intent": "search_photos", "slots": {"description": "去年拍的雪山"}}},
    {"input": "搜索'海滩度假'照片", "output": {"intent": "search_photos", "slots": {"description": "海滩度假"}}},
    {"input": "看看上个月在巴黎的街景照片", "output": {"intent": "search_photos", "slots": {"description": "上个月在巴黎的街景"}}},
    {"input": "找找猫的可爱照片", "output": {"intent": "search_photos", "slots": {"description": "猫的可爱"}}},
    {"input": "搜索'雨天城市'风景照", "output": {"intent": "search_photos", "slots": {"description": "雨天城市"}}},
    {"input": "找找'宝宝'的照片", "output": {"intent": "search_photos", "slots": {"description": "宝宝"}}},
    {"input": "看看'节日'的风景照", "output": {"intent": "search_photos", "slots": {"description": "节日"}}},
    {"input": "搜索'音乐节'照片", "output": {"intent": "search_photos", "slots": {"description": "音乐节"}}},
    {"input": "找找'宠物'的图片", "output": {"intent": "search_photos", "slots": {"description": "宠物"}}},
    {"input": "搜索'旅行'的照片", "output": {"intent": "search_photos", "slots": {"description": "旅行"}}},
    {"input": "找找'雪山'的照片", "output": {"intent": "search_photos", "slots": {"description": "雪山"}}},
    {"input": "查看所有相册", "output": {"intent": "get_album_list", "slots": {}}},
    {"input": "显示face相册", "output": {"intent": "get_album_list", "slots": {"album_type": "face"}}},
    {"input": "打开baby相册", "output": {"intent": "get_album_list", "slots": {"album_type": "baby"}}},
    {"input": "查看condition相册", "output": {"intent": "get_album_list", "slots": {"album_type": "condition"}}},
    {"input": "显示object相册", "output": {"intent": "get_album_list", "slots": {"album_type": "object"}}},
    {"input": "查看普通相册", "output": {"intent": "get_album_list", "slots": {"album_type": "normal"}}},
    {"input": "打开人物相册", "output": {"intent": "get_album_list", "slots": {"album_type": "face"}}},
    {"input": "查看宝宝相册", "output": {"intent": "get_album_list", "slots": {"album_type": "baby"}}},
    {"input": "显示条件相册", "output": {"intent": "get_album_list", "slots": {"album_type": "condition"}}},
    {"input": "显示对象相册", "output": {"intent": "get_album_list", "slots": {"album_type": "object"}}},
    {"input": "查看face相册列表", "output": {"intent": "get_album_list", "slots": {"album_type": "face"}}},
    {"input": "打开condition相册列表", "output": {"intent": "get_album_list", "slots": {"album_type": "condition"}}},
    {"input": "播放最近播放的歌", "output": {"intent": "music_play_control", "slots": {"source": "recent"}}},
    {"input": "播放favorites歌单", "output": {"intent": "music_play_control", "slots": {"source": "favorites"}}},
    {"input": "随机播放《晴天》", "output": {"intent": "music_play_control", "slots": {"title": "晴天", "play_mode": "random"}}},
    {"input": "顺序播放《七里香》", "output": {"intent": "music_play_control", "slots": {"title": "七里香", "play_mode": "normal"}}},
    {"input": "单曲循环《告白气球》", "output": {"intent": "music_play_control", "slots": {"title": "告白气球", "play_mode": "single"}}},
    {"input": "播放周杰伦《七里香》", "output": {"intent": "music_play_control", "slots": {"title": "周杰伦《七里香》", "play_mode": "normal"}}},
    {"input": "随机播放《青花瓷》", "output": {"intent": "music_play_control", "slots": {"title": "青花瓷", "play_mode": "random"}}},
    {"input": "顺序播放《稻香》", "output": {"intent": "music_play_control", "slots": {"title": "稻香", "play_mode": "normal"}}},
    {"input": "单曲循环《晴天》", "output": {"intent": "music_play_control", "slots": {"title": "晴天", "play_mode": "single"}}},
    {"input": "播放最近歌单", "output": {"intent": "music_play_control", "slots": {"source": "recent"}}},
    {"input": "播放周杰伦专辑", "output": {"intent": "music_play_control", "slots": {"title": "周杰伦专辑", "play_mode": "normal"}}},
    {"input": "播放《告白气球》", "output": {"intent": "music_play_control", "slots": {"title": "告白气球", "play_mode": "normal"}}},
    {"input": "设置自动停止30分钟", "output": {"intent": "music_settings_control", "slots": {"auto_stop_time": "30 minutes"}}},
    {"input": "1小时后自动停止", "output": {"intent": "music_settings_control", "slots": {"auto_stop_time": "1 hour"}}},
    {"input": "自动停止时间设为45分钟", "output": {"intent": "music_settings_control", "slots": {"auto_stop_time": "45 minutes"}}},
    {"input": "开启自动停止20分钟", "output": {"intent": "music_settings_control", "slots": {"auto_stop_time": "20 minutes"}}},
    {"input": "取消自动停止", "output": {"intent": "music_settings_control", "slots": {}}},
    {"input": "设置自动停止15分钟", "output": {"intent": "music_settings_control", "slots": {"auto_stop_time": "15 minutes"}}},
    {"input": "自动停止45分钟", "output": {"intent": "music_settings_control", "slots": {"auto_stop_time": "45 minutes"}}},
    {"input": "取消音乐自动停止", "output": {"intent": "music_settings_control", "slots": {}}},
    {"input": "设置自动停止1小时", "output": {"intent": "music_settings_control", "slots": {"auto_stop_time": "1 hour"}}},
    {"input": "自动停止30分钟", "output": {"intent": "music_settings_control", "slots": {"auto_stop_time": "30 minutes"}}},
    {"input": "设置自动停止20分钟", "output": {"intent": "music_settings_control", "slots": {"auto_stop_time": "20 minutes"}}},
    {"input": "取消自动停止功能", "output": {"intent": "music_settings_control", "slots": {}}},
    {"input": "搜索《甄嬛传》电视剧", "output": {"intent": "video_search_control", "slots": {"title": "甄嬛传", "type": "tv"}}},
    {"input": "找找《流浪地球》电影", "output": {"intent": "video_search_control", "slots": {"title": "流浪地球", "type": "movie"}}},
    {"input": "看看《动物世界》纪录片", "output": {"intent": "video_search_control", "slots": {"title": "动物世界", "type": "tv"}}},
    {"input": "搜索《复仇者联盟》系列", "output": {"intent": "video_search_control", "slots": {"title": "复仇者联盟", "type": "collection"}}},
    {"input": "找找《西游记》电视剧", "output": {"intent": "video_search_control", "slots": {"title": "西游记", "type": "tv"}}},
    {"input": "搜索《哪吒》电影", "output": {"intent": "video_search_control", "slots": {"title": "哪吒", "type": "movie"}}},
    {"input": "看看《哈利波特》系列", "output": {"intent": "video_search_control", "slots": {"title": "哈利波特", "type": "collection"}}},
    {"input": "找找《阿凡达》电影", "output": {"intent": "video_search_control", "slots": {"title": "阿凡达", "type": "movie"}}},
    {"input": "搜索《泰坦尼克号》", "output": {"intent": "video_search_control", "slots": {"title": "泰坦尼克号", "type": "movie"}}},
    {"input": "找找《猫和老鼠》动画", "output": {"intent": "video_search_control", "slots": {"title": "猫和老鼠", "type": "tv"}}},
    {"input": "搜索《大话西游》电影", "output": {"intent": "video_search_control", "slots": {"title": "大话西游", "type": "movie"}}},
    {"input": "找找《舌尖上的中国》", "output": {"intent": "video_search_control", "slots": {"title": "舌尖上的中国", "type": "tv"}}},
    {"input": "播放《甄嬛传》电视剧", "output": {"intent": "video_play_control", "slots": {"title": "甄嬛传", "type": "tv"}}},
    {"input": "播放《流浪地球》电影", "output": {"intent": "video_play_control", "slots": {"title": "流浪地球", "type": "movie"}}},
    {"input": "循环播放《动物世界》", "output": {"intent": "video_play_control", "slots": {"title": "动物世界", "type": "tv"}}},
    {"input": "播放《复仇者联盟》系列", "output": {"intent": "video_play_control", "slots": {"title": "复仇者联盟", "type": "collection"}}},
    {"input": "播放《西游记》", "output": {"intent": "video_play_control", "slots": {"title": "西游记", "type": "tv"}}},
    {"input": "播放《哪吒》电影", "output": {"intent": "video_play_control", "slots": {"title": "哪吒", "type": "movie"}}},
    {"input": "循环播放《哈利波特》", "output": {"intent": "video_play_control", "slots": {"title": "哈利波特", "type": "collection"}}},
    {"input": "播放《阿凡达》", "output": {"intent": "video_play_control", "slots": {"title": "阿凡达", "type": "movie"}}},
    {"input": "顺序播放《泰坦尼克号》", "output": {"intent": "video_play_control", "slots": {"title": "泰坦尼克号", "type": "movie"}}},
    {"input": "播放《猫和老鼠》", "output": {"intent": "video_play_control", "slots": {"title": "猫和老鼠", "type": "tv"}}},
    {"input": "播放《大话西游》", "output": {"intent": "video_play_control", "slots": {"title": "大话西游", "type": "movie"}}},
    {"input": "播放《舌尖上的中国》", "output": {"intent": "video_play_control", "slots": {"title": "舌尖上的中国", "type": "tv"}}},
    {"input": "查系统信息", "output": {"intent": "get_system_info", "slots": {"system_type": "system"}}},
    {"input": "查看设备信息", "output": {"intent": "get_system_info", "slots": {"system_type": "device"}}},
    {"input": "查存储空间", "output": {"intent": "get_system_info", "slots": {"system_type": "storage"}}},
    {"input": "查看网络状态", "output": {"intent": "get_system_info", "slots": {"system_type": "network"}}},
    {"input": "获取UGreen链接信息", "output": {"intent": "get_system_info", "slots": {"system_type": "uglink"}}},
    {"input": "查系统版本", "output": {"intent": "get_system_info", "slots": {"system_type": "system"}}},
    {"input": "查看手机型号", "output": {"intent": "get_system_info", "slots": {"system_type": "device"}}},
    {"input": "检查存储占用", "output": {"intent": "get_system_info", "slots": {"system_type": "storage"}}},
    {"input": "查看Wi-Fi设置", "output": {"intent": "get_system_info", "slots": {"system_type": "network"}}},
    {"input": "查询UGlink状态", "output": {"intent": "get_system_info", "slots": {"system_type": "uglink"}}}]

# %%
# 转换为DataFrame格式
df_qwen_data = []
for item in qwen_data:
    # 处理不同的输入字段名
    input_text = item.get('query') or item.get('input')
    output_data = item.get('response') or item.get('output')
    
    df_qwen_data.append({
        'input': input_text,
        'output': str(output_data),
        'output_intent': output_data['intent'],
        'output_slots': str(output_data['slots'])
    })

# 创建qwen数据的DataFrame
qwen_df = pd.DataFrame(df_qwen_data)

# 合并所有数据
final_combined_df = pd.concat([combined_df, qwen_df], ignore_index=True)

print(f"原合并数据集形状: {combined_df.shape}")
print(f"qwen数据集形状: {qwen_df.shape}")
print(f"最终合并数据集形状: {final_combined_df.shape}")
print(f"最终合并后列名: {final_combined_df.columns.tolist()}")

final_combined_df.head()
# Out:
# 原合并数据集形状: (300, 4)
# qwen数据集形状: (287, 4)
# 最终合并数据集形状: (587, 4)
# 最终合并后列名: ['input', 'output', 'output_intent', 'output_slots']
#             input                                             output  \
# 0         创建一个新相册            {'intent': 'create_album', 'slots': {}}
# 1     新建一个名为旅行的相册  {'intent': 'create_album', 'slots': {'album_na...
# 2      创建一个宝宝成长相册  {'intent': 'create_album', 'slots': {'album_na...
# 3    建立人物相册，名字叫家人  {'intent': 'create_album', 'slots': {'album_na...
# 4  创建一个普通相册，命名为风景  {'intent': 'create_album', 'slots': {'album_na...
#
#   output_intent                                  output_slots
# 0  create_album                                            {}
# 1  create_album                          {'album_name': '旅行'}
# 2  create_album  {'album_name': '宝宝成长', 'album_type': 'baby'}
# 3  create_album    {'album_name': '家人', 'album_type': 'face'}
# 4  create_album  {'album_name': '风景', 'album_type': 'normal'}

# %%
final_combined_df
# Out:
#               input                                             output  \
# 0           创建一个新相册            {'intent': 'create_album', 'slots': {}}
# 1       新建一个名为旅行的相册  {'intent': 'create_album', 'slots': {'album_na...
# 2        创建一个宝宝成长相册  {'intent': 'create_album', 'slots': {'album_na...
# 3      建立人物相册，名字叫家人  {'intent': 'create_album', 'slots': {'album_na...
# 4    创建一个普通相册，命名为风景  {'intent': 'create_album', 'slots': {'album_na...
# ..              ...                                                ...
# 582           查系统版本  {'intent': 'get_system_info', 'slots': {'syste...
# 583          查看手机型号  {'intent': 'get_system_info', 'slots': {'syste...
# 584          检查存储占用  {'intent': 'get_system_info', 'slots': {'syste...
# 585       查看Wi-Fi设置  {'intent': 'get_system_info', 'slots': {'syste...
# 586      查询UGlink状态  {'intent': 'get_system_info', 'slots': {'syste...
#
#        output_intent                                  output_slots
# 0       create_album                                            {}
# 1       create_album                          {'album_name': '旅行'}
# 2       create_album  {'album_name': '宝宝成长', 'album_type': 'baby'}
# 3       create_album    {'album_name': '家人', 'album_type': 'face'}
# 4       create_album  {'album_name': '风景', 'album_type': 'normal'}
# ..               ...                                           ...
# 582  get_system_info                     {'system_type': 'system'}
# 583  get_system_info                     {'system_type': 'device'}
# 584  get_system_info                    {'system_type': 'storage'}
# 585  get_system_info                    {'system_type': 'network'}
# 586  get_system_info                     {'system_type': 'uglink'}
#
# [587 rows x 4 columns]

# %%
qwen_data_2 = [
  {"input": "建个'毕业旅行'相册", "intent": "create_album", "slots": {"album_name": "毕业旅行"}},
  {"input": "新建'宠物日常'相册", "intent": "create_album", "slots": {"album_name": "宠物日常"}},
  {"input": "创建'2023年旅行'相册", "intent": "create_album", "slots": {"album_name": "2023年旅行"}},
  {"input": "给照片建个'樱花季'相册", "intent": "create_album", "slots": {"album_name": "樱花季"}},
  {"input": "创建'家庭合影'相册", "intent": "create_album", "slots": {"album_name": "家庭合影"}},
  {"input": "找找去年在巴黎拍的照片", "intent": "search_photos", "slots": {"description": "去年在巴黎拍的照片"}},
  {"input": "显示带狗的海滩照", "intent": "search_photos", "slots": {"description": "带狗的海滩照"}},
  {"input": "搜索2023年圣诞的全家福", "intent": "search_photos", "slots": {"description": "2023年圣诞的全家福"}},
  {"input": "找找关于雪山的照片", "intent": "search_photos", "slots": {"description": "关于雪山的照片"}},
  {"input": "查看'猫猫'的照片", "intent": "search_photos", "slots": {"description": "猫猫"}},
  {"input": "打开人物相册", "intent": "get_album_list", "slots": {"album_type": "face"}},
  {"input": "显示宝宝相册", "intent": "get_album_list", "slots": {"album_type": "baby"}},
  {"input": "查看条件相册：2023年夏天的", "intent": "get_album_list", "slots": {"album_type": "condition"}},
  {"input": "我的猫照片相册", "intent": "get_album_list", "slots": {"album_type": "object"}},
  {"input": "显示普通相册列表", "intent": "get_album_list", "slots": {"album_type": "normal"}},
  {"input": "播放《告白气球》", "intent": "music_play_control", "slots": {"title": "告白气球"}},
  {"input": "随机播放最近的", "intent": "music_play_control", "slots": {"source": "recent", "play_mode": "random"}},
  {"input": "单曲循环《稻香》", "intent": "music_play_control", "slots": {"title": "稻香", "play_mode": "single"}},
  {"input": "播放我的最爱", "intent": "music_play_control", "slots": {"source": "favorites"}},
  {"input": "用顺序播放模式", "intent": "music_play_control", "slots": {"play_mode": "normal"}},
  {"input": "设置自动停止45分钟", "intent": "music_settings_control", "slots": {"auto_stop_time": "45分钟"}},
  {"input": "音乐自动停止改为半小时", "intent": "music_settings_control", "slots": {"auto_stop_time": "半小时"}},
  {"input": "取消自动停止功能", "intent": "music_settings_control", "slots": {}},
  {"input": "搜索《黑豹》电影", "intent": "video_search_control", "slots": {"title": "黑豹", "type": "movie"}},
  {"input": "找部新剧", "intent": "video_search_control", "slots": {"type": "tv"}},
  {"input": "推荐《甄嬛传》", "intent": "video_search_control", "slots": {"title": "甄嬛传", "type": "tv"}},
  {"input": "看《复仇者联盟》", "intent": "video_search_control", "slots": {"title": "复仇者联盟", "type": "collection"}},
  {"input": "找部爱情片", "intent": "video_search_control", "slots": {"type": "movie"}},
  {"input": "播放《泰坦尼克号》", "intent": "video_play_control", "slots": {"title": "泰坦尼克号"}},
  {"input": "看《权力的游戏》", "intent": "video_play_control", "slots": {"title": "权力的游戏", "type": "tv"}},
  {"input": "播放《阿凡达2》", "intent": "video_play_control", "slots": {"title": "阿凡达2", "type": "movie"}},
  {"input": "播放《指环王3》", "intent": "video_play_control", "slots": {"title": "指环王3", "type": "collection"}},
  {"input": "查系统版本", "intent": "get_system_info", "slots": {"system_type": "system"}},
  {"input": "显示手机型号", "intent": "get_system_info", "slots": {"system_type": "device"}},
  {"input": "看存储空间占用", "intent": "get_system_info", "slots": {"system_type": "storage"}},
  {"input": "检查Wi-Fi状态", "intent": "get_system_info", "slots": {"system_type": "network"}},
  {"input": "问UGREEN Link怎么连接", "intent": "get_system_info", "slots": {"system_type": "uglink"}},
  {"input": "播放音乐", "intent": "music_play_control", "slots": {}},
  {"input": "查相册", "intent": "get_album_list", "slots": {}},
  {"input": "搜视频", "intent": "video_search_control", "slots": {}},
  {"input": "调音乐设置", "intent": "music_settings_control", "slots": {}},
  {"input": "手机能拍照吗", "intent": "unknown", "slots": {}},
  {"input": "相册里有啥", "intent": "unknown", "slots": {}},
  {"input": "播放《孤勇者》", "intent": "music_play_control", "slots": {"title": "孤勇者"}},
  {"input": "循环播放最近的", "intent": "music_play_control", "slots": {"source": "recent", "play_mode": "loop"}},
  {"input": "找张去年拍的", "intent": "search_photos", "slots": {"description": "去年拍的"}},
  {"input": "显示face相册", "intent": "get_album_list", "slots": {"album_type": "face"}},
  {"input": "创建'猫咪日记'相册", "intent": "create_album", "slots": {"album_name": "猫咪日记"}},
  {"input": "播放最近的歌", "intent": "music_play_control", "slots": {"source": "recent"}},
  {"input": "设置自动停止90分钟", "intent": "music_settings_control", "slots": {"auto_stop_time": "90分钟"}},
  {"input": "搜索《庆余年2》", "intent": "video_search_control", "slots": {"title": "庆余年2", "type": "tv"}},
  {"input": "看《阿凡达》", "intent": "video_play_control", "slots": {"title": "阿凡达", "type": "movie"}},
  {"input": "查网络", "intent": "get_system_info", "slots": {"system_type": "network"}},
  {"input": "创建'毕业季'相册", "intent": "create_album", "slots": {"album_name": "毕业季"}},
  {"input": "随机播放我的歌单", "intent": "music_play_control", "slots": {"source": "favorites", "play_mode": "random"}},
  {"input": "找雪景照片", "intent": "search_photos", "slots": {"description": "雪景照片"}},
  {"input": "显示baby相册", "intent": "get_album_list", "slots": {"album_type": "baby"}},
  {"input": "播放《起风了》", "intent": "music_play_control", "slots": {"title": "起风了"}},
  {"input": "自动停止15分钟", "intent": "music_settings_control", "slots": {"auto_stop_time": "15分钟"}},
  {"input": "找《哈利波特》系列", "intent": "video_search_control", "slots": {"title": "哈利波特", "type": "collection"}},
  {"input": "播放《甄嬛传》", "intent": "video_play_control", "slots": {"title": "甄嬛传", "type": "tv"}},
  {"input": "查设备信息", "intent": "get_system_info", "slots": {"system_type": "device"}},
  {"input": "创建'旅行日记'相册", "intent": "create_album", "slots": {"album_name": "旅行日记"}},
  {"input": "单曲循环《晴天》", "intent": "music_play_control", "slots": {"title": "晴天", "play_mode": "single"}},
  {"input": "搜索'雪景'的照片", "intent": "search_photos", "slots": {"description": "雪景"}},
  {"input": "条件相册：2023年夏天的", "intent": "get_album_list", "slots": {"album_type": "condition"}},
  {"input": "播放最近的", "intent": "music_play_control", "slots": {"source": "recent"}},
  {"input": "设置自动停止", "intent": "music_settings_control", "slots": {}},
  {"input": "搜索《星际穿越》", "intent": "video_search_control", "slots": {"title": "星际穿越", "type": "movie"}},
  {"input": "播放《指环王》", "intent": "video_play_control", "slots": {"title": "指环王", "type": "collection"}},
  {"input": "查存储", "intent": "get_system_info", "slots": {"system_type": "storage"}},
  {"input": "新建'亲子时光'相册", "intent": "create_album", "slots": {"album_name": "亲子时光"}},
  {"input": "播放收藏的歌", "intent": "music_play_control", "slots": {"source": "favorites"}},
  {"input": "找'樱花'的照片", "intent": "search_photos", "slots": {"description": "樱花"}},
  {"input": "人物相册", "intent": "get_album_list", "slots": {"album_type": "face"}},
  {"input": "创建'旅行回忆'相册", "intent": "create_album", "slots": {"album_name": "旅行回忆"}},
  {"input": "随机播放", "intent": "music_play_control", "slots": {"play_mode": "random"}},
  {"input": "播放《小幸运》", "intent": "music_play_control", "slots": {"title": "小幸运"}},
  {"input": "设置自动停止1小时", "intent": "music_settings_control", "slots": {"auto_stop_time": "1小时"}},
  {"input": "找《三体》电视剧", "intent": "video_search_control", "slots": {"title": "三体", "type": "tv"}},
  {"input": "播放《指环王1》", "intent": "video_play_control", "slots": {"title": "指环王1", "type": "collection"}}
]

# %%
# 转换为DataFrame格式
df_qwen_data_2 = []
for item in qwen_data_2:
    df_qwen_data_2.append({
        'input': item['input'],
        'output': str({"intent": item['intent'], "slots": item['slots']}),
        'output_intent': item['intent'],
        'output_slots': str(item['slots'])
    })

# 创建qwen_data_2的DataFrame
qwen_df_2 = pd.DataFrame(df_qwen_data_2)

# 合并所有数据
final_combined_df_2 = pd.concat([final_combined_df, qwen_df_2], ignore_index=True)

print(f"原最终合并数据集形状: {final_combined_df.shape}")
print(f"qwen_data_2数据集形状: {qwen_df_2.shape}")
print(f"新最终合并数据集形状: {final_combined_df_2.shape}")
print(f"新最终合并后列名: {final_combined_df_2.columns.tolist()}")

final_combined_df_2.head()
# Out:
# 原最终合并数据集形状: (587, 4)
# qwen_data_2数据集形状: (81, 4)
# 新最终合并数据集形状: (668, 4)
# 新最终合并后列名: ['input', 'output', 'output_intent', 'output_slots']
#             input                                             output  \
# 0         创建一个新相册            {'intent': 'create_album', 'slots': {}}
# 1     新建一个名为旅行的相册  {'intent': 'create_album', 'slots': {'album_na...
# 2      创建一个宝宝成长相册  {'intent': 'create_album', 'slots': {'album_na...
# 3    建立人物相册，名字叫家人  {'intent': 'create_album', 'slots': {'album_na...
# 4  创建一个普通相册，命名为风景  {'intent': 'create_album', 'slots': {'album_na...
#
#   output_intent                                  output_slots
# 0  create_album                                            {}
# 1  create_album                          {'album_name': '旅行'}
# 2  create_album  {'album_name': '宝宝成长', 'album_type': 'baby'}
# 3  create_album    {'album_name': '家人', 'album_type': 'face'}
# 4  create_album  {'album_name': '风景', 'album_type': 'normal'}

# %%
final_combined_df_2.to_excel('/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/new_deepseek_qwen3_create_datas/zh_data.xlsx')

# %%
final_combined_df_2
# Out:
#               input                                             output  \
# 0           创建一个新相册            {'intent': 'create_album', 'slots': {}}
# 1       新建一个名为旅行的相册  {'intent': 'create_album', 'slots': {'album_na...
# 2        创建一个宝宝成长相册  {'intent': 'create_album', 'slots': {'album_na...
# 3      建立人物相册，名字叫家人  {'intent': 'create_album', 'slots': {'album_na...
# 4    创建一个普通相册，命名为风景  {'intent': 'create_album', 'slots': {'album_na...
# ..              ...                                                ...
# 663            随机播放  {'intent': 'music_play_control', 'slots': {'pl...
# 664         播放《小幸运》  {'intent': 'music_play_control', 'slots': {'ti...
# 665       设置自动停止1小时  {'intent': 'music_settings_control', 'slots': ...
# 666        找《三体》电视剧  {'intent': 'video_search_control', 'slots': {'...
# 667        播放《指环王1》  {'intent': 'video_play_control', 'slots': {'ti...
#
#               output_intent                                  output_slots
# 0              create_album                                            {}
# 1              create_album                          {'album_name': '旅行'}
# 2              create_album  {'album_name': '宝宝成长', 'album_type': 'baby'}
# 3              create_album    {'album_name': '家人', 'album_type': 'face'}
# 4              create_album  {'album_name': '风景', 'album_type': 'normal'}
# ..                      ...                                           ...
# 663      music_play_control                       {'play_mode': 'random'}
# 664      music_play_control                              {'title': '小幸运'}
# 665  music_settings_control                     {'auto_stop_time': '1小时'}
# 666    video_search_control                 {'title': '三体', 'type': 'tv'}
# 667      video_play_control       {'title': '指环王1', 'type': 'collection'}
#
# [668 rows x 4 columns]

# %%
# 处理data4数据，生成DataFrame
all_data = []

# 处理create_album数据
create_album_data = [
  {
    "input": "新建一个名为校园生活的相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "校园生活"
      }
    }
  },
  {
    "input": "创建一个自动分类相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_type": "condition"
      }
    }
  },
  {
    "input": "建立花卉摄影相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "花卉摄影",
        "album_type": "object"
      }
    }
  },
  {
    "input": "创建一个普通类型的家庭影集",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "家庭影集",
        "album_type": "normal"
      }
    }
  },
  {
    "input": "新建人脸识别相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_type": "face"
      }
    }
  },
  {
    "input": "创建宝宝成长日记相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "宝宝成长日记",
        "album_type": "baby"
      }
    }
  },
  {
    "input": "建立一个城市风光集",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "城市风光集"
      }
    }
  },
  {
    "input": "创建亲友照片相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "亲友照片",
        "album_type": "face"
      }
    }
  },
  {
    "input": "新建一个空白相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_type": "normal"
      }
    }
  },
  {
    "input": "创建婴儿成长记录相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "婴儿成长记录",
        "album_type": "baby"
      }
    }
  },
  {
    "input": "建立美食摄影相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "美食摄影",
        "album_type": "object"
      }
    }
  },
  {
    "input": "创建一个地点筛选相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_type": "condition"
      }
    }
  },
  {
    "input": "新建节日纪念相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "节日纪念"
      }
    }
  },
  {
    "input": "创建同学合影相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "同学合影",
        "album_type": "face"
      }
    }
  },
  {
    "input": "建立通用相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_type": "normal"
      }
    }
  },
  {
    "input": "创建儿童照片相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "儿童照片",
        "album_type": "baby"
      }
    }
  },
  {
    "input": "新建建筑识别相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "建筑",
        "album_type": "object"
      }
    }
  },
  {
    "input": "创建时间范围相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_type": "condition"
      }
    }
  },
  {
    "input": "建立个人摄影作品相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "个人摄影作品"
      }
    }
  },
  {
    "input": "创建家人照片相册",
    "output": {
      "intent": "create_album",
      "slots": {
        "album_name": "家人照片",
        "album_type": "face"
      }
    }
  }
]

# 处理search_photos数据
search_photos_data = [
  {
    "input": "搜索秋天风景照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "秋天风景照片"
      }
    }
  },
  {
    "input": "查找庆典活动照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "庆典活动照片"
      }
    }
  },
  {
    "input": "搜索清晨拍摄的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "清晨拍摄的照片"
      }
    }
  },
  {
    "input": "找一下商务场合的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "商务场合的照片"
      }
    }
  },
  {
    "input": "搜索山区风景照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "山区风景照片"
      }
    }
  },
  {
    "input": "查找传统节日照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "传统节日照片"
      }
    }
  },
  {
    "input": "搜索阴天拍摄的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "阴天拍摄的照片"
      }
    }
  },
  {
    "input": "找一下工作环境照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "工作环境照片"
      }
    }
  },
  {
    "input": "搜索河流风景",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "河流风景"
      }
    }
  },
  {
    "input": "查找开幕式照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "开幕式照片"
      }
    }
  },
  {
    "input": "搜索露营时的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "露营时的照片"
      }
    }
  },
  {
    "input": "找一下婴儿照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "婴儿照片"
      }
    }
  },
  {
    "input": "搜索展览活动照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "展览活动照片"
      }
    }
  },
  {
    "input": "查找海边照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "海边照片"
      }
    }
  },
  {
    "input": "搜索烘焙过程照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "烘焙过程照片"
      }
    }
  },
  {
    "input": "找一下同事聚会照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "同事聚会照片"
      }
    }
  },
  {
    "input": "搜索雪景照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "雪景照片"
      }
    }
  },
  {
    "input": "查找生日礼物照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "生日礼物照片"
      }
    }
  },
  {
    "input": "搜索正午时分的照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "正午时分的照片"
      }
    }
  },
  {
    "input": "找一下节日装饰照片",
    "output": {
      "intent": "search_photos",
      "slots": {
        "description": "节日装饰照片"
      }
    }
  }
]

# 处理get_album_list数据
get_album_list_data = [
  {
    "input": "所有相册",
    "output": {
      "intent": "get_album_list",
      "slots": {}
    }
  },
  {
    "input": "显示肖像相册列表",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "face"
      }
    }
  },
  {
    "input": "查看宝贝相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "baby"
      }
    }
  },
  {
    "input": "获取条件相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "condition"
      }
    }
  },
  {
    "input": "显示对象相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "object"
      }
    }
  },
  {
    "input": "查看普通相册列表",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "normal"
      }
    }
  },
  {
    "input": "获取人脸相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "face"
      }
    }
  },
  {
    "input": "显示婴儿相册列表",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "baby"
      }
    }
  },
  {
    "input": "查看筛选相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "condition"
      }
    }
  },
  {
    "input": "获取物品识别相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "object"
      }
    }
  },
  {
    "input": "显示常规相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "normal"
      }
    }
  },
  {
    "input": "查看面部相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "face"
      }
    }
  },
  {
    "input": "获取儿童相册列表",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "baby"
      }
    }
  },
  {
    "input": "显示智能相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "condition"
      }
    }
  },
  {
    "input": "查看主题识别相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "object"
      }
    }
  },
  {
    "input": "获取标准相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "normal"
      }
    }
  },
  {
    "input": "显示人像相册列表",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "face"
      }
    }
  },
  {
    "input": "查看新生儿相册列表",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "baby"
      }
    }
  },
  {
    "input": "获取动态相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "condition"
      }
    }
  },
  {
    "input": "显示分类识别相册",
    "output": {
      "intent": "get_album_list",
      "slots": {
        "album_type": "object"
      }
    }
  }
]

# 处理music_play_control数据
music_play_control_data = [
  {
    "input": "播放环境音乐",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "环境音乐"
      }
    }
  },
  {
    "input": "播放最近听的列表",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "source": "recent"
      }
    }
  },
  {
    "input": "随机播放收藏歌曲",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "source": "favorites",
        "play_mode": "random"
      }
    }
  },
  {
    "input": "顺序播放民谣歌曲",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "民谣歌曲",
        "play_mode": "normal"
      }
    }
  },
  {
    "input": "单曲循环朋友",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "朋友",
        "play_mode": "single"
      }
    }
  },
  {
    "input": "循环播放新世纪",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "新世纪",
        "play_mode": "loop"
      }
    }
  },
  {
    "input": "播放张国荣的风继续吹",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "张国荣的风继续吹"
      }
    }
  },
  {
    "input": "随机播放说唱音乐",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "说唱音乐",
        "play_mode": "random"
      }
    }
  },
  {
    "input": "播放我的最爱音乐",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "source": "favorites"
      }
    }
  },
  {
    "input": "顺序播放法语歌曲",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "法语歌曲",
        "play_mode": "normal"
      }
    }
  },
  {
    "input": "单曲循环后来",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "后来",
        "play_mode": "single"
      }
    }
  },
  {
    "input": "循环播放朋克摇滚",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "朋克摇滚",
        "play_mode": "loop"
      }
    }
  },
  {
    "input": "播放Beyond的歌曲",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "Beyond的歌曲"
      }
    }
  },
  {
    "input": "随机播放独立音乐",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "独立音乐",
        "play_mode": "random"
      }
    }
  },
  {
    "input": "播放最近播放记录",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "source": "recent"
      }
    }
  },
  {
    "input": "顺序播放学习音乐",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "学习音乐",
        "play_mode": "normal"
      }
    }
  },
  {
    "input": "单曲循环勇气",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "勇气",
        "play_mode": "single"
      }
    }
  },
  {
    "input": "循环播放实验音乐",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "实验音乐",
        "play_mode": "loop"
      }
    }
  },
  {
    "input": "播放王杰的专辑",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "王杰的专辑"
      }
    }
  },
  {
    "input": "随机播放世界音乐",
    "output": {
      "intent": "music_play_control",
      "slots": {
        "title": "世界音乐",
        "play_mode": "random"
      }
    }
  }
]

# 处理music_settings_control数据
music_settings_control_data = [
  {
    "input": "设置8分钟后自动停止",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "8分钟"
      }
    }
  },
  {
    "input": "40分钟后停止播放音乐",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "40分钟"
      }
    }
  },
  {
    "input": "设置28分钟自动关闭",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "28分钟"
      }
    }
  },
  {
    "input": "一小时二十分后自动停止",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "1小时20分"
      }
    }
  },
  {
    "input": "设置38分钟自动关机",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "38分钟"
      }
    }
  },
  {
    "input": "55分钟后自动停止音乐",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "55分钟"
      }
    }
  },
  {
    "input": "设置1.5小时自动关闭播放器",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "1.5小时"
      }
    }
  },
  {
    "input": "二十五分钟后停止",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "25分钟"
      }
    }
  },
  {
    "input": "设置2.5小时自动停止",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "2.5小时"
      }
    }
  },
  {
    "input": "十二分钟后关闭音乐",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "12分钟"
      }
    }
  },
  {
    "input": "设置4小时自动停止",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "4小时"
      }
    }
  },
  {
    "input": "一小时后自动关机",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "1小时"
      }
    }
  },
  {
    "input": "设置18分钟自动停止播放",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "18分钟"
      }
    }
  },
  {
    "input": "48分钟后停止",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "48分钟"
      }
    }
  },
  {
    "input": "设置32分钟后自动关闭",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "32分钟"
      }
    }
  },
  {
    "input": "两小时十五分自动停止",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "2小时15分"
      }
    }
  },
  {
    "input": "设置22分钟自动关机",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "22分钟"
      }
    }
  },
  {
    "input": "一小时后停止播放",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "1小时"
      }
    }
  },
  {
    "input": "设置42分钟自动停止",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "42分钟"
      }
    }
  },
  {
    "input": "35分钟后关闭播放器",
    "output": {
      "intent": "music_settings_control",
      "slots": {
        "auto_stop_time": "35分钟"
      }
    }
  }
]

# 处理video_search_control数据
video_search_control_data = [
  {
    "input": "搜索历史电影",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "历史电影",
        "type": "movie"
      }
    }
  },
  {
    "input": "查找情景喜剧",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "情景喜剧",
        "type": "tv"
      }
    }
  },
  {
    "input": "搜索动画系列",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "动画系列",
        "type": "collection"
      }
    }
  },
  {
    "input": "查找梁朝伟的电影",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "梁朝伟",
        "type": "movie"
      }
    }
  },
  {
    "input": "搜索刑侦剧",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "刑侦剧",
        "type": "tv"
      }
    }
  },
  {
    "input": "查找加勒比海盗系列",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "加勒比海盗系列",
        "type": "collection"
      }
    }
  },
  {
    "input": "搜索伦理片",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "伦理片",
        "type": "movie"
      }
    }
  },
  {
    "input": "查找青春偶像剧",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "青春偶像剧",
        "type": "tv"
      }
    }
  },
  {
    "input": "搜索蝙蝠侠系列",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "蝙蝠侠系列",
        "type": "collection"
      }
    }
  },
  {
    "input": "查找动作喜剧片",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "动作喜剧片",
        "type": "movie"
      }
    }
  },
  {
    "input": "搜索医疗剧",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "医疗剧",
        "type": "tv"
      }
    }
  },
  {
    "input": "查找指环王全集",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "指环王全集",
        "type": "collection"
      }
    }
  },
  {
    "input": "搜索心理惊悚片",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "心理惊悚片",
        "type": "movie"
      }
    }
  },
  {
    "input": "查找宫廷剧",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "宫廷剧",
        "type": "tv"
      }
    }
  },
  {
    "input": "搜索黑客帝国系列",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "黑客帝国系列",
        "type": "collection"
      }
    }
  },
  {
    "input": "查找浪漫喜剧电影",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "浪漫喜剧电影",
        "type": "movie"
      }
    }
  },
  {
    "input": "搜索科幻剧",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "科幻剧",
        "type": "tv"
      }
    }
  },
  {
    "input": "查找哈利波特全系列",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "哈利波特全系列",
        "type": "collection"
      }
    }
  },
  {
    "input": "搜索传记片",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "传记片",
        "type": "movie"
      }
    }
  },
  {
    "input": "查找商战剧",
    "output": {
      "intent": "video_search_control",
      "slots": {
        "title": "商战剧",
        "type": "tv"
      }
    }
  }
]

# 处理video_play_control数据
video_play_control_data = [
  {
    "input": "播放历史题材电影",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "历史题材电影",
        "type": "movie"
      }
    }
  },
  {
    "input": "播放情景喜剧",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "情景喜剧",
        "type": "tv"
      }
    }
  },
  {
    "input": "播放动画系列电影",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "动画系列电影",
        "type": "collection"
      }
    }
  },
  {
    "input": "播放梁朝伟主演电影",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "梁朝伟主演电影",
        "type": "movie"
      }
    }
  },
  {
    "input": "播放刑侦题材剧",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "刑侦题材剧",
        "type": "tv"
      }
    }
  },
  {
    "input": "播放加勒比海盗全系列",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "加勒比海盗全系列",
        "type": "collection"
      }
    }
  },
  {
    "input": "播放伦理电影",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "伦理电影",
        "type": "movie"
      }
    }
  },
  {
    "input": "播放青春剧",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "青春剧",
        "type": "tv"
      }
    }
  },
  {
    "input": "播放蝙蝠侠系列电影",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "蝙蝠侠系列电影",
        "type": "collection"
      }
    }
  },
  {
    "input": "播放动作喜剧电影",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "动作喜剧电影",
        "type": "movie"
      }
    }
  },
  {
    "input": "播放医疗题材剧",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "医疗题材剧",
        "type": "tv"
      }
    }
  },
  {
    "input": "播放指环王系列",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "指环王系列",
        "type": "collection"
      }
    }
  },
  {
    "input": "播放心理惊悚电影",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "心理惊悚电影",
        "type": "movie"
      }
    }
  },
  {
    "input": "播放宫廷剧集",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "宫廷剧集",
        "type": "tv"
      }
    }
  },
  {
    "input": "播放黑客帝国全系列",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "黑客帝国全系列",
        "type": "collection"
      }
    }
  },
  {
    "input": "播放浪漫喜剧",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "浪漫喜剧",
        "type": "movie"
      }
    }
  },
  {
    "input": "播放科幻电视剧",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "科幻电视剧",
        "type": "tv"
      }
    }
  },
  {
    "input": "播放哈利波特全集",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "哈利波特全集",
        "type": "collection"
      }
    }
  },
  {
    "input": "播放传记电影",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "传记电影",
        "type": "movie"
      }
    }
  },
  {
    "input": "播放商战题材剧",
    "output": {
      "intent": "video_play_control",
      "slots": {
        "title": "商战题材剧",
        "type": "tv"
      }
    }
  }
]

# 处理get_system_info数据
get_system_info_data = [
  {
    "input": "系统状态信息",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "system"
      }
    }
  },
  {
    "input": "显示设备状态",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "device"
      }
    }
  },
  {
    "input": "查看硬盘使用情况",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "storage"
      }
    }
  },
  {
    "input": "网络连接信息",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "network"
      }
    }
  },
  {
    "input": "UGREEN Link系统状态",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "uglink"
      }
    }
  },
  {
    "input": "系统配置信息",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "system"
      }
    }
  },
  {
    "input": "设备运行信息",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "device"
      }
    }
  },
  {
    "input": "存储容量信息",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "storage"
      }
    }
  },
  {
    "input": "网络状态详情",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "network"
      }
    }
  },
  {
    "input": "UGREEN Link详情信息",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "uglink"
      }
    }
  },
  {
    "input": "系统资源信息",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "system"
      }
    }
  },
  {
    "input": "设备硬件状态",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "device"
      }
    }
  },
  {
    "input": "磁盘空间信息",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "storage"
      }
    }
  },
  {
    "input": "网络诊断信息",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "network"
      }
    }
  },
  {
    "input": "UGREEN Link连接详情",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "uglink"
      }
    }
  },
  {
    "input": "系统日志信息",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "system"
      }
    }
  },
  {
    "input": "设备温度信息",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "device"
      }
    }
  },
  {
    "input": "存储设备详情",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "storage"
      }
    }
  },
  {
    "input": "网络配置状态",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "network"
      }
    }
  },
  {
    "input": "UGREEN Link设备详情",
    "output": {
      "intent": "get_system_info",
      "slots": {
        "system_type": "uglink"
      }
    }
  }
]

# 合并所有数据
all_data.extend(create_album_data)
all_data.extend(search_photos_data)
all_data.extend(get_album_list_data)
all_data.extend(music_play_control_data)
all_data.extend(music_settings_control_data)
all_data.extend(video_search_control_data)
all_data.extend(video_play_control_data)
all_data.extend(get_system_info_data)

# 转换为DataFrame格式
df_data4 = []
for item in all_data:
    df_data4.append({
        'input': item['input'],
        'output': str(item['output']),
        'output_intent': item['output']['intent'],
        'output_slots': str(item['output']['slots'])
    })

# 创建DataFrame
data4_df = pd.DataFrame(df_data4)

print(f"data4数据集形状: {data4_df.shape}")
print(f"data4数据集列名: {data4_df.columns.tolist()}")

data4_df.head()
# Out:
# data4数据集形状: (160, 4)
# data4数据集列名: ['input', 'output', 'output_intent', 'output_slots']
#            input                                             output  \
# 0  新建一个名为校园生活的相册  {'intent': 'create_album', 'slots': {'album_na...
# 1     创建一个自动分类相册  {'intent': 'create_album', 'slots': {'album_ty...
# 2       建立花卉摄影相册  {'intent': 'create_album', 'slots': {'album_na...
# 3  创建一个普通类型的家庭影集  {'intent': 'create_album', 'slots': {'album_na...
# 4       新建人脸识别相册  {'intent': 'create_album', 'slots': {'album_ty...
#
#   output_intent                                    output_slots
# 0  create_album                          {'album_name': '校园生活'}
# 1  create_album                     {'album_type': 'condition'}
# 2  create_album  {'album_name': '花卉摄影', 'album_type': 'object'}
# 3  create_album  {'album_name': '家庭影集', 'album_type': 'normal'}
# 4  create_album                          {'album_type': 'face'}

# %%
data4_df
# Out:
#                input                                             output  \
# 0      新建一个名为校园生活的相册  {'intent': 'create_album', 'slots': {'album_na...
# 1         创建一个自动分类相册  {'intent': 'create_album', 'slots': {'album_ty...
# 2           建立花卉摄影相册  {'intent': 'create_album', 'slots': {'album_na...
# 3      创建一个普通类型的家庭影集  {'intent': 'create_album', 'slots': {'album_na...
# 4           新建人脸识别相册  {'intent': 'create_album', 'slots': {'album_ty...
# ..               ...                                                ...
# 155           系统日志信息  {'intent': 'get_system_info', 'slots': {'syste...
# 156           设备温度信息  {'intent': 'get_system_info', 'slots': {'syste...
# 157           存储设备详情  {'intent': 'get_system_info', 'slots': {'syste...
# 158           网络配置状态  {'intent': 'get_system_info', 'slots': {'syste...
# 159  UGREEN Link设备详情  {'intent': 'get_system_info', 'slots': {'syste...
#
#        output_intent                                    output_slots
# 0       create_album                          {'album_name': '校园生活'}
# 1       create_album                     {'album_type': 'condition'}
# 2       create_album  {'album_name': '花卉摄影', 'album_type': 'object'}
# 3       create_album  {'album_name': '家庭影集', 'album_type': 'normal'}
# 4       create_album                          {'album_type': 'face'}
# ..               ...                                             ...
# 155  get_system_info                       {'system_type': 'system'}
# 156  get_system_info                       {'system_type': 'device'}
# 157  get_system_info                      {'system_type': 'storage'}
# 158  get_system_info                      {'system_type': 'network'}
# 159  get_system_info                       {'system_type': 'uglink'}
#
# [160 rows x 4 columns]

# %%
import pandas as pd
final_combined_df_ori = pd.read_excel('/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/new_deepseek_qwen3_create_datas/merge_data.xlsx')
final_combined_df_ori.shape, final_combined_df_ori.columns
# Out:
# ((708, 8),
#  Index(['Unnamed: 0.1', 'Unnamed: 0', 'input', 'output', 'output_intent',
#         'output_slots', 'missing_required_fields', 'has_missing_required'],
#        dtype='object'))

# %% [markdown]
# # 数据检查

# %%
# Out:
# 数据验证统计:
# 总记录数: 160
# 缺少必须字段的记录数: 31
#
# 按intent分组的缺少必须字段统计:
#   create_album: 10条记录
#   get_album_list: 1条记录
#   search_photos: 20条记录
#
# 缺少必须字段的记录示例:
# 行0: input='新建一个名为校园生活的相册', intent=create_album, slots={'album_name': '校园生活'}, 缺少字段=['album_type']
# 行1: input='创建一个自动分类相册', intent=create_album, slots={'album_type': 'condition'}, 缺少字段=['album_name']
# 行4: input='新建人脸识别相册', intent=create_album, slots={'album_type': 'face'}, 缺少字段=['album_name']
# 行6: input='建立一个城市风光集', intent=create_album, slots={'album_name': '城市风光集'}, 缺少字段=['album_type']
# 行8: input='新建一个空白相册', intent=create_album, slots={'album_type': 'normal'}, 缺少字段=['album_name']
# 行11: input='创建一个地点筛选相册', intent=create_album, slots={'album_type': 'condition'}, 缺少字段=['album_name']
# 行12: input='新建节日纪念相册', intent=create_album, slots={'album_name': '节日纪念'}, 缺少字段=['album_type']
# 行14: input='建立通用相册', intent=create_album, slots={'album_type': 'normal'}, 缺少字段=['album_name']
# 行17: input='创建时间范围相册', intent=create_album, slots={'album_type': 'condition'}, 缺少字段=['album_name']
# 行18: input='建立个人摄影作品相册', intent=create_album, slots={'album_name': '个人摄影作品'}, 缺少字段=['album_type']
#            input                                             output  \
# 0  新建一个名为校园生活的相册  {'intent': 'create_album', 'slots': {'album_na...
# 1     创建一个自动分类相册  {'intent': 'create_album', 'slots': {'album_ty...
# 2       建立花卉摄影相册  {'intent': 'create_album', 'slots': {'album_na...
# 3  创建一个普通类型的家庭影集  {'intent': 'create_album', 'slots': {'album_na...
# 4       新建人脸识别相册  {'intent': 'create_album', 'slots': {'album_ty...
#
#   output_intent                                    output_slots  \
# 0  create_album                          {'album_name': '校园生活'}
# 1  create_album                     {'album_type': 'condition'}
# 2  create_album  {'album_name': '花卉摄影', 'album_type': 'object'}
# 3  create_album  {'album_name': '家庭影集', 'album_type': 'normal'}
# 4  create_album                          {'album_type': 'face'}
#
#   missing_required_fields  has_missing_required
# 0            [album_type]                  True
# 1            [album_name]                  True
# 2                      []                 False
# 3                      []                 False
# 4            [album_name]                  True

# %%
final_combined_df_2
# Out:
#                input                                             output  \
# 0      新建一个名为校园生活的相册  {'intent': 'create_album', 'slots': {'album_na...
# 1         创建一个自动分类相册  {'intent': 'create_album', 'slots': {'album_ty...
# 2           建立花卉摄影相册  {'intent': 'create_album', 'slots': {'album_na...
# 3      创建一个普通类型的家庭影集  {'intent': 'create_album', 'slots': {'album_na...
# 4           新建人脸识别相册  {'intent': 'create_album', 'slots': {'album_ty...
# ..               ...                                                ...
# 155           系统日志信息  {'intent': 'get_system_info', 'slots': {'syste...
# 156           设备温度信息  {'intent': 'get_system_info', 'slots': {'syste...
# 157           存储设备详情  {'intent': 'get_system_info', 'slots': {'syste...
# 158           网络配置状态  {'intent': 'get_system_info', 'slots': {'syste...
# 159  UGREEN Link设备详情  {'intent': 'get_system_info', 'slots': {'syste...
#
#        output_intent                                    output_slots  \
# 0       create_album                          {'album_name': '校园生活'}
# 1       create_album                     {'album_type': 'condition'}
# 2       create_album  {'album_name': '花卉摄影', 'album_type': 'object'}
# 3       create_album  {'album_name': '家庭影集', 'album_type': 'normal'}
# 4       create_album                          {'album_type': 'face'}
# ..               ...                                             ...
# 155  get_system_info                       {'system_type': 'system'}
# 156  get_system_info                       {'system_type': 'device'}
# 157  get_system_info                      {'system_type': 'storage'}
# 158  get_system_info                      {'system_type': 'network'}
# 159  get_system_info                       {'system_type': 'uglink'}
#
#     missing_required_fields  has_missing_required
# 0              [album_type]                  True
# 1              [album_name]                  True
# 2                        []                 False
# 3                        []                 False
# 4              [album_name]                  True
# ..                      ...                   ...
# 155                      []                 False
# 156                      []                 False
# 157                      []                 False
# 158                      []                 False
# 159                      []                 False
#
# [160 rows x 6 columns]

# %%
final_combined_df_merge = pd.concat([final_combined_df_2, final_combined_df_ori], axis=0)
final_combined_df_merge.columns, final_combined_df_merge.shape
# Out:
# (Index(['input', 'output', 'output_intent', 'output_slots',
#         'missing_required_fields', 'has_missing_required', 'Unnamed: 0.1',
#         'Unnamed: 0'],
#        dtype='object'),
#  (868, 8))

# %%
# 找到null数据的索引
null_mask = final_combined_df_merge['output_intent'].isna() | (final_combined_df_merge['output_intent'] == '')
final_combined_df_null = final_combined_df_merge[null_mask]

# 从final_combined_df_merge中去掉null数据
final_combined_df_merge = final_combined_df_merge[~null_mask]

# %%
final_combined_df_merge
# Out:
#              input                                             output  \
# 0    新建一个名为校园生活的相册  {'intent': 'create_album', 'slots': {'album_na...
# 1       创建一个自动分类相册  {'intent': 'create_album', 'slots': {'album_ty...
# 2         建立花卉摄影相册  {'intent': 'create_album', 'slots': {'album_na...
# 3    创建一个普通类型的家庭影集  {'intent': 'create_album', 'slots': {'album_na...
# 4         新建人脸识别相册  {'intent': 'create_album', 'slots': {'album_ty...
# ..             ...                                                ...
# 663           随机播放  {'intent': 'music_play_control', 'slots': {'pl...
# 664        播放《小幸运》  {'intent': 'music_play_control', 'slots': {'ti...
# 665      设置自动停止1小时  {'intent': 'music_settings_control', 'slots': ...
# 666       找《三体》电视剧  {'intent': 'video_search_control', 'slots': {'...
# 667       播放《指环王1》  {'intent': 'video_play_control', 'slots': {'ti...
#
#               output_intent                                    output_slots  \
# 0              create_album                          {'album_name': '校园生活'}
# 1              create_album                     {'album_type': 'condition'}
# 2              create_album  {'album_name': '花卉摄影', 'album_type': 'object'}
# 3              create_album  {'album_name': '家庭影集', 'album_type': 'normal'}
# 4              create_album                          {'album_type': 'face'}
# ..                      ...                                             ...
# 663      music_play_control                         {'play_mode': 'random'}
# 664      music_play_control                                {'title': '小幸运'}
# 665  music_settings_control                       {'auto_stop_time': '1小时'}
# 666    video_search_control                   {'title': '三体', 'type': 'tv'}
# 667      video_play_control         {'title': '指环王1', 'type': 'collection'}
#
#      missing_required_fields  has_missing_required  Unnamed: 0.1  Unnamed: 0
# 0               [album_type]                  True           NaN         NaN
# 1               [album_name]                  True           NaN         NaN
# 2                         []                 False           NaN         NaN
# 3                         []                 False           NaN         NaN
# 4               [album_name]                  True           NaN         NaN
# ..                       ...                   ...           ...         ...
# 663  ['title或source中至少需要一个']                  True         663.0       663.0
# 664                       []                 False         664.0       664.0
# 665                       []                 False         665.0       665.0
# 666                       []                 False         666.0       666.0
# 667                       []                 False         667.0       667.0
#
# [828 rows x 8 columns]

# %%
# 重新解析output字段，提取output_intent和output_slots
def parse_output_field(output_str):
    """解析output字段，提取intent和slots"""
    if pd.isna(output_str) or output_str == '' or output_str == 'NaN':
        return {'intent': None, 'slots': {}}
    
    try:
        # 如果是字符串，尝试解析为字典
        if isinstance(output_str, str):
            output_dict = eval(output_str)
        else:
            output_dict = output_str
            
        intent = output_dict.get('intent', None)
        slots = output_dict.get('slots', {})
        
        return {'intent': intent, 'slots': slots}
    except:
        return {'intent': None, 'slots': {}}

# 重新解析final_combined_df_null中的output字段
parsed_results = final_combined_df_null['output'].apply(parse_output_field)

# 更新output_intent和output_slots列
final_combined_df_null_fixed = final_combined_df_null.copy()
final_combined_df_null_fixed['output_intent'] = [result['intent'] for result in parsed_results]
final_combined_df_null_fixed['output_slots'] = [result['slots'] for result in parsed_results]

print("修复前的null数据:")
print(final_combined_df_null[['input', 'output', 'output_intent', 'output_slots']].head())

print("\n修复后的数据:")
print(final_combined_df_null_fixed[['input', 'output', 'output_intent', 'output_slots']].head())

final_combined_df_null_fixed
# Out:
# 修复前的null数据:
#              input                                             output  \
# 668  新建一个名为校园生活的相册  {'intent': 'create_album', 'slots': {'album_na...
# 669     创建一个自动分类相册  {'intent': 'create_album', 'slots': {'album_ty...
# 670       建立花卉摄影相册  {'intent': 'create_album', 'slots': {'album_na...
# 671  创建一个普通类型的家庭影集  {'intent': 'create_album', 'slots': {'album_na...
# 672       新建人脸识别相册  {'intent': 'create_album', 'slots': {'album_ty...
#
#     output_intent output_slots
# 668           NaN          NaN
# 669           NaN          NaN
# 670           NaN          NaN
# 671           NaN          NaN
# 672           NaN          NaN
#
# 修复后的数据:
#              input                                             output  \
# 668  新建一个名为校园生活的相册  {'intent': 'create_album', 'slots': {'album_na...
# 669     创建一个自动分类相册  {'intent': 'create_album', 'slots': {'album_ty...
# 670       建立花卉摄影相册  {'intent': 'create_album', 'slots': {'album_na...
# 671  创建一个普通类型的家庭影集  {'intent': 'create_album', 'slots': {'album_na...
# 672       新建人脸识别相册  {'intent': 'create_album', 'slots': {'album_ty...
#
#     output_intent                                    output_slots
# 668  create_album                          {'album_name': '校园生活'}
# 669  create_album                     {'album_type': 'condition'}
# 670  create_album  {'album_name': '花卉摄影', 'album_type': 'object'}
# 671  create_album  {'album_name': '家庭影集', 'album_type': 'normal'}
# 672  create_album                          {'album_type': 'face'}
#              input                                             output  \
# 668  新建一个名为校园生活的相册  {'intent': 'create_album', 'slots': {'album_na...
# 669     创建一个自动分类相册  {'intent': 'create_album', 'slots': {'album_ty...
# 670       建立花卉摄影相册  {'intent': 'create_album', 'slots': {'album_na...
# 671  创建一个普通类型的家庭影集  {'intent': 'create_album', 'slots': {'album_na...
# 672       新建人脸识别相册  {'intent': 'create_album', 'slots': {'album_ty...
# 673     创建宝宝成长日记相册  {'intent': 'create_album', 'slots': {'album_na...
# 674      建立一个城市风光集  {'intent': 'create_album', 'slots': {'album_na...
# 675       创建亲友照片相册  {'intent': 'create_album', 'slots': {'album_na...
# 676       新建一个空白相册  {'intent': 'create_album', 'slots': {'album_ty...
# 677     创建婴儿成长记录相册  {'intent': 'create_album', 'slots': {'album_na...
# 678       建立美食摄影相册  {'intent': 'create_album', 'slots': {'album_na...
# 679     创建一个地点筛选相册  {'intent': 'create_album', 'slots': {'album_ty...
# 680       新建节日纪念相册  {'intent': 'create_album', 'slots': {'album_na...
# 681       创建同学合影相册  {'intent': 'create_album', 'slots': {'album_na...
# 682         建立通用相册  {'intent': 'create_album', 'slots': {'album_ty...
# 683       创建儿童照片相册  {'intent': 'create_album', 'slots': {'album_na...
# 684       新建建筑识别相册  {'intent': 'create_album', 'slots': {'album_na...
# 685       创建时间范围相册  {'intent': 'create_album', 'slots': {'album_ty...
# 686     建立个人摄影作品相册  {'intent': 'create_album', 'slots': {'album_na...
# 687       创建家人照片相册  {'intent': 'create_album', 'slots': {'album_na...
# 688       搜索秋天风景照片  {'intent': 'search_photos', 'slots': {'descrip...
# 689       查找庆典活动照片  {'intent': 'search_photos', 'slots': {'descrip...
# 690      搜索清晨拍摄的照片  {'intent': 'search_photos', 'slots': {'descrip...
# 691     找一下商务场合的照片  {'intent': 'search_photos', 'slots': {'descrip...
# 692       搜索山区风景照片  {'intent': 'search_photos', 'slots': {'descrip...
# 693       查找传统节日照片  {'intent': 'search_photos', 'slots': {'descrip...
# 694      搜索阴天拍摄的照片  {'intent': 'search_photos', 'slots': {'descrip...
# 695      找一下工作环境照片  {'intent': 'search_photos', 'slots': {'descrip...
# 696         搜索河流风景  {'intent': 'search_photos', 'slots': {'descrip...
# 697        查找开幕式照片  {'intent': 'search_photos', 'slots': {'descrip...
# 698       搜索露营时的照片  {'intent': 'search_photos', 'slots': {'descrip...
# 699        找一下婴儿照片  {'intent': 'search_photos', 'slots': {'descrip...
# 700       搜索展览活动照片  {'intent': 'search_photos', 'slots': {'descrip...
# 701         查找海边照片  {'intent': 'search_photos', 'slots': {'descrip...
# 702       搜索烘焙过程照片  {'intent': 'search_photos', 'slots': {'descrip...
# 703      找一下同事聚会照片  {'intent': 'search_photos', 'slots': {'descrip...
# 704         搜索雪景照片  {'intent': 'search_photos', 'slots': {'descrip...
# 705       查找生日礼物照片  {'intent': 'search_photos', 'slots': {'descrip...
# 706      搜索正午时分的照片  {'intent': 'search_photos', 'slots': {'descrip...
# 707      找一下节日装饰照片  {'intent': 'search_photos', 'slots': {'descrip...
#
#      output_intent                                    output_slots  \
# 668   create_album                          {'album_name': '校园生活'}
# 669   create_album                     {'album_type': 'condition'}
# 670   create_album  {'album_name': '花卉摄影', 'album_type': 'object'}
# 671   create_album  {'album_name': '家庭影集', 'album_type': 'normal'}
# 672   create_album                          {'album_type': 'face'}
# 673   create_album  {'album_name': '宝宝成长日记', 'album_type': 'baby'}
# 674   create_album                         {'album_name': '城市风光集'}
# 675   create_album    {'album_name': '亲友照片', 'album_type': 'face'}
# 676   create_album                        {'album_type': 'normal'}
# 677   create_album  {'album_name': '婴儿成长记录', 'album_type': 'baby'}
# 678   create_album  {'album_name': '美食摄影', 'album_type': 'object'}
# 679   create_album                     {'album_type': 'condition'}
# 680   create_album                          {'album_name': '节日纪念'}
# 681   create_album    {'album_name': '同学合影', 'album_type': 'face'}
# 682   create_album                        {'album_type': 'normal'}
# 683   create_album    {'album_name': '儿童照片', 'album_type': 'baby'}
# 684   create_album    {'album_name': '建筑', 'album_type': 'object'}
# 685   create_album                     {'album_type': 'condition'}
# 686   create_album                        {'album_name': '个人摄影作品'}
# 687   create_album    {'album_name': '家人照片', 'album_type': 'face'}
# 688  search_photos                       {'description': '秋天风景照片'}
# 689  search_photos                       {'description': '庆典活动照片'}
# 690  search_photos                      {'description': '清晨拍摄的照片'}
# 691  search_photos                      {'description': '商务场合的照片'}
# 692  search_photos                       {'description': '山区风景照片'}
# 693  search_photos                       {'description': '传统节日照片'}
# 694  search_photos                      {'description': '阴天拍摄的照片'}
# 695  search_photos                       {'description': '工作环境照片'}
# 696  search_photos                         {'description': '河流风景'}
# 697  search_photos                        {'description': '开幕式照片'}
# 698  search_photos                       {'description': '露营时的照片'}
# 699  search_photos                         {'description': '婴儿照片'}
# 700  search_photos                       {'description': '展览活动照片'}
# 701  search_photos                         {'description': '海边照片'}
# 702  search_photos                       {'description': '烘焙过程照片'}
# 703  search_photos                       {'description': '同事聚会照片'}
# 704  search_photos                         {'description': '雪景照片'}
# 705  search_photos                       {'description': '生日礼物照片'}
# 706  search_photos                      {'description': '正午时分的照片'}
# 707  search_photos                       {'description': '节日装饰照片'}
#
#     missing_required_fields  has_missing_required  Unnamed: 0.1  Unnamed: 0
# 668                      []                 False         668.0         NaN
# 669                      []                 False         669.0         NaN
# 670                      []                 False         670.0         NaN
# 671                      []                 False         671.0         NaN
# 672                      []                 False         672.0         NaN
# 673                      []                 False         673.0         NaN
# 674                      []                 False         674.0         NaN
# 675                      []                 False         675.0         NaN
# 676                      []                 False         676.0         NaN
# 677                      []                 False         677.0         NaN
# 678                      []                 False         678.0         NaN
# 679                      []                 False         679.0         NaN
# 680                      []                 False         680.0         NaN
# 681                      []                 False         681.0         NaN
# 682                      []                 False         682.0         NaN
# 683                      []                 False         683.0         NaN
# 684                      []                 False         684.0         NaN
# 685                      []                 False         685.0         NaN
# 686                      []                 False         686.0         NaN
# 687                      []                 False         687.0         NaN
# 688                      []                 False         688.0         NaN
# 689                      []                 False         689.0         NaN
# 690                      []                 False         690.0         NaN
# 691                      []                 False         691.0         NaN
# 692                      []                 False         692.0         NaN
# 693                      []                 False         693.0         NaN
# 694                      []                 False         694.0         NaN
# 695                      []                 False         695.0         NaN
# 696                      []                 False         696.0         NaN
# 697                      []                 False         697.0         NaN
# 698                      []                 False         698.0         NaN
# 699                      []                 False         699.0         NaN
# 700                      []                 False         700.0         NaN
# 701                      []                 False         701.0         NaN
# 702                      []                 False         702.0         NaN
# 703                      []                 False         703.0         NaN
# 704                      []                 False         704.0         NaN
# 705                      []                 False         705.0         NaN
# 706                      []                 False         706.0         NaN
# 707                      []                 False         707.0         NaN

# %%
final_combined_df_null_fixed

# %%
final_combined_df_merge.shape, final_combined_df_null_fixed.shape
# Out:
# ((828, 8), (40, 8))

# %%
all_df = pd.concat([final_combined_df_merge, final_combined_df_null_fixed], axis=0)

# %%
all_df.columns
# Out:
# Index(['input', 'output', 'output_intent', 'output_slots'], dtype='object')

# %%
function_required_fields = {
    "create_album": ["album_name", "album_type"],
    "search_photos": ["keyword"],
    "get_album_list": ["album_type"],
    "music_play_control": [
        {"anyOf": [{"required": ["title"]}, {"required": ["source"]}]}
    ],
    "music_settings_control": ["auto_stop_time"],
    "video_search_control": ["title"],
    "video_play_control": ["title"],
    "get_system_info": ["system_type"]
}


# 检查final_combined_df_2中的数据
def check_required_fields(row):
    intent = row['output_intent']
    slots_str = row['output_slots']
    
    # 解析slots字符串为字典
    try:
        slots = eval(slots_str) if slots_str != '{}' else {}
    except:
        slots = {}
    
    # 获取该intent对应的required字段
    required_fields = function_required_fields.get(intent, [])
    
    # 检查必须字段是否存在
    missing_required = []
    
    # 处理特殊情况：music_play_control的anyOf逻辑
    if intent == "music_play_control" and len(required_fields) > 0 and isinstance(required_fields[0], dict):
        # 检查anyOf条件：至少需要title或source中的一个
        anyof_condition = required_fields[0].get("anyOf", [])
        has_any_required = False
        
        for condition in anyof_condition:
            condition_required = condition.get("required", [])
            if all(field in slots for field in condition_required):
                has_any_required = True
                break
        
        if not has_any_required:
            missing_required.append("title或source中至少需要一个")
    else:
        # 普通的required字段检查
        for field in required_fields:
            if isinstance(field, str) and field not in slots:
                missing_required.append(field)
    
    return {
        'missing_required': missing_required,
        'has_missing_required': len(missing_required) > 0
    }

final_combined_df_2 = all_df.copy()

# 应用检查函数到DataFrame
validation_results = final_combined_df_2.apply(check_required_fields, axis=1)

# 将结果添加到DataFrame的新列中
final_combined_df_2['missing_required_fields'] = [result['missing_required'] for result in validation_results]
final_combined_df_2['has_missing_required'] = [result['has_missing_required'] for result in validation_results]

# 显示统计信息
print(f"\n数据验证统计:")
print(f"总记录数: {len(final_combined_df_2)}")
print(f"缺少必须字段的记录数: {final_combined_df_2['has_missing_required'].sum()}")

# 按intent分组显示缺少必须字段的统计
missing_by_intent = final_combined_df_2[final_combined_df_2['has_missing_required']].groupby('output_intent').size()
if len(missing_by_intent) > 0:
    print(f"\n按intent分组的缺少必须字段统计:")
    for intent, count in missing_by_intent.items():
        print(f"  {intent}: {count}条记录")

# 显示有问题的记录示例
if final_combined_df_2['has_missing_required'].sum() > 0:
    print(f"\n缺少必须字段的记录示例:")
    missing_examples = final_combined_df_2[final_combined_df_2['has_missing_required']]
    for idx, row in missing_examples.head(10).iterrows():
        print(f"行{idx}: input='{row['input']}', intent={row['output_intent']}, slots={row['output_slots']}, 缺少字段={row['missing_required_fields']}")

final_combined_df_2.head()
# Out:
# 数据验证统计:
# 总记录数: 868
# 缺少必须字段的记录数: 249
#
# 按intent分组的缺少必须字段统计:
#   create_album: 99条记录
#   get_album_list: 7条记录
#   music_play_control: 7条记录
#   music_settings_control: 8条记录
#   search_photos: 123条记录
#   video_play_control: 1条记录
#   video_search_control: 4条记录
#
# 缺少必须字段的记录示例:
# 行0: input='新建一个名为校园生活的相册', intent=create_album, slots={'album_name': '校园生活'}, 缺少字段=['album_type']
# 行1: input='创建一个自动分类相册', intent=create_album, slots={'album_type': 'condition'}, 缺少字段=['album_name']
# 行4: input='新建人脸识别相册', intent=create_album, slots={'album_type': 'face'}, 缺少字段=['album_name']
# 行6: input='建立一个城市风光集', intent=create_album, slots={'album_name': '城市风光集'}, 缺少字段=['album_type']
# 行8: input='新建一个空白相册', intent=create_album, slots={'album_type': 'normal'}, 缺少字段=['album_name']
# 行11: input='创建一个地点筛选相册', intent=create_album, slots={'album_type': 'condition'}, 缺少字段=['album_name']
# 行12: input='新建节日纪念相册', intent=create_album, slots={'album_name': '节日纪念'}, 缺少字段=['album_type']
# 行14: input='建立通用相册', intent=create_album, slots={'album_type': 'normal'}, 缺少字段=['album_name']
# 行17: input='创建时间范围相册', intent=create_album, slots={'album_type': 'condition'}, 缺少字段=['album_name']
# 行18: input='建立个人摄影作品相册', intent=create_album, slots={'album_name': '个人摄影作品'}, 缺少字段=['album_type']
#            input                                             output  \
# 0  新建一个名为校园生活的相册  {'intent': 'create_album', 'slots': {'album_na...
# 1     创建一个自动分类相册  {'intent': 'create_album', 'slots': {'album_ty...
# 2       建立花卉摄影相册  {'intent': 'create_album', 'slots': {'album_na...
# 3  创建一个普通类型的家庭影集  {'intent': 'create_album', 'slots': {'album_na...
# 4       新建人脸识别相册  {'intent': 'create_album', 'slots': {'album_ty...
#
#   output_intent                                    output_slots  \
# 0  create_album                          {'album_name': '校园生活'}
# 1  create_album                     {'album_type': 'condition'}
# 2  create_album  {'album_name': '花卉摄影', 'album_type': 'object'}
# 3  create_album  {'album_name': '家庭影集', 'album_type': 'normal'}
# 4  create_album                          {'album_type': 'face'}
#
#   missing_required_fields  has_missing_required
# 0            [album_type]                  True
# 1            [album_name]                  True
# 2                      []                 False
# 3                      []                 False
# 4            [album_name]                  True

# %%
final_combined_df_2
# Out:
#              input                                             output  \
# 0    新建一个名为校园生活的相册  {'intent': 'create_album', 'slots': {'album_na...
# 1       创建一个自动分类相册  {'intent': 'create_album', 'slots': {'album_ty...
# 2         建立花卉摄影相册  {'intent': 'create_album', 'slots': {'album_na...
# 3    创建一个普通类型的家庭影集  {'intent': 'create_album', 'slots': {'album_na...
# 4         新建人脸识别相册  {'intent': 'create_album', 'slots': {'album_ty...
# ..             ...                                                ...
# 703      找一下同事聚会照片  {'intent': 'search_photos', 'slots': {'descrip...
# 704         搜索雪景照片  {'intent': 'search_photos', 'slots': {'descrip...
# 705       查找生日礼物照片  {'intent': 'search_photos', 'slots': {'descrip...
# 706      搜索正午时分的照片  {'intent': 'search_photos', 'slots': {'descrip...
# 707      找一下节日装饰照片  {'intent': 'search_photos', 'slots': {'descrip...
#
#      output_intent                                    output_slots  \
# 0     create_album                          {'album_name': '校园生活'}
# 1     create_album                     {'album_type': 'condition'}
# 2     create_album  {'album_name': '花卉摄影', 'album_type': 'object'}
# 3     create_album  {'album_name': '家庭影集', 'album_type': 'normal'}
# 4     create_album                          {'album_type': 'face'}
# ..             ...                                             ...
# 703  search_photos                       {'description': '同事聚会照片'}
# 704  search_photos                         {'description': '雪景照片'}
# 705  search_photos                       {'description': '生日礼物照片'}
# 706  search_photos                      {'description': '正午时分的照片'}
# 707  search_photos                       {'description': '节日装饰照片'}
#
#     missing_required_fields  has_missing_required
# 0              [album_type]                  True
# 1              [album_name]                  True
# 2                        []                 False
# 3                        []                 False
# 4              [album_name]                  True
# ..                      ...                   ...
# 703               [keyword]                  True
# 704               [keyword]                  True
# 705               [keyword]                  True
# 706               [keyword]                  True
# 707               [keyword]                  True
#
# [868 rows x 6 columns]

# %%
final_combined_df_2.to_excel('/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/new_deepseek_qwen3_create_datas/deepseek_qwen3_create_datas_all.xlsx')

# %%
all_df = all_df[['input', 'output', 'output_intent', 'output_slots']]

# %%
final_combined_df_2['has_missing_required'].value_counts()

# %%
final_combined_df_2['has_missing_required'].value_counts()
# Out:
# has_missing_required
# False    619
# True     249
# Name: count, dtype: int64

# %%
final_combined_df_3 = final_combined_df_2.drop_duplicates(subset=['input', 'output_intent'])
final_combined_df_3.shape, final_combined_df_3.columns
# Out:
# ((780, 6),
#  Index(['input', 'output', 'output_intent', 'output_slots',
#         'missing_required_fields', 'has_missing_required'],
#        dtype='object'))

# %%
579  has_missing_required==False

# %%
final_combined_df_3['has_missing_required'].value_counts()
# Out:
# has_missing_required
# False    579
# True     201
# Name: count, dtype: int64

# %%
final_combined_df_3[final_combined_df_3['has_missing_required']==False]
# Out:
#              input                                             output  \
# 2         建立花卉摄影相册  {'intent': 'create_album', 'slots': {'album_na...
# 3    创建一个普通类型的家庭影集  {'intent': 'create_album', 'slots': {'album_na...
# 5       创建宝宝成长日记相册  {'intent': 'create_album', 'slots': {'album_na...
# 7         创建亲友照片相册  {'intent': 'create_album', 'slots': {'album_na...
# 9       创建婴儿成长记录相册  {'intent': 'create_album', 'slots': {'album_na...
# ..             ...                                                ...
# 659         播放收藏的歌  {'intent': 'music_play_control', 'slots': {'so...
# 661           人物相册  {'intent': 'get_album_list', 'slots': {'album_...
# 664        播放《小幸运》  {'intent': 'music_play_control', 'slots': {'ti...
# 666       找《三体》电视剧  {'intent': 'video_search_control', 'slots': {'...
# 667       播放《指环王1》  {'intent': 'video_play_control', 'slots': {'ti...
#
#             output_intent                                    output_slots  \
# 2            create_album  {'album_name': '花卉摄影', 'album_type': 'object'}
# 3            create_album  {'album_name': '家庭影集', 'album_type': 'normal'}
# 5            create_album  {'album_name': '宝宝成长日记', 'album_type': 'baby'}
# 7            create_album    {'album_name': '亲友照片', 'album_type': 'face'}
# 9            create_album  {'album_name': '婴儿成长记录', 'album_type': 'baby'}
# ..                    ...                                             ...
# 659    music_play_control                         {'source': 'favorites'}
# 661        get_album_list                          {'album_type': 'face'}
# 664    music_play_control                                {'title': '小幸运'}
# 666  video_search_control                   {'title': '三体', 'type': 'tv'}
# 667    video_play_control         {'title': '指环王1', 'type': 'collection'}
#
#     missing_required_fields  has_missing_required
# 2                        []                 False
# 3                        []                 False
# 5                        []                 False
# 7                        []                 False
# 9                        []                 False
# ..                      ...                   ...
# 659                      []                 False
# 661                      []                 False
# 664                      []                 False
# 666                      []                 False
# 667                      []                 False
#
# [579 rows x 6 columns]

# %%
final_combined_df_3.to_excel('/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/new_deepseek_qwen3_create_datas/deepseek_qwen3_create_datas_all_v2.xlsx')
