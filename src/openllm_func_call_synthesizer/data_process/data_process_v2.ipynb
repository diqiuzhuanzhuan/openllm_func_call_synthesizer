# %%
#!/usr/bin/env python
# coding: utf-8

import pandas as pd
import requests
import json
import time
import json
from typing import List, Dict, Any

def change_decode(ll):
    # 解码并重新编码为正确格式
    for item in ll:
        function_call_data = json.loads(item['function_call'])
        item['function_call'] = json.dumps(function_call_data, ensure_ascii=False)
    return ll
def simple_vote_function(parsed_dicts, weights):
    """简化的投票函数，避免复杂的递归问题，空字典也参与投票"""
    if not parsed_dicts:
        return {}
    
    result = {}
    
    # 获取所有键，包括空字典的情况
    all_keys = set()
    # print('----------parsed_dicts-----', parsed_dicts)
    for d in parsed_dicts:
        # print('----------d-----', d)
        if d:  # 如果不是空字典
            all_keys.update(d.keys())
    
    # 如果所有字典都是空的，或者没有共同键，需要特殊处理
    if not all_keys:
        # 所有字典都是空的情况，投票选择空字典
        empty_weight = sum(weights[i] for i, d in enumerate(parsed_dicts) if not d)
        non_empty_weight = sum(weights[i] for i, d in enumerate(parsed_dicts) if d)
        return {} if empty_weight >= non_empty_weight else parsed_dicts[0]
    
    # 对每个键投票
    for key in all_keys:
        # 收集所有有该键的值和对应权重
        values_with_weights = []
        # 收集没有该键的情况（视为None）和对应权重
        none_weight = 0
        
        for i, d in enumerate(parsed_dicts):
            if key in d:
                values_with_weights.append((d[key], weights[i]))
            else:
                # 空字典或没有该键的情况
                none_weight += weights[i]
        
        if isinstance(values_with_weights[0][0], dict) if values_with_weights else False:
            # 嵌套字典：递归处理
            nested_values = [item[0] for item in values_with_weights]
            nested_weights = [item[1] for item in values_with_weights]
            result[key] = simple_vote_function(nested_values, nested_weights)
        else:
            # 简单值：投票选择
            counter = {}
            for val, weight in values_with_weights:
                counter[val] = counter.get(val, 0) + weight
            
            # 如果有空字典的权重，也要考虑进去（表示该键不存在）
            if none_weight > 0:
                counter[None] = none_weight
            
            # 选择权重最高的值
            max_val = max(counter, key=counter.get)
            if max_val is not None:
                result[key] = max_val
            # 如果None权重最高，则该键不包含在结果中
    
    return result
    
def vote_for_model_results(model_results: List[Dict]) -> Dict:
    """
    对多个模型的结果进行加权投票
    参数:
        model_results: 包含model和function_call的字典列表
                      格式: [{'model': 'model_name', 'function_call': 'json_string'}, ...]
    返回:
        投票后的最终function_call字典
    """
    # 模型权重映射
    model_weights = {
        'claude-sonnet-4': 1.5,
        'gemini-2.5': 1,
        'gpt-4o': 2,
        # 'qwen3-4b-2507': 0.5
    }
    
    print(f"输入的模型结果数量: {len(model_results)}")
    
    # 解析function_call JSON字符串并收集权重
    parsed_results = []
    weights = []
    
    for item in model_results:
        model_name = item['model']
        function_call_str = item['function_call']
        
        print(f"处理模型: {model_name}")
        
        try:
            # 解析JSON字符串
            function_call_dict = json.loads(function_call_str)
            parsed_results.append(function_call_dict)
            
            # 获取对应权重
            weight = model_weights.get(model_name, 1.0)  # 默认权重1.0
            weights.append(weight)
            
            print(f"  权重: {weight}")
            print(f"  Function Call: {function_call_dict}")
            
        except json.JSONDecodeError as e:
            print(f"  跳过无效的JSON: {function_call_str}")
            print(f"  错误: {e}")
            continue
    
    if not parsed_results:
        print("没有有效的结果可以投票")
        return {}
    
    print(f"\n有效结果数量: {len(parsed_results)}")
    print(f"对应权重: {weights}")
    
    # 使用现有的投票函数
    print("-------------调试信息：检查vote_for_nested_dict函数的输入-------------")
    print(parsed_results, type(parsed_results))
    # voted_result = vote_for_nested_dict(parsed_results, weights)
    # print('--------------------parsed_results--------------------', parsed_results)
    # print('--------------------weights--------------------', weights)
    voted_result = simple_vote_function(parsed_results, weights)
    # print('--------------------voted_result--------------------', voted_result)
    
    return voted_result


def batch_vote_for_queries(df_grouped_data):
    """
    批量处理多个query的投票
    
    参数:
        df_grouped_data: DataFrame，包含query和对应的model_function_call列表
    
    返回:
        DataFrame，包含每个query的投票结果
    """
    results = []
    
    for _, row in df_grouped_data.iterrows():
        try:
            query = row['query']
            model_function_calls = row['model_function_call']
            
            # print(f"\n{'='*50}")
            # print(f"处理Query: {query}")
            # print(f"模型数量: {len(model_function_calls)}")
            
            # 对当前query进行投票
            voted_result = vote_for_model_results(model_function_calls)
            
            results.append({
                'query': query,
                'model_function_calls': model_function_calls,
                'voted_function_call': voted_result
            })
        except:
            print('--------------------error--------------------', row)
            results.append({
                'query': query,
                'model_function_calls': model_function_calls,
                'voted_function_call': ""
            })
    
    return pd.DataFrame(results)

test_data = [{'model': 'claude-sonnet-4', 'function_call': '{}'},
 {'model': 'gemini-2.5',
  'function_call': '{"name": "music_play_control", "arguments": {"play_mode": "normal"}}'},
 {'model': 'gpt-4o',
  'function_call': '{"name": "music_play_control", "arguments": {}}'},
 {'model': 'qwen3-4b-2507',
  'function_call': '{"name": "music_play_control", "arguments": {"title": "Happy Birthday", "type": "song", "source": "recent", "play_mode": "normal"}}'}]

print("=== 测试相同结果的投票 ===")
result1 = vote_for_model_results(test_data)
print(f"\n最终投票结果: {result1}")
# Out:
# === 测试相同结果的投票 ===
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'play_mode': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {}}
# 处理模型: qwen3-4b-2507
#   权重: 1.0
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Happy Birthday', 'type': 'song', 'source': 'recent', 'play_mode': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 1.0]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{}, {'name': 'music_play_control', 'arguments': {'play_mode': 'normal'}}, {'name': 'music_play_control', 'arguments': {}}, {'name': 'music_play_control', 'arguments': {'title': 'Happy Birthday', 'type': 'song', 'source': 'recent', 'play_mode': 'normal'}}] <class 'list'>
#
# 最终投票结果: {'name': 'music_play_control', 'arguments': {'play_mode': 'normal'}}

# %%
import pandas as pd
df = pd.read_excel('/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/merge_data/query_and_function_call.xlsx')
df = df[['query', 'model_function_call']]

df['model_function_call'] = df['model_function_call'].apply(lambda x: eval(x))
df['model_function_call'] = df['model_function_call'].apply(lambda x: change_decode(x))

# %%
df_result = batch_vote_for_queries(df)
# Out:
# 输入的模型结果数量: 3
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 10}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 10}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Music', 'type': 'album', 'play_mode': 'normal', 'source': 'recent'}}
#
# 有效结果数量: 3
# 对应权重: [1.5, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 10}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 10}}, {'name': 'music_play_control', 'arguments': {'title': 'Music', 'type': 'album', 'play_mode': 'normal', 'source': 'recent'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'any_music_content', 'type': 'song', 'source': 'recent', 'play_mode': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_play_control', 'arguments': {'title': 'any_music_content', 'type': 'song', 'source': 'recent', 'play_mode': 'normal'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 60}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '8月に撮影された山の風景写真'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '山の風景写真 8月'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '8月に撮影された山の風景写真'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '山の風景写真 8月'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'search_photos', 'arguments': {'keyword': '8月に撮影された山の風景写真'}}, {'name': 'search_photos', 'arguments': {'keyword': '山の風景写真 8月'}}, {'name': 'search_photos', 'arguments': {'keyword': '8月に撮影された山の風景写真'}}, {'name': 'search_photos', 'arguments': {'keyword': '山の風景写真 8月'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Serie', 'type': 'tv'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_play_control', 'arguments': {'type': 'tv'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Serie', 'type': 'tv'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Serie', 'type': 'tv'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_play_control', 'arguments': {'title': 'Serie', 'type': 'tv'}}, {'name': 'video_play_control', 'arguments': {'type': 'tv'}}, {'name': 'video_play_control', 'arguments': {'title': 'Serie', 'type': 'tv'}}, {'name': 'video_play_control', 'arguments': {'title': 'Serie', 'type': 'tv'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Interstellar', 'type': 'movie'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Interstellar', 'type': 'album'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Interstellar', 'type': 'movie'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Interstellar', 'type': 'movie'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_play_control', 'arguments': {'title': 'Interstellar', 'type': 'movie'}}, {'name': 'music_play_control', 'arguments': {'title': 'Interstellar', 'type': 'album'}}, {'name': 'video_play_control', 'arguments': {'title': 'Interstellar', 'type': 'movie'}}, {'name': 'video_play_control', 'arguments': {'title': 'Interstellar', 'type': 'movie'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': '*', 'type': 'movie'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'movie', 'type': 'movie'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'Inception', 'type': 'movie'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_search_control', 'arguments': {'title': '*', 'type': 'movie'}}, {}, {'name': 'video_search_control', 'arguments': {'title': 'movie', 'type': 'movie'}}, {'name': 'video_search_control', 'arguments': {'title': 'Inception', 'type': 'movie'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}, {'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}, {'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}, {'name': 'create_album', 'arguments': {'album_name': 'Coworkers', 'album_type': 'face'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {}}, {'name': 'music_settings_control', 'arguments': {}}, {'name': 'music_settings_control', 'arguments': {}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
# 输入的模型结果数量: 2
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {}
#
# 有效结果数量: 2
# 对应权重: [1, 2]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, {}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Party', 'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'After Party Pictures', 'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'Party', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'After Party Pictures', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'party', 'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'party', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'Party Photos', 'album_type': 'normal'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'next', 'source': 'recent'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_play_control', 'arguments': {'source': 'recent'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'films', 'type': 'movie'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_play_control', 'arguments': {'title': 'next', 'source': 'recent'}}, {'name': 'video_play_control', 'arguments': {'source': 'recent'}}, {}, {'name': 'video_search_control', 'arguments': {'title': 'films', 'type': 'movie'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}, {'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}, {'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}, {'name': 'music_play_control', 'arguments': {'title': 'Mozart', 'type': 'artist'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'Hochzeit 2024', 'album_type': 'normal'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}, {'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}, {'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}, {'name': 'create_album', 'arguments': {'album_name': 'Klein Emma', 'album_type': 'baby'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}, {'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}, {'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}, {'name': 'music_play_control', 'arguments': {'title': 'Rammstein', 'type': 'artist', 'play_mode': 'random'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_system_info', 'arguments': {'system_type': 'network'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv', 'source': 'favorites'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_play_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv', 'source': 'favorites'}}, {'name': 'video_search_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv'}}, {'name': 'video_play_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv'}}, {'name': 'video_play_control', 'arguments': {'title': 'favorite TV series', 'type': 'tv'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}, {'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}, {'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}, {'name': 'video_search_control', 'arguments': {'title': 'old western movies', 'type': 'movie'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'type': 'album', 'source': 'favorites', 'play_mode': 'loop'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'my top album', 'type': 'album', 'play_mode': 'loop'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'top album', 'type': 'album', 'play_mode': 'loop'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'top album', 'type': 'album', 'play_mode': 'loop'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_play_control', 'arguments': {'type': 'album', 'source': 'favorites', 'play_mode': 'loop'}}, {'name': 'music_play_control', 'arguments': {'title': 'my top album', 'type': 'album', 'play_mode': 'loop'}}, {'name': 'music_play_control', 'arguments': {'title': 'top album', 'type': 'album', 'play_mode': 'loop'}}, {'name': 'music_play_control', 'arguments': {'title': 'top album', 'type': 'album', 'play_mode': 'loop'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'My First Album', 'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'My New Album', 'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'My First Album', 'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'create_album', 'arguments': {'album_name': 'My First Album', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'My New Album', 'album_type': 'normal'}}, {}, {'name': 'create_album', 'arguments': {'album_name': 'My First Album', 'album_type': 'normal'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}, {'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}, {'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}, {'name': 'search_photos', 'arguments': {'keyword': 'urban scenes'}}] <class 'list'>
# 输入的模型结果数量: 2
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'Placeholder Album Name', 'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
#
# 有效结果数量: 2
# 对应权重: [2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'create_album', 'arguments': {'album_name': 'Placeholder Album Name', 'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 0}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 0}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 0}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 0}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'device'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_system_info', 'arguments': {'system_type': 'network'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'network'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}] <class 'list'>
# 输入的模型结果数量: 3
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'Relaxing Music', 'type': 'album', 'play_mode': 'normal'}}
#
# 有效结果数量: 3
# 对应权重: [1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {}}, {'name': 'music_settings_control', 'arguments': {}}, {'name': 'music_play_control', 'arguments': {'title': 'Relaxing Music', 'type': 'album', 'play_mode': 'normal'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 30}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
# 输入的模型结果数量: 3
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 3
# 对应权重: [1.5, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'baby'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'baby'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'baby'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'baby'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_album_list', 'arguments': {'album_type': 'baby'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'baby'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'baby'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'baby'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'baby'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'baby'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'baby'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'baby'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_album_list', 'arguments': {'album_type': 'baby'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'baby'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'baby'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'baby'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Avatar', 'type': 'movie'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Avatar', 'type': 'movie'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Avatar', 'type': 'movie'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'Avatar', 'type': 'movie'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# ...
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'create_album', 'arguments': {'album_name': '顔認識アルバム', 'album_type': 'face'}}, {'name': 'create_album', 'arguments': {'album_name': '顔認識アルバム', 'album_type': 'face'}}, {'name': 'create_album', 'arguments': {'album_name': '新しい顔認識アルバム', 'album_type': 'face'}}, {'name': 'create_album', 'arguments': {'album_name': '顔認識アルバム', 'album_type': 'face'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '風景 山'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '風景写真 山'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'scenery with mountains'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'mountain landscape'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'search_photos', 'arguments': {'keyword': '風景 山'}}, {'name': 'search_photos', 'arguments': {'keyword': '風景写真 山'}}, {'name': 'search_photos', 'arguments': {'keyword': 'scenery with mountains'}}, {'name': 'search_photos', 'arguments': {'keyword': 'mountain landscape'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '風景'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '風景画像'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '風景'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '风景'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'search_photos', 'arguments': {'keyword': '風景'}}, {'name': 'search_photos', 'arguments': {'keyword': '風景画像'}}, {'name': 'search_photos', 'arguments': {'keyword': '風景'}}, {'name': 'search_photos', 'arguments': {'keyword': '风景'}}] <class 'list'>
# 输入的模型结果数量: 3
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'condition'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'condition'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
#
# 有效结果数量: 3
# 对应权重: [1.5, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_album_list', 'arguments': {'album_type': 'condition'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'condition'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': '鬼滅の刃', 'type': 'tv'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': '鬼滅の刃', 'type': 'tv'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': '鬼滅の刃', 'type': 'tv'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': '鬼滅の刃', 'type': 'tv'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_search_control', 'arguments': {'title': '鬼滅の刃', 'type': 'tv'}}, {'name': 'video_search_control', 'arguments': {'title': '鬼滅の刃', 'type': 'tv'}}, {'name': 'video_search_control', 'arguments': {'title': '鬼滅の刃', 'type': 'tv'}}, {'name': 'video_search_control', 'arguments': {'title': '鬼滅の刃', 'type': 'tv'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': '鬼滅の刃', 'type': 'tv'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': '鬼滅の刃', 'type': 'tv'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': '鬼滅の刃', 'type': 'tv'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': '鬼滅の刃', 'type': 'album'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_play_control', 'arguments': {'title': '鬼滅の刃', 'type': 'tv'}}, {'name': 'video_play_control', 'arguments': {'title': '鬼滅の刃', 'type': 'tv'}}, {'name': 'video_play_control', 'arguments': {'title': '鬼滅の刃', 'type': 'tv'}}, {'name': 'music_play_control', 'arguments': {'title': '鬼滅の刃', 'type': 'album'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': '新相册', 'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'new album', 'album_type': 'normal'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': '新相册', 'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'create_album', 'arguments': {'album_name': 'placeholder_album', 'album_type': 'normal'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'create_album', 'arguments': {'album_name': '新相册', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'new album', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': '新相册', 'album_type': 'normal'}}, {'name': 'create_album', 'arguments': {'album_name': 'placeholder_album', 'album_type': 'normal'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'source': 'favorites'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'source': 'favorites'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {'source': 'favorites'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'source': 'favorites'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_play_control', 'arguments': {'source': 'favorites'}}, {'name': 'music_play_control', 'arguments': {'source': 'favorites'}}, {'name': 'music_play_control', 'arguments': {'source': 'favorites'}}, {'name': 'music_play_control', 'arguments': {'source': 'favorites'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'normal'}}, {'name': 'get_album_list', 'arguments': {'album_type': 'common'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': '电视剧', 'type': 'tv'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': 'placeholder_tv_show_title', 'type': 'tv'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': '', 'type': 'tv'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': '热门电视剧', 'type': 'tv'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_search_control', 'arguments': {'title': '电视剧', 'type': 'tv'}}, {'name': 'video_search_control', 'arguments': {'title': 'placeholder_tv_show_title', 'type': 'tv'}}, {'name': 'video_search_control', 'arguments': {'title': '', 'type': 'tv'}}, {'name': 'video_search_control', 'arguments': {'title': '热门电视剧', 'type': 'tv'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': '泰坦尼克号', 'type': 'movie'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': '泰坦尼克号', 'type': 'movie'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': '泰坦尼克号', 'type': 'movie'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_search_control', 'arguments': {'title': '泰坦尼克号', 'type': 'movie'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_search_control', 'arguments': {'title': '泰坦尼克号', 'type': 'movie'}}, {'name': 'video_search_control', 'arguments': {'title': '泰坦尼克号', 'type': 'movie'}}, {'name': 'video_search_control', 'arguments': {'title': '泰坦尼克号', 'type': 'movie'}}, {'name': 'video_search_control', 'arguments': {'title': '泰坦尼克号', 'type': 'movie'}}] <class 'list'>
# 输入的模型结果数量: 8
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '图片'}}
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '图片'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '图片'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': '图片'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'Placeholder keyword'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': ''}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'placeholder'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'search_photos', 'arguments': {'keyword': 'placeholder'}}
#
# 有效结果数量: 8
# 对应权重: [1.5, 1.5, 1, 1, 2, 2, 0.5, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'search_photos', 'arguments': {'keyword': '图片'}}, {'name': 'search_photos', 'arguments': {'keyword': '图片'}}, {'name': 'search_photos', 'arguments': {'keyword': '图片'}}, {'name': 'search_photos', 'arguments': {'keyword': '图片'}}, {'name': 'search_photos', 'arguments': {'keyword': 'Placeholder keyword'}}, {'name': 'search_photos', 'arguments': {'keyword': ''}}, {'name': 'search_photos', 'arguments': {'keyword': 'placeholder'}}, {'name': 'search_photos', 'arguments': {'keyword': 'placeholder'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}, {'name': 'get_system_info', 'arguments': {'system_type': 'system'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}, {'name': 'music_settings_control', 'arguments': {'auto_stop_time': 15}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': '', 'source': 'recent'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_play_control', 'arguments': {'source': 'recent'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'source': 'recent', 'title': 'placeholder'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': 'recent', 'source': 'recent'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_play_control', 'arguments': {'title': '', 'source': 'recent'}}, {'name': 'video_play_control', 'arguments': {'source': 'recent'}}, {'name': 'video_play_control', 'arguments': {'source': 'recent', 'title': 'placeholder'}}, {'name': 'video_play_control', 'arguments': {'title': 'recent', 'source': 'recent'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': '速度与激情', 'type': 'movie'}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': '速度与激情', 'type': 'collection'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': '速度与激情', 'type': 'movie'}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'video_play_control', 'arguments': {'title': '速度与激情', 'type': 'movie'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'video_play_control', 'arguments': {'title': '速度与激情', 'type': 'movie'}}, {'name': 'video_play_control', 'arguments': {'title': '速度与激情', 'type': 'collection'}}, {'name': 'video_play_control', 'arguments': {'title': '速度与激情', 'type': 'movie'}}, {'name': 'video_play_control', 'arguments': {'title': '速度与激情', 'type': 'movie'}}] <class 'list'>
# 输入的模型结果数量: 4
# 处理模型: claude-sonnet-4
#   权重: 1.5
#   Function Call: {'name': 'music_play_control', 'arguments': {}}
# 处理模型: gemini-2.5
#   权重: 1
#   Function Call: {'name': 'music_play_control', 'arguments': {'type': 'song'}}
# 处理模型: gpt-4o
#   权重: 2
#   Function Call: {'name': 'music_play_control', 'arguments': {}}
# 处理模型: qwen3-4b-2507
#   权重: 0.5
#   Function Call: {'name': 'music_play_control', 'arguments': {'title': 'music', 'type': 'song'}}
#
# 有效结果数量: 4
# 对应权重: [1.5, 1, 2, 0.5]
# -------------调试信息：检查vote_for_nested_dict函数的输入-------------
# [{'name': 'music_play_control', 'arguments': {}}, {'name': 'music_play_control', 'arguments': {'type': 'song'}}, {'name': 'music_play_control', 'arguments': {}}, {'name': 'music_play_control', 'arguments': {'title': 'music', 'type': 'song'}}] <class 'list'>

# %%
df_result
# Out:
#                                 query  \
# 0                 10分間だけ音楽を流してから停止したい
# 1                15分でミュージックアプリの再生を止めて
# 2       15分後に音楽が停止するようにタイマーをセットしてください
# 3     15分後に音楽が止まるように設定するにはどうすれば良いですか？
# 4              15分後に音楽を止めるようにお願いしたいです
# ...                               ...
# 3326                   麻烦帮我设定音乐定时停止功能
# 3327          麻烦帮我设置一下，音乐听完15分钟就自动停掉。
# 3328                    麻烦帮我调出最近的观看记录
# 3329                  麻烦播放一下《速度与激情》电影
# 3330                         麻烦播放一下音乐
#
#                                    model_function_calls  \
# 0     [{'model': 'claude-sonnet-4', 'function_call':...
# 1     [{'model': 'claude-sonnet-4', 'function_call':...
# 2     [{'model': 'claude-sonnet-4', 'function_call':...
# 3     [{'model': 'claude-sonnet-4', 'function_call':...
# 4     [{'model': 'claude-sonnet-4', 'function_call':...
# ...                                                 ...
# 3326  [{'model': 'claude-sonnet-4', 'function_call':...
# 3327  [{'model': 'claude-sonnet-4', 'function_call':...
# 3328  [{'model': 'claude-sonnet-4', 'function_call':...
# 3329  [{'model': 'claude-sonnet-4', 'function_call':...
# 3330  [{'model': 'claude-sonnet-4', 'function_call':...
#
#                                     voted_function_call
# 0     {'name': 'music_settings_control', 'arguments'...
# 1     {'name': 'music_settings_control', 'arguments'...
# 2     {'name': 'music_settings_control', 'arguments'...
# 3     {'name': 'music_settings_control', 'arguments'...
# 4     {'name': 'music_settings_control', 'arguments'...
# ...                                                 ...
# 3326  {'name': 'music_settings_control', 'arguments'...
# 3327  {'name': 'music_settings_control', 'arguments'...
# 3328  {'name': 'video_play_control', 'arguments': {'...
# 3329  {'name': 'video_play_control', 'arguments': {'...
# 3330    {'name': 'music_play_control', 'arguments': {}}
#
# [3331 rows x 3 columns]

# %%
df_raw = pd.read_excel('/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/merge_data/merge_data.xlsx')
df_raw.columns, df_raw.shape
# Out:
# (Index(['Unnamed: 0', 'query', 'dimension', 'language', 'function',
#         'function_hash', 'provider', 'model', 'functions', 'prompt',
#         'function_call', 'function_call_model', 'model_function_call'],
#        dtype='object'),
#  (12882, 13))

# %%
df_result.columns,df_result.shape
# Out:
# (Index(['query', 'model_function_calls', 'voted_function_call'], dtype='object'),
#  (3331, 3))

# %%
df_result = df_result.drop_duplicates(subset=['query'])
df_result.columns, df_result.shape
# Out:
# (Index(['query', 'model_function_calls', 'voted_function_call'], dtype='object'),
#  (3331, 3))

# %%
df_raw = df_raw.drop_duplicates(subset=['query'])
df_raw.columns, df_raw.shape
# Out:
# (Index(['Unnamed: 0', 'query', 'dimension', 'language', 'function',
#         'function_hash', 'provider', 'model', 'functions', 'prompt',
#         'function_call', 'function_call_model', 'model_function_call'],
#        dtype='object'),
#  (3331, 13))

# %%
df_raw = df_raw[['query', 'dimension', 'language', 'function_call_model', 'model_function_call']]

# %%
df_merge = pd.merge(df_result, df_raw, on=['query'], how='left')
df_merge.columns, df_merge.shape
# Out:
# (Index(['query', 'model_function_calls', 'voted_function_call', 'dimension',
#         'language', 'function_call_model', 'model_function_call'],
#        dtype='object'),
#  (3331, 7))

# %%
df_merge.to_excel('/data0/work/SusieSu/project/openllm_func_call_synthesizer/data/data/merge_data/voted_function_call_rs_0919.xlsx')

# %%
df_merge['language'].value_counts()
# Out:
# language
# German      857
# English     853
# Japanese    814
# Chinese     807
# Name: count, dtype: int64

# %%
{'name': 'video_play_control', 'arguments': {'source': 'recent', 'title': '', 'type': 'movie'}}

# %%
ll = [{'model': 'claude-sonnet-4', 'function_call': '{"name": "video_play_control", "arguments": {"title": "\\u653e\\u677e\\u7535\\u5f71", "type": "movie"}}'}, {'model': 'gemini-2.5', 'function_call': '{"name": "video_play_control", "arguments": {"title": "\\u7535\\u5f71"}}'}, {'model': 'gpt-4o', 'function_call': '{"name": "video_search_control", "arguments": {"title": "", "type": "movie"}}'}, {'model': 'qwen3-4b-2507', 'function_call': '{"name": "video_play_control", "arguments": {"title": "The Dark Knight", "type": "movie", "source": "recent"}}'}]
# Out:
# [{'model': 'claude-sonnet-4',
#   'function_call': '{"name": "video_play_control", "arguments": {"title": "放松电影", "type": "movie"}}'},
#  {'model': 'gemini-2.5',
#   'function_call': '{"name": "video_play_control", "arguments": {"title": "电影"}}'},
#  {'model': 'gpt-4o',
#   'function_call': '{"name": "video_search_control", "arguments": {"title": "", "type": "movie"}}'},
#  {'model': 'qwen3-4b-2507',
#   'function_call': '{"name": "video_play_control", "arguments": {"title": "The Dark Knight", "type": "movie", "source": "recent"}}'}]

# %%
ll = [{'model': 'claude-sonnet-4', 'function_call': '{}'}, {'model': 'gemini-2.5', 'function_call': '{"name": "music_play_control", "arguments": {"play_mode": "normal"}}'}, {'model': 'gpt-4o', 'function_call': '{"name": "music_play_control", "arguments": {}}'}, {'model': 'qwen3-4b-2507', 'function_call': '{"name": "music_play_control", "arguments": {"title": "Happy Birthday", "type": "song", "source": "recent", "play_mode": "normal"}}'}]
ll
# Out:
# [{'model': 'claude-sonnet-4', 'function_call': '{}'},
#  {'model': 'gemini-2.5',
#   'function_call': '{"name": "music_play_control", "arguments": {"play_mode": "normal"}}'},
#  {'model': 'gpt-4o',
#   'function_call': '{"name": "music_play_control", "arguments": {}}'},
#  {'model': 'qwen3-4b-2507',
#   'function_call': '{"name": "music_play_control", "arguments": {"title": "Happy Birthday", "type": "song", "source": "recent", "play_mode": "normal"}}'}]

# %%
df_raw.iloc[1]['query']
# Out:
# 'How do I set up a fresh photo album?'

# %%
df_result.iloc[1]['query']
# Out:
# '15分でミュージックアプリの再生を止めて'
